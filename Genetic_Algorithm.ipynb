# %%
import pandas as pd
import numpy as np

import datetime
import os, sys
import importlib

import utils
importlib.reload(utils)

from utils import plot_series, plot_series_with_names, plot_series_bar
from utils import plot_dataframe
from utils import get_universe_adjusted_series, scale_weights_to_one, scale_to_book_long_short
from utils import generate_portfolio, backtest_portfolio
from utils import match_implementations

import plotly.graph_objects as go

# %%
# This directory can be used if you're working on a Kaggle Notebook inside the competition
# Change the directory as per your requirements if you're working somewhere else
data_dir = "/kaggle/input/qrt-quant-quest-iit-bombay-2025/"

features = pd.read_parquet(os.path.join(data_dir, "features.parquet"))

universe = pd.read_parquet(os.path.join(data_dir, "universe.parquet"))
 
returns = pd.read_parquet(os.path.join(data_dir, "returns.parquet"))

# %%
# Original selected features
selected_features = [
    'on_balance_volume', 'macd', 'ichimoku',
    'stochastic_oscillator', 'chaikin_money_flow', 'volume',
    'commodity_channel_index','williams_r',
     'volatility_20', 'trend_5_20','relative_strength_index'
]

# %%
train_features = features.loc["2005":"2015"]
validation_features = features.loc["2016":"2018"]
test_features = features.loc["2019"]

train_universe = universe.loc["2005":"2015"]
validation_universe = universe.loc["2016":"2018"]
test_universe = universe.loc["2019"]

train_returns = returns.loc["2005":"2015"]
validation_returns = returns.loc["2016":"2018"]
test_returns = returns.loc["2019"]

# Filter features based on selected features

# Check if columns have a MultiIndex
if isinstance(train_features.columns, pd.MultiIndex):
    # Filter columns based on level 0 of MultiIndex
    train_features = train_features.loc[:, train_features.columns.get_level_values(0).isin(selected_features)]
    validation_features = validation_features.loc[:, validation_features.columns.get_level_values(0).isin(selected_features)]
    test_features = test_features.loc[:, test_features.columns.get_level_values(0).isin(selected_features)]
    
    # Remove unused levels from MultiIndex
    train_features.columns = train_features.columns.remove_unused_levels()
    validation_features.columns = validation_features.columns.remove_unused_levels()
    test_features.columns = test_features.columns.remove_unused_levels()
else:
    # If columns are not MultiIndexed, filter directly
    train_features = train_features[selected_features]
    validation_features = validation_features[selected_features]
    test_features = test_features[selected_features]

# Debugging: Print filtered column levels
if isinstance(train_features.columns, pd.MultiIndex):
    print("Filtered Train Features Columns (Level 0):", train_features.columns.get_level_values(0).unique())
else:
    print("Filtered Train Features Columns:", train_features.columns)
# Out:
# Filtered Train Features Columns (Level 0): Index(['macd', 'trend_5_20', 'ichimoku', 'volatility_20', 'on_balance_volume',
#        'chaikin_money_flow', 'relative_strength_index',
#        'stochastic_oscillator', 'williams_r', 'volume',
#        'commodity_channel_index'],
#       dtype='object')

# %%
def backtest_portfolio_new(portfolio: pd.DataFrame, returns: pd.DataFrame, universe: pd.DataFrame, plot_: bool, print_: bool):

    """
    Computes performance metrics from a given portfolio DataFrame.

    This function calculates the net Sharpe ratio, along with other portfolio metrics,
    ensuring that certain constraints are met. It performs checks for:
    - Shape alignment of input DataFrames.
    - portfolio weights only in stocks that are part of the universe.
    - Dollar neutrality.
    - Unit capital constraint.
    - Maximum weight constraint.

    Parameters:
    ----------
    portfolio : pd.DataFrame
        DataFrame representing portfolio over time.
    returns : pd.DataFrame
        DataFrame containing stock returns corresponding to the portfolio.
    universe : pd.DataFrame
        Boolean DataFrame indicating whether a stock is part of the investable universe.
    plot_: bool
        Boolean Flag which decides whether to plot the cumulative PnL
    print_: bool
        Boolean Flag which decides whether to print the metrics of backtest

    Raises:
    ------
    ValueError
        If the input DataFrames do not have matching shapes.
        If portfolio contain stocks that are not in the universe.
        If the portfolio violates the dollar neutrality constraint.
        If the unit capital constraint is violated.
        If the maximum weight constraint is exceeded.

    Returns
    -------
    tuple
        - Net Sharpe Ratio (rounded to 3 decimal places).
        - Pandas Series containing gross PnL over time.

    Additional Outputs:
    -------------------
    - Prints the gross and net Sharpe ratios.
    - Prints the turnover percentage.
    - Plots cumulative Gross and Net PnL.

    Notes:
    ------
    - The turnover is calculated as the average traded capital divided by the average book value.
    - The gross and net Sharpe ratios are annualized using a factor of √252.
    - The net PnL accounts for trading costs (assumed to be 0.01% per unit traded).
    """

    universe = universe.astype(bool)
    
    if not (portfolio.shape == returns.shape == universe.shape):
        raise ValueError("Shapes of portfolio, returns and universe are not algined")

    if ((portfolio.replace(0, np.nan))[~universe].notna().sum().sum() != 0):
        raise ValueError("Your portfolio are present for a stock not present in the universe")

    if ((portfolio.sum(1).abs() > 0.01).sum() > 0):
        raise ValueError("Dollar Neutral Constraint is violated")
    
    if (((portfolio.abs().sum(1) - 1) > 0.01).sum() > 0):
        raise ValueError("Unit Capital Constraint is violated")

    if ((portfolio.abs().max(1) > 0.1).sum() > 0):
        raise ValueError("Maximum Weight Constraint is violated")

    portfolio = portfolio.fillna(0)

    rets = returns.fillna(0)

    gross_pnl = (portfolio * rets).sum(axis=1)

    traded = portfolio.diff(1).abs().sum(axis=1).fillna(0)

    net_pnl = gross_pnl - traded * 1e-4

    gross_sharpe_ratio = (gross_pnl.mean() / gross_pnl.std()) * np.sqrt(252)

    net_sharpe_ratio = (net_pnl.mean() / net_pnl.std()) * np.sqrt(252)

    if print_:
        print("Gross Sharpe Ratio: ", round(gross_sharpe_ratio, 3))
        print("Net Sharpe Ratio: ", round(net_sharpe_ratio, 3))

    return round(net_sharpe_ratio, 3), gross_pnl

# %%
def normalize_signal(feature, universe_boolean):
    """
    Normalize a feature signal for a given universe.
    Parameters:
        feature (pd.DataFrame): Feature data for all stocks.
        universe_boolean (pd.DataFrame): Boolean DataFrame indicating tradable stocks.
    Returns:
        pd.DataFrame: Normalized signal.
    """
    signal = feature.shift(1)  # Avoid lookahead bias
    signal = signal.where(universe_boolean, np.nan)
    signal = signal.rank(axis=1, method="min", ascending=True)
    signal = signal.sub(signal.mean(axis=1), axis=0)
    signal = signal.div(signal.abs().sum(axis=1), axis=0)
    return signal
    
def generate_portfolio_vectorized(features, universe, weights):
    """
    Generate portfolio weights using a vectorized approach.
    Parameters:
        features (pd.DataFrame): DataFrame containing all features for stocks.
        universe (pd.DataFrame): Binary DataFrame indicating tradable stocks.
        weights (array-like): Weights for each feature.
    Returns:
        pd.DataFrame: Portfolio weights for each stock on each trading day.
    """
    universe_boolean = universe.astype(bool)
    # features =  features.loc[:'2019']
    # Combine signals into a portfolio
    portfolio_weights = pd.DataFrame(0, index=features.index, columns=features.columns.get_level_values(1).unique())
    
    for i, feature_name in enumerate(features.columns.levels[0]):
        feature_data = features[feature_name]
        normalized_signal = normalize_signal(feature_data, universe_boolean)
        portfolio_weights += normalized_signal * weights[i]
    
    # Enforce dollar neutrality and normalize weights to sum to 1 per day
    portfolio_weights = portfolio_weights.sub(portfolio_weights.mean(axis=1), axis=0)
    portfolio_weights = portfolio_weights.div(portfolio_weights.abs().sum(axis=1), axis=0)
    
    return portfolio_weights.fillna(0)

# %%
from bayes_opt import BayesianOptimization
import numpy as np
import matplotlib.pyplot as plt
from joblib import Parallel, delayed

# %%
def optimize_signal_weights_bayesian(features_train, features_validation, universe_train, universe_validation, returns_train, returns_validation):

    def sharpe_ratio_objective(**weights):
        # Get all feature names from train_features
        all_features = sorted(features_train.columns.levels[0])
        
        # Assign 0 weight to features not in selected_features
        weight_array = np.array([weights.get(feature, 0) if feature in selected_features else 0 for feature in all_features])
        
        # Debug: Print the weight array
        # print(f"Weight Array: {weight_array}")
        
        # Generate portfolio weights for training set
        portfolio_weights_train = generate_portfolio_vectorized(features_train, universe_train, weight_array)
        
        # Backtest on training data
        sr_train, _ = backtest_portfolio_new(portfolio_weights_train, returns_train, universe_train, False, False)
        
        # Validate on validation set
        portfolio_weights_validation = generate_portfolio_vectorized(features_validation, universe_validation, weight_array)
        sr_validation, _ = backtest_portfolio_new(portfolio_weights_validation, validation_returns, validation_universe, False, False)
        
        print(f"Train Sharpe Ratio: {sr_train}, Validation Sharpe Ratio: {sr_validation}")
        
        # Combine training and validation Sharpe ratios
        alpha = 0.4  # Weight for training Sharpe ratio
        combined_sharpe_ratio = alpha * sr_train + (1 - alpha) * sr_validation
        
        # Add penalties to prevent overfitting
        penalty_l2 = np.sum(np.square(weight_array)) * combined_sharpe_ratio * 0.002
        penalty_l1 = np.sum(np.abs(weight_array)) * combined_sharpe_ratio * 0.009
        
        result = combined_sharpe_ratio * 10 - penalty_l2 - penalty_l1
        print(f"Debug: L2 penalty: {penalty_l2}")
        print(f"Debug: L1 penalty: {penalty_l1}")
        print(f"Debug: Objective function value (with penalty): {result}")
        print("-" * 50)
        return result

    # Create pbounds for selected features only
    pbounds = {feature: (-20, 20) for feature in selected_features}
    print(f"Parameter Bounds (pbounds): {pbounds}")
    
    optimizer = BayesianOptimization(
        f=sharpe_ratio_objective,
        pbounds=pbounds,
        random_state=42
    )
    
    optimizer.maximize(init_points=20, n_iter=300)
    
    optimal_weights = optimizer.max['params']
    
    return optimal_weights

# Run Bayesian Optimization using train/validation split
optimal_weights = optimize_signal_weights_bayesian(
    train_features,
    validation_features,
    train_universe,
    validation_universe,
    train_returns,
    validation_returns
)

# Evaluate on test set
portfolio_weights_test = generate_portfolio_vectorized(test_features, test_universe, np.array(list(optimal_weights.values())))
sr_test, _ = backtest_portfolio_new(portfolio_weights_test, test_returns, test_universe,False,False)

print("Optimal Weights:", optimal_weights)
print("Test Set Sharpe Ratio:", sr_test)
# Out:
# Parameter Bounds (pbounds): {'on_balance_volume': (-20, 20), 'macd': (-20, 20), 'ichimoku': (-20, 20), 'stochastic_oscillator': (-20, 20), 'chaikin_money_flow': (-20, 20), 'volume': (-20, 20), 'commodity_channel_index': (-20, 20), 'williams_r': (-20, 20), 'volatility_20': (-20, 20), 'trend_5_20': (-20, 20), 'relative_strength_index': (-20, 20)}
# |   iter    |  target   | chaiki... | commod... | ichimoku  |   macd    | on_bal... | relati... | stocha... | trend_... | volati... |  volume   | willia... |
# -------------------------------------------------------------------------------------------------------------------------------------------------------------
# Train Sharpe Ratio: -0.558, Validation Sharpe Ratio: 0.06
# Debug: L2 penalty: -0.6780137992204086
# Debug: L1 penalty: -0.2150821800300543
# Debug: Objective function value (with penalty): -0.9789040207495375
# --------------------------------------------------
# | 1         | -0.9789   | -5.018    | 18.03     | 9.28      | 3.946     | -13.76    | -13.76    | -17.68    | 14.65     | 4.045     | 8.323     | -19.18    |
# Train Sharpe Ratio: 0.588, Validation Sharpe Ratio: 0.755
# Debug: L2 penalty: 1.8612819380204317
# Debug: L1 penalty: 0.6675635445670248
# Debug: Objective function value (with penalty): 4.353154517412543
# --------------------------------------------------
# | 2         | 4.353     | 18.8      | 13.3      | -11.51    | -12.73    | -12.66    | -7.83     | 0.9903    | -2.722    | -8.351    | 4.474     | -14.42    |
# Train Sharpe Ratio: 0.692, Validation Sharpe Ratio: 0.537
# Debug: L2 penalty: 1.4534417411743679
# Debug: L1 penalty: 0.5182030678863476
# Debug: Objective function value (with penalty): 4.0183551909392845
# --------------------------------------------------
# | 3         | 4.018     | -8.314    | -5.346    | -1.757    | 11.41     | -12.01    | 0.5694    | 3.697     | -18.14    | 4.302     | -13.18    | -17.4     |
# Train Sharpe Ratio: -1.835, Validation Sharpe Ratio: -1.132
# Debug: L2 penalty: -5.780340635937582
# Debug: L1 penalty: -1.6902910270353333
# Debug: Objective function value (with penalty): -6.661368337027082
# --------------------------------------------------
# | 4         | -6.661    | 17.96     | 18.63     | 12.34     | -7.815    | -16.09    | 7.369     | -2.394    | -15.12    | -0.1929   | -18.62    | 16.37     |
# Train Sharpe Ratio: -1.112, Validation Sharpe Ratio: -1.027
# Debug: L2 penalty: -2.9768935494081408
# Debug: L1 penalty: -1.012537303199145
# Debug: Objective function value (with penalty): -6.620569147392714
# --------------------------------------------------
# | 5         | -6.621    | -9.649    | 6.501     | -7.532    | 0.8027    | 1.868     | -12.61    | 18.78     | 11.01     | 17.58     | 15.79     | 3.916     |
# Train Sharpe Ratio: 0.285, Validation Sharpe Ratio: -0.176
# Debug: L2 penalty: 0.024733498623885096
# Debug: L1 penalty: 0.008589855512480501
# Debug: Objective function value (with penalty): 0.05067664586363445
# --------------------------------------------------
# | 6         | 0.05068   | 16.87     | -16.46    | -12.16    | -18.19    | -6.987    | -4.453    | -9.146    | 13.15     | -5.73     | -8.763    | 1.708     |
# Train Sharpe Ratio: 0.437, Validation Sharpe Ratio: 0.172
# Debug: L2 penalty: 1.170767029714778
# Debug: L1 penalty: 0.3667143676213385
# Debug: Objective function value (with penalty): 1.2425186026638837
# --------------------------------------------------
# | 7         | 1.243     | -14.36    | 12.09     | -17.02    | 19.48     | 10.89     | -12.05    | -19.78    | 12.62     | 8.274     | 9.16      | 10.85     |
# Train Sharpe Ratio: 1.476, Validation Sharpe Ratio: 0.788
# Debug: L2 penalty: 2.9023809067352015
# Debug: L1 penalty: 1.0619698220331997
# Debug: Objective function value (with penalty): 6.6676492712316
# --------------------------------------------------
# | 8         | 6.668     | -17.04    | -5.661    | -15.37    | 14.52     | 4.932     | -6.764    | -17.46    | -7.561    | -6.993    | 9.184     | 5.502     |
# Train Sharpe Ratio: 0.549, Validation Sharpe Ratio: 0.168
# Debug: L2 penalty: 0.7352355982176102
# Debug: L1 penalty: 0.25117942364305085
# Debug: Objective function value (with penalty): 2.217584978139339
# --------------------------------------------------
# | 9         | 2.218     | 15.49     | -1.111    | -15.22    | 8.53      | 10.43     | 2.451     | 10.84     | -0.2482   | 0.9093    | -2.898    | -18.98    |
# Train Sharpe Ratio: -0.134, Validation Sharpe Ratio: 0.101
# Debug: L2 penalty: 0.021980034798825855
# Debug: L1 penalty: 0.0072802016119635675
# Debug: Objective function value (with penalty): 0.0407397635892105
# --------------------------------------------------
# | 10        | 0.04074   | -15.68    | -18.74    | 5.456     | -7.426    | 0.3428    | 16.3      | -10.03    | -3.585    | 10.22     | -10.85    | -16.92    |
# Train Sharpe Ratio: -1.515, Validation Sharpe Ratio: -1.535
# Debug: L2 penalty: -5.0572193936475935
# Debug: L1 penalty: -1.730602695756505
# Debug: Objective function value (with penalty): -8.482177910595901
# --------------------------------------------------
# | 11        | -8.482    | -8.41     | -13.55    | 17.19     | 12.32     | 5.336     | 14.86     | 12.15     | -12.54    | 15.7      | 1.574     | 12.3      |
# Train Sharpe Ratio: 0.704, Validation Sharpe Ratio: 0.06
# Debug: L2 penalty: 0.9959120579693018
# Debug: L1 penalty: 0.3265452918069115
# Debug: Objective function value (with penalty): 1.8535426502237868
# --------------------------------------------------
# | 12        | 1.854     | 15.84     | -7.28     | -15.6     | -10.88    | -2.916    | 12.72     | 14.43     | -19.72    | 0.4299    | -3.304    | -11.12    |
# Train Sharpe Ratio: -2.341, Validation Sharpe Ratio: -1.375
# Debug: L2 penalty: -5.391402944679564
# Debug: L1 penalty: -1.7156348180835073
# Debug: Objective function value (with penalty): -10.50696223723693
# --------------------------------------------------
# | 13        | -10.51    | -15.21    | -6.495    | 17.72     | -7.072    | 0.7516    | 8.121     | -5.455    | 18.87     | 18.5      | -9.929    | -0.1101   |
# Train Sharpe Ratio: 1.383, Validation Sharpe Ratio: 0.798
# Debug: L2 penalty: 3.049161787634964
# Debug: L1 penalty: 1.0008261191533032
# Debug: Objective function value (with penalty): 6.270012093211733
# --------------------------------------------------
# | 14        | 6.27      | -7.965    | -8.606    | -18.52    | 4.383     | 0.1072    | -17.94    | -8.854    | 16.33     | -10.42    | -14.2     | -0.4219   |
# Train Sharpe Ratio: -0.568, Validation Sharpe Ratio: -0.699
# Debug: L2 penalty: -1.538065233841415
# Debug: L1 penalty: -0.5846091196279691
# Debug: Objective function value (with penalty): -4.343325646530615
# --------------------------------------------------
# | 15        | -4.343    | 19.43     | -10.32    | 6.885     | 10.46     | -10.49    | 9.129     | -5.289    | 5.292     | 5.341     | 1.431     | -16.39    |
# Train Sharpe Ratio: 1.041, Validation Sharpe Ratio: 0.546
# Debug: L2 penalty: 2.212350746042921
# Debug: L1 penalty: 0.7487472287008392
# Debug: Objective function value (with penalty): 4.4789020252562395
# --------------------------------------------------
# | 16        | 4.479     | 13.41     | -7.169    | -12.54    | -18.37    | 3.636     | 7.103     | -19.34    | 0.4837    | -10.94    | 5.807     | -13.03    |
# Train Sharpe Ratio: -1.12, Validation Sharpe Ratio: -0.993
# Debug: L2 penalty: -3.5193248665454506
# Debug: L1 penalty: -1.1912481227660903
# Debug: Objective function value (with penalty): -5.7274270106884595
# --------------------------------------------------
# | 17        | -5.727    | 7.638     | -4.531    | 17.47     | -14.5     | -6.357    | -15.46    | 16.99     | 15.09     | -9.682    | 6.399     | 12.69     |
# Train Sharpe Ratio: -0.158, Validation Sharpe Ratio: -0.362
# Debug: L2 penalty: -0.7441722219950306
# Debug: L1 penalty: -0.2640148101989494
# Debug: Objective function value (with penalty): -1.7958129678060197
# --------------------------------------------------
# | 18        | -1.796    | 2.208     | 1.186     | -10.33    | -16.28    | 15.89     | 16.02     | 5.324     | -6.439    | -6.032    | 9.038     | 15.88     |
# Train Sharpe Ratio: 0.028, Validation Sharpe Ratio: 0.278
# Debug: L2 penalty: 0.7845418755701203
# Debug: L1 penalty: 0.23171198405589774
# Debug: Objective function value (with penalty): 0.7637461403739817
# --------------------------------------------------
# | 19        | 0.7637    | 15.48     | 11.2      | 5.681     | -16.63    | -13.53    | 15.94     | 4.257     | -19.63    | -15.94    | 6.54      | -19.8     |
# Train Sharpe Ratio: -0.527, Validation Sharpe Ratio: -0.465
# Debug: L2 penalty: -0.9451461393630574
# Debug: L1 penalty: -0.4236088066019277
# Debug: Objective function value (with penalty): -3.5292450540350147
# --------------------------------------------------
# | 20        | -3.529    | -13.57    | 1.949     | 7.676     | 6.078     | -11.03    | 8.487     | -10.51    | -6.984    | 9.86      | 5.985     | 13.97     |
# Train Sharpe Ratio: 1.321, Validation Sharpe Ratio: 0.886
# Debug: L2 penalty: 6.619716546019944
# Debug: L1 penalty: 1.570705366770839
# Debug: Objective function value (with penalty): 2.4095780872092183
# --------------------------------------------------
# | 21        | 2.41      | -20.0     | -6.608    | -20.0     | -1.306    | -0.0825   | -20.0     | -20.0     | -20.0     | -20.0     | -16.65    | -20.0     |
# Train Sharpe Ratio: 0.626, Validation Sharpe Ratio: 0.433
# Debug: L2 penalty: 1.3015435437699208
# Debug: L1 penalty: 0.4714889071098853
# Debug: Objective function value (with penalty): 3.328967549120194
# --------------------------------------------------
# | 22        | 3.329     | -7.111    | -10.17    | 4.556     | 10.04     | -18.52    | -2.242    | 6.637     | -14.24    | 4.557     | -5.916    | -18.69    |
# Train Sharpe Ratio: 1.301, Validation Sharpe Ratio: 0.74
# Debug: L2 penalty: 5.195580823878074
# Debug: L1 penalty: 1.3358983871561743
# Debug: Objective function value (with penalty): 3.1125207889657505
# --------------------------------------------------
# | 23        | 3.113     | -16.94    | -14.75    | -20.0     | 19.53     | -20.0     | -0.8122   | -9.931    | -1.662    | -20.0     | 10.3      | -20.0     |
# Train Sharpe Ratio: -0.419, Validation Sharpe Ratio: -0.487
# Debug: L2 penalty: -1.9346150872437688
# Debug: L1 penalty: -0.6208918128500158
# Debug: Objective function value (with penalty): -2.042493099906215
# --------------------------------------------------
# | 24        | -2.042    | -13.93    | 15.1      | -12.47    | 17.78     | 10.7      | -12.08    | -9.502    | 16.2      | 14.76     | 14.22     | 13.29     |
# Train Sharpe Ratio: 1.788, Validation Sharpe Ratio: 0.891
# Debug: L2 penalty: 6.434739234961583
# Debug: L1 penalty: 1.7553508101484343
# Debug: Objective function value (with penalty): 4.3079099548899835
# --------------------------------------------------
# | 25        | 4.308     | 13.78     | -2.603    | -20.0     | 7.39      | 12.71     | -20.0     | -20.0     | -14.23    | -20.0     | 17.02     | -8.32     |
# Train Sharpe Ratio: 1.358, Validation Sharpe Ratio: 0.752
# Debug: L2 penalty: 6.310762789962701
# Debug: L1 penalty: 1.5314615038170885
# Debug: Objective function value (with penalty): 2.1017757062202094
# --------------------------------------------------
# | 26        | 2.102     | -5.55     | -20.0     | -20.0     | -4.694    | -20.0     | -17.59    | 20.0      | 3.283     | -20.0     | -20.0     | -20.0     |
# Train Sharpe Ratio: -0.896, Validation Sharpe Ratio: -0.121
# Debug: L2 penalty: -1.2110996696894925
# Debug: L1 penalty: -0.4319236412655027
# Debug: Objective function value (with penalty): -2.6669766890450055
# --------------------------------------------------
# | 27        | -2.667    | -17.25    | -11.61    | 12.19     | -9.39     | 1.797     | 10.68     | -8.405    | -0.1118   | 11.94     | -11.34    | -16.64    |
# Train Sharpe Ratio: 1.077, Validation Sharpe Ratio: 0.705
# Debug: L2 penalty: 5.64993823987842
# Debug: L1 penalty: 1.3576645619500245
# Debug: Objective function value (with penalty): 1.5303971981715558
# --------------------------------------------------
# | 28        | 1.53      | 7.608     | 20.0      | -20.0     | 20.0      | -20.0     | -20.0     | 6.733     | -20.0     | -20.0     | -2.341    | -20.0     |
# Train Sharpe Ratio: 1.608, Validation Sharpe Ratio: 0.866
# Debug: L2 penalty: 7.919943564927234
# Debug: L1 penalty: 1.908071546221436
# Debug: Objective function value (with penalty): 1.7999848888513303
# --------------------------------------------------
# | 29        | 1.8       | -20.0     | -20.0     | -20.0     | -2.32     | 20.0      | 9.836     | -20.0     | -20.0     | -10.17    | 20.0      | -20.0     |
# Train Sharpe Ratio: 0.511, Validation Sharpe Ratio: -0.096
# Debug: L2 penalty: 0.3536160015848317
# Debug: L1 penalty: 0.1325587487167207
# Debug: Objective function value (with penalty): 0.981825249698448
# --------------------------------------------------
# | 30        | 0.9818    | 18.14     | -5.507    | -6.518    | 13.49     | 11.38     | 3.609     | 10.79     | -7.112    | 3.483     | 3.341     | -16.96    |
# Train Sharpe Ratio: 1.375, Validation Sharpe Ratio: 0.75
# Debug: L2 penalty: 4.065779825241748
# Debug: L1 penalty: 1.2497945183705685
# Debug: Objective function value (with penalty): 4.684425656387684
# --------------------------------------------------
# | 31        | 4.684     | -11.69    | -16.83    | -17.02    | 18.95     | 16.32     | -12.95    | -9.675    | -5.506    | -14.46    | -13.96    | -1.505    |
# Train Sharpe Ratio: 0.8, Validation Sharpe Ratio: 0.98
# Debug: L2 penalty: 6.065000456792014
# Debug: L1 penalty: 1.5026271550548274
# Debug: Objective function value (with penalty): 1.5123723881531583
# --------------------------------------------------
# | 32        | 1.512     | 11.13     | 19.38     | -20.0     | -20.0     | 13.2      | -20.0     | -20.0     | 15.69     | -20.0     | -4.483    | -20.0     |
# Train Sharpe Ratio: 1.489, Validation Sharpe Ratio: 0.732
# Debug: L2 penalty: 6.446609210347862
# Debug: L1 penalty: 1.5858595250506144
# Debug: Objective function value (with penalty): 2.315531264601522
# --------------------------------------------------
# | 33        | 2.316     | -20.0     | -17.97    | -20.0     | 14.87     | -12.61    | -20.0     | -20.0     | 2.532     | -20.0     | -2.292    | 20.0      |
# Train Sharpe Ratio: 0.173, Validation Sharpe Ratio: -0.161
# Debug: L2 penalty: -0.09597465827991288
# Debug: L1 penalty: -0.028886821123901788
# Debug: Objective function value (with penalty): -0.14913852059618543
# --------------------------------------------------
# | 34        | -0.1491   | 10.48     | -9.017    | -15.44    | -16.35    | -1.033    | 17.38     | 19.63     | -16.79    | 1.87      | 0.1602    | -8.999    |
# Train Sharpe Ratio: 1.605, Validation Sharpe Ratio: 0.865
# Debug: L2 penalty: 6.8747664889498
# Debug: L1 penalty: 1.7936016071036087
# Debug: Objective function value (with penalty): 2.9416319039465906
# --------------------------------------------------
# | 35        | 2.942     | -15.84    | -17.22    | -20.0     | 7.201     | 14.08     | -20.0     | -20.0     | 20.0      | -20.0     | 6.073     | -11.24    |
# Train Sharpe Ratio: 1.436, Validation Sharpe Ratio: 0.912
# Debug: L2 penalty: 3.094171978167453
# Debug: L1 penalty: 0.9607236759370269
# Debug: Objective function value (with penalty): 7.161104345895518
# --------------------------------------------------
# | 36        | 7.161     | -5.826    | 4.803     | -20.0     | 7.447     | 1.007     | 4.77      | -20.0     | -3.945    | -20.0     | -4.106    | -3.27     |
# Train Sharpe Ratio: 1.687, Validation Sharpe Ratio: 1.074
# Debug: L2 penalty: 3.2368100921156366
# Debug: L1 penalty: 1.1908580298757634
# Debug: Objective function value (with penalty): 8.764331878008601
# --------------------------------------------------
# | 37        | 8.764     | -2.948    | 1.187     | -18.8     | -8.296    | -9.206    | -10.52    | -7.362    | -15.44    | -5.501    | 5.284     | -15.75    |
# Train Sharpe Ratio: 1.498, Validation Sharpe Ratio: 0.872
# Debug: L2 penalty: 5.75729306322178
# Debug: L1 penalty: 1.483430928698157
# Debug: Objective function value (with penalty): 3.9832760080800638
# --------------------------------------------------
# | 38        | 3.983     | 0.5055    | -10.64    | -20.0     | -2.956    | -20.0     | -14.7     | -20.0     | -20.0     | 14.66     | 3.39      | -20.0     |
# Train Sharpe Ratio: 1.618, Validation Sharpe Ratio: 1.105
# Debug: L2 penalty: 7.88127592894999
# Debug: L1 penalty: 2.004179709216855
# Debug: Objective function value (with penalty): 3.216544361833155
# --------------------------------------------------
# | 39        | 3.217     | -8.657    | 12.84     | -20.0     | -20.0     | -18.06    | -4.525    | -20.0     | -20.0     | -19.51    | 20.0      | -6.371    |
# Train Sharpe Ratio: 1.796, Validation Sharpe Ratio: 0.926
# Debug: L2 penalty: 2.5883833507846243
# Debug: L1 penalty: 0.9425880328505352
# Debug: Objective function value (with penalty): 9.20902861636484
# --------------------------------------------------
# | 40        | 9.209     | 0.06653   | -9.481    | -20.0     | 0.6833    | -4.344    | -7.205    | -9.231    | -14.32    | -11.83    | 0.09621   | -4.953    |
# Train Sharpe Ratio: 1.521, Validation Sharpe Ratio: 0.823
# Debug: L2 penalty: 2.865967869236765
# Debug: L1 penalty: 1.027558726708379
# Debug: Objective function value (with penalty): 7.128473404054856
# --------------------------------------------------
# | 41        | 7.128     | -19.57    | -5.316    | -13.96    | 10.54     | 4.559     | -10.65    | -11.16    | -12.33    | -1.69     | 12.98     | 0.8275    |
# Train Sharpe Ratio: 1.956, Validation Sharpe Ratio: 0.972
# Debug: L2 penalty: 6.39876937190226
# Debug: L1 penalty: 1.7780769639731195
# Debug: Objective function value (with penalty): 5.4791536641246195
# --------------------------------------------------
# | 42        | 5.479     | 4.3       | -14.97    | -20.0     | -9.912    | -2.516    | -20.0     | 6.522     | -20.0     | -11.95    | 14.51     | -20.0     |
# Train Sharpe Ratio: 1.792, Validation Sharpe Ratio: 1.064
# Debug: L2 penalty: 2.854049973051313
# Debug: L1 penalty: 0.9850792463857057
# Debug: Objective function value (with penalty): 9.71287078056298
# --------------------------------------------------
# | 43        | 9.713     | -10.78    | 2.875     | -20.0     | -0.2369   | 2.007     | -12.47    | -2.169    | -8.709    | -16.56    | 1.509     | -3.451    |
# Train Sharpe Ratio: 1.559, Validation Sharpe Ratio: 0.924
# Debug: L2 penalty: 7.162798812161973
# Debug: L1 penalty: 1.7895755552198371
# Debug: Objective function value (with penalty): 2.827625632618189
# --------------------------------------------------
# | 44        | 2.828     | -20.0     | 18.11     | -20.0     | 6.405     | 18.79     | -20.0     | -7.141    | -20.0     | -20.0     | 2.146     | 16.21     |
# Train Sharpe Ratio: 1.773, Validation Sharpe Ratio: 0.857
# Debug: L2 penalty: 2.0827174470965453
# Debug: L1 penalty: 0.8850012799673622
# Debug: Objective function value (with penalty): 9.266281272936093
# --------------------------------------------------
# | 45        | 9.266     | -0.4369   | -12.83    | -17.34    | 1.569     | -8.013    | -4.747    | -12.99    | -5.192    | -6.717    | 5.113     | -5.425    |
# Train Sharpe Ratio: 1.485, Validation Sharpe Ratio: 0.815
# Debug: L2 penalty: 2.5938326629565647
# Debug: L1 penalty: 0.8985680394569182
# Debug: Objective function value (with penalty): 7.337599297586516
# --------------------------------------------------
# | 46        | 7.338     | -18.53    | 0.1773    | -8.754    | 8.021     | 1.592     | -7.664    | -6.872    | -14.66    | -6.43     | 18.64     | 0.8421    |
# Train Sharpe Ratio: 1.784, Validation Sharpe Ratio: 0.929
# Debug: L2 penalty: 3.662723630932598
# Debug: L1 penalty: 1.2352875622870447
# Debug: Objective function value (with penalty): 7.811988806780356
# --------------------------------------------------
# | 47        | 7.812     | -12.56    | -2.702    | -17.56    | 3.89      | -8.712    | -12.93    | -0.8642   | -14.58    | -17.08    | 13.93     | 3.178     |
# Train Sharpe Ratio: 1.779, Validation Sharpe Ratio: 0.965
# Debug: L2 penalty: 2.3735979521649533
# Debug: L1 penalty: 0.9645316547777039
# Debug: Objective function value (with penalty): 9.567870393057342
# --------------------------------------------------
# | 48        | 9.568     | -10.92    | 0.1321    | -13.15    | -0.7222   | -10.61    | -12.99    | 0.5011    | -12.29    | -7.829    | 11.21     | 2.68      |
# Train Sharpe Ratio: 1.475, Validation Sharpe Ratio: 0.763
# Debug: L2 penalty: 2.0275234366872312
# Debug: L1 penalty: 0.8018526959965439
# Debug: Objective function value (with penalty): 7.648623867316227
# --------------------------------------------------
# | 49        | 7.649     | -9.391    | -6.716    | -13.88    | 12.33     | 4.121     | -4.101    | -19.55    | -0.1017   | -4.759    | 5.208     | 4.875     |
# Train Sharpe Ratio: 1.506, Validation Sharpe Ratio: 0.808
# Debug: L2 penalty: 2.87727083677643
# Debug: L1 penalty: 0.8621711529495628
# Debug: Objective function value (with penalty): 7.132558010274009
# --------------------------------------------------
# | 50        | 7.133     | -18.37    | -1.383    | -5.182    | 4.307     | 0.5974    | -19.72    | -0.1698   | -12.33    | -3.675    | 19.35     | 3.028     |
# Train Sharpe Ratio: 1.309, Validation Sharpe Ratio: 0.763
# Debug: L2 penalty: 2.138659466563257
# Debug: L1 penalty: 0.8460128145181263
# Debug: Objective function value (with penalty): 6.829327718918616
# --------------------------------------------------
# | 51        | 6.829     | -11.96    | -5.304    | -0.7545   | 5.378     | -7.818    | -16.42    | -12.43    | -10.13    | -15.71    | 6.582     | -3.293    |
# Train Sharpe Ratio: 2.098, Validation Sharpe Ratio: 1.146
# Debug: L2 penalty: 3.3191799423463166
# Debug: L1 penalty: 1.1736755571878796
# Debug: Objective function value (with penalty): 10.775144500465801
# --------------------------------------------------
# | 52        | 10.78     | -5.187    | -0.07641  | -20.0     | -6.854    | -2.209    | -18.4     | -12.42    | -5.934    | -5.113    | 6.991     | 2.221     |
# Train Sharpe Ratio: 1.446, Validation Sharpe Ratio: 0.713
# Debug: L2 penalty: 3.7705175402669173
# Debug: L1 penalty: 1.2128796198550045
# Debug: Objective function value (with penalty): 5.078602839878077
# --------------------------------------------------
# | 53        | 5.079     | -7.841    | -13.78    | -19.3     | 10.19     | 4.003     | -17.64    | -11.95    | 17.26     | -13.42    | -12.87    | 5.681     |
# Train Sharpe Ratio: 1.928, Validation Sharpe Ratio: 1.124
# Debug: L2 penalty: 3.4450247774431797
# Debug: L1 penalty: 1.2417356536433415
# Debug: Objective function value (with penalty): 9.769239568913477
# --------------------------------------------------
# | 54        | 9.769     | -10.37    | -7.843    | -16.14    | -15.44    | -6.636    | -9.511    | -1.303    | -18.05    | -7.457    | 0.2473    | 2.444     |
# Train Sharpe Ratio: 1.526, Validation Sharpe Ratio: 1.009
# Debug: L2 penalty: 5.667683151867448
# Debug: L1 penalty: 1.6360098791169744
# Debug: Objective function value (with penalty): 4.854306969015577
# --------------------------------------------------
# | 55        | 4.854     | -17.68    | -5.254    | -18.54    | -16.96    | -17.63    | -18.38    | -13.13    | -5.592    | -5.752    | -13.59    | 17.01     |
# Train Sharpe Ratio: 1.52, Validation Sharpe Ratio: 0.803
# Debug: L2 penalty: 4.20359211423323
# Debug: L1 penalty: 1.281001213628481
# Debug: Objective function value (with penalty): 5.41340667213829
# --------------------------------------------------
# | 56        | 5.413     | -18.34    | -6.173    | -18.04    | 15.64     | 7.897     | -11.18    | -11.88    | -19.77    | 6.131     | 15.06     | -0.4918   |
# Train Sharpe Ratio: 1.914, Validation Sharpe Ratio: 0.983
# Debug: L2 penalty: 3.0992993990628044
# Debug: L1 penalty: 1.2434410371261582
# Debug: Objective function value (with penalty): 9.211259563811035
# --------------------------------------------------
# | 57        | 9.211     | -11.49    | -15.71    | -15.54    | -8.348    | 1.566     | -12.51    | -9.701    | -7.006    | -6.786    | 9.551     | -3.725    |
# Train Sharpe Ratio: 2.101, Validation Sharpe Ratio: 1.243
# Debug: L2 penalty: 4.380158592830419
# Debug: L1 penalty: 1.1971859063083643
# Debug: Objective function value (with penalty): 10.284655500861216
# --------------------------------------------------
# | 58        | 10.28     | -7.113    | 1.713     | -20.0     | -11.02    | 1.478     | -20.0     | -0.4338   | -20.0     | -0.2072   | 1.809     | 0.08531   |
# Train Sharpe Ratio: 1.886, Validation Sharpe Ratio: 1.168
# Debug: L2 penalty: 2.3593901327294207
# Debug: L1 penalty: 0.9453730141951934
# Debug: Objective function value (with penalty): 11.247236853075387
# --------------------------------------------------
# | 59        | 11.25     | -10.82    | -1.349    | -20.0     | -6.639    | -0.7633   | -8.735    | -9.612    | -8.073    | -2.606    | -1.853    | -1.731    |
# Train Sharpe Ratio: 1.665, Validation Sharpe Ratio: 1.122
# Debug: L2 penalty: 2.854405538246922
# Debug: L1 penalty: 1.06525262601504
# Debug: Objective function value (with penalty): 9.472341835738037
# --------------------------------------------------
# | 60        | 9.472     | -13.83    | -0.9757   | -16.12    | -11.07    | -1.776    | -12.72    | -1.457    | -14.17    | -6.926    | 0.6879    | -8.65     |
# Train Sharpe Ratio: 2.267, Validation Sharpe Ratio: 1.157
# Debug: L2 penalty: 5.267448644247581
# Debug: L1 penalty: 1.6680672547623132
# Debug: Objective function value (with penalty): 9.074484100990103
# --------------------------------------------------
# | 61        | 9.074     | -10.82    | -5.107    | -19.4     | -6.489    | 12.37     | -18.08    | -9.191    | -19.48    | 2.447     | -0.8564   | 11.52     |
# Train Sharpe Ratio: 1.962, Validation Sharpe Ratio: 1.16
# Debug: L2 penalty: 2.9826942449700096
# Debug: L1 penalty: 1.0274414186832908
# Debug: Objective function value (with penalty): 10.7978643363467
# --------------------------------------------------
# | 62        | 10.8      | -2.078    | 5.572     | -18.41    | -5.652    | -0.1722   | -19.16    | -9.169    | -11.84    | -2.288    | -1.029    | 1.714     |
# Train Sharpe Ratio: 1.767, Validation Sharpe Ratio: 1.158
# Debug: L2 penalty: 2.9112554745867003
# Debug: L1 penalty: 1.078267479201938
# Debug: Objective function value (with penalty): 10.026477046211362
# --------------------------------------------------
# | 63        | 10.03     | -3.182    | 4.076     | -16.9     | -6.904    | 2.566     | -4.129    | -19.17    | -14.68    | 6.532     | 2.576     | -4.768    |
# Train Sharpe Ratio: 2.058, Validation Sharpe Ratio: 0.904
# Debug: L2 penalty: 7.300046856458266
# Debug: L1 penalty: 1.937996350807496
# Debug: Objective function value (with penalty): 4.417956792734237
# --------------------------------------------------
# | 64        | 4.418     | 7.701     | -5.996    | -20.0     | -20.0     | 4.616     | -20.0     | -20.0     | -20.0     | 9.62      | 18.13     | 11.62     |
# Train Sharpe Ratio: 1.341, Validation Sharpe Ratio: 1.041
# Debug: L2 penalty: 5.40778042861122
# Debug: L1 penalty: 1.430392257607011
# Debug: Objective function value (with penalty): 4.771827313781769
# --------------------------------------------------
# | 65        | 4.772     | 1.195     | -0.819    | -20.0     | -11.55    | 20.0      | -10.44    | -20.0     | -20.0     | 7.262     | -20.0     | -5.623    |
# Train Sharpe Ratio: 0.995, Validation Sharpe Ratio: 0.613
# Debug: L2 penalty: 1.6251284931608854
# Debug: L1 penalty: 0.6892292062266436
# Debug: Objective function value (with penalty): 5.343642300612471
# --------------------------------------------------
# | 66        | 5.344     | -12.06    | -6.554    | 10.89     | 7.801     | -4.356    | -13.5     | -13.76    | -9.887    | -13.1     | 3.57      | -4.518    |
# Train Sharpe Ratio: 2.399, Validation Sharpe Ratio: 1.0
# Debug: L2 penalty: 12.577715275592722
# Debug: L1 penalty: 2.9255134379439633
# Debug: Objective function value (with penalty): 0.09277128646331523
# --------------------------------------------------
# | 67        | 0.09277   | -20.0     | -20.0     | -20.0     | -20.0     | -20.0     | -20.0     | 20.0      | -20.0     | -10.44    | 20.0      | 17.98     |
# Train Sharpe Ratio: 1.803, Validation Sharpe Ratio: 1.032
# Debug: L2 penalty: 2.35303883499544
# Debug: L1 penalty: 0.9626239822814826
# Debug: Objective function value (with penalty): 10.088337182723077
# --------------------------------------------------
# | 68        | 10.09     | -8.21     | 4.21      | -19.23    | 1.577     | 4.136     | -11.24    | -13.46    | -7.622    | 3.032     | 4.866     | 2.219     |
# Train Sharpe Ratio: 1.747, Validation Sharpe Ratio: 0.935
# Debug: L2 penalty: 2.672140385502487
# Debug: L1 penalty: 0.9780622843266253
# Debug: Objective function value (with penalty): 8.94779733017089
# --------------------------------------------------
# | 69        | 8.948     | -6.046    | -1.22     | -15.74    | 4.067     | -0.8656   | -13.51    | -3.689    | -19.85    | -4.434    | -6.712    | 10.13     |
# Train Sharpe Ratio: 1.468, Validation Sharpe Ratio: 1.145
# Debug: L2 penalty: 4.67550834324596
# Debug: L1 penalty: 1.3310634510870734
# Debug: Objective function value (with penalty): 6.735428205666967
# --------------------------------------------------
# | 70        | 6.735     | -4.768    | 17.31     | -18.08    | -15.61    | -5.279    | -17.69    | -14.2     | -19.86    | -0.3712   | 1.768     | -1.123    |
# Train Sharpe Ratio: 1.464, Validation Sharpe Ratio: 0.987
# Debug: L2 penalty: 5.183120693149791
# Debug: L1 penalty: 1.565555334854746
# Debug: Objective function value (with penalty): 5.029323971995462
# --------------------------------------------------
# | 71        | 5.029     | -13.85    | -5.474    | -15.81    | -18.99    | -17.66    | -16.57    | -7.018    | -7.446    | -15.85    | -16.0     | 13.03     |
# Train Sharpe Ratio: 1.838, Validation Sharpe Ratio: 1.083
# Debug: L2 penalty: 2.884106076375084
# Debug: L1 penalty: 1.0803448184365951
# Debug: Objective function value (with penalty): 9.88554910518832
# --------------------------------------------------
# | 72        | 9.886     | -1.004    | 12.86     | -15.98    | -1.61     | 8.946     | -17.19    | -2.182    | -12.86    | -6.438    | 4.48      | -3.123    |
# Train Sharpe Ratio: 0.541, Validation Sharpe Ratio: 0.444
# Debug: L2 penalty: 3.951255983453735
# Debug: L1 penalty: 0.9107225693409639
# Debug: Objective function value (with penalty): -0.033978552794698635
# --------------------------------------------------
# | 73        | -0.03398  | -9.593    | 20.0      | 20.0      | 20.0      | 20.0      | -20.0     | 20.0      | -20.0     | -20.0     | 20.0      | -20.0     |
# Train Sharpe Ratio: 1.803, Validation Sharpe Ratio: 0.97
# Debug: L2 penalty: 3.525670512550444
# Debug: L1 penalty: 1.1484167543214263
# Debug: Objective function value (with penalty): 8.35791273312813
# --------------------------------------------------
# | 74        | 8.358     | -17.91    | -5.72     | -17.05    | -0.3801   | -7.765    | -6.177    | 0.06346   | -10.89    | -16.82    | 14.42     | -0.7185   |
# Train Sharpe Ratio: 1.737, Validation Sharpe Ratio: 0.976
# Debug: L2 penalty: 2.7726563490425002
# Debug: L1 penalty: 1.015454228250979
# Debug: Objective function value (with penalty): 9.015889422706524
# --------------------------------------------------
# | 75        | 9.016     | -11.62    | 2.326     | -15.74    | 1.345     | -4.599    | -9.124    | -4.151    | -19.37    | -8.918    | 10.79     | -0.1393   |
# Train Sharpe Ratio: 1.601, Validation Sharpe Ratio: 1.05
# Debug: L2 penalty: 2.962263308236214
# Debug: L1 penalty: 0.9881267277915021
# Debug: Objective function value (with penalty): 8.753609963972284
# --------------------------------------------------
# | 76        | 8.754     | -0.1478   | 1.431     | -10.66    | -10.39    | 16.06     | -15.96    | -3.723    | -19.54    | 0.7138    | 2.682     | -5.113    |
# Train Sharpe Ratio: 1.505, Validation Sharpe Ratio: 0.819
# Debug: L2 penalty: 3.955335630834753
# Debug: L1 penalty: 1.27281845298812
# Debug: Objective function value (with penalty): 5.705845916177126
# --------------------------------------------------
# | 77        | 5.706     | -8.375    | -16.63    | -19.19    | 11.71     | 14.18     | -14.04    | -14.57    | -1.525    | -12.88    | -12.91    | -3.328    |
# Train Sharpe Ratio: 1.52, Validation Sharpe Ratio: 0.932
# Debug: L2 penalty: 7.259567639772981
# Debug: L1 penalty: 1.7439275363543256
# Debug: Objective function value (with penalty): 2.668504823872696
# --------------------------------------------------
# | 78        | 2.669     | 16.57     | 20.0      | -20.0     | 0.6729    | 18.2      | -0.401    | -20.0     | -20.0     | 10.17     | 20.0      | -20.0     |
# Train Sharpe Ratio: 1.782, Validation Sharpe Ratio: 0.889
# Debug: L2 penalty: 3.876313184619323
# Debug: L1 penalty: 1.2165125056423483
# Debug: Objective function value (with penalty): 7.3691743097383275
# --------------------------------------------------
# | 79        | 7.369     | -19.97    | -6.934    | -19.96    | 5.193     | 2.003     | -6.985    | -9.988    | -10.69    | -1.13     | 19.4      | 6.212     |
# Train Sharpe Ratio: 2.257, Validation Sharpe Ratio: 1.015
# Debug: L2 penalty: 2.8946608744295497
# Debug: L1 penalty: 1.0944736783655267
# Debug: Objective function value (with penalty): 11.128865447204925
# --------------------------------------------------
# | 80        | 11.13     | 5.686     | -0.7015   | -16.86    | -0.5407   | -5.001    | -17.32    | -6.161    | -3.85     | -9.245    | 13.16     | 1.917     |
# Train Sharpe Ratio: 2.534, Validation Sharpe Ratio: 0.851
# Debug: L2 penalty: 3.464387871375701
# Debug: L1 penalty: 1.2944490106059567
# Debug: Objective function value (with penalty): 10.483163118018343
# --------------------------------------------------
# | 81        | 10.48     | 10.01     | -10.05    | -17.04    | 2.217     | 10.01     | -18.35    | -4.4      | -11.02    | -0.106    | 5.56      | 5.602     |
# Train Sharpe Ratio: 2.856, Validation Sharpe Ratio: 1.187
# Debug: L2 penalty: 1.8029175330364877
# Debug: L1 penalty: 0.9318022683033804
# Debug: Objective function value (with penalty): 15.81128019866013
# --------------------------------------------------
# | 82        | 15.81     | 0.8709    | -1.272    | -10.82    | -3.226    | 3.689     | -11.25    | -0.5057   | -12.35    | -1.389    | 3.393     | 7.062     |
# Train Sharpe Ratio: 1.647, Validation Sharpe Ratio: 0.953
# Debug: L2 penalty: 3.337460405333575
# Debug: L1 penalty: 1.1299822634799435
# Debug: Objective function value (with penalty): 7.838557331186481
# --------------------------------------------------
# | 83        | 7.839     | -14.94    | -0.8141   | -19.57    | 3.359     | -6.826    | -12.52    | -0.3345   | -17.22    | -7.235    | 10.35     | -8.863    |
# Train Sharpe Ratio: 2.273, Validation Sharpe Ratio: 0.819
# Debug: L2 penalty: 3.0957590101833867
# Debug: L1 penalty: 1.2435695222785557
# Debug: Objective function value (with penalty): 9.666671467538059
# --------------------------------------------------
# | 84        | 9.667     | 0.4834    | -9.926    | -13.19    | 4.926     | 6.794     | -9.775    | -4.825    | -6.611    | -16.04    | 12.03     | 14.05     |
# Train Sharpe Ratio: 1.687, Validation Sharpe Ratio: 1.119
# Debug: L2 penalty: 3.07101119216085
# Debug: L1 penalty: 1.098776900056638
# Debug: Objective function value (with penalty): 9.292211907782512
# --------------------------------------------------
# | 85        | 9.292     | -9.862    | 5.845     | -19.91    | -5.542    | 1.349     | -18.78    | -2.146    | -7.858    | -8.977    | -1.583    | -8.836    |
# Train Sharpe Ratio: 1.048, Validation Sharpe Ratio: 0.363
# Debug: L2 penalty: 1.1071004551821815
# Debug: L1 penalty: 0.4861632497366692
# Debug: Objective function value (with penalty): 4.776736295081149
# --------------------------------------------------
# | 86        | 4.777     | 10.89     | 1.597     | -3.129    | -10.37    | 7.357     | -12.43    | 4.73      | -14.36    | -9.859    | -0.2787   | 9.802     |
# Train Sharpe Ratio: 2.297, Validation Sharpe Ratio: 1.148
# Debug: L2 penalty: 4.623296173872711
# Debug: L1 penalty: 1.5094053041174922
# Debug: Objective function value (with penalty): 9.943298522009798
# --------------------------------------------------
# | 87        | 9.943     | -12.42    | -4.544    | -15.41    | -5.885    | 11.58     | -18.74    | -0.4073   | -17.9     | 0.7985    | -3.525    | 13.11     |
# Train Sharpe Ratio: 1.615, Validation Sharpe Ratio: 0.907
# Debug: L2 penalty: 1.3647971735630626
# Debug: L1 penalty: 0.7259160700331382
# Debug: Objective function value (with penalty): 9.811286756403799
# --------------------------------------------------
# | 88        | 9.811     | 1.604     | -1.478    | -8.126    | -11.25    | 2.938     | -8.091    | -8.118    | -10.82    | 4.663     | 9.823     | 0.8601    |
# Train Sharpe Ratio: 2.783, Validation Sharpe Ratio: 0.97
# Debug: L2 penalty: 2.545912640868322
# Debug: L1 penalty: 1.0890143237333367
# Debug: Objective function value (with penalty): 13.31707303539834
# --------------------------------------------------
# | 89        | 13.32     | 2.003     | -0.8928   | -13.4     | 0.606     | 4.944     | -12.26    | -2.595    | -10.83    | -0.7862   | 12.2      | 10.86     |
# Train Sharpe Ratio: 2.372, Validation Sharpe Ratio: 1.014
# Debug: L2 penalty: 2.7325587238159077
# Debug: L1 penalty: 0.9766109121340882
# Debug: Objective function value (with penalty): 11.862830364050003
# --------------------------------------------------
# | 90        | 11.86     | 7.401     | -0.7005   | -19.42    | 0.5135    | 2.755     | 4.772     | -3.213    | -18.12    | -3.696    | 7.777     | -1.321    |
# Train Sharpe Ratio: 2.069, Validation Sharpe Ratio: 1.097
# Debug: L2 penalty: 1.6893735075695275
# Debug: L1 penalty: 0.7920720346231696
# Debug: Objective function value (with penalty): 12.376554457807304
# --------------------------------------------------
# | 91        | 12.38     | -0.6892   | -1.518    | -14.94    | 1.74      | 11.06     | -10.71    | -6.077    | -3.15     | -7.255    | -1.653    | -0.4377   |
# Train Sharpe Ratio: 1.951, Validation Sharpe Ratio: 0.901
# Debug: L2 penalty: 3.9780756760628857
# Debug: L1 penalty: 1.3478262202807214
# Debug: Objective function value (with penalty): 7.8840981036563935
# --------------------------------------------------
# | 92        | 7.884     | -15.67    | -9.739    | -18.25    | 4.028     | 4.695     | -4.261    | -10.92    | -14.85    | -3.812    | 18.73     | 8.416     |
# Train Sharpe Ratio: 1.809, Validation Sharpe Ratio: 0.983
# Debug: L2 penalty: 1.3407693002019634
# Debug: L1 penalty: 0.6942071630829963
# Debug: Objective function value (with penalty): 11.099023536715041
# --------------------------------------------------
# | 93        | 11.1      | 2.277     | -1.022    | -6.594    | -1.468    | 7.293     | -11.78    | -0.4539   | -12.52    | -9.613    | -3.523    | 2.183     |
# Train Sharpe Ratio: 2.314, Validation Sharpe Ratio: 1.061
# Debug: L2 penalty: 3.729222906796093
# Debug: L1 penalty: 1.2387725079735705
# Debug: Objective function value (with penalty): 10.654004585230338
# --------------------------------------------------
# | 94        | 10.65     | -0.1193   | 1.332     | -18.36    | -14.03    | -6.04     | -8.527    | -4.514    | -13.22    | -0.3915   | 3.016     | 18.55     |
# Train Sharpe Ratio: 2.083, Validation Sharpe Ratio: 1.036
# Debug: L2 penalty: 2.8910177521844926
# Debug: L1 penalty: 1.104958709575092
# Debug: Objective function value (with penalty): 10.552023538240418
# --------------------------------------------------
# | 95        | 10.55     | -5.903    | -10.09    | -14.77    | -4.208    | 12.76     | -3.876    | -4.181    | -19.61    | 6.097     | -1.363    | -1.538    |
# Train Sharpe Ratio: 2.108, Validation Sharpe Ratio: 0.765
# Debug: L2 penalty: 2.7416145054512957
# Debug: L1 penalty: 1.0047088143915186
# Debug: Objective function value (with penalty): 9.275676680157186
# --------------------------------------------------
# | 96        | 9.276     | -1.271    | -12.56    | -16.55    | 6.103     | -0.2074   | -17.94    | 9.352     | -10.54    | 0.7185    | 7.005     | 3.48      |
# Train Sharpe Ratio: 2.199, Validation Sharpe Ratio: 0.928
# Debug: L2 penalty: 2.545823372008372
# Debug: L1 penalty: 1.1479426251643445
# Debug: Objective function value (with penalty): 10.670234002827282
# --------------------------------------------------
# | 97        | 10.67     | 5.86      | -2.512    | -15.15    | -11.99    | 6.276     | -8.937    | -8.037    | -13.53    | 2.398     | 7.089     | 7.015     |
# Train Sharpe Ratio: 2.975, Validation Sharpe Ratio: 1.371
# Debug: L2 penalty: 3.791911003515093
# Debug: L1 penalty: 1.4023204984816853
# Debug: Objective function value (with penalty): 14.931768498003219
# --------------------------------------------------
# | 98        | 14.93     | -9.282    | -3.862    | -19.21    | -8.565    | 1.422     | 2.395     | 10.05     | -16.21    | -0.9736   | 0.3507    | 5.096     |
# Train Sharpe Ratio: 1.254, Validation Sharpe Ratio: 0.708
# Debug: L2 penalty: 2.683363266223756
# Debug: L1 penalty: 0.8691729037365793
# Debug: Objective function value (with penalty): 5.711463830039664
# --------------------------------------------------
# | 99        | 5.711     | -18.94    | -1.496    | -15.75    | 19.18     | 5.125     | -8.513    | -15.67    | -7.289    | 0.2868    | 6.992     | 5.008     |
# Train Sharpe Ratio: 2.02, Validation Sharpe Ratio: 1.104
# Debug: L2 penalty: 2.2266384361367666
# Debug: L1 penalty: 0.9719630529817925
# Debug: Objective function value (with penalty): 11.505398510881442
# --------------------------------------------------
# | 100       | 11.51     | -5.605    | 2.204     | -14.72    | 1.053     | 3.502     | -6.609    | 9.31      | -17.42    | -3.914    | 4.333     | -4.773    |
# Train Sharpe Ratio: 2.287, Validation Sharpe Ratio: 1.043
# Debug: L2 penalty: 2.031832840695664
# Debug: L1 penalty: 0.9455156413287389
# Debug: Objective function value (with penalty): 12.428651517975595
# --------------------------------------------------
# | 101       | 12.43     | 3.061     | -0.7078   | -11.27    | -9.896    | -2.675    | -11.9     | 2.571     | -13.83    | 2.226     | 1.681     | 8.368     |
# Train Sharpe Ratio: 1.847, Validation Sharpe Ratio: 0.903
# Debug: L2 penalty: 2.8051041072928817
# Debug: L1 penalty: 1.1181527791991082
# Debug: Objective function value (with penalty): 8.88274311350801
# --------------------------------------------------
# | 102       | 8.883     | -10.34    | 4.703     | -16.25    | -3.363    | 7.736     | -1.067    | 14.08     | -14.22    | -7.21     | -6.325    | 11.73     |
# Train Sharpe Ratio: 2.473, Validation Sharpe Ratio: 0.995
# Debug: L2 penalty: 3.9204393602565935
# Debug: L1 penalty: 1.4609233358165332
# Debug: Objective function value (with penalty): 10.480637303926871
# --------------------------------------------------
# | 103       | 10.48     | -6.933    | -6.738    | -17.92    | -5.464    | -3.837    | 11.0      | -7.743    | -19.77    | 9.704     | 3.214     | 10.01     |
# Train Sharpe Ratio: 1.379, Validation Sharpe Ratio: 0.634
# Debug: L2 penalty: 2.241224282550798
# Debug: L1 penalty: 0.8387238117183357
# Debug: Objective function value (with penalty): 6.2400519057308665
# --------------------------------------------------
# | 104       | 6.24      | -10.25    | -5.444    | -19.93    | -6.127    | -7.949    | 14.78     | 3.035     | -12.0     | -0.8018   | -8.423    | 11.26     |
# Train Sharpe Ratio: 0.468, Validation Sharpe Ratio: 0.222
# Debug: L2 penalty: 0.8218586168217455
# Debug: L1 penalty: 0.29936055148526797
# Debug: Objective function value (with penalty): 2.082780831692987
# --------------------------------------------------
# | 105       | 2.083     | -14.78    | 4.947     | -17.27    | -11.74    | 4.702     | 0.8977    | 10.66     | -16.52    | 8.261     | 3.323     | 10.71     |
# Train Sharpe Ratio: 2.428, Validation Sharpe Ratio: 1.162
# Debug: L2 penalty: 3.007379639150026
# Debug: L1 penalty: 1.1236937545652477
# Debug: Objective function value (with penalty): 12.552926606284728
# --------------------------------------------------
# | 106       | 12.55     | -7.961    | -7.142    | -19.23    | -3.991    | 2.396     | -8.67     | 1.206     | -17.18    | 0.7802    | 4.455     | 1.827     |
# Train Sharpe Ratio: 2.373, Validation Sharpe Ratio: 1.23
# Debug: L2 penalty: 3.1267711717623206
# Debug: L1 penalty: 1.1955302603467544
# Debug: Objective function value (with penalty): 12.549698567890928
# --------------------------------------------------
# | 107       | 12.55     | -0.6284   | 2.926     | -17.63    | -3.589    | 4.42      | -13.86    | 6.243     | -16.75    | -6.531    | 3.784     | -2.363    |
# Train Sharpe Ratio: 1.687, Validation Sharpe Ratio: 0.804
# Debug: L2 penalty: 1.916198765667342
# Debug: L1 penalty: 0.8956430147344997
# Debug: Objective function value (with penalty): 8.760158219598157
# --------------------------------------------------
# | 108       | 8.76      | 3.297     | -9.234    | -17.82    | 6.08      | -6.226    | 3.441     | -10.18    | -8.106    | -8.213    | 6.955     | -6.449    |
# Train Sharpe Ratio: 2.623, Validation Sharpe Ratio: 0.378
# Debug: L2 penalty: 3.934783089904658
# Debug: L1 penalty: 1.2469451236528641
# Debug: Objective function value (with penalty): 7.57827178644248
# --------------------------------------------------
# | 109       | 7.578     | 4.017     | -18.93    | -19.93    | 2.333     | 15.21     | -4.871    | 10.44     | -14.28    | -3.243    | 1.8       | 13.52     |
# Train Sharpe Ratio: 3.014, Validation Sharpe Ratio: 1.249
# Debug: L2 penalty: 4.382005513819073
# Debug: L1 penalty: 1.7146624285623226
# Debug: Objective function value (with penalty): 13.453332057618605
# --------------------------------------------------
# | 110       | 13.45     | -4.293    | 4.506     | -19.36    | -7.435    | 2.605     | -4.342    | 8.233     | -11.72    | -13.85    | 12.37     | 8.741     |
# Train Sharpe Ratio: 2.452, Validation Sharpe Ratio: 1.075
# Debug: L2 penalty: 2.9419145348295
# Debug: L1 penalty: 1.2086444147274806
# Debug: Objective function value (with penalty): 12.107441050443018
# --------------------------------------------------
# | 111       | 12.11     | 2.69      | -4.412    | -16.47    | -4.039    | -4.159    | -15.31    | -2.834    | -4.378    | -14.38    | 8.931     | 4.996     |
# Train Sharpe Ratio: 2.149, Validation Sharpe Ratio: 0.891
# Debug: L2 penalty: 3.0043154453210756
# Debug: L1 penalty: 1.2139393894807693
# Debug: Objective function value (with penalty): 9.723745165198155
# --------------------------------------------------
# | 112       | 9.724     | -5.177    | -4.652    | -19.95    | 6.616     | 8.663     | 7.796     | 4.542     | -10.49    | -11.65    | 12.9      | 4.31      |
# Train Sharpe Ratio: 2.656, Validation Sharpe Ratio: 1.282
# Debug: L2 penalty: 2.534807928091223
# Debug: L1 penalty: 1.113009435175163
# Debug: Objective function value (with penalty): 14.668182636733613
# --------------------------------------------------
# | 113       | 14.67     | -6.002    | 1.52      | -18.34    | -2.617    | 11.37     | 2.642     | 1.39      | -9.213    | -6.108    | 6.935     | -1.38     |
# Train Sharpe Ratio: 1.691, Validation Sharpe Ratio: 1.255
# Debug: L2 penalty: 3.1216941373417395
# Debug: L1 penalty: 1.2217503531754021
# Debug: Objective function value (with penalty): 9.950555509482859
# --------------------------------------------------
# | 114       | 9.951     | -12.2     | 9.144     | -18.09    | -13.21    | 6.248     | 1.27      | 4.767     | -8.127    | -14.06    | 3.815     | -4.049    |
# Train Sharpe Ratio: 3.03, Validation Sharpe Ratio: 0.982
# Debug: L2 penalty: 2.2903309257525746
# Debug: L1 penalty: 1.0675859462966075
# Debug: Objective function value (with penalty): 14.65408312795082
# --------------------------------------------------
# | 115       | 14.65     | -0.8091   | -5.096    | -16.43    | -2.26     | -1.686    | -0.08458  | 9.683     | -6.241    | -9.252    | 9.45      | 4.865     |
# Train Sharpe Ratio: 1.892, Validation Sharpe Ratio: 1.132
# Debug: L2 penalty: 2.048594368540026
# Debug: L1 penalty: 0.8959126523239985
# Debug: Objective function value (with penalty): 11.415492979135974
# --------------------------------------------------
# ...
# Debug: Objective function value (with penalty): 8.834373060002383
# --------------------------------------------------
# | 283       | 8.834     | -12.44    | -5.968    | -13.81    | -10.63    | -6.129    | -9.096    | -7.221    | 12.03     | -9.199    | 16.12     | -7.423    |
# Train Sharpe Ratio: 1.76, Validation Sharpe Ratio: 1.093
# Debug: L2 penalty: 2.2268080169032523
# Debug: L1 penalty: 0.974275616393173
# Debug: Objective function value (with penalty): 10.396916366703573
# --------------------------------------------------
# | 284       | 10.4      | -9.687    | -0.1513   | -11.47    | -7.605    | -12.87    | -0.7258   | 2.068     | -4.703    | -14.32    | 10.22     | -5.794    |
# Train Sharpe Ratio: 2.78, Validation Sharpe Ratio: 1.332
# Debug: L2 penalty: 4.327948641704163
# Debug: L1 penalty: 1.5336352561588789
# Debug: Objective function value (with penalty): 13.25041610213696
# --------------------------------------------------
# | 285       | 13.25     | -4.906    | 0.8777    | -18.48    | -10.98    | 4.758     | -7.576    | -1.3      | -18.92    | -5.185    | 3.197     | 12.98     |
# Train Sharpe Ratio: 0.316, Validation Sharpe Ratio: 0.043
# Debug: L2 penalty: 1.33936
# Debug: L1 penalty: 0.301356
# Debug: Objective function value (with penalty): -0.1187160000000001
# --------------------------------------------------
# | 286       | -0.1187   | 20.0      | -20.0     | 20.0      | -20.0     | 20.0      | -20.0     | -20.0     | 20.0      | -20.0     | 20.0      | -20.0     |
# Train Sharpe Ratio: 1.235, Validation Sharpe Ratio: 0.537
# Debug: L2 penalty: 1.255441950513724
# Debug: L1 penalty: 0.5611669865084769
# Debug: Objective function value (with penalty): 6.3453910629778
# --------------------------------------------------
# | 287       | 6.345     | 2.307     | 6.093     | -18.32    | 0.7122    | -10.54    | 8.775     | 7.808     | -7.831    | -6.919    | 5.439     | 1.652     |
# Train Sharpe Ratio: 1.218, Validation Sharpe Ratio: 0.819
# Debug: L2 penalty: 1.8134384229368115
# Debug: L1 penalty: 0.7735211476080296
# Debug: Objective function value (with penalty): 7.199040429455159
# --------------------------------------------------
# | 288       | 7.199     | -9.093    | -4.024    | -17.9     | 10.16     | 8.895     | -0.8604   | -3.646    | 9.958     | -6.28     | -4.792    | -12.21    |
# Train Sharpe Ratio: 2.377, Validation Sharpe Ratio: 0.846
# Debug: L2 penalty: 2.998179390858284
# Debug: L1 penalty: 1.1934058624855521
# Debug: Objective function value (with penalty): 10.392414746656165
# --------------------------------------------------
# | 289       | 10.39     | 3.872     | -9.294    | -9.881    | -7.763    | -1.628    | -10.24    | 9.041     | -15.9     | -4.502    | 17.45     | -1.351    |
# Train Sharpe Ratio: 2.294, Validation Sharpe Ratio: 0.618
# Debug: L2 penalty: 2.457472157204863
# Debug: L1 penalty: 0.8378937651009019
# Debug: Objective function value (with penalty): 9.588634077694236
# --------------------------------------------------
# | 290       | 9.589     | -0.0989   | -16.62    | -12.13    | -3.889    | -1.164    | 1.781     | 0.07849   | -19.87    | -2.016    | 5.747     | 8.855     |
# Train Sharpe Ratio: 2.793, Validation Sharpe Ratio: 1.127
# Debug: L2 penalty: 2.9903308927368273
# Debug: L1 penalty: 1.2287564658248529
# Debug: Objective function value (with penalty): 13.714912641438321
# --------------------------------------------------
# | 291       | 13.71     | -2.609    | -4.675    | -13.75    | -1.325    | 8.858     | -16.33    | 1.302     | -13.43    | 7.665     | 0.9632    | 5.215     |
# Train Sharpe Ratio: 2.0, Validation Sharpe Ratio: 1.119
# Debug: L2 penalty: 2.8294686412657026
# Debug: L1 penalty: 1.044359717856356
# Debug: Objective function value (with penalty): 10.840171640877942
# --------------------------------------------------
# | 292       | 10.84     | -5.49     | 0.2668    | -16.64    | -4.389    | 5.186     | -13.3     | -3.324    | -18.13    | -9.118    | 2.96      | 0.06859   |
# Train Sharpe Ratio: 2.663, Validation Sharpe Ratio: 1.051
# Debug: L2 penalty: 2.249501980324061
# Debug: L1 penalty: 0.9539583142670439
# Debug: Objective function value (with penalty): 13.754539705408893
# --------------------------------------------------
# | 293       | 13.75     | 1.818     | -2.018    | -14.62    | 2.734     | 15.05     | -5.281    | 0.9641    | -10.85    | 0.6656    | 7.78      | 0.7192    |
# Train Sharpe Ratio: 2.065, Validation Sharpe Ratio: 1.011
# Debug: L2 penalty: 1.7766199596568866
# Debug: L1 penalty: 0.8301973832075727
# Debug: Objective function value (with penalty): 11.71918265713554
# --------------------------------------------------
# | 294       | 11.72     | 0.2568    | -0.3774   | -9.778    | -2.586    | -5.524    | -7.234    | -0.6573   | -11.64    | -13.64    | 10.36     | 2.338     |
# Train Sharpe Ratio: 1.894, Validation Sharpe Ratio: 1.29
# Debug: L2 penalty: 2.651219563744417
# Debug: L1 penalty: 1.0365776077635054
# Debug: Objective function value (with penalty): 11.628202828492078
# --------------------------------------------------
# | 295       | 11.63     | -8.638    | 0.6688    | -17.07    | -11.56    | 0.3604    | -2.478    | 3.787     | -1.732    | -14.63    | 3.542     | -10.73    |
# Train Sharpe Ratio: 1.931, Validation Sharpe Ratio: 0.809
# Debug: L2 penalty: 2.454675172018932
# Debug: L1 penalty: 0.9753421521624237
# Debug: Objective function value (with penalty): 9.147982675818643
# --------------------------------------------------
# | 296       | 9.148     | 4.771     | -13.27    | -15.66    | -1.882    | -5.486    | -0.6137   | -13.67    | -11.06    | -10.0     | 9.398     | -0.3448   |
# Train Sharpe Ratio: 1.763, Validation Sharpe Ratio: 1.108
# Debug: L2 penalty: 2.3788198316414033
# Debug: L1 penalty: 0.9649877757260992
# Debug: Objective function value (with penalty): 10.356192392632499
# --------------------------------------------------
# | 297       | 10.36     | -7.78     | -0.268    | -14.06    | -4.813    | 14.21     | 1.409     | -1.039    | -14.88    | -8.308    | 2.197     | -9.301    |
# Train Sharpe Ratio: 1.493, Validation Sharpe Ratio: 1.05
# Debug: L2 penalty: 1.473144550853649
# Debug: L1 penalty: 0.669076137784626
# Debug: Objective function value (with penalty): 10.129779311361725
# --------------------------------------------------
# | 298       | 10.13     | 2.972     | 4.701     | -15.62    | -0.8912   | 0.569     | -7.412    | -6.408    | 0.6862    | 6.625     | 1.188     | -13.51    |
# Train Sharpe Ratio: 2.282, Validation Sharpe Ratio: 0.902
# Debug: L2 penalty: 2.8690592157025003
# Debug: L1 penalty: 1.0379431151493559
# Debug: Objective function value (with penalty): 10.632997669148148
# --------------------------------------------------
# | 299       | 10.63     | 3.703     | 1.38      | -18.17    | 3.2       | 8.927     | -17.85    | 2.201     | -10.82    | 10.19     | 0.3796    | 2.49      |
# Train Sharpe Ratio: 1.787, Validation Sharpe Ratio: 1.291
# Debug: L2 penalty: 2.7231776904951914
# Debug: L1 penalty: 1.0871427832391658
# Debug: Objective function value (with penalty): 11.083679526265641
# --------------------------------------------------
# | 300       | 11.08     | -3.849    | -1.646    | -19.66    | -15.26    | -7.904    | -4.431    | 2.069     | -5.227    | -9.399    | -3.931    | -7.723    |
# Train Sharpe Ratio: 1.208, Validation Sharpe Ratio: 1.172
# Debug: L2 penalty: 3.8499270233541725
# Debug: L1 penalty: 1.2426827782214165
# Debug: Objective function value (with penalty): 6.77139019842441
# --------------------------------------------------
# | 301       | 6.771     | -0.5618   | 9.831     | -18.99    | -12.33    | 10.13     | -1.915    | -15.33    | -16.23    | 10.49     | -3.713    | -16.87    |
# Train Sharpe Ratio: 1.691, Validation Sharpe Ratio: 1.101
# Debug: L2 penalty: 2.3809032590287464
# Debug: L1 penalty: 1.0621076390211597
# Debug: Objective function value (with penalty): 9.926989101950095
# --------------------------------------------------
# | 302       | 9.927     | -9.711    | 4.13      | -10.93    | -5.424    | 11.51     | -1.102    | 3.023     | -14.65    | -12.38    | 7.082     | -8.323    |
# Train Sharpe Ratio: 1.78, Validation Sharpe Ratio: 0.764
# Debug: L2 penalty: 1.2587342511153292
# Debug: L1 penalty: 0.6871837567295578
# Debug: Objective function value (with penalty): 9.758081992155113
# --------------------------------------------------
# | 303       | 9.758     | -5.252    | -12.28    | -10.75    | -5.698    | 10.32     | 3.543     | -0.08696  | -5.137    | -6.245    | -5.142    | -0.791    |
# Train Sharpe Ratio: 2.071, Validation Sharpe Ratio: 1.05
# Debug: L2 penalty: 1.1631699046536677
# Debug: L1 penalty: 0.6731128203097869
# Debug: Objective function value (with penalty): 12.747717275036546
# --------------------------------------------------
# | 304       | 12.75     | -5.138    | -4.522    | -13.44    | -0.3857   | 2.01      | -7.757    | -8.362    | -0.05964  | -5.144    | 2.804     | 1.664     |
# Train Sharpe Ratio: 1.607, Validation Sharpe Ratio: 1.081
# Debug: L2 penalty: 2.1269069307406743
# Debug: L1 penalty: 0.890331170793611
# Debug: Objective function value (with penalty): 9.896761898465712
# --------------------------------------------------
# | 305       | 9.897     | -10.13    | 1.776     | -17.51    | -3.657    | 0.4331    | 2.92      | -8.083    | -6.823    | -5.978    | 4.388     | -14.9     |
# Train Sharpe Ratio: 1.95, Validation Sharpe Ratio: 1.169
# Debug: L2 penalty: 3.0470628755438245
# Debug: L1 penalty: 1.1360937621566864
# Debug: Objective function value (with penalty): 10.630843362299489
# --------------------------------------------------
# | 306       | 10.63     | -3.712    | 1.202     | -19.9     | -7.799    | -8.485    | -5.171    | -1.96     | -17.49    | -9.307    | -7.27     | 2.917     |
# Train Sharpe Ratio: 0.104, Validation Sharpe Ratio: 0.294
# Debug: L2 penalty: 1.9183999999999997
# Debug: L1 penalty: 0.4316399999999999
# Debug: Objective function value (with penalty): -0.17003999999999986
# --------------------------------------------------
# | 307       | -0.17     | -20.0     | 20.0      | -20.0     | 20.0      | 20.0      | -20.0     | 20.0      | 20.0      | -20.0     | -20.0     | -20.0     |
# Train Sharpe Ratio: 2.265, Validation Sharpe Ratio: 1.066
# Debug: L2 penalty: 2.141032363957703
# Debug: L1 penalty: 0.9372791917765223
# Debug: Objective function value (with penalty): 12.377688444265779
# --------------------------------------------------
# | 308       | 12.38     | 0.388     | 1.46      | -8.518    | -3.04     | -2.162    | -5.107    | 5.795     | -9.312    | -18.24    | 10.89     | 2.464     |
# Train Sharpe Ratio: 2.006, Validation Sharpe Ratio: 1.047
# Debug: L2 penalty: 2.237764312646063
# Debug: L1 penalty: 0.8779131595839522
# Debug: Objective function value (with penalty): 11.190322527769984
# --------------------------------------------------
# | 309       | 11.19     | -11.95    | -4.997    | -19.48    | -1.086    | 0.006253  | -10.9     | 0.1909    | 5.023     | -5.423    | 7.607     | -1.52     |
# Train Sharpe Ratio: 2.258, Validation Sharpe Ratio: 0.413
# Debug: L2 penalty: 2.3706267593690553
# Debug: L1 penalty: 0.9522083383641037
# Debug: Objective function value (with penalty): 8.187164902266842
# --------------------------------------------------
# | 310       | 8.187     | 12.47     | -6.174    | -12.49    | -2.513    | 16.76     | -13.5     | -6.332    | -3.397    | -3.464    | 3.094     | 11.73     |
# Train Sharpe Ratio: 2.121, Validation Sharpe Ratio: 1.045
# Debug: L2 penalty: 2.359703198616521
# Debug: L1 penalty: 1.016152785335683
# Debug: Objective function value (with penalty): 11.378144016047797
# --------------------------------------------------
# | 311       | 11.38     | 0.1883    | -7.918    | -16.14    | -5.748    | 10.13     | -10.26    | -1.919    | 3.562     | 1.719     | 5.184     | -13.76    |
# Train Sharpe Ratio: 2.101, Validation Sharpe Ratio: 1.201
# Debug: L2 penalty: 2.2257679829128874
# Debug: L1 penalty: 1.072024069827308
# Debug: Objective function value (with penalty): 12.312207947259804
# --------------------------------------------------
# | 312       | 12.31     | 5.108     | 3.534     | -14.16    | -8.344    | -10.67    | -2.287    | -1.085    | -5.087    | -13.07    | 7.759     | -5.201    |
# Train Sharpe Ratio: 2.564, Validation Sharpe Ratio: 0.632
# Debug: L2 penalty: 1.1862493216718297
# Debug: L1 penalty: 0.7251289621931919
# Debug: Objective function value (with penalty): 12.136621716134979
# --------------------------------------------------
# | 313       | 12.14     | 1.716     | -7.229    | -7.136    | 0.7689    | 4.638     | -6.52     | 9.594     | 0.3181    | -6.185    | 10.71     | -2.542    |
# Train Sharpe Ratio: 0.782, Validation Sharpe Ratio: 0.679
# Debug: L2 penalty: 6.33776
# Debug: L1 penalty: 1.425996
# Debug: Objective function value (with penalty): -0.5617559999999995
# --------------------------------------------------
# | 314       | -0.5618   | -20.0     | -20.0     | -20.0     | -20.0     | 20.0      | 20.0      | -20.0     | 20.0      | -20.0     | -20.0     | -20.0     |
# Train Sharpe Ratio: 1.989, Validation Sharpe Ratio: 0.998
# Debug: L2 penalty: 1.9346600006379135
# Debug: L1 penalty: 0.8855814887434292
# Debug: Objective function value (with penalty): 11.123758510618657
# --------------------------------------------------
# | 315       | 11.12     | -1.691    | -5.088    | -15.48    | 1.792     | -1.584    | -12.77    | 1.823     | 5.419     | -11.51    | 5.86      | -7.547    |
# Train Sharpe Ratio: 2.62, Validation Sharpe Ratio: 1.144
# Debug: L2 penalty: 2.8617264155270266
# Debug: L1 penalty: 1.0947322174721097
# Debug: Objective function value (with penalty): 13.387541367000864
# --------------------------------------------------
# | 316       | 13.39     | -0.8072   | -5.497    | -19.12    | -0.4762   | 7.334     | -16.9     | 4.999     | -3.679    | 1.811     | 3.734     | -5.781    |
# Train Sharpe Ratio: 2.19, Validation Sharpe Ratio: 0.931
# Debug: L2 penalty: 3.0824819314186374
# Debug: L1 penalty: 1.2327810670866481
# Debug: Objective function value (with penalty): 10.030737001494714
# --------------------------------------------------
# | 317       | 10.03     | -12.02    | -4.32     | -15.67    | 2.588     | 11.25     | 5.928     | 1.464     | -10.38    | -8.915    | 16.2      | 6.747     |
# Train Sharpe Ratio: 2.058, Validation Sharpe Ratio: 0.905
# Debug: L2 penalty: 0.6954231641885676
# Debug: L1 penalty: 0.5436631528043946
# Debug: Objective function value (with penalty): 12.422913683007037
# --------------------------------------------------
# | 318       | 12.42     | -1.049    | -5.069    | -8.137    | -0.6221   | 7.85      | 3.493     | 3.2       | -7.323    | -2.509    | -4.033    | -0.9301   |
# Train Sharpe Ratio: 2.737, Validation Sharpe Ratio: 1.29
# Debug: L2 penalty: 1.8794101545519433
# Debug: L1 penalty: 1.0141067659462404
# Debug: Objective function value (with penalty): 15.794483079501815
# --------------------------------------------------
# | 319       | 15.79     | -0.6135   | -1.806    | -16.1     | -6.901    | -5.176    | -7.428    | -4.52     | 2.835     | -6.158    | 6.06      | 2.696     |
# Train Sharpe Ratio: 2.571, Validation Sharpe Ratio: 0.937
# Debug: L2 penalty: 2.921342277681344
# Debug: L1 penalty: 1.201511767449804
# Debug: Objective function value (with penalty): 11.783145954868855
# --------------------------------------------------
# | 320       | 11.78     | 5.054     | -6.753    | -18.46    | -6.437    | -6.959    | 0.4029    | -15.87    | -5.733    | -3.059    | 5.767     | 9.439     |
# =============================================================================================================================================================
# Optimal Weights: {'chaikin_money_flow': -1.697566003618114, 'commodity_channel_index': 2.63298068628799, 'ichimoku': -15.210999990711741, 'macd': -4.3184416305031945, 'on_balance_volume': 1.801076438077768, 'relative_strength_index': -1.987566696300462, 'stochastic_oscillator': 7.034615005095066, 'trend_5_20': -9.08187249866745, 'volatility_20': -11.548659198226305, 'volume': 10.299394203266733, 'williams_r': 5.266552879824356}
# Test Set Sharpe Ratio: 0.17
