# %%
import pandas as pd
import numpy as np

import datetime
import os, sys
import importlib

import utils
importlib.reload(utils)

from utils import plot_series, plot_series_with_names, plot_series_bar
from utils import plot_dataframe
from utils import get_universe_adjusted_series, scale_weights_to_one, scale_to_book_long_short
from utils import generate_portfolio, backtest_portfolio
from utils import match_implementations

import plotly.graph_objects as go

# %%
# This directory can be used if you're working on a Kaggle Notebook inside the competition
# Change the directory as per your requirements if you're working somewhere else
data_dir = "/kaggle/input/qrt-quant-quest-iit-bombay-2025/"

features = pd.read_parquet(os.path.join(data_dir, "features.parquet"))

universe = pd.read_parquet(os.path.join(data_dir, "universe.parquet"))
 
returns = pd.read_parquet(os.path.join(data_dir, "returns.parquet"))

# %%
train_features = features.loc["2005":"2015"]
validation_features = features.loc["2016":"2018"]
test_features = features.loc["2019"]

train_universe = universe.loc["2005":"2015"]
validation_universe = universe.loc["2016":"2018"]
test_universe = universe.loc["2019"]

train_returns = returns.loc["2005":"2015"]
validation_returns = returns.loc["2016":"2018"]
test_returns = returns.loc["2019"]

# %%
def backtest_portfolio_new(portfolio: pd.DataFrame, returns: pd.DataFrame, universe: pd.DataFrame, plot_: bool, print_: bool):

    """
    Computes performance metrics from a given portfolio DataFrame.

    This function calculates the net Sharpe ratio, along with other portfolio metrics,
    ensuring that certain constraints are met. It performs checks for:
    - Shape alignment of input DataFrames.
    - portfolio weights only in stocks that are part of the universe.
    - Dollar neutrality.
    - Unit capital constraint.
    - Maximum weight constraint.

    Parameters:
    ----------
    portfolio : pd.DataFrame
        DataFrame representing portfolio over time.
    returns : pd.DataFrame
        DataFrame containing stock returns corresponding to the portfolio.
    universe : pd.DataFrame
        Boolean DataFrame indicating whether a stock is part of the investable universe.
    plot_: bool
        Boolean Flag which decides whether to plot the cumulative PnL
    print_: bool
        Boolean Flag which decides whether to print the metrics of backtest

    Raises:
    ------
    ValueError
        If the input DataFrames do not have matching shapes.
        If portfolio contain stocks that are not in the universe.
        If the portfolio violates the dollar neutrality constraint.
        If the unit capital constraint is violated.
        If the maximum weight constraint is exceeded.

    Returns
    -------
    tuple
        - Net Sharpe Ratio (rounded to 3 decimal places).
        - Pandas Series containing gross PnL over time.

    Additional Outputs:
    -------------------
    - Prints the gross and net Sharpe ratios.
    - Prints the turnover percentage.
    - Plots cumulative Gross and Net PnL.

    Notes:
    ------
    - The turnover is calculated as the average traded capital divided by the average book value.
    - The gross and net Sharpe ratios are annualized using a factor of √252.
    - The net PnL accounts for trading costs (assumed to be 0.01% per unit traded).
    """

    universe = universe.astype(bool)
    
    if not (portfolio.shape == returns.shape == universe.shape):
        raise ValueError("Shapes of portfolio, returns and universe are not algined")

    if ((portfolio.replace(0, np.nan))[~universe].notna().sum().sum() != 0):
        raise ValueError("Your portfolio are present for a stock not present in the universe")

    if ((portfolio.sum(1).abs() > 0.01).sum() > 0):
        raise ValueError("Dollar Neutral Constraint is violated")
    
    if (((portfolio.abs().sum(1) - 1) > 0.01).sum() > 0):
        raise ValueError("Unit Capital Constraint is violated")

    if ((portfolio.abs().max(1) > 0.1).sum() > 0):
        raise ValueError("Maximum Weight Constraint is violated")

    portfolio = portfolio.fillna(0)

    rets = returns.fillna(0)

    gross_pnl = (portfolio * rets).sum(axis=1)

    traded = portfolio.diff(1).abs().sum(axis=1).fillna(0)

    net_pnl = gross_pnl - traded * 1e-4

    gross_sharpe_ratio = (gross_pnl.mean() / gross_pnl.std()) * np.sqrt(252)

    net_sharpe_ratio = (net_pnl.mean() / net_pnl.std()) * np.sqrt(252)

    if print_:
        print("Gross Sharpe Ratio: ", round(gross_sharpe_ratio, 3))
        print("Net Sharpe Ratio: ", round(net_sharpe_ratio, 3))

    return round(net_sharpe_ratio, 3), gross_pnl

# %%
def normalize_signal(feature, universe_boolean):
    """
    Normalize a feature signal for a given universe.
    """
    signal = feature.shift(1)  # Avoid lookahead bias
    signal = signal.where(universe_boolean, np.nan)
    signal = signal.rank(axis=1, method="min", ascending=True)
    signal = signal.sub(signal.mean(axis=1), axis=0)
    signal = signal.div(signal.abs().sum(axis=1), axis=0)
    return signal

def generate_portfolio_vectorized(features, universe, weights):
    """
    Generate portfolio weights using a vectorized approach.
    """
    universe_boolean = universe.astype(bool)
    
    # Combine signals into a portfolio
    portfolio_weights = pd.DataFrame(0, index=features.index, columns=features.columns.get_level_values(1).unique())
    
    for i, feature_name in enumerate(features.columns.levels[0]):
        feature_data = features[feature_name]
        normalized_signal = normalize_signal(feature_data, universe_boolean)
        portfolio_weights += normalized_signal * weights[i]
    
    # Enforce dollar neutrality and normalize weights to sum to 1 per day
    portfolio_weights = portfolio_weights.sub(portfolio_weights.mean(axis=1), axis=0)
    portfolio_weights = portfolio_weights.div(portfolio_weights.abs().sum(axis=1), axis=0)
    
    return portfolio_weights.fillna(0)

# %%
initial_weights = {
   'accumulation_distribution_index': -10.0,
   'aroon': -0.09222290817164171,
   'average_true_range': -10.0,
   'chaikin_money_flow': -10.0,
   'chande_momentum_oscillator': 3.318011135314672,
   'commodity_channel_index': 10.0,
   'ease_of_movement': 5.821824288780287,
   'ichimoku': -10.0,
   'know_sure_thing': 10.0,
   'macd': -3.867991947270643,
   'on_balance_volume': 1.8025161396173899,
   'relative_strength_index': 0.6147723614862542,
   'stochastic_oscillator': -10.0,
   'trend_1_3': 10.0,
   'trend_20_60': -10.0,
   'trend_5_20': -10.0,
   'trix': -0.8681094745966318,
   'ultimate_oscillator': 1.3625158710488225,
   'volatility_20': 10.0,
   'volatility_60': -10.0,
   'volume': 10.0,
   'williams_r': -6.987324378181491
}

# Define Bayesian Optimization function
def optimize_signal_weights_bayesian(features_train, features_validation, universe_train, universe_validation, returns_train, returns_validation):
    
    def sharpe_ratio_objective(**weights):
        weight_array = np.array([weights[key] for key in sorted(weights.keys())])
        
        # Generate portfolio weights for training set
        portfolio_weights_train = generate_portfolio_vectorized(features_train, universe_train, weight_array)
        
        # Backtest on training data
        sr_train, _ = backtest_portfolio_new(portfolio_weights_train, returns_train, universe_train,False,False)
        # print(f"Debug: Sharpe ratio calculated: {sr_train}")
        # Validate on validation set
        portfolio_weights_validation = generate_portfolio_vectorized(features_validation, universe_validation, weight_array)
        sr_validation, _ = backtest_portfolio_new(portfolio_weights_validation, returns_validation, universe_validation,False,False)
        print(f"Train Sharpe Ratio: {sr_train}, Validation Sharpe Ratio: {sr_validation}")
        # Add penalties to prevent overfitting
        alpha = 0.7  # Weight for training Sharpe ratio (adjust as needed)
        combined_sharpe_ratio = alpha * sr_train + (1 - alpha) * sr_validation
        
        # Add penalties to prevent overfitting
        penalty_l2 = np.sum(np.square(weight_array)) * combined_sharpe_ratio * 0.0005
        penalty_l1 = np.sum(np.abs(weight_array)) * combined_sharpe_ratio * 0.001
        
        result = combined_sharpe_ratio * 10 - penalty_l2 - penalty_l1
        print(f"Debug: L2 penalty: {penalty_l2}")
        print(f"Debug: L1 penalty: {penalty_l1}")
        
        print(f"Debug: Objective function value (with penalty): {result}")
        print("-" * 50)
        return result
    
    pbounds = {feature: (-20, 20) for feature in features_train.columns.levels[0]}
    
    optimizer = BayesianOptimization(
        f=sharpe_ratio_objective,
        pbounds=pbounds,
        random_state=42
    )
    
    optimizer.maximize(init_points=20, n_iter=250)
    
    optimal_weights = optimizer.max['params']
    
    return optimal_weights

# Run Bayesian Optimization using train/validation split
optimal_weights = optimize_signal_weights_bayesian(
    train_features,
    validation_features,
    train_universe,
    validation_universe,
    train_returns,
    validation_returns
)

# Evaluate on test set
portfolio_weights_test = generate_portfolio_vectorized(test_features, test_universe, np.array(list(optimal_weights.values())))
sr_test, _ = backtest_portfolio_new(portfolio_weights_test, test_returns, test_universe)

print("Optimal Weights:", optimal_weights)
print("Test Set Sharpe Ratio:", sr_test)
# Out:
# |   iter    |  target   | accumu... |   aroon   | averag... | chaiki... | chande... | commod... | ease_o... | ichimoku  | know_s... |   macd    | on_bal... | relati... | stocha... | trend_1_3 | trend_... | trend_... |   trix    | ultima... | volati... | volati... |  volume   | willia... |
# -------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------
# Train Sharpe Ratio: -0.538, Validation Sharpe Ratio: -0.432
# Debug: L2 penalty: -0.8006102263438701
# Debug: L1 penalty: -0.11917956704397133
# Debug: Objective function value (with penalty): -4.142210206612157
# --------------------------------------------------
# | 1         | -4.142    | -5.018    | 18.03     | 9.28      | 3.946     | -13.76    | -13.76    | -17.68    | 14.65     | 4.045     | 8.323     | -19.18    | 18.8      | 13.3      | -11.51    | -12.73    | -12.66    | -7.83     | 0.9903    | -2.722    | -8.351    | 4.474     | -14.42    |
# Train Sharpe Ratio: -0.728, Validation Sharpe Ratio: -0.959
# Debug: L2 penalty: -1.2989405319270875
# Debug: L1 penalty: -0.1825982754529749
# Debug: Objective function value (with penalty): -6.491461192619937
# --------------------------------------------------
# | 2         | -6.491    | -8.314    | -5.346    | -1.757    | 11.41     | -12.01    | 0.5694    | 3.697     | -18.14    | 4.302     | -13.18    | -17.4     | 17.96     | 18.63     | 12.34     | -7.815    | -16.09    | 7.369     | -2.394    | -15.12    | -0.1929   | -18.62    | 16.37     |
# Train Sharpe Ratio: 0.548, Validation Sharpe Ratio: -0.848
# Debug: L2 penalty: 0.18573169692962002
# Debug: L1 penalty: 0.028379862587124674
# Debug: Objective function value (with penalty): 1.077888440483255
# --------------------------------------------------
# | 3         | 1.078     | -9.649    | 6.501     | -7.532    | 0.8027    | 1.868     | -12.61    | 18.78     | 11.01     | 17.58     | 15.79     | 3.916     | 16.87     | -16.46    | -12.16    | -18.19    | -6.987    | -4.453    | -9.146    | 13.15     | -5.73     | -8.763    | 1.708     |
# Train Sharpe Ratio: -0.094, Validation Sharpe Ratio: -0.352
# Debug: L2 penalty: -0.29743240477738964
# Debug: L1 penalty: -0.04414424859934946
# Debug: Objective function value (with penalty): -1.372423346623261
# --------------------------------------------------
# | 4         | -1.372    | -14.36    | 12.09     | -17.02    | 19.48     | 10.89     | -12.05    | -19.78    | 12.62     | 8.274     | 9.16      | 10.85     | -17.04    | -5.661    | -15.37    | 14.52     | 4.932     | -6.764    | -17.46    | -7.561    | -6.993    | 9.184     | 5.502     |
# Train Sharpe Ratio: 1.172, Validation Sharpe Ratio: 0.214
# Debug: L2 penalty: 1.201894473132863
# Debug: L1 penalty: 0.1792774153499906
# Debug: Objective function value (with penalty): 7.464828111517146
# --------------------------------------------------
# | 5         | 7.465     | 15.49     | -1.111    | -15.22    | 8.53      | 10.43     | 2.451     | 10.84     | -0.2482   | 0.9093    | -2.898    | -18.98    | -15.68    | -18.74    | 5.456     | -7.426    | 0.3428    | 16.3      | -10.03    | -3.585    | 10.22     | -10.85    | -16.92    |
# Train Sharpe Ratio: -0.577, Validation Sharpe Ratio: -0.759
# Debug: L2 penalty: -1.018077502659061
# Debug: L1 penalty: -0.15168929299718437
# Debug: Objective function value (with penalty): -5.146233204343754
# --------------------------------------------------
# | 6         | -5.146    | -8.41     | -13.55    | 17.19     | 12.32     | 5.336     | 14.86     | 12.15     | -12.54    | 15.7      | 1.574     | 12.3      | 15.84     | -7.28     | -15.6     | -10.88    | -2.916    | 12.72     | 14.43     | -19.72    | 0.4299    | -3.304    | -11.12    |
# Train Sharpe Ratio: -0.207, Validation Sharpe Ratio: -0.144
# Debug: L2 penalty: -0.2828777817585748
# Debug: L1 penalty: -0.04062563891844593
# Debug: Objective function value (with penalty): -1.5574965793229791
# --------------------------------------------------
# | 7         | -1.557    | -15.21    | -6.495    | 17.72     | -7.072    | 0.7516    | 8.121     | -5.455    | 18.87     | 18.5      | -9.929    | -0.1101   | -7.965    | -8.606    | -18.52    | 4.383     | 0.1072    | -17.94    | -8.854    | 16.33     | -10.42    | -14.2     | -0.4219   |
# Train Sharpe Ratio: 0.304, Validation Sharpe Ratio: 0.169
# Debug: L2 penalty: 0.35258186208210257
# Debug: L1 penalty: 0.05593544663961607
# Debug: Objective function value (with penalty): 2.2264826912782816
# --------------------------------------------------
# | 8         | 2.226     | 19.43     | -10.32    | 6.885     | 10.46     | -10.49    | 9.129     | -5.289    | 5.292     | 5.341     | 1.431     | -16.39    | 13.41     | -7.169    | -12.54    | -18.37    | 3.636     | 7.103     | -19.34    | 0.4837    | -10.94    | 5.807     | -13.03    |
# Train Sharpe Ratio: -1.582, Validation Sharpe Ratio: -1.0
# Debug: L2 penalty: -2.120112037587224
# Debug: L1 penalty: -0.32570767623059804
# Debug: Objective function value (with penalty): -11.628180286182177
# --------------------------------------------------
# | 9         | -11.63    | 7.638     | -4.531    | 17.47     | -14.5     | -6.357    | -15.46    | 16.99     | 15.09     | -9.682    | 6.399     | 12.69     | 2.208     | 1.186     | -10.33    | -16.28    | 15.89     | 16.02     | 5.324     | -6.439    | -6.032    | 9.038     | 15.88     |
# Train Sharpe Ratio: 0.633, Validation Sharpe Ratio: -0.227
# Debug: L2 penalty: 0.5941121169550572
# Debug: L1 penalty: 0.09027556218281876
# Debug: Objective function value (with penalty): 3.065612320862124
# --------------------------------------------------
# | 10        | 3.066     | 15.48     | 11.2      | 5.681     | -16.63    | -13.53    | 15.94     | 4.257     | -19.63    | -15.94    | 6.54      | -19.8     | -13.57    | 1.949     | 7.676     | 6.078     | -11.03    | 8.487     | -10.51    | -6.984    | 9.86      | 5.985     | 13.97     |
# Train Sharpe Ratio: 0.584, Validation Sharpe Ratio: -0.604
# Debug: L2 penalty: 0.32299292339380276
# Debug: L1 penalty: 0.04848008447287807
# Debug: Objective function value (with penalty): 1.904526992133318
# --------------------------------------------------
# | 11        | 1.905     | 6.305     | 2.732     | -16.25    | -5.291    | -9.392    | -10.24    | 18.92     | -4.276    | 15.68     | 5.246     | 11.79     | 0.1055    | 3.076     | -0.2993   | -12.19    | 8.898     | -8.769    | -19.03    | 5.819     | -12.92    | 17.62     | 18.16     |
# Train Sharpe Ratio: -0.936, Validation Sharpe Ratio: -1.114
# Debug: L2 penalty: -1.799530517368086
# Debug: L1 penalty: -0.2431161698831004
# Debug: Objective function value (with penalty): -7.851353312748815
# --------------------------------------------------
# | 12        | -7.851    | 16.59     | -5.194    | -19.38    | 17.13     | -2.873    | 18.67     | 18.54     | 14.12     | -8.222    | -4.596    | 14.05     | -7.323    | -13.22    | 2.272     | 17.45     | 7.841     | 2.802     | -16.11    | 4.6       | 19.6      | -14.4     | 0.7332    |
# Train Sharpe Ratio: -1.363, Validation Sharpe Ratio: -1.363
# Debug: L2 penalty: -1.8100290403115906
# Debug: L1 penalty: -0.2915733116619431
# Debug: Objective function value (with penalty): -11.528397648026464
# --------------------------------------------------
# | 13        | -11.53    | 15.09     | 9.631     | 7.881     | 8.099     | -5.62     | -8.256    | 12.37     | 12.4      | 14.68     | 16.53     | 0.4537    | 0.06065   | 11.93     | 5.999     | 8.079     | 11.83     | 15.6      | -6.48     | -4.977    | -16.24    | 3.131     | -18.56    |
# Train Sharpe Ratio: 0.996, Validation Sharpe Ratio: 0.666
# Debug: L2 penalty: 1.1674323564929565
# Debug: L1 penalty: 0.17279175117914508
# Debug: Objective function value (with penalty): 7.629775892327899
# --------------------------------------------------
# | 14        | 7.63      | -1.376    | 1.706     | -8.538    | 3.633     | -18.78    | -18.51    | 12.9      | -5.592    | -14.92    | 0.8897    | 10.8      | -11.37    | 4.916     | -16.59    | -17.93    | 1.254     | 1.625     | 5.497     | 9.044     | 19.03     | 0.652     | -7.082    |
# Train Sharpe Ratio: 0.012, Validation Sharpe Ratio: -0.135
# Debug: L2 penalty: -0.043110160430775105
# Debug: L1 penalty: -0.006834530341842295
# Debug: Objective function value (with penalty): -0.27105530922738275
# --------------------------------------------------
# | 15        | -0.2711   | 11.81     | -9.167    | -2.441    | -16.86    | -18.99    | 18.51     | 13.44     | 7.839     | -3.642    | -13.07    | -13.74    | -9.99     | 1.969     | 8.584     | 6.408     | -8.803    | 18.19     | 9.516     | 2.174     | 4.469     | -3.216    | -10.09    |
# Train Sharpe Ratio: 1.317, Validation Sharpe Ratio: 0.57
# Debug: L2 penalty: 1.5187328502570752
# Debug: L1 penalty: 0.21935174270326038
# Debug: Objective function value (with penalty): 9.190915407039665
# --------------------------------------------------
# | 16        | 9.191     | -5.761    | 10.31     | -19.42    | -15.36    | -18.16    | -18.37    | 14.22     | 8.146     | -1.033    | -16.09    | -0.3354   | -1.061    | -13.07    | -2.646    | -4.06     | 4.634     | 5.404     | -18.19    | -5.015    | 5.034     | 0.1255    | 14.26     |
# Train Sharpe Ratio: -1.044, Validation Sharpe Ratio: -0.56
# Debug: L2 penalty: -1.6277047339133324
# Debug: L1 penalty: -0.2197161735276541
# Debug: Objective function value (with penalty): -7.140579092559013
# --------------------------------------------------
# | 17        | -7.141    | 6.348     | -13.48    | -17.18    | 5.697     | -18.94    | 3.431     | 17.61     | 3.019     | -4.473    | 5.732     | -1.67     | 1.825     | 17.66     | -4.556    | 18.45     | 16.21     | -12.17    | -17.23    | -15.97    | -19.27    | -16.22    | 7.32      |
# Train Sharpe Ratio: -1.304, Validation Sharpe Ratio: -1.055
# Debug: L2 penalty: -2.026603115487803
# Debug: L1 penalty: -0.307708712545447
# Debug: Objective function value (with penalty): -9.95868817196675
# --------------------------------------------------
# | 18        | -9.959    | -17.15    | -7.241    | 13.8      | -19.07    | 12.58     | -8.726    | -15.27    | 7.869     | 5.158     | 15.1      | 9.403     | 12.14     | -8.719    | -12.9     | 10.02     | 12.27     | 19.62     | -3.495    | -5.119    | 11.06     | -6.368    | 17.23     |
# Train Sharpe Ratio: -2.591, Validation Sharpe Ratio: -1.365
# Debug: L2 penalty: -3.5481369445637214
# Debug: L1 penalty: -0.5132755976940796
# Debug: Objective function value (with penalty): -18.1705874577422
# --------------------------------------------------
# | 19        | -18.17    | 14.34     | -2.84     | 10.03     | 10.18     | -15.88    | 16.1      | 0.2101    | 13.06     | -7.198    | 15.82     | -4.432    | -19.57    | 16.22     | -16.35    | -7.227    | 18.0      | 18.02     | 2.938     | 5.273     | -2.062    | -8.272    | -6.853    |
# Train Sharpe Ratio: 0.462, Validation Sharpe Ratio: 0.395
# Debug: L2 penalty: 0.7199462578533795
# Debug: L1 penalty: 0.10635813057649794
# Debug: Objective function value (with penalty): 3.592695611570123
# --------------------------------------------------
# | 20        | 3.593     | 6.901     | 10.09     | 11.66     | 11.58     | -16.35    | -0.2232   | -17.7     | 1.981     | -2.339    | 15.51     | -5.963    | -15.32    | -14.28    | 10.46     | 4.729     | -15.96    | -16.64    | 8.039     | -17.09    | 12.87     | 8.25      | -16.75    |
# Train Sharpe Ratio: 1.533, Validation Sharpe Ratio: 0.813
# Debug: L2 penalty: 1.9610065129829217
# Debug: L1 penalty: 0.2987486219259992
# Debug: Objective function value (with penalty): 10.91024486509108
# --------------------------------------------------
# | 21        | 10.91     | 2.989     | 7.686     | -20.0     | -6.399    | -13.19    | -16.41    | 9.776     | -9.786    | -4.821    | -11.57    | -10.65    | -13.5     | -20.0     | -3.522    | -17.89    | -9.408    | -2.19     | -12.95    | 2.708     | 16.24     | 6.551     | -8.591    |
# Train Sharpe Ratio: -1.613, Validation Sharpe Ratio: -1.184
# Debug: L2 penalty: -2.457582916773039
# Debug: L1 penalty: -0.36575350387357763
# Debug: Objective function value (with penalty): -12.019663579353384
# --------------------------------------------------
# | 22        | -12.02    | -8.757    | -5.354    | -5.328    | 8.452     | -19.54    | 17.83     | -15.38    | 14.43     | 10.14     | 2.496     | -14.73    | 19.71     | 15.07     | 7.271     | 9.814     | 10.88     | 14.08     | 11.73     | 11.85     | 12.2      | -11.3     | 0.0778    |
# Train Sharpe Ratio: -0.664, Validation Sharpe Ratio: -1.083
# Debug: L2 penalty: -1.2460679527119871
# Debug: L1 penalty: -0.1780778705709121
# Debug: Objective function value (with penalty): -6.4728541767171
# --------------------------------------------------
# | 23        | -6.473    | -4.149    | 9.876     | -5.076    | 15.93     | -1.627    | -12.0     | 3.443     | -15.37    | -13.05    | 16.0      | -1.093    | -17.45    | -0.2364   | 15.2      | 12.72     | 16.02     | 10.12     | -11.39    | -3.705    | 19.67     | 2.815     | 18.55     |
# Train Sharpe Ratio: -0.808, Validation Sharpe Ratio: -0.804
# Debug: L2 penalty: -1.282083713369528
# Debug: L1 penalty: -0.18511423928437162
# Debug: Objective function value (with penalty): -6.600802047346102
# --------------------------------------------------
# | 24        | -6.601    | 11.68     | 14.68     | -11.89    | 19.79     | 14.93     | 2.302     | 7.894     | 0.723     | 5.172     | -16.86    | 8.869     | -5.743    | 7.986     | -6.956    | 1.749     | 18.1      | -17.83    | -12.29    | -2.114    | -15.46    | 19.34     | -7.081    |
# Train Sharpe Ratio: 0.303, Validation Sharpe Ratio: 0.063
# Debug: L2 penalty: 0.34106029683060807
# Debug: L1 penalty: 0.048601032578257354
# Debug: Objective function value (with penalty): 1.9203386705911343
# --------------------------------------------------
# | 25        | 1.92      | 5.936     | 2.867     | -3.21     | -0.1664   | 11.91     | -14.25    | 14.08     | 3.377     | 9.162     | -14.04    | 9.455     | -19.3     | -1.696    | 9.83      | -17.94    | 11.14     | -18.55    | -4.899    | -19.53    | -1.002    | 17.47     | -0.5798   |
# Train Sharpe Ratio: -1.911, Validation Sharpe Ratio: -1.566
# Debug: L2 penalty: -2.878721049740101
# Debug: L1 penalty: -0.41437955597869147
# Debug: Objective function value (with penalty): -14.781899394281211
# --------------------------------------------------
# | 26        | -14.78    | 17.47     | -3.715    | -3.444    | 12.05     | 8.264     | -6.353    | 17.42     | 2.573     | -15.01    | -1.605    | -19.68    | -8.01     | -15.11    | 12.78     | -0.6837   | 17.53     | 11.83     | 2.022     | 9.415     | -10.74    | 16.15     | 17.42     |
# Train Sharpe Ratio: 1.524, Validation Sharpe Ratio: 0.746
# Debug: L2 penalty: 2.9437341573342146
# Debug: L1 penalty: 0.3606424205336819
# Debug: Objective function value (with penalty): 9.601623422132104
# --------------------------------------------------
# | 27        | 9.602     | 13.75     | 0.7438    | -20.0     | -20.0     | -11.72    | -5.247    | 5.437     | -1.676    | 14.36     | -9.687    | -5.281    | -16.57    | -20.0     | -7.731    | -20.0     | -20.0     | 2.591     | -20.0     | -20.0     | 13.4      | -11.25    | -20.0     |
# Train Sharpe Ratio: 0.487, Validation Sharpe Ratio: 0.286
# Debug: L2 penalty: 0.5698110386846287
# Debug: L1 penalty: 0.08240604844011952
# Debug: Objective function value (with penalty): 3.6147829128752513
# --------------------------------------------------
# | 28        | 3.615     | 17.43     | 2.107     | 2.772     | -16.35    | -16.56    | 7.235     | 3.172     | -19.07    | -8.004    | 0.9511    | -15.22    | -14.09    | -1.959    | 0.3348    | -1.016    | -3.49     | 11.58     | -1.493    | 5.582     | 17.33     | -17.71    | 9.672     |
# Train Sharpe Ratio: 1.471, Validation Sharpe Ratio: 0.256
# Debug: L2 penalty: 2.1016870330225186
# Debug: L1 penalty: 0.2918842286604622
# Debug: Objective function value (with penalty): 8.67142873831702
# --------------------------------------------------
# | 29        | 8.671     | 4.741     | -9.807    | -12.69    | 14.83     | 17.62     | 11.5      | 15.81     | -0.7298   | -11.97    | -12.89    | -18.44    | -11.89    | -14.83    | 15.34     | -15.94    | -9.611    | 19.41     | -13.09    | -0.3424   | 3.334     | -10.35    | -18.63    |
# Train Sharpe Ratio: 1.203, Validation Sharpe Ratio: 0.648
# Debug: L2 penalty: 1.1873541480127847
# Debug: L1 penalty: 0.20335296261542415
# Debug: Objective function value (with penalty): 8.97429288937179
# --------------------------------------------------
# | 30        | 8.974     | -8.3      | 6.88      | -10.1     | -8.631    | -14.39    | -18.64    | 10.6      | -4.006    | -8.46     | -8.401    | -2.157    | -0.9912   | -12.88    | -8.671    | -4.948    | -6.579    | -10.19    | -0.9776   | 13.39     | 18.26     | 15.1      | 3.638     |
# Train Sharpe Ratio: 0.74, Validation Sharpe Ratio: 0.162
# Debug: L2 penalty: 0.877322926906447
# Debug: L1 penalty: 0.13902569651618063
# Debug: Objective function value (with penalty): 4.649651376577372
# --------------------------------------------------
# | 31        | 4.65      | -12.81    | -11.17    | 19.16     | -14.18    | -11.82    | -4.099    | 7.888     | 10.54     | 11.87     | 12.47     | -10.25    | 15.89     | -16.31    | 4.621     | -12.21    | -13.81    | -8.693    | -4.194    | 16.58     | -9.789    | -5.328    | -11.69    |
# Train Sharpe Ratio: 0.305, Validation Sharpe Ratio: 0.47
# Debug: L2 penalty: 0.6130975671502468
# Debug: L1 penalty: 0.0899024395897524
# Debug: Objective function value (with penalty): 2.841999993260001
# --------------------------------------------------
# | 32        | 2.842     | -18.12    | 5.563     | 8.245     | -11.51    | 2.019     | -4.471    | -10.69    | 4.462     | -13.87    | -17.83    | 13.57     | -10.32    | 18.14     | -10.07    | -14.33    | 14.38     | -16.95    | -11.9     | 17.74     | -12.83    | -13.37    | -3.222    |
# Train Sharpe Ratio: 1.308, Validation Sharpe Ratio: 0.763
# Debug: L2 penalty: 3.538657252289737
# Debug: L1 penalty: 0.3986635008998348
# Debug: Objective function value (with penalty): 7.507679246810429
# --------------------------------------------------
# | 33        | 7.508     | -20.0     | -1.731    | -9.218    | -20.0     | -20.0     | -20.0     | 16.47     | -15.63    | -20.0     | -17.76    | 20.0      | -17.83    | -10.45    | 1.754     | -20.0     | -20.0     | -16.65    | -20.0     | 14.33     | 13.86     | -12.65    | -20.0     |
# Train Sharpe Ratio: 0.102, Validation Sharpe Ratio: -0.063
# Debug: L2 penalty: 0.08366925459387245
# Debug: L1 penalty: 0.011877421677999878
# Debug: Objective function value (with penalty): 0.4294533237281276
# --------------------------------------------------
# | 34        | 0.4295    | 6.194     | 0.1894    | 3.893     | -3.067    | -19.38    | 18.73     | -14.2     | -0.2034   | 2.523     | -9.247    | 15.9      | 19.29     | -13.12    | -13.0     | 3.789     | -15.87    | 9.686     | 10.85     | 16.37     | 16.11     | -10.91    | -3.703    |
# Train Sharpe Ratio: -1.608, Validation Sharpe Ratio: -0.486
# Debug: L2 penalty: -1.5395148745852945
# Debug: L1 penalty: -0.2612335711494166
# Debug: Objective function value (with penalty): -10.913251554265289
# --------------------------------------------------
# | 35        | -10.91    | -2.596    | -5.947    | 5.826     | -9.719    | -16.42    | 5.697     | 9.355     | 17.66     | -7.318    | -7.295    | -7.186    | 1.963     | -11.72    | 9.981     | 9.359     | 12.74     | 4.772     | 11.0      | 5.067     | -18.72    | -18.27    | -6.865    |
# Train Sharpe Ratio: 1.473, Validation Sharpe Ratio: 0.671
# Debug: L2 penalty: 3.7844759128041514
# Debug: L1 penalty: 0.4139381108284204
# Debug: Objective function value (with penalty): 8.125585976367429
# --------------------------------------------------
# | 36        | 8.126     | -12.99    | 20.0      | -20.0     | -20.0     | -20.0     | -20.0     | -4.164    | -6.373    | 2.219     | -20.0     | 20.0      | -20.0     | 1.57      | -20.0     | -20.0     | -20.0     | -11.92    | -20.0     | 4.651     | 20.0      | 12.0      | 20.0      |
# Train Sharpe Ratio: 1.419, Validation Sharpe Ratio: 0.708
# Debug: L2 penalty: 3.263541419195554
# Debug: L1 penalty: 0.38295199254455514
# Debug: Objective function value (with penalty): 8.410506588259892
# --------------------------------------------------
# | 37        | 8.411     | 11.96     | -20.0     | -7.069    | -20.0     | 12.59     | 15.14     | -9.822    | -20.0     | 6.056     | -12.92    | -20.0     | -10.16    | -20.0     | 13.65     | -20.0     | -20.0     | -0.4589   | -20.0     | 15.4      | 20.0      | 2.391     | -20.0     |
# Train Sharpe Ratio: 1.41, Validation Sharpe Ratio: 0.716
# Debug: L2 penalty: 4.221419814874674
# Debug: L1 penalty: 0.44261983112487385
# Debug: Objective function value (with penalty): 7.353960354000453
# --------------------------------------------------
# | 38        | 7.354     | 0.8682    | -20.0     | -20.0     | -20.0     | -20.0     | -18.11    | 20.0      | -6.24     | -6.382    | -20.0     | -20.0     | 15.17     | -20.0     | -20.0     | -20.0     | -20.0     | 20.0      | -20.0     | 19.57     | 20.0      | -1.962    | -20.0     |
# Train Sharpe Ratio: 1.079, Validation Sharpe Ratio: 0.637
# Debug: L2 penalty: 3.661400286800094
# Debug: L1 penalty: 0.37575157159352923
# Debug: Objective function value (with penalty): 5.426848141606378
# --------------------------------------------------
# | 39        | 5.427     | -20.0     | 20.0      | -20.0     | -20.0     | -20.0     | -20.0     | 20.0      | 20.0      | -20.0     | -20.0     | -20.0     | -20.0     | -20.0     | -20.0     | -20.0     | -5.7      | -20.0     | -20.0     | -20.0     | 20.0      | -1.148    | -10.18    |
# Train Sharpe Ratio: 1.777, Validation Sharpe Ratio: 0.69
# Debug: L2 penalty: 4.805518612313294
# Debug: L1 penalty: 0.5320291739517881
# Debug: Objective function value (with penalty): 9.171452213734916
# --------------------------------------------------
# | 40        | 9.171     | -20.0     | 11.19     | -20.0     | -20.0     | -20.0     | -20.0     | 8.012     | -18.02    | 20.0      | -20.0     | 13.88     | -7.116    | -20.0     | 10.4      | -20.0     | 5.251     | 20.0      | -20.0     | 16.9      | 17.57     | 18.34     | -20.0     |
# Train Sharpe Ratio: -0.591, Validation Sharpe Ratio: -0.644
# Debug: L2 penalty: -0.9038521151122563
# Debug: L1 penalty: -0.13604012166018079
# Debug: Objective function value (with penalty): -5.029107763227563
# --------------------------------------------------
# | 41        | -5.029    | -1.336    | 19.51     | 9.968     | 15.9      | 15.37     | -14.06    | -2.236    | -4.258    | -9.87     | 16.03     | -15.12    | -13.93    | -16.34    | -8.388    | -15.69    | -8.304    | -0.4696   | 10.99     | -2.166    | -9.068    | -3.407    | 11.76     |
# Train Sharpe Ratio: -1.811, Validation Sharpe Ratio: -0.827
# Debug: L2 penalty: -2.4582820299985135
# Debug: L1 penalty: -0.35618426559421285
# Debug: Objective function value (with penalty): -12.343533704407271
# --------------------------------------------------
# | 42        | -12.34    | -18.48    | -4.206    | 11.31     | -9.038    | -5.657    | -0.4449   | -5.822    | 11.09     | 18.14     | -15.99    | -2.49     | 18.67     | 18.85     | 3.932     | -1.971    | 11.18     | -14.22    | 15.7      | -7.709    | -14.33    | -13.72    | -12.02    |
# Train Sharpe Ratio: 1.092, Validation Sharpe Ratio: 0.478
# Debug: L2 penalty: 1.097136362801218
# Debug: L1 penalty: 0.18836194325741343
# Debug: Objective function value (with penalty): 7.792501693941368
# --------------------------------------------------
# | 43        | 7.793     | 12.66     | 9.104     | -12.92    | 5.816     | -14.51    | -18.55    | 12.22     | -13.42    | -9.268    | 9.763     | 12.35     | 6.455     | 4.726     | -12.38    | -14.3     | -1.387    | 9.111     | 5.865     | 1.174     | 13.01     | -2.331    | -6.164    |
# Train Sharpe Ratio: -1.751, Validation Sharpe Ratio: -1.383
# Debug: L2 penalty: -2.412560051393451
# Debug: L1 penalty: -0.36926294853268715
# Debug: Objective function value (with penalty): -13.62417700007386
# --------------------------------------------------
# | 44        | -13.62    | 1.529     | 9.28      | 18.19     | 16.68     | -14.97    | -3.955    | 5.827     | 15.5      | 9.892     | 15.61     | 7.327     | 19.63     | 11.29     | -6.005    | -2.904    | 7.496     | 5.635     | -9.376    | 12.45     | -16.71    | -12.77    | -2.061    |
# Train Sharpe Ratio: 1.794, Validation Sharpe Ratio: 0.865
# Debug: L2 penalty: 5.271915630915203
# Debug: L1 penalty: 0.552211931272064
# Debug: Objective function value (with penalty): 9.328872437812734
# --------------------------------------------------
# | 45        | 9.329     | 20.0      | 13.88     | -20.0     | -20.0     | -20.0     | -20.0     | -1.857    | -20.0     | -20.0     | 17.17     | 20.0      | 20.0      | -20.0     | 1.726     | -20.0     | -20.0     | -2.033    | -20.0     | -7.758    | 20.0      | 20.0      | -20.0     |
# Train Sharpe Ratio: -0.29, Validation Sharpe Ratio: -0.074
# Debug: L2 penalty: -0.31992382962270366
# Debug: L1 penalty: -0.04725077054838165
# Debug: Objective function value (with penalty): -1.8848253998289146
# --------------------------------------------------
# | 46        | -1.885    | 19.89     | 2.474     | -0.3742   | -11.82    | -18.26    | 18.64     | -14.15    | -6.198    | -6.487    | 0.8532    | 3.828     | -5.676    | 1.488     | 10.08     | -3.002    | -10.12    | -8.077    | 8.596     | -12.01    | 19.24     | 16.92     | 11.63     |
# Train Sharpe Ratio: 0.005, Validation Sharpe Ratio: -0.756
# Debug: L2 penalty: -0.3235882031680744
# Debug: L1 penalty: -0.04841706749111535
# Debug: Objective function value (with penalty): -1.8609947293408104
# --------------------------------------------------
# | 47        | -1.861    | -8.687    | -13.45    | -9.003    | -17.52    | 6.126     | -13.7     | 19.54     | 17.49     | 11.31     | 2.031     | -8.187    | 5.228     | -0.6932   | 0.7898    | -19.95    | -15.54    | 8.734     | 6.311     | 5.034     | -15.34    | 2.671     | 9.492     |
# Train Sharpe Ratio: 1.592, Validation Sharpe Ratio: 0.952
# Debug: L2 penalty: 4.761451271908279
# Debug: L1 penalty: 0.5140487388409315
# Debug: Objective function value (with penalty): 8.72449998925079
# --------------------------------------------------
# | 48        | 8.724     | -6.93     | -17.81    | -20.0     | -20.0     | -20.0     | -20.0     | -20.0     | -20.0     | 4.494     | 13.65     | 8.501     | -2.825    | -20.0     | -20.0     | -20.0     | -20.0     | -20.0     | -20.0     | 20.0      | -18.31    | 14.65     | -20.0     |
# Train Sharpe Ratio: 1.589, Validation Sharpe Ratio: 0.635
# Debug: L2 penalty: 4.639355717586366
# Debug: L1 penalty: 0.4801957013443258
# Debug: Objective function value (with penalty): 7.908448581069307
# --------------------------------------------------
# | 49        | 7.908     | 20.0      | -16.64    | -20.0     | 1.958     | -20.0     | -20.0     | 20.0      | -20.0     | 2.248     | 20.0      | -20.0     | -5.666    | -20.0     | 20.0      | -20.0     | -20.0     | 20.0      | -20.0     | -20.0     | 20.0      | -2.077    | -20.0     |
# Train Sharpe Ratio: 1.18, Validation Sharpe Ratio: 0.761
# Debug: L2 penalty: 3.676223941288934
# Debug: L1 penalty: 0.3949636169478987
# Debug: Objective function value (with penalty): 6.471812441763166
# --------------------------------------------------
# | 50        | 6.472     | 19.98     | 20.0      | -20.0     | -20.0     | -20.0     | -20.0     | 0.4639    | -20.0     | -5.571    | -20.0     | 16.21     | 17.39     | -11.41    | -20.0     | -20.0     | 13.67     | -17.53    | -20.0     | 20.0      | 20.0      | -12.39    | -20.0     |
# Train Sharpe Ratio: -0.975, Validation Sharpe Ratio: -1.967
# Debug: L2 penalty: -1.6507529180590492
# Debug: L1 penalty: -0.2658689946510907
# Debug: Objective function value (with penalty): -10.809378087289861
# --------------------------------------------------
# | 51        | -10.81    | -10.49    | 17.65     | 4.397     | -8.213    | -16.4     | -8.964    | 17.27     | 11.95     | -14.23    | 16.66     | -1.272    | 15.58     | -0.9342   | 11.91     | 5.529     | -9.037    | 5.674     | -12.37    | 2.25      | -6.186    | -8.849    | 3.111     |
# Train Sharpe Ratio: 1.866, Validation Sharpe Ratio: 0.737
# Debug: L2 penalty: 5.225371420925273
# Debug: L1 penalty: 0.5580846204569335
# Debug: Objective function value (with penalty): 9.489543958617796
# --------------------------------------------------
# | 52        | 9.49      | 20.0      | 12.54     | -20.0     | -15.98    | 20.0      | -20.0     | 20.0      | -20.0     | -20.0     | -20.0     | 9.468     | -16.69    | 0.208     | -14.79    | -20.0     | -20.0     | 20.0      | -20.0     | -15.59    | 20.0      | -0.1417   | -20.0     |
# Train Sharpe Ratio: 0.863, Validation Sharpe Ratio: 0.695
# Debug: L2 penalty: 0.9981666795587819
# Debug: L1 penalty: 0.15305615387445018
# Debug: Objective function value (with penalty): 6.974777166566767
# --------------------------------------------------
# | 53        | 6.975     | 5.471     | -3.113    | -2.322    | -15.53    | -8.81     | -5.828    | -9.451    | 0.3515    | -12.05    | 17.31     | 11.2      | 1.141     | -8.97     | -7.319    | -0.2693   | -13.14    | 1.588     | -0.1227   | 19.88     | -18.55    | -15.53    | -10.42    |
# Train Sharpe Ratio: 1.405, Validation Sharpe Ratio: 0.839
# Debug: L2 penalty: 4.108173682044023
# Debug: L1 penalty: 0.4420173821296503
# Debug: Objective function value (with penalty): 7.801808935826324
# --------------------------------------------------
# | 54        | 7.802     | 20.0      | -2.495    | -20.0     | -14.42    | 0.8957    | -20.0     | -20.0     | -20.0     | -13.88    | -15.28    | 14.62     | -18.23    | -20.0     | 1.869     | -20.0     | -20.0     | 20.0      | -20.0     | 16.15     | -20.0     | -20.0     | -20.0     |
# Train Sharpe Ratio: 0.882, Validation Sharpe Ratio: 0.382
# Debug: L2 penalty: 0.8413515933624933
# Debug: L1 penalty: 0.1375990857284266
# Debug: Objective function value (with penalty): 6.341049320909081
# --------------------------------------------------
# | 55        | 6.341     | -2.77     | 4.008     | -6.776    | -15.65    | -15.27    | -8.554    | 9.714     | 9.074     | -0.474    | -14.66    | 10.43     | 0.6892    | -16.93    | 0.5429    | 16.08     | -2.721    | 2.104     | -10.69    | -10.7     | 2.4       | 13.56     | 14.18     |
# Train Sharpe Ratio: 0.985, Validation Sharpe Ratio: 0.684
# Debug: L2 penalty: 1.1048508169729716
# Debug: L1 penalty: 0.17892564919791504
# Debug: Objective function value (with penalty): 7.663223533829114
# --------------------------------------------------
# | 56        | 7.663     | -0.7797   | 3.928     | -12.78    | 5.063     | -7.318    | -19.8     | 17.87     | -11.85    | -14.1     | -14.48    | 14.22     | -8.016    | -2.059    | -10.46    | -4.334    | 11.13     | 1.814     | 9.034     | 5.675     | 14.89     | -0.9755   | -9.416    |
# Train Sharpe Ratio: 2.022, Validation Sharpe Ratio: 0.892
# Debug: L2 penalty: 5.150772826193004
# Debug: L1 penalty: 0.5712651685890604
# Debug: Objective function value (with penalty): 11.107962005217935
# --------------------------------------------------
# | 57        | 11.11     | 7.871     | 10.11     | -20.0     | -20.0     | -20.0     | -20.0     | 19.0      | -20.0     | 2.873     | -7.801    | 20.0      | -20.0     | -20.0     | -20.0     | 20.0      | -20.0     | 10.5      | -0.7492   | -8.663    | 11.87     | 20.0      | -20.0     |
# Train Sharpe Ratio: 1.028, Validation Sharpe Ratio: 0.313
# Debug: L2 penalty: 0.7730146269548595
# Debug: L1 penalty: 0.1313724472204253
# Debug: Objective function value (with penalty): 7.230612925824715
# --------------------------------------------------
# | 58        | 7.231     | -10.08    | 7.895     | 0.09938   | -16.13    | -5.929    | -15.43    | 6.579     | 7.851     | 1.022     | -6.006    | 3.63      | -0.7225   | -0.01768  | 3.061     | -4.12     | -12.43    | -3.27     | -5.619    | 16.43     | 13.33     | 19.23     | 2.61      |
# Train Sharpe Ratio: -1.144, Validation Sharpe Ratio: -0.741
# Debug: L2 penalty: -1.5759319406754209
# Debug: L1 penalty: -0.23109650313105404
# Debug: Objective function value (with penalty): -8.423971556193523
# --------------------------------------------------
# | 59        | -8.424    | 19.65     | -17.49    | 17.27     | -1.299    | 12.06     | 15.38     | -18.49    | -3.324    | -16.12    | 7.243     | -9.733    | 15.29     | -7.737    | 5.175     | 3.009     | -4.423    | 16.79     | -6.554    | -1.189    | 8.986     | -6.465    | -12.2     |
# Train Sharpe Ratio: -1.018, Validation Sharpe Ratio: -0.174
# Debug: L2 penalty: -1.4302483862177215
# Debug: L1 penalty: -0.1940386458103786
# Debug: Objective function value (with penalty): -6.023712967971901
# --------------------------------------------------
# | 60        | -6.024    | 18.65     | -3.075    | -19.81    | 10.7      | 10.81     | 19.37     | -18.69    | 5.832     | -14.27    | -15.65    | -13.81    | -16.37    | 0.1623    | -13.84    | 1.468     | 17.41     | -7.325    | 5.6       | 3.944     | -8.864    | 17.49     | 10.59     |
# Train Sharpe Ratio: 2.277, Validation Sharpe Ratio: 0.718
# Debug: L2 penalty: 5.3078418944064385
# Debug: L1 penalty: 0.5989048242550257
# Debug: Objective function value (with penalty): 12.186253281338535
# --------------------------------------------------
# | 61        | 12.19     | -14.6     | 11.28     | -20.0     | -20.0     | -4.048    | 20.0      | 9.569     | -20.0     | -0.6263   | -20.0     | -20.0     | -20.0     | -20.0     | -13.22    | -8.345    | -20.0     | 20.0      | -20.0     | 2.156     | -13.16    | 14.01     | -20.0     |
# Train Sharpe Ratio: 1.741, Validation Sharpe Ratio: 0.86
# Debug: L2 penalty: 4.821011696336875
# Debug: L1 penalty: 0.5039256255411776
# Debug: Objective function value (with penalty): 9.442062678121948
# --------------------------------------------------
# | 62        | 9.442     | -2.139    | -2.492    | -20.0     | 20.0      | -20.0     | -20.0     | 9.11      | -20.0     | -5.845    | -20.0     | 20.0      | -0.5894   | -20.0     | -20.0     | -20.0     | -20.0     | 20.0      | -20.0     | -20.0     | 1.076     | 20.0      | -20.0     |
# Train Sharpe Ratio: 1.512, Validation Sharpe Ratio: 0.758
# Debug: L2 penalty: 4.787249430317388
# Debug: L1 penalty: 0.5037255202491864
# Debug: Objective function value (with penalty): 7.567025049433426
# --------------------------------------------------
# | 63        | 7.567     | -11.43    | 20.0      | -20.0     | -20.0     | -20.0     | -20.0     | -20.0     | -20.0     | -20.0     | -20.0     | -6.819    | -20.0     | -7.911    | -20.0     | 20.0      | -20.0     | 20.0      | -20.0     | 20.0      | 6.52      | 19.08     | -20.0     |
# Train Sharpe Ratio: 1.132, Validation Sharpe Ratio: 0.716
# Debug: L2 penalty: 1.4302612075429264
# Debug: L1 penalty: 0.2243641542478817
# Debug: Objective function value (with penalty): 8.417374638209191
# --------------------------------------------------
# | 64        | 8.417     | 9.02      | -2.264    | -12.64    | 16.31     | -16.47    | -9.768    | 16.76     | -12.05    | -18.37    | 12.44     | 6.494     | -6.966    | 3.479     | -11.34    | -19.72    | -9.872    | 2.32      | 5.957     | 7.065     | 13.54     | -4.007    | -5.907    |
# Train Sharpe Ratio: 0.636, Validation Sharpe Ratio: 0.201
# Debug: L2 penalty: 0.6687504749802804
# Debug: L1 penalty: 0.10637185990776576
# Debug: Objective function value (with penalty): 4.279877665111954
# --------------------------------------------------
# | 65        | 4.28      | -13.82    | 0.3427    | 2.01      | -16.52    | 2.246     | -13.6     | 10.09     | 16.11     | -5.436    | -1.631    | 15.02     | 7.086     | 6.361     | 7.107     | -8.096    | -15.78    | -16.44    | 4.852     | 16.42     | 13.55     | 10.6      | -7.304    |
# Train Sharpe Ratio: 2.34, Validation Sharpe Ratio: 0.466
# Debug: L2 penalty: 7.0597956188228554
# Debug: L1 penalty: 0.7302050644731305
# Debug: Objective function value (with penalty): 9.987999316704013
# --------------------------------------------------
# | 66        | 9.988     | -7.456    | 20.0      | -20.0     | -20.0     | -20.0     | -14.43    | 20.0      | -20.0     | 20.0      | -20.0     | -20.0     | -20.0     | -20.0     | -8.846    | 20.0      | -20.0     | 20.0      | -20.0     | -20.0     | 20.0      | 20.0      | 20.0      |
# Train Sharpe Ratio: 1.405, Validation Sharpe Ratio: 0.435
# Debug: L2 penalty: 1.1264448312030877
# Debug: L1 penalty: 0.19904830584813707
# Debug: Objective function value (with penalty): 9.814506862948774
# --------------------------------------------------
# | 67        | 9.815     | -2.662    | 4.713     | -5.425    | -15.22    | -11.44    | -17.52    | 9.221     | 4.217     | 12.86     | -5.868    | 3.363     | -8.549    | -4.901    | -10.29    | -1.379    | 2.366     | 8.263     | -19.13    | -1.262    | 11.18     | 13.37     | 5.48      |
# Train Sharpe Ratio: 2.196, Validation Sharpe Ratio: 0.856
# Debug: L2 penalty: 6.5327260942819185
# Debug: L1 penalty: 0.6920063316815454
# Debug: Objective function value (with penalty): 10.715267574036536
# --------------------------------------------------
# | 68        | 10.72     | -20.0     | -20.0     | -20.0     | -20.0     | 20.0      | -20.0     | 20.0      | -20.0     | 20.0      | -20.0     | -12.25    | -20.0     | -20.0     | 1.546     | 16.69     | -20.0     | 6.758     | -20.0     | -14.65    | 13.84     | 20.0      | -20.0     |
# Train Sharpe Ratio: 1.412, Validation Sharpe Ratio: 0.737
# Debug: L2 penalty: 4.348596619314891
# Debug: L1 penalty: 0.4561495171712683
# Debug: Objective function value (with penalty): 7.29025386351384
# --------------------------------------------------
# | 69        | 7.29      | -20.0     | -20.0     | -20.0     | -20.0     | -20.0     | -20.0     | 7.937     | 20.0      | 20.0      | -20.0     | 20.0      | -20.0     | -20.0     | -6.261    | 16.33     | -20.0     | -3.085    | -20.0     | 20.0      | -3.529    | 20.0      | -20.0     |
# Train Sharpe Ratio: 1.572, Validation Sharpe Ratio: 0.177
# Debug: L2 penalty: 4.858679927183655
# Debug: L1 penalty: 0.490149057317257
# Debug: Objective function value (with penalty): 6.186171015499088
# --------------------------------------------------
# | 70        | 6.186     | 20.0      | 20.0      | -20.0     | -20.0     | -4.923    | 20.0      | 20.0      | -20.0     | 20.0      | 20.0      | -20.0     | -20.0     | -20.0     | -20.0     | -20.0     | -20.0     | 20.0      | -20.0     | 20.0      | 20.0      | 20.0      | -20.0     |
# Train Sharpe Ratio: 1.402, Validation Sharpe Ratio: 1.016
# Debug: L2 penalty: 4.894107413988168
# Debug: L1 penalty: 0.5091398260373102
# Debug: Objective function value (with penalty): 7.458752759974522
# --------------------------------------------------
# | 71        | 7.459     | 20.0      | -20.0     | -20.0     | -20.0     | -20.0     | 5.433     | 20.0      | -20.0     | -20.0     | -20.0     | -20.0     | -20.0     | -20.0     | -20.0     | 3.749     | -20.0     | -10.98    | -20.0     | -20.0     | -20.0     | 15.69     | -20.0     |
# Train Sharpe Ratio: 1.059, Validation Sharpe Ratio: -0.131
# Debug: L2 penalty: 1.4016163016036993
# Debug: L1 penalty: 0.1822383313166501
# Debug: Objective function value (with penalty): 5.43614536707965
# --------------------------------------------------
# | 72        | 5.436     | 9.51      | -1.727    | -3.171    | -13.3     | 11.83     | 5.027     | -3.681    | -1.669    | 6.25      | 19.01     | 19.11     | -18.23    | -16.14    | 17.77     | -19.45    | -17.41    | 17.71     | -18.52    | -17.58    | 9.038     | 11.04     | 2.409     |
# Train Sharpe Ratio: 1.396, Validation Sharpe Ratio: 0.631
# Debug: L2 penalty: 3.3006555548362404
# Debug: L1 penalty: 0.36247892131987286
# Debug: Objective function value (with penalty): 8.001865523843886
# --------------------------------------------------
# | 73        | 8.002     | 11.27     | 2.542     | 20.0      | -20.0     | -20.0     | -20.0     | 15.22     | -20.0     | 20.0      | -20.0     | -3.72     | -20.0     | -20.0     | -0.8741   | -5.588    | -20.0     | 3.197     | -20.0     | 5.445     | -2.887    | 20.0      | -20.0     |
# Train Sharpe Ratio: -0.54, Validation Sharpe Ratio: -1.38
# Debug: L2 penalty: -1.444164464125395
# Debug: L1 penalty: -0.19174182362710637
# Debug: Objective function value (with penalty): -6.284093712247499
# --------------------------------------------------
# | 74        | -6.284    | -14.25    | 19.57     | 19.03     | -1.82     | -3.665    | 17.76     | 9.89      | 16.31     | 18.1      | 16.35     | -2.898    | -16.58    | -19.68    | 13.2      | 6.614     | -4.411    | -3.593    | -7.756    | -19.29    | 5.656     | 4.539     | -1.115    |
# Train Sharpe Ratio: -0.463, Validation Sharpe Ratio: 0.224
# Debug: L2 penalty: -0.4197224185914689
# Debug: L1 penalty: -0.06205561963156933
# Debug: Objective function value (with penalty): -2.087221961776962
# --------------------------------------------------
# | 75        | -2.087    | 1.334     | 12.81     | -5.775    | 18.95     | -10.52    | -11.71    | -14.54    | 1.701     | -19.7     | -12.52    | 14.71     | 10.97     | -2.959    | -18.78    | 14.6      | -5.446    | -6.6      | 6.371     | -13.16    | -12.47    | -10.49    | -15.45    |
# Train Sharpe Ratio: -0.908, Validation Sharpe Ratio: -1.222
# Debug: L2 penalty: -1.3639151345124412
# Debug: L1 penalty: -0.2151965439217972
# Debug: Objective function value (with penalty): -8.442888321565762
# --------------------------------------------------
# | 76        | -8.443    | 12.86     | -4.989    | -16.55    | 1.15      | 5.074     | 9.194     | 17.61     | -8.454    | 15.39     | 2.255     | 12.78     | 6.418     | 6.354     | 4.278     | -1.17     | 13.23     | -9.603    | -16.72    | -13.19    | 5.802     | 14.69     | 16.96     |
# Train Sharpe Ratio: 1.822, Validation Sharpe Ratio: 0.958
# Debug: L2 penalty: 6.529491928788973
# Debug: L1 penalty: 0.665487835811427
# Debug: Objective function value (with penalty): 8.4330202353996
# --------------------------------------------------
# | 77        | 8.433     | -20.0     | -20.0     | -20.0     | -20.0     | -20.0     | -20.0     | 20.0      | -20.0     | -16.27    | -20.0     | 20.0      | -20.0     | -20.0     | -20.0     | 9.558     | -20.0     | 20.0      | -20.0     | -20.0     | 20.0      | 20.0      | 20.0      |
# Train Sharpe Ratio: -1.597, Validation Sharpe Ratio: -1.445
# Debug: L2 penalty: -2.764386246153932
# Debug: L1 penalty: -0.39923985288902897
# Debug: Objective function value (with penalty): -12.350373900957042
# --------------------------------------------------
# | 78        | -12.35    | 17.3      | 17.25     | 5.214     | -17.51    | -15.52    | -2.682    | 10.19     | 10.18     | -16.9     | 15.09     | 3.339     | 9.757     | 16.31     | -11.42    | -10.69    | 13.91     | 17.77     | 4.528     | 5.097     | 8.469     | 17.39     | -10.82    |
# Train Sharpe Ratio: 1.698, Validation Sharpe Ratio: 0.786
# Debug: L2 penalty: 5.591049711757889
# Debug: L1 penalty: 0.5787712257502688
# Debug: Objective function value (with penalty): 8.07417906249184
# --------------------------------------------------
# | 79        | 8.074     | -20.0     | -20.0     | -20.0     | -20.0     | 20.0      | 20.0      | 5.943     | -20.0     | -20.0     | 12.11     | -20.0     | -20.0     | -20.0     | -20.0     | -20.0     | -20.0     | -8.277    | -20.0     | 20.0      | -20.0     | -20.0     | -20.0     |
# Train Sharpe Ratio: 0.446, Validation Sharpe Ratio: -0.894
# Debug: L2 penalty: 0.05717756556898296
# Debug: L1 penalty: 0.009009633888668657
# Debug: Objective function value (with penalty): 0.37381280054234767
# --------------------------------------------------
# | 80        | 0.3738    | 0.1727    | 18.13     | 9.651     | 12.12     | 4.073     | 12.11     | -14.89    | -0.3322   | 3.602     | -19.95    | -7.607    | 10.52     | -8.646    | 16.77     | -7.115    | -14.85    | 6.068     | -10.68    | 1.285     | 9.558     | 13.62     | -3.011    |
# Train Sharpe Ratio: 2.143, Validation Sharpe Ratio: 0.799
# Debug: L2 penalty: 6.784389231035683
# Debug: L1 penalty: 0.7032593848711819
# Debug: Objective function value (with penalty): 9.910351384093133
# --------------------------------------------------
# | 81        | 9.91      | -20.0     | 12.67     | -20.0     | -20.0     | 20.0      | -20.0     | 5.691     | -20.0     | -6.937    | -20.0     | 20.0      | -20.0     | -20.0     | 18.92     | -20.0     | -20.0     | 20.0      | 20.0      | -20.0     | 20.0      | 20.0      | -20.0     |
# Train Sharpe Ratio: -1.27, Validation Sharpe Ratio: -0.568
# Debug: L2 penalty: -1.903289106521033
# Debug: L1 penalty: -0.27405201471997176
# Debug: Objective function value (with penalty): -8.416658878758994
# --------------------------------------------------
# | 82        | -8.417    | 13.0      | -8.582    | 15.1      | -5.154    | -3.179    | 13.12     | 17.45     | 18.63     | -3.401    | -6.155    | -15.69    | 8.3       | 18.74     | -8.135    | -16.15    | -9.199    | -17.27    | 4.838     | -11.1     | 15.02     | -15.35    | -15.12    |
# Train Sharpe Ratio: 1.999, Validation Sharpe Ratio: 0.715
# Debug: L2 penalty: 5.5924101041841725
# Debug: L1 penalty: 0.5980294355476095
# Debug: Objective function value (with penalty): 9.947560460268217
# --------------------------------------------------
# | 83        | 9.948     | -20.0     | -14.44    | -20.0     | 20.0      | 20.0      | 10.16     | -3.937    | -20.0     | 2.092     | -20.0     | -20.0     | -20.0     | -20.0     | -10.33    | -20.0     | -20.0     | 20.0      | -20.0     | -20.0     | 20.0      | 9.616     | -20.0     |
# Train Sharpe Ratio: 1.525, Validation Sharpe Ratio: 0.549
# Debug: L2 penalty: 4.349878531481259
# Debug: L1 penalty: 0.45833354207081434
# Debug: Objective function value (with penalty): 7.513787926447925
# --------------------------------------------------
# | 84        | 7.514     | -5.848    | 7.439     | -20.0     | -20.0     | -0.5926   | -20.0     | -20.0     | 10.91     | 20.0      | -20.0     | -20.0     | -20.0     | -20.0     | 20.0      | 7.179     | -20.0     | 20.0      | -20.0     | -20.0     | 20.0      | 20.0      | -20.0     |
# Train Sharpe Ratio: 0.714, Validation Sharpe Ratio: 0.262
# Debug: L2 penalty: 1.2300695330703126
# Debug: L1 penalty: 0.15604142906354132
# Debug: Objective function value (with penalty): 4.397889037866147
# --------------------------------------------------
# | 85        | 4.398     | -19.14    | 1.561     | 3.155     | 19.72     | 2.323     | -14.26    | -16.67    | -7.023    | 1.777     | 10.07     | 12.07     | 13.97     | -18.71    | -4.818    | 7.217     | -19.57    | -16.0     | 19.68     | 8.694     | 19.98     | 19.94     | -13.43    |
# Train Sharpe Ratio: 1.561, Validation Sharpe Ratio: 0.711
# Debug: L2 penalty: 5.259829653344071
# Debug: L1 penalty: 0.5421322528775507
# Debug: Objective function value (with penalty): 7.258038093778377
# --------------------------------------------------
# | 86        | 7.258     | 17.12     | 8.886     | -20.0     | -20.0     | -20.0     | 20.0      | -20.0     | -20.0     | 9.106     | 20.0      | -20.0     | -20.0     | -20.0     | 20.0      | -20.0     | -20.0     | -20.0     | -20.0     | 20.0      | -20.0     | -20.0     | -20.0     |
# Train Sharpe Ratio: -2.037, Validation Sharpe Ratio: -1.297
# Debug: L2 penalty: -2.5826835881847208
# Debug: L1 penalty: -0.3963429641342873
# Debug: Objective function value (with penalty): -15.17097344768099
# --------------------------------------------------
# | 87        | -15.17    | 7.156     | -18.91    | -12.7     | 5.813     | 18.11     | 9.617     | -7.532    | 10.02     | -14.15    | 6.172     | 2.8       | 3.708     | 2.065     | 14.2      | 19.45     | 18.95     | 15.23     | 8.247     | -8.358    | 4.736     | -7.878    | 2.555     |
# Train Sharpe Ratio: 1.899, Validation Sharpe Ratio: 0.799
# Debug: L2 penalty: 6.7560019857541205
# Debug: L1 penalty: 0.6823405630438014
# ...
# Debug: L1 penalty: -0.3607545717507054
# Debug: Objective function value (with penalty): -15.210050156509844
# --------------------------------------------------
# | 243       | -15.21    | -4.838    | -4.482    | -0.01247  | 15.05     | 10.24     | 19.53     | 7.218     | 7.956     | -13.06    | 11.58     | -7.178    | 13.9      | 14.79     | 18.18     | -10.52    | 8.503     | -2.671    | 5.361     | -15.46    | 8.743     | -0.791    | 2.529     |
# Train Sharpe Ratio: 0.878, Validation Sharpe Ratio: 0.176
# Debug: L2 penalty: 0.5933719641986923
# Debug: L1 penalty: 0.1124204932719132
# Debug: Objective function value (with penalty): 5.968207542529393
# --------------------------------------------------
# | 244       | 5.968     | 9.088     | 17.06     | -4.885    | -11.45    | -7.58     | -3.245    | 6.449     | -9.544    | 2.372     | 0.6586    | 8.662     | -9.718    | -13.79    | -15.92    | 11.45     | 2.903     | -0.4839   | -5.053    | 12.22     | 8.092     | -0.8322   | 6.983     |
# Train Sharpe Ratio: 1.716, Validation Sharpe Ratio: 0.982
# Debug: L2 penalty: 6.3508895813613755
# Debug: L1 penalty: 0.6425542783741862
# Debug: Objective function value (with penalty): 7.9645561402644365
# --------------------------------------------------
# | 245       | 7.965     | -20.0     | -20.0     | -20.0     | -20.0     | -20.0     | 20.0      | -20.0     | -20.0     | 20.0      | -20.0     | 9.572     | -20.0     | -20.0     | 20.0      | 20.0      | -20.0     | -20.0     | -20.0     | 20.0      | -20.0     | -20.0     | -20.0     |
# Train Sharpe Ratio: 0.759, Validation Sharpe Ratio: 0.072
# Debug: L2 penalty: 0.8714503344365482
# Debug: L1 penalty: 0.13050577090143392
# Debug: Objective function value (with penalty): 4.527043894662018
# --------------------------------------------------
# | 246       | 4.527     | 16.82     | -9.116    | -7.243    | -17.15    | 15.27     | -15.99    | 14.19     | 1.873     | 7.856     | -1.221    | -14.52    | 14.54     | -14.03    | -1.112    | -9.764    | -13.05    | 6.465     | -4.633    | -13.41    | 17.67     | -14.49    | -5.631    |
# Train Sharpe Ratio: 0.238, Validation Sharpe Ratio: -0.145
# Debug: L2 penalty: 0.17090865176328965
# Debug: L1 penalty: 0.027543543305621768
# Debug: Objective function value (with penalty): 1.0325478049310883
# --------------------------------------------------
# | 247       | 1.033     | -5.494    | 1.17      | 16.94     | -14.76    | 8.379     | -14.8     | 13.45     | 12.46     | 12.75     | -14.14    | 6.689     | -4.05     | -13.28    | -10.61    | 13.05     | -16.25    | -5.831    | -0.1517   | 8.804     | -5.096    | -11.57    | -14.02    |
# Train Sharpe Ratio: -0.816, Validation Sharpe Ratio: -0.719
# Debug: L2 penalty: -1.1219214760779128
# Debug: L1 penalty: -0.16835297953046896
# Debug: Objective function value (with penalty): -6.578725544391618
# --------------------------------------------------
# | 248       | -6.579    | -10.51    | -7.517    | -17.32    | -6.52     | 7.85      | 19.6      | 8.376     | 16.19     | -5.541    | -9.037    | -2.215    | 10.75     | 0.6897    | -19.14    | -17.47    | 10.81     | -2.793    | -3.421    | -11.8     | 2.908     | -4.694    | 18.79     |
# Train Sharpe Ratio: 2.426, Validation Sharpe Ratio: 0.306
# Debug: L2 penalty: 4.761614913885436
# Debug: L1 penalty: 0.5658282140400295
# Debug: Objective function value (with penalty): 12.572556872074534
# --------------------------------------------------
# | 249       | 12.57     | -20.0     | 20.0      | -20.0     | 8.589     | -20.0     | 20.0      | -0.8176   | -20.0     | 13.57     | -10.57    | -20.0     | 6.664     | 5.596     | 10.61     | -20.0     | 14.09     | 7.776     | -15.49    | -8.585    | 13.75     | 20.0      | -20.0     |
# Train Sharpe Ratio: 2.438, Validation Sharpe Ratio: 0.821
# Debug: L2 penalty: 7.6013378152923
# Debug: L1 penalty: 0.7844842325998589
# Debug: Objective function value (with penalty): 11.143177952107841
# --------------------------------------------------
# | 250       | 11.14     | -20.0     | -6.882    | -20.0     | -20.0     | 18.12     | -20.0     | 20.0      | -20.0     | -20.0     | -20.0     | 18.66     | 20.0      | -20.0     | 16.03     | -20.0     | -20.0     | 20.0      | -20.0     | -20.0     | 20.0      | 20.0      | 2.017     |
# Train Sharpe Ratio: 2.34, Validation Sharpe Ratio: 1.084
# Debug: L2 penalty: 7.088947470539418
# Debug: L1 penalty: 0.7443896959455557
# Debug: Objective function value (with penalty): 11.798662833515028
# --------------------------------------------------
# | 251       | 11.8      | -20.0     | -20.0     | -20.0     | 4.852     | 0.946     | 20.0      | -9.813    | -20.0     | -16.16    | -20.0     | 20.0      | -20.0     | -20.0     | 20.0      | 20.0      | -20.0     | 20.0      | -20.0     | -19.39    | 8.02      | 20.0      | -20.0     |
# Train Sharpe Ratio: 1.873, Validation Sharpe Ratio: 0.978
# Debug: L2 penalty: 4.742906901705274
# Debug: L1 penalty: 0.5173905911970988
# Debug: Objective function value (with penalty): 10.784702507097629
# --------------------------------------------------
# | 252       | 10.78     | -20.0     | -20.0     | -20.0     | 20.0      | -0.2626   | 20.0      | -20.0     | -20.0     | -10.09    | -1.018    | 20.0      | -20.0     | -20.0     | -2.844    | 7.322     | -20.0     | -6.026    | -7.635    | 20.0      | -7.265    | 20.0      | -20.0     |
# Train Sharpe Ratio: 1.886, Validation Sharpe Ratio: 0.951
# Debug: L2 penalty: 4.740926982302463
# Debug: L1 penalty: 0.5102248177899824
# Debug: Objective function value (with penalty): 10.803848199907554
# --------------------------------------------------
# | 253       | 10.8      | -20.0     | -20.0     | -20.0     | -20.0     | 18.63     | -5.15     | -20.0     | -20.0     | -7.342    | -20.0     | 20.0      | 1.538     | -20.0     | 5.258     | 20.0      | -20.0     | 3.708     | -20.0     | -0.2087   | 15.3      | 20.0      | 0.6629    |
# Train Sharpe Ratio: 2.632, Validation Sharpe Ratio: 1.18
# Debug: L2 penalty: 4.238712786490616
# Debug: L1 penalty: 0.5471404729704177
# Debug: Objective function value (with penalty): 17.178146740538967
# --------------------------------------------------
# | 254       | 17.18     | -20.0     | -0.3483   | -20.0     | 1.872     | -8.191    | 16.26     | -6.941    | -20.0     | -7.09     | -19.18    | -3.705    | 3.902     | -6.775    | 6.287     | -20.0     | 13.94     | 20.0      | -10.47    | 2.535     | -10.7     | 10.91     | -20.0     |
# Train Sharpe Ratio: 1.596, Validation Sharpe Ratio: 0.539
# Debug: L2 penalty: 3.3478599959158952
# Debug: L1 penalty: 0.39567784134559253
# Debug: Objective function value (with penalty): 9.045462162738511
# --------------------------------------------------
# | 255       | 9.045     | -10.74    | 5.012     | 12.06     | -20.0     | -9.549    | -20.0     | 18.9      | -20.0     | 1.604     | -7.789    | 13.04     | -20.0     | -4.741    | 12.89     | -20.0     | -20.0     | 4.72      | -20.0     | -20.0     | 19.44     | 20.0      | 8.911     |
# Train Sharpe Ratio: 1.474, Validation Sharpe Ratio: 1.043
# Debug: L2 penalty: 4.753144954412078
# Debug: L1 penalty: 0.512506397321917
# Debug: Objective function value (with penalty): 8.181348648266002
# --------------------------------------------------
# | 256       | 8.181     | -20.0     | -9.355    | -20.0     | -20.0     | -9.41     | -20.0     | 20.0      | -20.0     | -20.0     | 20.0      | -20.0     | 20.0      | -11.85    | -20.0     | -20.0     | 14.92     | -20.0     | -5.711    | -20.0     | -9.877    | 20.0      | -20.0     |
# Train Sharpe Ratio: -0.234, Validation Sharpe Ratio: 0.196
# Debug: L2 penalty: -0.18924143991460657
# Debug: L1 penalty: -0.02594421040446888
# Debug: Objective function value (with penalty): -0.8348143496809244
# --------------------------------------------------
# | 257       | -0.8348   | 11.42     | 4.152     | 1.653     | -2.374    | 12.64     | -17.96    | -15.87    | 9.451     | -14.12    | -0.1915   | 1.038     | -18.26    | 17.5      | -8.006    | 20.0      | -11.68    | -16.34    | 11.48     | 19.16     | 6.321     | 14.5      | -12.97    |
# Train Sharpe Ratio: 1.828, Validation Sharpe Ratio: 0.823
# Debug: L2 penalty: 3.444824060650851
# Debug: L1 penalty: 0.3939127058384069
# Debug: Objective function value (with penalty): 11.426263233510745
# --------------------------------------------------
# | 258       | 11.43     | -18.39    | 0.001715  | -20.0     | -20.0     | 1.09      | -20.0     | 10.42     | -4.113    | 1.121     | 0.2112    | 2.494     | 1.349     | -20.0     | -15.72    | 12.56     | -20.0     | -19.22    | -20.0     | -20.0     | 6.062     | 20.0      | 5.297     |
# Train Sharpe Ratio: 0.112, Validation Sharpe Ratio: -0.409
# Debug: L2 penalty: -0.07570555227101561
# Debug: L1 penalty: -0.010880464902973517
# Debug: Objective function value (with penalty): -0.35641398282601106
# --------------------------------------------------
# | 259       | -0.3564   | -9.311    | 9.663     | 17.89     | -19.52    | -0.08659  | -6.75     | -8.788    | -13.82    | 11.4      | 17.71     | -14.25    | -7.064    | -15.84    | -4.016    | 13.92     | -0.1482   | 18.0      | 18.29     | -7.12     | -8.073    | 10.5      | -13.45    |
# Train Sharpe Ratio: 2.182, Validation Sharpe Ratio: 1.108
# Debug: L2 penalty: 2.689919023053005
# Debug: L1 penalty: 0.366843010895306
# Debug: Objective function value (with penalty): 15.541237966051689
# --------------------------------------------------
# | 260       | 15.54     | -11.52    | -2.758    | -20.0     | 3.313     | -10.76    | 14.33     | -7.689    | -20.0     | 2.567     | -11.14    | -9.552    | -3.587    | 1.325     | 0.1063    | -20.0     | 10.14     | -0.7368   | -20.0     | 2.189     | -3.6      | 1.949     | -20.0     |
# Train Sharpe Ratio: 1.338, Validation Sharpe Ratio: 0.86
# Debug: L2 penalty: 3.2680228851978104
# Debug: L1 penalty: 0.38053262408492944
# Debug: Objective function value (with penalty): 8.297444490717258
# --------------------------------------------------
# | 261       | 8.297     | 9.128     | 6.366     | -14.1     | -20.0     | -17.99    | -20.0     | 11.06     | -20.0     | 15.6      | -1.347    | -13.28    | -20.0     | -11.03    | -20.0     | -20.0     | 11.28     | -20.0     | -20.0     | 5.265     | -20.0     | -20.0     | -2.093    |
# Train Sharpe Ratio: 1.111, Validation Sharpe Ratio: 0.7
# Debug: L2 penalty: 3.9253497784056575
# Debug: L1 penalty: 0.4048360681675904
# Debug: Objective function value (with penalty): 5.546814153426753
# --------------------------------------------------
# | 262       | 5.547     | 15.33     | -20.0     | -20.0     | -20.0     | 20.0      | -20.0     | -20.0     | -20.0     | 20.0      | 20.0      | -20.0     | -20.0     | -20.0     | -20.0     | 20.0      | -20.0     | -20.0     | -20.0     | 9.23      | 20.0      | -20.0     | -5.318    |
# Train Sharpe Ratio: -2.679, Validation Sharpe Ratio: -1.591
# Debug: L2 penalty: -4.802155531163105
# Debug: L1 penalty: -0.6371600647460324
# Debug: Objective function value (with penalty): -18.086684404090857
# --------------------------------------------------
# | 263       | -18.09    | 17.56     | -9.1      | 15.75     | 17.39     | 17.91     | -11.8     | -4.179    | 17.25     | -2.124    | 0.885     | -18.33    | 15.61     | -5.187    | -6.675    | 16.73     | -5.723    | 11.0      | 8.927     | 18.67     | -19.61    | -14.97    | 15.44     |
# Train Sharpe Ratio: 2.134, Validation Sharpe Ratio: 1.042
# Debug: L2 penalty: 4.358395344568379
# Debug: L1 penalty: 0.510020721778692
# Debug: Objective function value (with penalty): 13.195583933652925
# --------------------------------------------------
# | 264       | 13.2      | -20.0     | 4.208     | -20.0     | 20.0      | -20.0     | 9.011     | -12.01    | -20.0     | -7.718    | -1.207    | -4.537    | 4.663     | -15.56    | 9.807     | -20.0     | 19.65     | 20.0      | 0.008687  | -12.33    | -1.633    | 20.0      | -20.0     |
# Train Sharpe Ratio: 2.98, Validation Sharpe Ratio: 1.004
# Debug: L2 penalty: 4.197964968863256
# Debug: L1 penalty: 0.5502429680618373
# Debug: Objective function value (with penalty): 19.123792063074905
# --------------------------------------------------
# | 265       | 19.12     | -20.0     | 1.848     | -20.0     | 5.898     | -9.354    | 20.0      | 8.089     | -20.0     | -7.256    | -5.874    | -11.93    | 11.69     | -4.979    | -1.995    | -20.0     | 5.072     | 9.353     | -3.046    | 1.863     | -2.249    | 20.0      | -20.0     |
# Train Sharpe Ratio: 1.479, Validation Sharpe Ratio: 0.415
# Debug: L2 penalty: 4.602877699258794
# Debug: L1 penalty: 0.47311610701857576
# Debug: Objective function value (with penalty): 6.522006193722633
# --------------------------------------------------
# | 266       | 6.522     | 20.0      | -3.459    | -20.0     | -20.0     | 20.0      | -20.0     | 20.0      | -20.0     | 20.0      | -20.0     | 20.0      | -20.0     | -20.0     | 20.0      | -20.0     | -20.0     | 20.0      | -20.0     | 20.0      | 15.84     | -20.0     | -8.629    |
# Train Sharpe Ratio: 1.876, Validation Sharpe Ratio: 0.493
# Debug: L2 penalty: 3.3482191300736566
# Debug: L1 penalty: 0.41069948410037876
# Debug: Objective function value (with penalty): 10.852081385825965
# --------------------------------------------------
# | 267       | 10.85     | -20.0     | 6.012     | -20.0     | 9.109     | -20.0     | 20.0      | 3.711     | -20.0     | -3.704    | -7.585    | -7.001    | 12.35     | 7.022     | -3.762    | -20.0     | 10.16     | 15.79     | -12.48    | -2.409    | -20.0     | 20.0      | -20.0     |
# Train Sharpe Ratio: 0.955, Validation Sharpe Ratio: 0.712
# Debug: L2 penalty: 2.498282539758921
# Debug: L1 penalty: 0.2839416661637255
# Debug: Objective function value (with penalty): 6.038775794077353
# --------------------------------------------------
# | 268       | 6.039     | 20.0      | -8.214    | 15.23     | -20.0     | -20.0     | -20.0     | -16.88    | -20.0     | 5.755     | -1.316    | 20.0      | -18.63    | 4.0       | -5.87     | -20.0     | -20.0     | -20.0     | -20.0     | 20.0      | -11.72    | -5.102    | 9.171     |
# Train Sharpe Ratio: 1.939, Validation Sharpe Ratio: 0.829
# Debug: L2 penalty: 3.1610225736137396
# Debug: L1 penalty: 0.40336947314874283
# Debug: Objective function value (with penalty): 12.495607953237517
# --------------------------------------------------
# | 269       | 12.5      | -20.0     | 3.322     | -20.0     | 5.555     | -4.92     | 20.0      | -0.001229 | -20.0     | -8.287    | -6.155    | -6.702    | 7.002     | -14.73    | 10.2      | -20.0     | 17.76     | -0.5329   | -6.464    | 10.3      | 9.23      | 20.0      | -20.0     |
# Train Sharpe Ratio: 2.396, Validation Sharpe Ratio: 0.946
# Debug: L2 penalty: 3.497109199289533
# Debug: L1 penalty: 0.44804837980006984
# Debug: Objective function value (with penalty): 15.664842420910396
# --------------------------------------------------
# | 270       | 15.66     | -20.0     | 2.889     | -20.0     | 5.187     | -13.57    | 20.0      | -1.885    | -20.0     | 0.03016   | -9.481    | -19.97    | -1.721    | -7.913    | -5.019    | -20.0     | 5.024     | 14.54     | 4.771     | -4.167    | 3.744     | 8.565     | -20.0     |
# =================================================================================================================================================================================================================================================================================================
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-15-47563505656b> in <cell line: 84>()
#      82 # Evaluate on test set
#      83 portfolio_weights_test = generate_portfolio_vectorized(test_features, test_universe, np.array(list(optimal_weights.values())))
# ---> 84 sr_test, _ = backtest_portfolio_new(portfolio_weights_test, test_returns, test_universe)
#      85
#      86 print("Optimal Weights:", optimal_weights)
#
# TypeError: backtest_portfolio_new() missing 2 required positional arguments: 'plot_' and 'print_'

# %%
optimal_weights =
# Out:
# {'accumulation_distribution_index': -20.0,
#  'aroon': 1.8475694801189855,
#  'average_true_range': -20.0,
#  'chaikin_money_flow': 5.898065359965044,
#  'chande_momentum_oscillator': -9.354101362538275,
#  'commodity_channel_index': 20.0,
#  'ease_of_movement': 8.08903939705811,
#  'ichimoku': -20.0,
#  'know_sure_thing': -7.25558502973287,
#  'macd': -5.873723274987229,
#  'on_balance_volume': -11.932050044738435,
#  'relative_strength_index': 11.688643060816238,
#  'stochastic_oscillator': -4.979467865847553,
#  'trend_1_3': -1.9952749754513066,
#  'trend_20_60': -20.0,
#  'trend_5_20': 5.072363909076035,
#  'trix': 9.352609868081357,
#  'ultimate_oscillator': -3.046442913727308,
#  'volatility_20': 1.8633451855091139,
#  'volatility_60': -2.248940148121792,
#  'volume': 20.0,
#  'williams_r': -20.0}

# %%
portfolio_weights_test = generate_portfolio_vectorized(test_features, test_universe, np.array(list(optimal_weights.values())))
sr_test, _ = backtest_portfolio_new(portfolio_weights_test, test_returns, test_universe,True,True)
# Out:
# Gross Sharpe Ratio:  -0.33
# Net Sharpe Ratio:  -0.817

# %%
selected_features = [
    'on_balance_volume', 'trend_1_3', 'macd', 'ichimoku',
    'ultimate_oscillator',
    'chaikin_money_flow', 'volume', 'know_sure_thing',
    'chande_momentum_oscillator', 'average_true_range',
    'volatility_20', 'trend_5_20'
]
train_features = features.loc["2005":"2015"]
validation_features = features.loc["2016":"2018"]
test_features = features.loc["2019"]

train_universe = universe.loc["2005":"2015"]
validation_universe = universe.loc["2016":"2018"]
test_universe = universe.loc["2019"]

train_returns = returns.loc["2005":"2015"]
validation_returns = returns.loc["2016":"2018"]
test_returns = returns.loc["2019"]

# Filter your training and validation feature sets to include only selected features
train_features = train_features[selected_features]
validation_features = validation_features[selected_features]
test_features = test_features[selected_features]  # Test set for evaluation

# %%
from bayes_opt import BayesianOptimization
import numpy as np
import matplotlib.pyplot as plt
from joblib import Parallel, delayed

# %%
initial_weights = {
   'accumulation_distribution_index': -10.0,
   'aroon': -0.09222290817164171,
   'average_true_range': -10.0,
   'chaikin_money_flow': -10.0,
   'chande_momentum_oscillator': 3.318011135314672,
   'commodity_channel_index': 10.0,
   'ease_of_movement': 5.821824288780287,
   'ichimoku': -10.0,
   'know_sure_thing': 10.0,
   'macd': -3.867991947270643,
   'on_balance_volume': 1.8025161396173899,
   'relative_strength_index': 0.6147723614862542,
   'stochastic_oscillator': -10.0,
   'trend_1_3': 10.0,
   'trend_20_60': -10.0,
   'trend_5_20': -10.0,
   'trix': -0.8681094745966318,
   'ultimate_oscillator': 1.3625158710488225,
   'volatility_20': 10.0,
   'volatility_60': -10.0,
   'volume': 10.0,
   'williams_r': -6.987324378181491
}

# Define Bayesian Optimization function
def optimize_signal_weights_bayesian(features_train, features_validation, universe_train, universe_validation, returns_train, returns_validation):
    
    def sharpe_ratio_objective(**weights):
        weight_array = np.array([weights[key] for key in sorted(weights.keys())])
        
        # Generate portfolio weights for training set
        portfolio_weights_train = generate_portfolio_vectorized(features_train, universe_train, weight_array)
        
        # Backtest on training data
        sr_train, _ = backtest_portfolio_new(portfolio_weights_train, returns_train, universe_train,False,False)
        # print(f"Debug: Sharpe ratio calculated: {sr_train}")
        # Validate on validation set
        portfolio_weights_validation = generate_portfolio_vectorized(features_validation, universe_validation, weight_array)
        sr_validation, _ = backtest_portfolio_new(portfolio_weights_validation, returns_validation, universe_validation,False,False)
        print(f"Train Sharpe Ratio: {sr_train}, Validation Sharpe Ratio: {sr_validation}")
        # Add penalties to prevent overfitting
        alpha = 0.5  # Weight for training Sharpe ratio (adjust as needed)
        combined_sharpe_ratio = alpha * sr_train + (1 - alpha) * sr_validation
        
        # Add penalties to prevent overfitting
        penalty_l2 = np.sum(np.square(weight_array)) * combined_sharpe_ratio * 0.0005
        penalty_l1 = np.sum(np.abs(weight_array)) * combined_sharpe_ratio * 0.001
        
        result = combined_sharpe_ratio * 10 - penalty_l2 - penalty_l1
        print(f"Debug: L2 penalty: {penalty_l2}")
        print(f"Debug: L1 penalty: {penalty_l1}")
        
        print(f"Debug: Objective function value (with penalty): {result}")
        print("-" * 50)
        return result
    
    pbounds = {feature: (-20, 20) for feature in features_train.columns.levels[0]}
    
    optimizer = BayesianOptimization(
        f=sharpe_ratio_objective,
        pbounds=pbounds,
        random_state=42
    )
    
    optimizer.maximize(init_points=20, n_iter=250)
    
    optimal_weights = optimizer.max['params']
    
    return optimal_weights

# Run Bayesian Optimization using train/validation split
optimal_weights = optimize_signal_weights_bayesian(
    train_features,
    validation_features,
    train_universe,
    validation_universe,
    train_returns,
    validation_returns
)

# Evaluate on test set
portfolio_weights_test = generate_portfolio_vectorized(test_features, test_universe, np.array(list(optimal_weights.values())))
sr_test, _ = backtest_portfolio_new(portfolio_weights_test, test_returns, test_universe,True,True)

print("Optimal Weights:", optimal_weights)
print("Test Set Sharpe Ratio:", sr_test)
# Out:
# |   iter    |  target   | accumu... |   aroon   | averag... | chaiki... | chande... | commod... | ease_o... | ichimoku  | know_s... |   macd    | on_bal... | relati... | stocha... | trend_1_3 | trend_... | trend_... |   trix    | ultima... | volati... | volati... |  volume   | willia... |
# -------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------
# Train Sharpe Ratio: -0.538, Validation Sharpe Ratio: -0.432
# Debug: L2 penalty: -0.7670801259912623
# Debug: L1 penalty: -0.11418824578491918
# Debug: Objective function value (with penalty): -3.9687316282238188
# --------------------------------------------------
# | 1         | -3.969    | -5.018    | 18.03     | 9.28      | 3.946     | -13.76    | -13.76    | -17.68    | 14.65     | 4.045     | 8.323     | -19.18    | 18.8      | 13.3      | -11.51    | -12.73    | -12.66    | -7.83     | 0.9903    | -2.722    | -8.351    | 4.474     | -14.42    |
# Train Sharpe Ratio: -0.728, Validation Sharpe Ratio: -0.959
# Debug: L2 penalty: -1.374208376621721
# Debug: L1 penalty: -0.19317903592698402
# Debug: Objective function value (with penalty): -6.867612587451294
# --------------------------------------------------
# | 2         | -6.868    | -8.314    | -5.346    | -1.757    | 11.41     | -12.01    | 0.5694    | 3.697     | -18.14    | 4.302     | -13.18    | -17.4     | 17.96     | 18.63     | 12.34     | -7.815    | -16.09    | 7.369     | -2.394    | -15.12    | -0.1929   | -18.62    | 16.37     |
# Train Sharpe Ratio: 0.548, Validation Sharpe Ratio: -0.848
# Debug: L2 penalty: -0.21563277507308826
# Debug: L1 penalty: -0.03294875687359676
# Debug: Objective function value (with penalty): -1.2514184680533147
# --------------------------------------------------
# | 3         | -1.251    | -9.649    | 6.501     | -7.532    | 0.8027    | 1.868     | -12.61    | 18.78     | 11.01     | 17.58     | 15.79     | 3.916     | 16.87     | -16.46    | -12.16    | -18.19    | -6.987    | -4.453    | -9.146    | 13.15     | -5.73     | -8.763    | 1.708     |
# Train Sharpe Ratio: -0.094, Validation Sharpe Ratio: -0.352
# Debug: L2 penalty: -0.38697448229497017
# Debug: L1 penalty: -0.05743388236671488
# Debug: Objective function value (with penalty): -1.7855916353383146
# --------------------------------------------------
# | 4         | -1.786    | -14.36    | 12.09     | -17.02    | 19.48     | 10.89     | -12.05    | -19.78    | 12.62     | 8.274     | 9.16      | 10.85     | -17.04    | -5.661    | -15.37    | 14.52     | 4.932     | -6.764    | -17.46    | -7.561    | -6.993    | 9.184     | 5.502     |
# Train Sharpe Ratio: 1.172, Validation Sharpe Ratio: 0.214
# Debug: L2 penalty: 0.9415700541273728
# Debug: L1 penalty: 0.1404468108043675
# Debug: Objective function value (with penalty): 5.847983135068259
# --------------------------------------------------
# | 5         | 5.848     | 15.49     | -1.111    | -15.22    | 8.53      | 10.43     | 2.451     | 10.84     | -0.2482   | 0.9093    | -2.898    | -18.98    | -15.68    | -18.74    | 5.456     | -7.426    | 0.3428    | 16.3      | -10.03    | -3.585    | 10.22     | -10.85    | -16.92    |
# Train Sharpe Ratio: -0.577, Validation Sharpe Ratio: -0.759
# Debug: L2 penalty: -1.0767507469541684
# Debug: L1 penalty: -0.16043136118131593
# Debug: Objective function value (with penalty): -5.442817891864515
# --------------------------------------------------
# | 6         | -5.443    | -8.41     | -13.55    | 17.19     | 12.32     | 5.336     | 14.86     | 12.15     | -12.54    | 15.7      | 1.574     | 12.3      | 15.84     | -7.28     | -15.6     | -10.88    | -2.916    | 12.72     | 14.43     | -19.72    | 0.4299    | -3.304    | -11.12    |
# Train Sharpe Ratio: -0.207, Validation Sharpe Ratio: -0.144
# Debug: L2 penalty: -0.26392903082737845
# Debug: L1 penalty: -0.03790430425405242
# Debug: Objective function value (with penalty): -1.453166664918569
# --------------------------------------------------
# | 7         | -1.453    | -15.21    | -6.495    | 17.72     | -7.072    | 0.7516    | 8.121     | -5.455    | 18.87     | 18.5      | -9.929    | -0.1101   | -7.965    | -8.606    | -18.52    | 4.383     | 0.1072    | -17.94    | -8.854    | 16.33     | -10.42    | -14.2     | -0.4219   |
# Train Sharpe Ratio: 0.304, Validation Sharpe Ratio: 0.169
# Debug: L2 penalty: 0.3164539293450371
# Debug: L1 penalty: 0.050203920797985566
# Debug: Objective function value (with penalty): 1.9983421498569771
# --------------------------------------------------
# | 8         | 1.998     | 19.43     | -10.32    | 6.885     | 10.46     | -10.49    | 9.129     | -5.289    | 5.292     | 5.341     | 1.431     | -16.39    | 13.41     | -7.169    | -12.54    | -18.37    | 3.636     | 7.103     | -19.34    | 0.4837    | -10.94    | 5.807     | -13.03    |
# Train Sharpe Ratio: -1.582, Validation Sharpe Ratio: -1.0
# Debug: L2 penalty: -1.944766690724106
# Debug: L1 penalty: -0.2987697953770798
# Debug: Objective function value (with penalty): -10.666463513898815
# --------------------------------------------------
# | 9         | -10.67    | 7.638     | -4.531    | 17.47     | -14.5     | -6.357    | -15.46    | 16.99     | 15.09     | -9.682    | 6.399     | 12.69     | 2.208     | 1.186     | -10.33    | -16.28    | 15.89     | 16.02     | 5.324     | -6.439    | -6.032    | 9.038     | 15.88     |
# Train Sharpe Ratio: 0.633, Validation Sharpe Ratio: -0.227
# Debug: L2 penalty: 0.32161269264500425
# Debug: L1 penalty: 0.04886917099496589
# Debug: Objective function value (with penalty): 1.6595181363600302
# --------------------------------------------------
# | 10        | 1.66      | 15.48     | 11.2      | 5.681     | -16.63    | -13.53    | 15.94     | 4.257     | -19.63    | -15.94    | 6.54      | -19.8     | -13.57    | 1.949     | 7.676     | 6.078     | -11.03    | 8.487     | -10.51    | -6.984    | 9.86      | 5.985     | 13.97     |
# Train Sharpe Ratio: 0.584, Validation Sharpe Ratio: -0.604
# Debug: L2 penalty: -0.014191253224683795
# Debug: L1 penalty: -0.0021300564355394612
# Debug: Objective function value (with penalty): -0.08367869033977683
# --------------------------------------------------
# | 11        | -0.08368  | 6.305     | 2.732     | -16.25    | -5.291    | -9.392    | -10.24    | 18.92     | -4.276    | 15.68     | 5.246     | 11.79     | 0.1055    | 3.076     | -0.2993   | -12.19    | 8.898     | -8.769    | -19.03    | 5.819     | -12.92    | 17.62     | 18.16     |
# Train Sharpe Ratio: -0.936, Validation Sharpe Ratio: -1.114
# Debug: L2 penalty: -1.8642801498911346
# Debug: L1 penalty: -0.2518638307359793
# Debug: Objective function value (with penalty): -8.133856019372887
# --------------------------------------------------
# | 12        | -8.134    | 16.59     | -5.194    | -19.38    | 17.13     | -2.873    | 18.67     | 18.54     | 14.12     | -8.222    | -4.596    | 14.05     | -7.323    | -13.22    | 2.272     | 17.45     | 7.841     | 2.802     | -16.11    | 4.6       | 19.6      | -14.4     | 0.7332    |
# Train Sharpe Ratio: -1.363, Validation Sharpe Ratio: -1.363
# Debug: L2 penalty: -1.8100290403115906
# Debug: L1 penalty: -0.2915733116619431
# Debug: Objective function value (with penalty): -11.528397648026464
# --------------------------------------------------
# | 13        | -11.53    | 15.09     | 9.631     | 7.881     | 8.099     | -5.62     | -8.256    | 12.37     | 12.4      | 14.68     | 16.53     | 0.4537    | 0.06065   | 11.93     | 5.999     | 8.079     | 11.83     | 15.6      | -6.48     | -4.977    | -16.24    | 3.131     | -18.56    |
# Train Sharpe Ratio: 0.996, Validation Sharpe Ratio: 0.666
# Debug: L2 penalty: 1.081534323573742
# Debug: L1 penalty: 0.1600779768448936
# Debug: Objective function value (with penalty): 7.068387699581364
# --------------------------------------------------
# | 14        | 7.068     | -1.376    | 1.706     | -8.538    | 3.633     | -18.78    | -18.51    | 12.9      | -5.592    | -14.92    | 0.8897    | 10.8      | -11.37    | 4.916     | -16.59    | -17.93    | 1.254     | 1.625     | 5.497     | 9.044     | 19.03     | 0.652     | -7.082    |
# Train Sharpe Ratio: 0.012, Validation Sharpe Ratio: -0.135
# Debug: L2 penalty: -0.08259423260101771
# Debug: L1 penalty: -0.013094193645585703
# Debug: Objective function value (with penalty): -0.5193115737533966
# --------------------------------------------------
# | 15        | -0.5193   | 11.81     | -9.167    | -2.441    | -16.86    | -18.99    | 18.51     | 13.44     | 7.839     | -3.642    | -13.07    | -13.74    | -9.99     | 1.969     | 8.584     | 6.408     | -8.803    | 18.19     | 9.516     | 2.174     | 4.469     | -3.216    | -10.09    |
# Train Sharpe Ratio: 1.317, Validation Sharpe Ratio: 0.57
# Debug: L2 penalty: 1.3111212775345873
# Debug: L1 penalty: 0.1893662450732237
# Debug: Objective function value (with penalty): 7.93451247739219
# --------------------------------------------------
# | 16        | 7.935     | -5.761    | 10.31     | -19.42    | -15.36    | -18.16    | -18.37    | 14.22     | 8.146     | -1.033    | -16.09    | -0.3354   | -1.061    | -13.07    | -2.646    | -4.06     | 4.634     | 5.404     | -18.19    | -5.015    | 5.034     | 0.1255    | 14.26     |
# Train Sharpe Ratio: -1.044, Validation Sharpe Ratio: -0.56
# Debug: L2 penalty: -1.452402310412208
# Debug: L1 penalty: -0.19605292742454225
# Debug: Objective function value (with penalty): -6.371544762163249
# --------------------------------------------------
# | 17        | -6.372    | 6.348     | -13.48    | -17.18    | 5.697     | -18.94    | 3.431     | 17.61     | 3.019     | -4.473    | 5.732     | -1.67     | 1.825     | 17.66     | -4.556    | 18.45     | 16.21     | -12.17    | -17.23    | -15.97    | -19.27    | -16.22    | 7.32      |
# Train Sharpe Ratio: -1.304, Validation Sharpe Ratio: -1.055
# Debug: L2 penalty: -1.9445036807271325
# Debug: L1 penalty: -0.2952431680203
# Debug: Objective function value (with penalty): -9.555253151252568
# --------------------------------------------------
# | 18        | -9.555    | -17.15    | -7.241    | 13.8      | -19.07    | 12.58     | -8.726    | -15.27    | 7.869     | 5.158     | 15.1      | 9.403     | 12.14     | -8.719    | -12.9     | 10.02     | 12.27     | 19.62     | -3.495    | -5.119    | 11.06     | -6.368    | 17.23     |
# Train Sharpe Ratio: -2.591, Validation Sharpe Ratio: -1.365
# Debug: L2 penalty: -3.1568076989686222
# Debug: L1 penalty: -0.45666567660979196
# Debug: Objective function value (with penalty): -16.16652662442159
# --------------------------------------------------
# | 19        | -16.17    | 14.34     | -2.84     | 10.03     | 10.18     | -15.88    | 16.1      | 0.2101    | 13.06     | -7.198    | 15.82     | -4.432    | -19.57    | 16.22     | -16.35    | -7.227    | 18.0      | 18.02     | 2.938     | 5.273     | -2.062    | -8.272    | -6.853    |
# Train Sharpe Ratio: 0.462, Validation Sharpe Ratio: 0.395
# Debug: L2 penalty: 0.6981148936188574
# Debug: L1 penalty: 0.10313296888895532
# Debug: Objective function value (with penalty): 3.4837521374921874
# --------------------------------------------------
# | 20        | 3.484     | 6.901     | 10.09     | 11.66     | 11.58     | -16.35    | -0.2232   | -17.7     | 1.981     | -2.339    | 15.51     | -5.963    | -15.32    | -14.28    | 10.46     | 4.729     | -15.96    | -16.64    | 8.039     | -17.09    | 12.87     | 8.25      | -16.75    |
# Train Sharpe Ratio: 1.477, Validation Sharpe Ratio: 0.816
# Debug: L2 penalty: 1.4229699523950965
# Debug: L1 penalty: 0.22991775248423837
# Debug: Objective function value (with penalty): 9.812112295120665
# --------------------------------------------------
# | 21        | 9.812     | 1.502     | 7.311     | -19.3     | -5.494    | -14.62    | -16.57    | 9.318     | -6.421    | -6.705    | -11.12    | -7.871    | -12.95    | -16.96    | -4.462    | -15.38    | -6.285    | -0.006284 | -10.16    | 1.37      | 16.15     | 3.946     | -6.633    |
# Train Sharpe Ratio: -1.613, Validation Sharpe Ratio: -1.184
# Debug: L2 penalty: -2.3155222725238125
# Debug: L1 penalty: -0.34461111309519527
# Debug: Objective function value (with penalty): -11.32486661438099
# --------------------------------------------------
# | 22        | -11.32    | -8.757    | -5.354    | -5.328    | 8.452     | -19.54    | 17.83     | -15.38    | 14.43     | 10.14     | 2.496     | -14.73    | 19.71     | 15.07     | 7.271     | 9.814     | 10.88     | 14.08     | 11.73     | 11.85     | 12.2      | -11.3     | 0.0778    |
# Train Sharpe Ratio: -0.664, Validation Sharpe Ratio: -1.083
# Debug: L2 penalty: -1.3782960069569719
# Debug: L1 penalty: -0.1969748258119434
# Debug: Objective function value (with penalty): -7.1597291672310845
# --------------------------------------------------
# | 23        | -7.16     | -4.149    | 9.876     | -5.076    | 15.93     | -1.627    | -12.0     | 3.443     | -15.37    | -13.05    | 16.0      | -1.093    | -17.45    | -0.2364   | 15.2      | 12.72     | 16.02     | 10.12     | -11.39    | -3.705    | 19.67     | 2.815     | 18.55     |
# Train Sharpe Ratio: -0.808, Validation Sharpe Ratio: -0.804
# Debug: L2 penalty: -1.2808124355178974
# Debug: L1 penalty: -0.1849306852543425
# Debug: Objective function value (with penalty): -6.5942568792277605
# --------------------------------------------------
# | 24        | -6.594    | 11.68     | 14.68     | -11.89    | 19.79     | 14.93     | 2.302     | 7.894     | 0.723     | 5.172     | -16.86    | 8.869     | -5.743    | 7.986     | -6.956    | 1.749     | 18.1      | -17.83    | -12.29    | -2.114    | -15.46    | 19.34     | -7.081    |
# Train Sharpe Ratio: 0.303, Validation Sharpe Ratio: 0.063
# Debug: L2 penalty: 0.27019062476191036
# Debug: L1 penalty: 0.03850211671784025
# Debug: Objective function value (with penalty): 1.5213072585202494
# --------------------------------------------------
# | 25        | 1.521     | 5.936     | 2.867     | -3.21     | -0.1664   | 11.91     | -14.25    | 14.08     | 3.377     | 9.162     | -14.04    | 9.455     | -19.3     | -1.696    | 9.83      | -17.94    | 11.14     | -18.55    | -4.899    | -19.53    | -1.002    | 17.47     | -0.5798   |
# Train Sharpe Ratio: -1.911, Validation Sharpe Ratio: -1.566
# Debug: L2 penalty: -2.7688279640238815
# Debug: L1 penalty: -0.3985609173272228
# Debug: Objective function value (with penalty): -14.217611118648898
# --------------------------------------------------
# | 26        | -14.22    | 17.47     | -3.715    | -3.444    | 12.05     | 8.264     | -6.353    | 17.42     | 2.573     | -15.01    | -1.605    | -19.68    | -8.01     | -15.11    | 12.78     | -0.6837   | 17.53     | 11.83     | 2.022     | 9.415     | -10.74    | 16.15     | 17.42     |
# Train Sharpe Ratio: 1.416, Validation Sharpe Ratio: 0.825
# Debug: L2 penalty: 2.6470198108268415
# Debug: L1 penalty: 0.32791045174697747
# Debug: Objective function value (with penalty): 8.23006973742618
# --------------------------------------------------
# | 27        | 8.23      | 3.301     | -2.569    | -18.54    | -20.0     | -20.0     | -18.19    | 9.252     | -2.452    | 7.366     | -14.72    | 9.347     | -19.14    | -11.09    | -16.76    | -20.0     | -17.71    | -7.153    | -20.0     | -17.0     | 15.86     | -5.589    | -16.6     |
# Train Sharpe Ratio: 0.487, Validation Sharpe Ratio: 0.286
# Debug: L2 penalty: 0.5161283488437052
# Debug: L1 penalty: 0.07464246009399154
# Debug: Objective function value (with penalty): 3.2742291910623025
# --------------------------------------------------
# | 28        | 3.274     | 17.43     | 2.107     | 2.772     | -16.35    | -16.56    | 7.235     | 3.172     | -19.07    | -8.004    | 0.9511    | -15.22    | -14.09    | -1.959    | 0.3348    | -1.016    | -3.49     | 11.58     | -1.493    | 5.582     | 17.33     | -17.71    | 9.672     |
# Train Sharpe Ratio: 1.471, Validation Sharpe Ratio: 0.256
# Debug: L2 penalty: 1.640132628120149
# Debug: L1 penalty: 0.22778312828586453
# Debug: Objective function value (with penalty): 6.767084243593986
# --------------------------------------------------
# | 29        | 6.767     | 4.741     | -9.807    | -12.69    | 14.83     | 17.62     | 11.5      | 15.81     | -0.7298   | -11.97    | -12.89    | -18.44    | -11.89    | -14.83    | 15.34     | -15.94    | -9.611    | 19.41     | -13.09    | -0.3424   | 3.334     | -10.35    | -18.63    |
# Train Sharpe Ratio: 1.203, Validation Sharpe Ratio: 0.648
# Debug: L2 penalty: 1.0601990004687238
# Debug: L1 penalty: 0.18157565547571158
# Debug: Objective function value (with penalty): 8.013225344055563
# --------------------------------------------------
# | 30        | 8.013     | -8.3      | 6.88      | -10.1     | -8.631    | -14.39    | -18.64    | 10.6      | -4.006    | -8.46     | -8.401    | -2.157    | -0.9912   | -12.88    | -8.671    | -4.948    | -6.579    | -10.19    | -0.9776   | 13.39     | 18.26     | 15.1      | 3.638     |
# Train Sharpe Ratio: 0.74, Validation Sharpe Ratio: 0.162
# Debug: L2 penalty: 0.6983279915898475
# Debug: L1 penalty: 0.11066111741757406
# Debug: Objective function value (with penalty): 3.701010890992578
# --------------------------------------------------
# | 31        | 3.701     | -12.81    | -11.17    | 19.16     | -14.18    | -11.82    | -4.099    | 7.888     | 10.54     | 11.87     | 12.47     | -10.25    | 15.89     | -16.31    | 4.621     | -12.21    | -13.81    | -8.693    | -4.194    | 16.58     | -9.789    | -5.328    | -11.69    |
# Train Sharpe Ratio: 0.305, Validation Sharpe Ratio: 0.47
# Debug: L2 penalty: 0.6701701192403965
# Debug: L1 penalty: 0.09827135498174626
# Debug: Objective function value (with penalty): 3.106558525777857
# --------------------------------------------------
# | 32        | 3.107     | -18.12    | 5.563     | 8.245     | -11.51    | 2.019     | -4.471    | -10.69    | 4.462     | -13.87    | -17.83    | 13.57     | -10.32    | 18.14     | -10.07    | -14.33    | 14.38     | -16.95    | -11.9     | 17.74     | -12.83    | -13.37    | -3.222    |
# Train Sharpe Ratio: 1.208, Validation Sharpe Ratio: 0.733
# Debug: L2 penalty: 2.825914472610587
# Debug: L1 penalty: 0.31911449108655526
# Debug: Objective function value (with penalty): 6.559971036302856
# --------------------------------------------------
# | 33        | 6.56      | -14.28    | -1.216    | 6.048     | -20.0     | -20.0     | -10.55    | 4.999     | -20.0     | -20.0     | -17.97    | 0.6424    | -18.72    | -20.0     | 9.785     | -20.0     | -20.0     | -17.39    | -20.0     | 20.0      | 14.87     | -12.35    | -20.0     |
# Train Sharpe Ratio: 0.102, Validation Sharpe Ratio: -0.063
# Debug: L2 penalty: 0.03107715170629548
# Debug: L1 penalty: 0.00441161376611424
# Debug: Objective function value (with penalty): 0.15951123452759022
# --------------------------------------------------
# | 34        | 0.1595    | 6.194     | 0.1894    | 3.893     | -3.067    | -19.38    | 18.73     | -14.2     | -0.2034   | 2.523     | -9.247    | 15.9      | 19.29     | -13.12    | -13.0     | 3.789     | -15.87    | 9.686     | 10.85     | 16.37     | 16.11     | -10.91    | -3.703    |
# Train Sharpe Ratio: -1.608, Validation Sharpe Ratio: -0.486
# Debug: L2 penalty: -1.267793042072364
# Debug: L1 penalty: -0.2151262773269146
# Debug: Objective function value (with penalty): -8.987080680600723
# --------------------------------------------------
# | 35        | -8.987    | -2.596    | -5.947    | 5.826     | -9.719    | -16.42    | 5.697     | 9.355     | 17.66     | -7.318    | -7.295    | -7.186    | 1.963     | -11.72    | 9.981     | 9.359     | 12.74     | 4.772     | 11.0      | 5.067     | -18.72    | -18.27    | -6.865    |
# Train Sharpe Ratio: 1.405, Validation Sharpe Ratio: 0.645
# Debug: L2 penalty: 3.4366902776776165
# Debug: L1 penalty: 0.3750121564501033
# Debug: Objective function value (with penalty): 6.43829756587228
# --------------------------------------------------
# | 36        | 6.438     | -20.0     | 20.0      | -20.0     | -20.0     | -20.0     | -20.0     | 9.452     | -10.09    | -20.0     | -20.0     | 20.0      | -20.0     | 9.436     | -20.0     | -20.0     | -19.08    | -3.539    | -20.0     | 17.61     | 20.0      | 8.044     | 8.619     |
# Train Sharpe Ratio: 1.555, Validation Sharpe Ratio: 0.818
# Debug: L2 penalty: 3.180534817015871
# Debug: L1 penalty: 0.36737199237122176
# Debug: Objective function value (with penalty): 8.317093190612905
# --------------------------------------------------
# | 37        | 8.317     | 20.0      | -20.0     | -16.99    | -20.0     | 6.154     | 10.65     | -12.74    | -19.14    | 7.455     | -15.04    | -20.0     | -6.897    | -20.0     | 5.11      | -20.0     | -20.0     | 1.029     | -20.0     | 3.691     | 20.0      | 4.727     | -20.0     |
# Train Sharpe Ratio: 1.852, Validation Sharpe Ratio: 0.618
# Debug: L2 penalty: 4.605761103215752
# Debug: L1 penalty: 0.4811559546469568
# Debug: Objective function value (with penalty): 7.263082942137293
# --------------------------------------------------
# | 38        | 7.263     | 12.91     | 20.0      | -20.0     | -20.0     | 13.63     | 5.775     | 20.0      | -20.0     | -16.51    | -20.0     | -20.0     | -20.0     | -20.0     | 0.7845    | -20.0     | -20.0     | 20.0      | -20.0     | -20.0     | 20.0      | -20.0     | -20.0     |
# Train Sharpe Ratio: 1.279, Validation Sharpe Ratio: 0.956
# Debug: L2 penalty: 3.904041900596641
# Debug: L1 penalty: 0.41797469447720875
# Debug: Objective function value (with penalty): 6.852983404926149
# --------------------------------------------------
# | 39        | 6.853     | -0.5631   | -20.0     | -20.0     | -20.0     | -20.0     | -20.0     | -14.03    | -20.0     | -20.0     | 7.638     | 7.556     | -18.53    | -20.0     | -20.0     | -20.0     | -20.0     | -20.0     | 20.0      | 13.44     | 20.0      | 12.27     | -20.0     |
# Train Sharpe Ratio: 1.378, Validation Sharpe Ratio: 0.742
# Debug: L2 penalty: 3.908857808218169
# Debug: L1 penalty: 0.4129943055803594
# Debug: Objective function value (with penalty): 6.278147886201473
# --------------------------------------------------
# | 40        | 6.278     | 9.389     | -20.0     | -20.0     | -20.0     | -20.0     | -20.0     | 20.0      | -9.7      | -11.25    | -20.0     | -20.0     | 15.99     | -20.0     | -20.0     | -20.0     | -20.0     | 20.0      | -20.0     | 20.0      | 20.0      | -3.294    | -20.0     |
# Train Sharpe Ratio: -0.591, Validation Sharpe Ratio: -0.644
# Debug: L2 penalty: -0.9196386242903578
# Debug: L1 penalty: -0.1384161725575245
# Debug: Objective function value (with penalty): -5.116945203152117
# --------------------------------------------------
# | 41        | -5.117    | -1.336    | 19.51     | 9.968     | 15.9      | 15.37     | -14.06    | -2.236    | -4.258    | -9.87     | 16.03     | -15.12    | -13.93    | -16.34    | -8.388    | -15.69    | -8.304    | -0.4696   | 10.99     | -2.166    | -9.068    | -3.407    | 11.76     |
# Train Sharpe Ratio: 0.041, Validation Sharpe Ratio: -0.021
# Debug: L2 penalty: 0.011069130551234806
# Debug: L1 penalty: 0.0018936143534180564
# Debug: Objective function value (with penalty): 0.08703725509534714
# --------------------------------------------------
# | 42        | 0.08704   | -13.33    | 3.21      | 16.31     | -5.677    | -15.76    | 0.1867    | 2.84      | 11.51     | 2.142     | 12.41     | -4.066    | 15.15     | -12.28    | -4.977    | -11.91    | -0.432    | -14.67    | 7.799     | 6.542     | -9.731    | -5.146    | -13.28    |
# Train Sharpe Ratio: 1.092, Validation Sharpe Ratio: 0.478
# Debug: L2 penalty: 0.9487244379807844
# Debug: L1 penalty: 0.16288183020166286
# Debug: Objective function value (with penalty): 6.7383937318175535
# --------------------------------------------------
# | 43        | 6.738     | 12.66     | 9.104     | -12.92    | 5.816     | -14.51    | -18.55    | 12.22     | -13.42    | -9.268    | 9.763     | 12.35     | 6.455     | 4.726     | -12.38    | -14.3     | -1.387    | 9.111     | 5.865     | 1.174     | 13.01     | -2.331    | -6.164    |
# Train Sharpe Ratio: -1.751, Validation Sharpe Ratio: -1.383
# Debug: L2 penalty: -2.30432866057146
# Debug: L1 penalty: -0.3526972085521887
# Debug: Objective function value (with penalty): -13.012974130876351
# --------------------------------------------------
# | 44        | -13.01    | 1.529     | 9.28      | 18.19     | 16.68     | -14.97    | -3.955    | 5.827     | 15.5      | 9.892     | 15.61     | 7.327     | 19.63     | 11.29     | -6.005    | -2.904    | 7.496     | 5.635     | -9.376    | 12.45     | -16.71    | -12.77    | -2.061    |
# Train Sharpe Ratio: 1.469, Validation Sharpe Ratio: 0.965
# Debug: L2 penalty: 3.879701963667458
# Debug: L1 penalty: 0.4246025180534716
# Debug: Objective function value (with penalty): 7.865695518279073
# --------------------------------------------------
# | 45        | 7.866     | 13.67     | 20.0      | -20.0     | -20.0     | -20.0     | -20.0     | -5.258    | -20.0     | -20.0     | -3.067    | 18.31     | 20.0      | -20.0     | -8.484    | -20.0     | 6.19      | -20.0     | -20.0     | -9.147    | 20.0      | 4.766     | -20.0     |
# Train Sharpe Ratio: -0.29, Validation Sharpe Ratio: -0.074
# Debug: L2 penalty: -0.2585530061782063
# Debug: L1 penalty: -0.03818667957284841
# Debug: Objective function value (with penalty): -1.523260314248945
# --------------------------------------------------
# | 46        | -1.523    | 19.89     | 2.474     | -0.3742   | -11.82    | -18.26    | 18.64     | -14.15    | -6.198    | -6.487    | 0.8532    | 3.828     | -5.676    | 1.488     | 10.08     | -3.002    | -10.12    | -8.077    | 8.596     | -12.01    | 19.24     | 16.92     | 11.63     |
# Train Sharpe Ratio: 0.005, Validation Sharpe Ratio: -0.756
# Debug: L2 penalty: -0.5441440675755124
# Debug: L1 penalty: -0.08141786315680168
# Debug: Objective function value (with penalty): -3.1294380692676858
# --------------------------------------------------
# | 47        | -3.129    | -8.687    | -13.45    | -9.003    | -17.52    | 6.126     | -13.7     | 19.54     | 17.49     | 11.31     | 2.031     | -8.187    | 5.228     | -0.6932   | 0.7898    | -19.95    | -15.54    | 8.734     | 6.311     | 5.034     | -15.34    | 2.671     | 9.492     |
# Train Sharpe Ratio: 1.678, Validation Sharpe Ratio: 0.649
# Debug: L2 penalty: 4.408685271157454
# Debug: L1 penalty: 0.4476272181456658
# Debug: Objective function value (with penalty): 6.77868751069688
# --------------------------------------------------
# | 48        | 6.779     | -20.0     | 20.0      | -20.0     | -20.0     | -20.0     | -20.0     | 20.0      | -4.323    | 20.0      | -20.0     | -20.0     | 0.8726    | -20.0     | 20.0      | -20.0     | 0.5946    | -20.0     | -20.0     | -18.93    | 20.0      | 20.0      | -20.0     |
# Train Sharpe Ratio: 1.524, Validation Sharpe Ratio: 0.928
# Debug: L2 penalty: 4.091506269969249
# Debug: L1 penalty: 0.43628210992187644
# Debug: Objective function value (with penalty): 7.732211620108874
# --------------------------------------------------
# | 49        | 7.732     | -20.0     | -1.092    | -20.0     | -20.0     | -20.0     | -20.0     | -20.0     | -20.0     | 17.69     | -20.0     | 6.059     | -2.656    | -20.0     | -20.0     | -20.0     | 15.0      | -20.0     | -20.0     | 20.0      | -7.796    | 5.57      | -20.0     |
# Train Sharpe Ratio: 1.065, Validation Sharpe Ratio: 0.753
# Debug: L2 penalty: 3.6333852959107595
# Debug: L1 penalty: 0.3783847496209372
# Debug: Objective function value (with penalty): 5.078229954468303
# --------------------------------------------------
# | 50        | 5.078     | -20.0     | -11.03    | -20.0     | -20.0     | 20.0      | -20.0     | -20.0     | 20.0      | -16.91    | -20.0     | -20.0     | -20.0     | -20.0     | 18.43     | -20.0     | -20.0     | -20.0     | -20.0     | -20.0     | 14.7      | -15.2     | -20.0     |
# Train Sharpe Ratio: -0.975, Validation Sharpe Ratio: -1.967
# Debug: L2 penalty: -1.9081074512532306
# Debug: L1 penalty: -0.3073183177210077
# Debug: Objective function value (with penalty): -12.494574231025764
# --------------------------------------------------
# | 51        | -12.49    | -10.49    | 17.65     | 4.397     | -8.213    | -16.4     | -8.964    | 17.27     | 11.95     | -14.23    | 16.66     | -1.272    | 15.58     | -0.9342   | 11.91     | 5.529     | -9.037    | 5.674     | -12.37    | 2.25      | -6.186    | -8.849    | 3.111     |
# Train Sharpe Ratio: 1.152, Validation Sharpe Ratio: 0.666
# Debug: L2 penalty: 3.117080260509125
# Debug: L1 penalty: 0.33705639533279086
# Debug: Objective function value (with penalty): 5.635863344158084
# --------------------------------------------------
# | 52        | 5.636     | 20.0      | 20.0      | -20.0     | -20.0     | -20.0     | -20.0     | 20.0      | -20.0     | 12.44     | -20.0     | 10.01     | 3.515     | -12.26    | -20.0     | -20.0     | -4.189    | -17.37    | 20.0      | 20.0      | 20.0      | -11.01    | -20.0     |
# Train Sharpe Ratio: 0.863, Validation Sharpe Ratio: 0.695
# Debug: L2 penalty: 0.9568937280042961
# Debug: L1 penalty: 0.14672747214890067
# Debug: Objective function value (with penalty): 6.6863787998468025
# --------------------------------------------------
# | 53        | 6.686     | 5.471     | -3.113    | -2.322    | -15.53    | -8.81     | -5.828    | -9.451    | 0.3515    | -12.05    | 17.31     | 11.2      | 1.141     | -8.97     | -7.319    | -0.2693   | -13.14    | 1.588     | -0.1227   | 19.88     | -18.55    | -15.53    | -10.42    |
# Train Sharpe Ratio: 1.239, Validation Sharpe Ratio: 0.922
# Debug: L2 penalty: 3.9176918852209686
# Debug: L1 penalty: 0.4102964827477095
# Debug: Objective function value (with penalty): 6.4770116320313225
# --------------------------------------------------
# | 54        | 6.477     | 20.0      | -20.0     | -9.56     | -20.0     | -20.0     | -20.0     | -20.0     | -20.0     | -3.448    | 20.0      | 3.595     | 5.73      | -20.0     | -17.39    | -20.0     | -20.0     | -20.0     | -20.0     | 20.0      | -20.0     | -20.0     | -20.0     |
# Train Sharpe Ratio: 1.039, Validation Sharpe Ratio: 0.562
# Debug: L2 penalty: 0.9823495358003074
# Debug: L1 penalty: 0.15791154224940018
# Debug: Objective function value (with penalty): 6.864738921950291
# --------------------------------------------------
# | 55        | 6.865     | -3.375    | 12.85     | -9.395    | -1.966    | -13.31    | -13.97    | 3.395     | 4.435     | 0.2226    | -3.31     | -16.6     | -19.31    | -8.472    | -16.09    | -17.57    | -6.264    | -5.654    | -2.775    | 4.935     | 8.946     | -11.23    | -13.19    |
# Train Sharpe Ratio: 0.985, Validation Sharpe Ratio: 0.684
# Debug: L2 penalty: 1.0305107932982507
# Debug: L1 penalty: 0.1668866147934057
# Debug: Objective function value (with penalty): 7.147602591908345
# --------------------------------------------------
# | 56        | 7.148     | -0.7797   | 3.928     | -12.78    | 5.063     | -7.318    | -19.8     | 17.87     | -11.85    | -14.1     | -14.48    | 14.22     | -8.016    | -2.059    | -10.46    | -4.334    | 11.13     | 1.814     | 9.034     | 5.675     | 14.89     | -0.9755   | -9.416    |
# Train Sharpe Ratio: 1.458, Validation Sharpe Ratio: 0.871
# Debug: L2 penalty: 3.658896101298443
# Debug: L1 penalty: 0.41198728741788443
# Debug: Objective function value (with penalty): 7.574116611283673
# --------------------------------------------------
# | 57        | 7.574     | 11.75     | 7.547     | -20.0     | -20.0     | 1.397     | -20.0     | -20.0     | -20.0     | -18.02    | -20.0     | 20.0      | -17.92    | -20.0     | -10.36    | -12.96    | -20.0     | 20.0      | -8.053    | 15.46     | -16.26    | -14.07    | -20.0     |
# Train Sharpe Ratio: 1.214, Validation Sharpe Ratio: 0.798
# Debug: L2 penalty: 2.891272546690531
# Debug: L1 penalty: 0.3236454981236263
# Debug: Objective function value (with penalty): 6.845081955185844
# --------------------------------------------------
# | 58        | 6.845     | 11.62     | -5.153    | -20.0     | -20.0     | 20.0      | -20.0     | -1.578    | -20.0     | -20.0     | 9.855     | 20.0      | -6.015    | 8.049     | -7.688    | -20.0     | -20.0     | -11.25    | 0.5079    | 20.0      | 20.0      | -20.0     | -20.0     |
# Train Sharpe Ratio: -1.144, Validation Sharpe Ratio: -0.741
# Debug: L2 penalty: -1.4517797420453369
# Debug: L1 penalty: -0.21289067950446525
# Debug: Objective function value (with penalty): -7.760329578450197
# --------------------------------------------------
# | 59        | -7.76     | 19.65     | -17.49    | 17.27     | -1.299    | 12.06     | 15.38     | -18.49    | -3.324    | -16.12    | 7.243     | -9.733    | 15.29     | -7.737    | 5.175     | 3.009     | -4.423    | 16.79     | -6.554    | -1.189    | 8.986     | -6.465    | -12.2     |
# Train Sharpe Ratio: -1.018, Validation Sharpe Ratio: -0.174
# Debug: L2 penalty: -1.114576409761718
# Debug: L1 penalty: -0.15121212461164438
# Debug: Objective function value (with penalty): -4.694211465626637
# --------------------------------------------------
# | 60        | -4.694    | 18.65     | -3.075    | -19.81    | 10.7      | 10.81     | 19.37     | -18.69    | 5.832     | -14.27    | -15.65    | -13.81    | -16.37    | 0.1623    | -13.84    | 1.468     | 17.41     | -7.325    | 5.6       | 3.944     | -8.864    | 17.49     | 10.59     |
# Train Sharpe Ratio: 1.384, Validation Sharpe Ratio: 0.861
# Debug: L2 penalty: 4.095009694805443
# Debug: L1 penalty: 0.4407093262334784
# Debug: Objective function value (with penalty): 6.68928097896108
# --------------------------------------------------
# | 61        | 6.689     | -15.52    | 18.27     | -20.0     | -20.0     | -20.0     | -20.0     | -20.0     | -20.0     | -7.782    | 14.27     | 20.0      | -20.0     | -20.0     | -20.0     | 20.0      | -20.0     | -20.0     | 14.05     | 20.0      | -12.29    | -10.43    | -20.0     |
# Train Sharpe Ratio: 1.742, Validation Sharpe Ratio: 0.8
# Debug: L2 penalty: 4.166547504697587
# Debug: L1 penalty: 0.4470098392026997
# Debug: Objective function value (with penalty): 8.096442656099711
# --------------------------------------------------
# | 62        | 8.096     | -18.2     | 5.424     | -20.0     | -20.0     | -20.0     | -20.0     | -4.113    | -20.0     | 20.0      | -19.53    | 20.0      | -20.0     | -20.0     | 19.91     | -20.0     | -4.419    | 20.0      | 2.441     | 5.722     | 20.0      | 11.93     | -20.0     |
# Train Sharpe Ratio: 1.241, Validation Sharpe Ratio: 0.854
# Debug: L2 penalty: 3.7700418714179733
# Debug: L1 penalty: 0.3934086376782917
# Debug: Objective function value (with penalty): 6.311549490903737
# --------------------------------------------------
# | 63        | 6.312     | -15.48    | -20.0     | -20.0     | -20.0     | -20.0     | -10.41    | -20.0     | 20.0      | -6.773    | -20.0     | 20.0      | 1.627     | -20.0     | -1.28     | -20.0     | -20.0     | -20.0     | -20.0     | 20.0      | -20.0     | 20.0      | -20.0     |
# Train Sharpe Ratio: 1.132, Validation Sharpe Ratio: 0.716
# Debug: L2 penalty: 1.3121141340048292
# Debug: L1 penalty: 0.20583049893272706
# Debug: Objective function value (with penalty): 7.722055367062442
# --------------------------------------------------
# | 64        | 7.722     | 9.02      | -2.264    | -12.64    | 16.31     | -16.47    | -9.768    | 16.76     | -12.05    | -18.37    | 12.44     | 6.494     | -6.966    | 3.479     | -11.34    | -19.72    | -9.872    | 2.32      | 5.957     | 7.065     | 13.54     | -4.007    | -5.907    |
# Train Sharpe Ratio: -0.4, Validation Sharpe Ratio: -0.716
# Debug: L2 penalty: -0.6879168876631869
# Debug: L1 penalty: -0.1132109297224463
# Debug: Objective function value (with penalty): -4.778872182614367
# --------------------------------------------------
# | 65        | -4.779    | 16.38     | -13.08    | 5.731     | 8.105     | 1.839     | 7.345     | 7.155     | 7.088     | -0.2771   | 5.776     | -9.809    | 7.414     | -5.184    | -2.677    | -8.049    | 12.31     | 18.46     | -19.98    | -9.13     | -9.622    | 9.228     | -18.24    |
# Train Sharpe Ratio: 1.329, Validation Sharpe Ratio: 0.922
# Debug: L2 penalty: 3.2649152356919093
# Debug: L1 penalty: 0.3560963621301013
# Debug: Objective function value (with penalty): 7.633988402177989
# --------------------------------------------------
# | 66        | 7.634     | 8.666     | -20.0     | -20.0     | 20.0      | -20.0     | -20.0     | 0.2615    | -20.0     | 4.625     | 4.185     | 20.0      | -20.0     | -20.0     | 8.521     | -20.0     | -20.0     | -1.233    | 10.16     | 19.48     | -1.101    | -18.15    | -20.0     |
# Train Sharpe Ratio: 1.266, Validation Sharpe Ratio: 0.662
# Debug: L2 penalty: 1.0925029205027796
# Debug: L1 penalty: 0.17872533197932278
# Debug: Objective function value (with penalty): 8.368771747517899
# --------------------------------------------------
# | 67        | 8.369     | -2.538    | 7.674     | -11.62    | -5.919    | -11.18    | -12.52    | 0.7024    | -2.263    | 17.38     | -4.359    | -13.21    | -18.09    | -3.882    | -3.691    | -17.86    | -0.3672   | -6.655    | -3.273    | -4.515    | 16.4      | -9.64     | -11.67    |
# Train Sharpe Ratio: 1.49, Validation Sharpe Ratio: 0.967
# Debug: L2 penalty: 4.916276502781608
# Debug: L1 penalty: 0.4947001862608164
# Debug: Objective function value (with penalty): 6.8740233109575755
# --------------------------------------------------
# | 68        | 6.874     | -20.0     | 1.564     | -20.0     | 20.0      | -20.0     | -20.0     | 20.0      | -20.0     | -20.0     | -20.0     | 20.0      | -1.122    | -20.0     | -20.0     | -20.0     | -20.0     | -20.0     | 20.0      | -20.0     | 20.0      | 20.0      | -20.0     |
# Train Sharpe Ratio: 1.475, Validation Sharpe Ratio: 0.861
# Debug: L2 penalty: 4.101071001244459
# Debug: L1 penalty: 0.4281726145615867
# Debug: Objective function value (with penalty): 7.150756384193956
# --------------------------------------------------
# | 69        | 7.151     | -20.0     | 20.0      | -20.0     | -20.0     | -20.0     | -20.0     | 2.269     | -20.0     | 5.323     | -20.0     | 3.025     | -20.0     | -20.0     | -20.0     | -13.1     | 20.0      | -20.0     | -20.0     | -20.0     | 20.0      | -2.874    | 20.0      |
# Train Sharpe Ratio: 1.322, Validation Sharpe Ratio: 0.86
# Debug: L2 penalty: 3.9798527995334667
# Debug: L1 penalty: 0.41706816316903905
# Debug: Objective function value (with penalty): 6.513079037297495
# --------------------------------------------------
# | 70        | 6.513     | 20.0      | 7.533     | -20.0     | -3.713    | -20.0     | -20.0     | 20.0      | -20.0     | -20.0     | 20.0      | 20.0      | -20.0     | -20.0     | -5.998    | -20.0     | -20.0     | 6.36      | 20.0      | -20.0     | 20.0      | -18.68    | -20.0     |
# Train Sharpe Ratio: 1.4, Validation Sharpe Ratio: 0.978
# Debug: L2 penalty: 4.131439542628986
# Debug: L1 penalty: 0.4293099194695523
# Debug: Objective function value (with penalty): 7.329250537901463
# --------------------------------------------------
# | 71        | 7.329     | -20.0     | -20.0     | -20.0     | -20.0     | -20.0     | -20.0     | 20.0      | -20.0     | -20.0     | -20.0     | 20.0      | -2.211    | -20.0     | -20.0     | -20.0     | 10.63     | -0.985    | -20.0     | -5.104    | -20.0     | -2.141    | -20.0     |
# Train Sharpe Ratio: 1.059, Validation Sharpe Ratio: -0.131
# Debug: L2 penalty: 0.926424450062844
# Debug: L1 penalty: 0.1204538258275294
# Debug: Objective function value (with penalty): 3.5931217241096265
# --------------------------------------------------
# | 72        | 3.593     | 9.51      | -1.727    | -3.171    | -13.3     | 11.83     | 5.027     | -3.681    | -1.669    | 6.25      | 19.01     | 19.11     | -18.23    | -16.14    | 17.77     | -19.45    | -17.41    | 17.71     | -18.52    | -17.58    | 9.038     | 11.04     | 2.409     |
# Train Sharpe Ratio: 1.078, Validation Sharpe Ratio: 0.895
# Debug: L2 penalty: 3.761204242244978
# Debug: L1 penalty: 0.38629441682374754
# Debug: Objective function value (with penalty): 5.717501340931275
# --------------------------------------------------
# | 73        | 5.718     | -20.0     | -6.17     | -20.0     | 20.0      | -20.0     | -20.0     | -20.0     | -20.0     | -20.0     | -20.0     | 20.0      | 19.16     | -20.0     | -20.0     | -20.0     | 3.702     | -20.0     | 2.549     | 20.0      | 20.0      | -20.0     | -20.0     |
# Train Sharpe Ratio: -0.54, Validation Sharpe Ratio: -1.38
# Debug: L2 penalty: -1.7505023807580542
# Debug: L1 penalty: -0.23241433166921982
# Debug: Objective function value (with penalty): -7.617083287572726
# --------------------------------------------------
# | 74        | -7.617    | -14.25    | 19.57     | 19.03     | -1.82     | -3.665    | 17.76     | 9.89      | 16.31     | 18.1      | 16.35     | -2.898    | -16.58    | -19.68    | 13.2      | 6.614     | -4.411    | -3.593    | -7.756    | -19.29    | 5.656     | 4.539     | -1.115    |
# Train Sharpe Ratio: -0.463, Validation Sharpe Ratio: 0.224
# Debug: L2 penalty: -0.19523872721557234
# Debug: L1 penalty: -0.028865887683816798
# Debug: Objective function value (with penalty): -0.9708953851006109
# --------------------------------------------------
# | 75        | -0.9709   | 1.334     | 12.81     | -5.775    | 18.95     | -10.52    | -11.71    | -14.54    | 1.701     | -19.7     | -12.52    | 14.71     | 10.97     | -2.959    | -18.78    | 14.6      | -5.446    | -6.6      | 6.371     | -13.16    | -12.47    | -10.49    | -15.45    |
# Train Sharpe Ratio: -0.908, Validation Sharpe Ratio: -1.222
# Debug: L2 penalty: -1.449380980099531
# Debug: L1 penalty: -0.2286812205914129
# Debug: Objective function value (with penalty): -8.971937799309055
# --------------------------------------------------
# | 76        | -8.972    | 12.86     | -4.989    | -16.55    | 1.15      | 5.074     | 9.194     | 17.61     | -8.454    | 15.39     | 2.255     | 12.78     | 6.418     | 6.354     | 4.278     | -1.17     | 13.23     | -9.603    | -16.72    | -13.19    | 5.802     | 14.69     | 16.96     |
# Train Sharpe Ratio: 1.963, Validation Sharpe Ratio: 0.723
# Debug: L2 penalty: 4.062364817098787
# Debug: L1 penalty: 0.4494246864420481
# Debug: Objective function value (with penalty): 8.918210496459164
# --------------------------------------------------
# | 77        | 8.918     | 4.491     | 0.4432    | -20.0     | -20.0     | -20.0     | 20.0      | -10.08    | -20.0     | 16.87     | 10.27     | -20.0     | -20.0     | -20.0     | 5.421     | -20.0     | -20.0     | 10.69     | -20.0     | 13.66     | -20.0     | 2.715     | -20.0     |
# Train Sharpe Ratio: -1.597, Validation Sharpe Ratio: -1.445
# Debug: L2 penalty: -2.7102175328091596
# Debug: L1 penalty: -0.39141666639436185
# Debug: Objective function value (with penalty): -12.108365800796479
# --------------------------------------------------
# | 78        | -12.11    | 17.3      | 17.25     | 5.214     | -17.51    | -15.52    | -2.682    | 10.19     | 10.18     | -16.9     | 15.09     | 3.339     | 9.757     | 16.31     | -11.42    | -10.69    | 13.91     | 17.77     | 4.528     | 5.097     | 8.469     | 17.39     | -10.82    |
# Train Sharpe Ratio: 1.276, Validation Sharpe Ratio: 0.689
# Debug: L2 penalty: 3.630656174699573
# Debug: L1 penalty: 0.37883663083834535
# Debug: Objective function value (with penalty): 5.81550719446208
# --------------------------------------------------
# | 79        | 5.816     | 0.6084    | -5.15     | 20.0      | -20.0     | -20.0     | -20.0     | -20.0     | -20.0     | 20.0      | 20.0      | 20.0      | -20.0     | -20.0     | 15.2      | -20.0     | -20.0     | -20.0     | -8.473    | 16.15     | -20.0     | 20.0      | -20.0     |
# Train Sharpe Ratio: 0.446, Validation Sharpe Ratio: -0.894
# Debug: L2 penalty: -0.2910857883511864
# Debug: L1 penalty: -0.04586722706958597
# Debug: Objective function value (with penalty): -1.903046984579228
# --------------------------------------------------
# | 80        | -1.903    | 0.1727    | 18.13     | 9.651     | 12.12     | 4.073     | 12.11     | -14.89    | -0.3322   | 3.602     | -19.95    | -7.607    | 10.52     | -8.646    | 16.77     | -7.115    | -14.85    | 6.068     | -10.68    | 1.285     | 9.558     | 13.62     | -3.011    |
# Train Sharpe Ratio: 1.71, Validation Sharpe Ratio: 0.521
# Debug: L2 penalty: 4.633254294547415
# Debug: L1 penalty: 0.4738423495242067
# Debug: Objective function value (with penalty): 6.047903355928378
# --------------------------------------------------
# | 81        | 6.048     | -20.0     | -20.0     | -20.0     | -20.0     | 20.0      | 12.48     | 20.0      | -20.0     | 20.0      | -20.0     | -20.0     | -20.0     | -20.0     | 20.0      | -20.0     | -20.0     | 20.0      | -20.0     | 20.0      | 12.3      | -20.0     | -20.0     |
# Train Sharpe Ratio: -1.27, Validation Sharpe Ratio: -0.568
# Debug: L2 penalty: -1.6510503010126765
# Debug: L1 penalty: -0.23773249153072876
# Debug: Objective function value (with penalty): -7.301217207456596
# --------------------------------------------------
# | 82        | -7.301    | 13.0      | -8.582    | 15.1      | -5.154    | -3.179    | 13.12     | 17.45     | 18.63     | -3.401    | -6.155    | -15.69    | 8.3       | 18.74     | -8.135    | -16.15    | -9.199    | -17.27    | 4.838     | -11.1     | 15.02     | -15.35    | -15.12    |
# Train Sharpe Ratio: 1.645, Validation Sharpe Ratio: 0.968
# Debug: L2 penalty: 4.63060650649259
# Debug: L1 penalty: 0.49038185674254126
# Debug: Objective function value (with penalty): 7.944011636764868
# --------------------------------------------------
# | 83        | 7.944     | -20.0     | -14.68    | -20.0     | -20.0     | 7.117     | 20.0      | -20.0     | -20.0     | -20.0     | 20.0      | 11.44     | -20.0     | -20.0     | -2.199    | -20.0     | -20.0     | -20.0     | -3.296    | 20.0      | -20.0     | -16.61    | -20.0     |
# Train Sharpe Ratio: 1.128, Validation Sharpe Ratio: 0.974
# Debug: L2 penalty: 3.1594393250942088
# Debug: L1 penalty: 0.3436027048215371
# Debug: Objective function value (with penalty): 7.006957970084255
# --------------------------------------------------
# | 84        | 7.007     | 2.014     | -0.8178   | -20.0     | -20.0     | -20.0     | -20.0     | -5.656    | -20.0     | -20.0     | -20.0     | 20.0      | -7.47     | -9.857    | -20.0     | -20.0     | -9.012    | -20.0     | 0.2146    | 20.0      | -20.0     | -11.89    | 20.0      |
# Train Sharpe Ratio: 0.714, Validation Sharpe Ratio: 0.262
# Debug: L2 penalty: 1.0378180016222556
# Debug: L1 penalty: 0.1316532112430985
# Debug: Objective function value (with penalty): 3.7105287871346455
# --------------------------------------------------
# | 85        | 3.711     | -19.14    | 1.561     | 3.155     | 19.72     | 2.323     | -14.26    | -16.67    | -7.023    | 1.777     | 10.07     | 12.07     | 13.97     | -18.71    | -4.818    | 7.217     | -19.57    | -16.0     | 19.68     | 8.694     | 19.98     | 19.94     | -13.43    |
# Train Sharpe Ratio: 1.75, Validation Sharpe Ratio: 0.832
# Debug: L2 penalty: 4.7905081779117715
# Debug: L1 penalty: 0.4954804438677596
# Debug: Objective function value (with penalty): 7.6240113782204695
# --------------------------------------------------
# | 86        | 7.624     | 20.0      | 3.478     | -20.0     | -20.0     | -20.0     | -20.0     | -13.54    | -20.0     | 20.0      | -20.0     | -20.0     | -20.0     | -20.0     | -2.167    | 20.0      | -20.0     | 20.0      | -20.0     | -20.0     | 4.61      | 20.0      | -20.0     |
# Train Sharpe Ratio: -2.037, Validation Sharpe Ratio: -1.297
# Debug: L2 penalty: -2.3720845958699335
# Debug: L1 penalty: -0.3640240888219597
# Debug: Objective function value (with penalty): -13.933891315308104
# --------------------------------------------------
# | 87        | -13.93    | 7.156     | -18.91    | -12.7     | 5.813     | 18.11     | 9.617     | -7.532    | 10.02     | -14.15    | 6.172     | 2.8       | 3.708     | 2.065     | 14.2      | 19.45     | 18.95     | 15.23     | 8.247     | -8.358    | 4.736     | -7.878    | 2.555     |
# Train Sharpe Ratio: 1.552, Validation Sharpe Ratio: 0.958
# Debug: L2 penalty: 5.2569319258440075
# Debug: L1 penalty: 0.5332191427399535
# ...
# Train Sharpe Ratio: 0.99, Validation Sharpe Ratio: 0.139
# Debug: L2 penalty: 0.6475161868898963
# Debug: L1 penalty: 0.10326299529719382
# Debug: Objective function value (with penalty): 4.89422081781291
# --------------------------------------------------
# | 153       | 4.894     | -15.61    | -5.382    | -8.033    | -4.177    | -17.54    | -3.873    | 8.298     | -0.9301   | -3.325    | 3.041     | -8.693    | -4.066    | 3.876     | 17.6      | -5.953    | 5.515     | 3.432     | -1.825    | -19.95    | 16.43     | 17.1      | 8.273     |
# Train Sharpe Ratio: 1.345, Validation Sharpe Ratio: 0.783
# Debug: L2 penalty: 2.6538576640617233
# Debug: L1 penalty: 0.3098550854677523
# Debug: Objective function value (with penalty): 7.676287250470525
# --------------------------------------------------
# | 154       | 7.676     | -14.87    | -20.0     | -10.74    | 6.699     | -6.58     | 7.318     | -20.0     | -2.754    | 2.26      | -1.003    | -20.0     | -4.885    | -20.0     | -4.184    | -20.0     | -20.0     | -13.02    | -20.0     | 20.0      | -20.0     | -16.9     | -20.0     |
# Train Sharpe Ratio: 1.581, Validation Sharpe Ratio: 0.968
# Debug: L2 penalty: 3.823258098270926
# Debug: L1 penalty: 0.4226605843466664
# Debug: Objective function value (with penalty): 8.499081317382407
# --------------------------------------------------
# | 155       | 8.499     | -7.464    | -20.0     | -20.0     | 20.0      | 20.0      | -20.0     | 4.214     | -20.0     | -20.0     | -2.414    | 11.65     | -20.0     | -20.0     | -5.677    | -20.0     | -20.0     | 6.038     | -4.302    | -20.0     | 20.0      | -9.868    | -20.0     |
# Train Sharpe Ratio: 0.253, Validation Sharpe Ratio: 0.443
# Debug: L2 penalty: 0.44921408776395133
# Debug: L1 penalty: 0.06846055041182722
# Debug: Objective function value (with penalty): 2.962325361824221
# --------------------------------------------------
# | 156       | 2.962     | 14.09     | 5.049     | -1.594    | -12.37    | -19.12    | -0.4091   | -2.216    | 1.604     | -0.6149   | -13.22    | -14.63    | 9.382     | 6.472     | -16.28    | -10.57    | 13.71     | -15.22    | -8.693    | -4.759    | 19.24     | -6.653    | 0.828     |
# Train Sharpe Ratio: 1.253, Validation Sharpe Ratio: 0.79
# Debug: L2 penalty: 3.120769674717464
# Debug: L1 penalty: 0.34020887139609907
# Debug: Objective function value (with penalty): 6.754021453886438
# --------------------------------------------------
# | 157       | 6.754     | -20.0     | -20.0     | 2.197     | 3.891     | 20.0      | 3.092     | -17.32    | -15.66    | -20.0     | -15.42    | 20.0      | -20.0     | -20.0     | -20.0     | -20.0     | -20.0     | -20.0     | -6.327    | 20.0      | 1.759     | 7.38      | -20.0     |
# Train Sharpe Ratio: 0.799, Validation Sharpe Ratio: 0.377
# Debug: L2 penalty: 0.9198355159129125
# Debug: L1 penalty: 0.13153375559969366
# Debug: Objective function value (with penalty): 4.828630728487394
# --------------------------------------------------
# | 158       | 4.829     | -19.47    | -17.97    | -4.525    | -3.952    | -3.658    | -7.761    | 18.97     | 18.49     | -15.71    | 9.613     | 12.92     | -1.517    | 9.443     | -7.799    | -1.833    | -10.14    | -7.574    | -5.762    | 4.297     | 18.8      | 4.256     | -19.24    |
# Train Sharpe Ratio: 2.095, Validation Sharpe Ratio: 1.071
# Debug: L2 penalty: 4.713571368200231
# Debug: L1 penalty: 0.5100487717971058
# Debug: Objective function value (with penalty): 10.606379860002665
# --------------------------------------------------
# | 159       | 10.61     | -20.0     | -20.0     | -20.0     | -0.2797   | -20.0     | 3.036     | 9.699     | -20.0     | -2.456    | 20.0      | -20.0     | 0.4496    | -20.0     | 10.79     | -20.0     | -20.0     | -5.601    | 9.896     | -20.0     | 20.0      | 20.0      | -20.0     |
# Train Sharpe Ratio: -1.516, Validation Sharpe Ratio: -0.51
# Debug: L2 penalty: -1.8367844086264256
# Debug: L1 penalty: -0.2581425320940548
# Debug: Objective function value (with penalty): -8.035073059279519
# --------------------------------------------------
# | 160       | -8.035    | 2.769     | 8.234     | 7.502     | -12.78    | -0.1135   | -19.96    | 16.55     | 6.917     | -13.04    | -15.56    | 11.26     | 11.88     | -10.87    | -7.388    | 3.299     | 16.13     | -18.65    | 16.07     | 10.74     | -19.02    | -7.406    | 18.69     |
# Train Sharpe Ratio: -1.186, Validation Sharpe Ratio: -0.809
# Debug: L2 penalty: -1.6426914022938217
# Debug: L1 penalty: -0.23090016500467025
# Debug: Objective function value (with penalty): -8.10140843270151
# --------------------------------------------------
# | 161       | -8.101    | 1.113     | -15.5     | 15.06     | 10.96     | -6.462    | 3.777     | 6.905     | 12.39     | 15.58     | 15.47     | -2.23     | 17.53     | 3.922     | -13.75    | 4.134     | 1.109     | 2.174     | 19.72     | -13.68    | -19.01    | 17.52     | -13.48    |
# Train Sharpe Ratio: 1.192, Validation Sharpe Ratio: 0.771
# Debug: L2 penalty: 3.039417312651462
# Debug: L1 penalty: 0.33916320307784936
# Debug: Objective function value (with penalty): 6.436419484270689
# --------------------------------------------------
# | 162       | 6.436     | 20.0      | -11.47    | -20.0     | -20.0     | -20.0     | -9.168    | -6.103    | -20.0     | 6.773     | 6.87      | -20.0     | -20.0     | -20.0     | -20.0     | 15.88     | -20.0     | 18.29     | 5.067     | 20.0      | 5.94      | -20.0     | -20.0     |
# Train Sharpe Ratio: -1.19, Validation Sharpe Ratio: -1.094
# Debug: L2 penalty: -2.421147819870136
# Debug: L1 penalty: -0.3292343326351856
# Debug: Objective function value (with penalty): -8.669617847494678
# --------------------------------------------------
# | 163       | -8.67     | -15.43    | 17.13     | 10.57     | -18.34    | -11.51    | -18.37    | 15.67     | 17.9      | 16.85     | 8.893     | -7.833    | 8.029     | -3.339    | -19.11    | 13.09     | 12.35     | 11.63     | 17.0      | -19.92    | -8.197    | -9.109    | -8.025    |
# Train Sharpe Ratio: 1.415, Validation Sharpe Ratio: 1.052
# Debug: L2 penalty: 1.5012309770427017
# Debug: L1 penalty: 0.23621934527856664
# Debug: Objective function value (with penalty): 10.597549677678732
# --------------------------------------------------
# | 164       | 10.6      | -18.79    | -16.51    | -3.859    | 0.98      | -17.82    | -15.67    | 8.211     | -16.3     | 1.118     | -4.483    | -12.5     | 4.876     | -4.708    | -3.873    | 8.016     | -3.502    | -5.089    | -10.05    | -18.68    | -3.128    | 8.462     | 4.862     |
# Train Sharpe Ratio: 1.849, Validation Sharpe Ratio: 1.066
# Debug: L2 penalty: 4.397167727969589
# Debug: L1 penalty: 0.5046154619272213
# Debug: Objective function value (with penalty): 9.67321681010319
# --------------------------------------------------
# | 165       | 9.673     | -20.0     | -20.0     | -20.0     | -10.93    | -20.0     | -20.0     | 11.58     | -20.0     | 8.235     | 7.756     | -20.0     | 17.19     | -20.0     | -20.0     | 2.418     | 14.4      | -14.71    | -15.39    | -20.0     | 14.21     | 20.0      | -9.389    |
# Train Sharpe Ratio: 0.538, Validation Sharpe Ratio: 0.07
# Debug: L2 penalty: 0.4950637758334181
# Debug: L1 penalty: 0.07442725250604056
# Debug: Objective function value (with penalty): 2.470508971660542
# --------------------------------------------------
# | 166       | 2.471     | -9.866    | 19.61     | 7.019     | -8.341    | -18.67    | 17.35     | 3.506     | 2.265     | -15.67    | 10.67     | -16.72    | 11.66     | 6.737     | -9.51     | -13.98    | -4.599    | -12.03    | -7.751    | 18.38     | 8.562     | -9.306    | -12.62    |
# Train Sharpe Ratio: -1.454, Validation Sharpe Ratio: -1.342
# Debug: L2 penalty: -1.6924944498426995
# Debug: L1 penalty: -0.2572785525664885
# Debug: Objective function value (with penalty): -12.030226997590812
# --------------------------------------------------
# | 167       | -12.03    | -4.568    | 17.12     | 10.79     | 14.74     | 15.63     | 12.38     | -11.06    | 13.92     | 0.6068    | 16.95     | -13.19    | -5.137    | 0.7225    | 0.06063   | 4.868     | 2.179     | -0.6609   | -4.881    | -0.5106   | -3.293    | 19.52     | 11.23     |
# Train Sharpe Ratio: 1.543, Validation Sharpe Ratio: 0.771
# Debug: L2 penalty: 4.594267310523331
# Debug: L1 penalty: 0.4764443862702359
# Debug: Objective function value (with penalty): 6.499288303206433
# --------------------------------------------------
# | 168       | 6.499     | -20.0     | -20.0     | -20.0     | -20.0     | -20.0     | 20.0      | 20.0      | -20.0     | -20.0     | 17.6      | -20.0     | -20.0     | 10.9      | 7.072     | -20.0     | -20.0     | -20.0     | -20.0     | 20.0      | 20.0      | 16.22     | -20.0     |
# Train Sharpe Ratio: -2.322, Validation Sharpe Ratio: -1.682
# Debug: L2 penalty: -3.050446456502234
# Debug: L1 penalty: -0.46369781091595186
# Debug: Objective function value (with penalty): -16.50585573258181
# --------------------------------------------------
# | 169       | -16.51    | -18.4     | 2.861     | 11.8      | 17.69     | 14.83     | -4.521    | 8.834     | 19.56     | 2.576     | -4.509    | -8.065    | 8.626     | -2.795    | 10.92     | 7.531     | 13.82     | -17.22    | 8.486     | -17.65    | 10.24     | 12.26     | 8.42      |
# Train Sharpe Ratio: -0.773, Validation Sharpe Ratio: 0.106
# Debug: L2 penalty: -0.42460103819517186
# Debug: L1 penalty: -0.06502872141779745
# Debug: Objective function value (with penalty): -2.8453702403870307
# --------------------------------------------------
# | 170       | -2.845    | 17.71     | -7.136    | -17.15    | 16.04     | -6.672    | -2.517    | 1.366     | 5.104     | -0.9131   | -9.476    | -3.452    | 18.42     | -2.052    | -5.793    | -13.81    | 10.51     | -8.344    | 10.57     | -19.17    | 4.521     | -0.06609  | -14.19    |
# Train Sharpe Ratio: 1.733, Validation Sharpe Ratio: 1.032
# Debug: L2 penalty: 3.5322361789576293
# Debug: L1 penalty: 0.4093532939923944
# Debug: Objective function value (with penalty): 9.883410527049977
# --------------------------------------------------
# | 171       | 9.883     | -20.0     | -20.0     | -20.0     | -20.0     | -20.0     | -20.0     | 12.23     | -20.0     | 10.66     | -9.235    | -15.02    | -20.0     | -3.585    | 4.139     | 3.742     | 4.956     | -1.253    | -20.0     | -20.0     | -6.652    | 20.0      | -4.62     |
# Train Sharpe Ratio: 1.545, Validation Sharpe Ratio: 0.544
# Debug: L2 penalty: 4.386906727031664
# Debug: L1 penalty: 0.4388085443762721
# Debug: Objective function value (with penalty): 5.619284728592064
# --------------------------------------------------
# | 172       | 5.619     | -20.0     | 20.0      | -20.0     | -20.0     | 20.0      | 20.0      | -20.0     | -20.0     | -20.0     | 20.0      | -20.0     | 0.1135    | -20.0     | -20.0     | -20.0     | -20.0     | -20.0     | -20.0     | 20.0      | 20.0      | 20.0      | -20.0     |
# Train Sharpe Ratio: 1.743, Validation Sharpe Ratio: 1.065
# Debug: L2 penalty: 3.158750651862126
# Debug: L1 penalty: 0.37218660863887354
# Debug: Objective function value (with penalty): 10.509062739498999
# --------------------------------------------------
# | 173       | 10.51     | -20.0     | -20.0     | -18.04    | -2.362    | -20.0     | -20.0     | -9.413    | -20.0     | 3.732     | 11.43     | 13.59     | -1.583    | -20.0     | -9.03     | 1.751     | -17.6     | 1.587     | 2.93      | -20.0     | -0.09079  | 20.0      | -11.96    |
# Train Sharpe Ratio: 0.063, Validation Sharpe Ratio: 0.306
# Debug: L2 penalty: 0.2916580996172035
# Debug: L1 penalty: 0.043568849993953676
# Debug: Objective function value (with penalty): 1.5097730503888427
# --------------------------------------------------
# | 174       | 1.51      | 3.133     | -0.8611   | 13.3      | -19.65    | -9.376    | -5.38     | -9.505    | 9.903     | -16.59    | -7.509    | 12.26     | -2.822    | 14.15     | -17.17    | -17.05    | 5.251     | 11.72     | -15.84    | 16.88     | -14.76    | -7.884    | 5.158     |
# Train Sharpe Ratio: 0.672, Validation Sharpe Ratio: -0.012
# Debug: L2 penalty: 0.4831363276837052
# Debug: L1 penalty: 0.07368539151363081
# Debug: Objective function value (with penalty): 2.7431782808026646
# --------------------------------------------------
# | 175       | 2.743     | -5.41     | -5.807    | 19.98     | -2.029    | -14.44    | 6.097     | 15.22     | -3.191    | -13.28    | 13.35     | -7.203    | 18.03     | -14.05    | 2.037     | -13.06    | -5.54     | 19.07     | -14.51    | 9.799     | 10.61     | -6.102    | -4.479    |
# Train Sharpe Ratio: -0.124, Validation Sharpe Ratio: -0.592
# Debug: L2 penalty: -0.3709365133885518
# Debug: L1 penalty: -0.06400351153564678
# Debug: Objective function value (with penalty): -3.1450599750758017
# --------------------------------------------------
# | 176       | -3.145    | -3.731    | 1.744     | 19.76     | -4.775    | -11.93    | 18.73     | 2.126     | -3.338    | -10.11    | -8.243    | 16.55     | 10.43     | -6.914    | -5.748    | -6.862    | 0.8923    | 7.882     | -10.0     | 5.693     | -14.38    | 2.19      | 6.751     |
# Train Sharpe Ratio: -0.795, Validation Sharpe Ratio: -0.597
# Debug: L2 penalty: -0.9558036675165693
# Debug: L1 penalty: -0.14626893904926644
# Debug: Objective function value (with penalty): -5.857927393434163
# --------------------------------------------------
# | 177       | -5.858    | 5.26      | 14.58     | -5.028    | -11.27    | -2.174    | -14.09    | 1.855     | 11.05     | -0.5069   | 10.77     | -1.794    | 8.866     | -4.956    | -7.416    | -18.14    | 16.89     | -1.123    | 14.9      | -17.95    | -15.89    | 14.61     | 11.04     |
# Train Sharpe Ratio: 0.511, Validation Sharpe Ratio: 0.321
# Debug: L2 penalty: 0.7134753685958382
# Debug: L1 penalty: 0.09892006392448609
# Debug: Objective function value (with penalty): 3.3476045674796757
# --------------------------------------------------
# | 178       | 3.348     | -16.13    | -18.04    | -18.8     | 15.35     | -18.83    | 2.794     | -12.53    | 2.532     | -14.01    | 14.39     | -1.112    | 3.675     | 5.994     | -12.79    | 19.26     | -11.92    | 18.15     | 4.858     | 8.711     | -4.799    | -1.025    | -12.09    |
# Train Sharpe Ratio: -0.717, Validation Sharpe Ratio: -1.177
# Debug: L2 penalty: -0.9976162275321316
# Debug: L1 penalty: -0.1724978630596996
# Debug: Objective function value (with penalty): -8.299885909408168
# --------------------------------------------------
# | 179       | -8.3      | -1.92     | 7.713     | -2.25     | -9.45     | 1.638     | 12.1      | -19.08    | 14.07     | 11.69     | 5.994     | -14.35    | -10.56    | -5.031    | 7.219     | 2.685     | 17.73     | 8.545     | -12.04    | 0.5086    | -4.213    | 10.12     | -3.232    |
# Train Sharpe Ratio: 1.085, Validation Sharpe Ratio: 0.682
# Debug: L2 penalty: 3.686339276048762
# Debug: L1 penalty: 0.376447419579963
# Debug: Objective function value (with penalty): 4.772213304371274
# --------------------------------------------------
# | 180       | 4.772     | 20.0      | 20.0      | -20.0     | -20.0     | 20.0      | -20.0     | 14.56     | -20.0     | -20.0     | -20.0     | 20.0      | -20.0     | -11.53    | -20.0     | -20.0     | 20.0      | -20.0     | -20.0     | 20.0      | 20.0      | -20.0     | -20.0     |
# Train Sharpe Ratio: -0.003, Validation Sharpe Ratio: 0.241
# Debug: L2 penalty: 0.1602618917191764
# Debug: L1 penalty: 0.02492444174167001
# Debug: Objective function value (with penalty): 1.0048136665391534
# --------------------------------------------------
# | 181       | 1.005     | 8.217     | 4.26      | 5.432     | 14.65     | -9.091    | 10.31     | -16.46    | 6.005     | -8.363    | -3.455    | 17.35     | 11.45     | -13.86    | -0.758    | 6.071     | -8.591    | -16.56    | 0.01324   | -12.72    | -0.9857   | 19.19     | -15.65    |
