# %%
import pandas as pd
import numpy as np

import datetime
import os, sys
import importlib

import utils
importlib.reload(utils)

from utils import plot_series, plot_series_with_names, plot_series_bar
from utils import plot_dataframe
from utils import get_universe_adjusted_series, scale_weights_to_one, scale_to_book_long_short
from utils import generate_portfolio, backtest_portfolio
from utils import match_implementations

import plotly.graph_objects as go

# %%
# This directory can be used if you're working on a Kaggle Notebook inside the competition
# Change the directory as per your requirements if you're working somewhere else
data_dir = "/kaggle/input/qrt-quant-quest-iit-bombay-2025/"

features = pd.read_parquet(os.path.join(data_dir, "features.parquet"))

universe = pd.read_parquet(os.path.join(data_dir, "universe.parquet"))
 
returns = pd.read_parquet(os.path.join(data_dir, "returns.parquet"))

# %%
# Original selected features
selected_features = [
    'on_balance_volume', 'trend_1_3', 'macd', 'ichimoku',
    'ultimate_oscillator', 'chaikin_money_flow', 'volume',
    'know_sure_thing', 'chande_momentum_oscillator',
    'average_true_range', 'volatility_20', 'trend_5_20'
]

# %%
train_features = features.loc["2005":"2015"]
validation_features = features.loc["2016":"2018"]
test_features = features.loc["2019"]

train_universe = universe.loc["2005":"2015"]
validation_universe = universe.loc["2016":"2018"]
test_universe = universe.loc["2019"]

train_returns = returns.loc["2005":"2015"]
validation_returns = returns.loc["2016":"2018"]
test_returns = returns.loc["2019"]

# Filter features based on selected features

# Check if columns have a MultiIndex
if isinstance(train_features.columns, pd.MultiIndex):
    # Filter columns based on level 0 of MultiIndex
    train_features = train_features.loc[:, train_features.columns.get_level_values(0).isin(selected_features)]
    validation_features = validation_features.loc[:, validation_features.columns.get_level_values(0).isin(selected_features)]
    test_features = test_features.loc[:, test_features.columns.get_level_values(0).isin(selected_features)]
    
    # Remove unused levels from MultiIndex
    train_features.columns = train_features.columns.remove_unused_levels()
    validation_features.columns = validation_features.columns.remove_unused_levels()
    test_features.columns = test_features.columns.remove_unused_levels()
else:
    # If columns are not MultiIndexed, filter directly
    train_features = train_features[selected_features]
    validation_features = validation_features[selected_features]
    test_features = test_features[selected_features]

# Debugging: Print filtered column levels
if isinstance(train_features.columns, pd.MultiIndex):
    print("Filtered Train Features Columns (Level 0):", train_features.columns.get_level_values(0).unique())
else:
    print("Filtered Train Features Columns:", train_features.columns)
# Out:
# Filtered Train Features Columns (Level 0): Index(['macd', 'trend_1_3', 'trend_5_20', 'ichimoku', 'know_sure_thing',
#        'average_true_range', 'volatility_20', 'on_balance_volume',
#        'chaikin_money_flow', 'volume', 'ultimate_oscillator',
#        'chande_momentum_oscillator'],
#       dtype='object')

# %%
def backtest_portfolio_new(portfolio: pd.DataFrame, returns: pd.DataFrame, universe: pd.DataFrame, plot_: bool, print_: bool):

    """
    Computes performance metrics from a given portfolio DataFrame.

    This function calculates the net Sharpe ratio, along with other portfolio metrics,
    ensuring that certain constraints are met. It performs checks for:
    - Shape alignment of input DataFrames.
    - portfolio weights only in stocks that are part of the universe.
    - Dollar neutrality.
    - Unit capital constraint.
    - Maximum weight constraint.

    Parameters:
    ----------
    portfolio : pd.DataFrame
        DataFrame representing portfolio over time.
    returns : pd.DataFrame
        DataFrame containing stock returns corresponding to the portfolio.
    universe : pd.DataFrame
        Boolean DataFrame indicating whether a stock is part of the investable universe.
    plot_: bool
        Boolean Flag which decides whether to plot the cumulative PnL
    print_: bool
        Boolean Flag which decides whether to print the metrics of backtest

    Raises:
    ------
    ValueError
        If the input DataFrames do not have matching shapes.
        If portfolio contain stocks that are not in the universe.
        If the portfolio violates the dollar neutrality constraint.
        If the unit capital constraint is violated.
        If the maximum weight constraint is exceeded.

    Returns
    -------
    tuple
        - Net Sharpe Ratio (rounded to 3 decimal places).
        - Pandas Series containing gross PnL over time.

    Additional Outputs:
    -------------------
    - Prints the gross and net Sharpe ratios.
    - Prints the turnover percentage.
    - Plots cumulative Gross and Net PnL.

    Notes:
    ------
    - The turnover is calculated as the average traded capital divided by the average book value.
    - The gross and net Sharpe ratios are annualized using a factor of √252.
    - The net PnL accounts for trading costs (assumed to be 0.01% per unit traded).
    """

    universe = universe.astype(bool)
    
    if not (portfolio.shape == returns.shape == universe.shape):
        raise ValueError("Shapes of portfolio, returns and universe are not algined")

    if ((portfolio.replace(0, np.nan))[~universe].notna().sum().sum() != 0):
        raise ValueError("Your portfolio are present for a stock not present in the universe")

    if ((portfolio.sum(1).abs() > 0.01).sum() > 0):
        raise ValueError("Dollar Neutral Constraint is violated")
    
    if (((portfolio.abs().sum(1) - 1) > 0.01).sum() > 0):
        raise ValueError("Unit Capital Constraint is violated")

    if ((portfolio.abs().max(1) > 0.1).sum() > 0):
        raise ValueError("Maximum Weight Constraint is violated")

    portfolio = portfolio.fillna(0)

    rets = returns.fillna(0)

    gross_pnl = (portfolio * rets).sum(axis=1)

    traded = portfolio.diff(1).abs().sum(axis=1).fillna(0)

    net_pnl = gross_pnl - traded * 1e-4

    gross_sharpe_ratio = (gross_pnl.mean() / gross_pnl.std()) * np.sqrt(252)

    net_sharpe_ratio = (net_pnl.mean() / net_pnl.std()) * np.sqrt(252)

    if print_:
        print("Gross Sharpe Ratio: ", round(gross_sharpe_ratio, 3))
        print("Net Sharpe Ratio: ", round(net_sharpe_ratio, 3))

    return round(net_sharpe_ratio, 3), gross_pnl

# %%
def normalize_signal(feature, universe_boolean):
    """
    Normalize a feature signal for a given universe.
    Parameters:
        feature (pd.DataFrame): Feature data for all stocks.
        universe_boolean (pd.DataFrame): Boolean DataFrame indicating tradable stocks.
    Returns:
        pd.DataFrame: Normalized signal.
    """
    signal = feature.shift(1)  # Avoid lookahead bias
    signal = signal.where(universe_boolean, np.nan)
    signal = signal.rank(axis=1, method="min", ascending=True)
    signal = signal.sub(signal.mean(axis=1), axis=0)
    signal = signal.div(signal.abs().sum(axis=1), axis=0)
    return signal
    
def generate_portfolio_vectorized(features, universe, weights):
    """
    Generate portfolio weights using a vectorized approach.
    Parameters:
        features (pd.DataFrame): DataFrame containing all features for stocks.
        universe (pd.DataFrame): Binary DataFrame indicating tradable stocks.
        weights (array-like): Weights for each feature.
    Returns:
        pd.DataFrame: Portfolio weights for each stock on each trading day.
    """
    universe_boolean = universe.astype(bool)
    # features =  features.loc[:'2019']
    # Combine signals into a portfolio
    portfolio_weights = pd.DataFrame(0, index=features.index, columns=features.columns.get_level_values(1).unique())
    
    for i, feature_name in enumerate(features.columns.levels[0]):
        feature_data = features[feature_name]
        normalized_signal = normalize_signal(feature_data, universe_boolean)
        portfolio_weights += normalized_signal * weights[i]
    
    # Enforce dollar neutrality and normalize weights to sum to 1 per day
    portfolio_weights = portfolio_weights.sub(portfolio_weights.mean(axis=1), axis=0)
    portfolio_weights = portfolio_weights.div(portfolio_weights.abs().sum(axis=1), axis=0)
    
    return portfolio_weights.fillna(0)

# %%
from bayes_opt import BayesianOptimization
import numpy as np
import matplotlib.pyplot as plt
from joblib import Parallel, delayed

# %%
def optimize_signal_weights_bayesian(features_train, features_validation, universe_train, universe_validation, returns_train, returns_validation):
    selected_features = [
        'on_balance_volume', 'trend_1_3', 'macd', 'ichimoku',
        'ultimate_oscillator', 'chaikin_money_flow', 'volume',
        'know_sure_thing', 'chande_momentum_oscillator',
        'average_true_range', 'volatility_20', 'trend_5_20'
    ]

    def sharpe_ratio_objective(**weights):
        # Get all feature names from train_features
        all_features = sorted(features_train.columns.levels[0])
        
        # Assign 0 weight to features not in selected_features
        weight_array = np.array([weights.get(feature, 0) if feature in selected_features else 0 for feature in all_features])
        
        # Debug: Print the weight array
        # print(f"Weight Array: {weight_array}")
        
        # Generate portfolio weights for training set
        portfolio_weights_train = generate_portfolio_vectorized(features_train, universe_train, weight_array)
        
        # Backtest on training data
        sr_train, _ = backtest_portfolio_new(portfolio_weights_train, returns_train, universe_train, False, False)
        
        # Validate on validation set
        portfolio_weights_validation = generate_portfolio_vectorized(features_validation, universe_validation, weight_array)
        sr_validation, _ = backtest_portfolio_new(portfolio_weights_validation, validation_returns, validation_universe, False, False)
        
        print(f"Train Sharpe Ratio: {sr_train}, Validation Sharpe Ratio: {sr_validation}")
        
        # Combine training and validation Sharpe ratios
        alpha = 0.3  # Weight for training Sharpe ratio
        combined_sharpe_ratio = alpha * sr_train + (1 - alpha) * sr_validation
        
        # Add penalties to prevent overfitting
        penalty_l2 = np.sum(np.square(weight_array)) * combined_sharpe_ratio * 0.002
        penalty_l1 = np.sum(np.abs(weight_array)) * combined_sharpe_ratio * 0.003
        
        result = combined_sharpe_ratio * 10 - penalty_l2 - penalty_l1
        print(f"Debug: L2 penalty: {penalty_l2}")
        print(f"Debug: L1 penalty: {penalty_l1}")
        print(f"Debug: Objective function value (with penalty): {result}")
        print("-" * 50)
        return result

    # Create pbounds for selected features only
    pbounds = {feature: (-20, 20) for feature in selected_features}
    print(f"Parameter Bounds (pbounds): {pbounds}")
    
    optimizer = BayesianOptimization(
        f=sharpe_ratio_objective,
        pbounds=pbounds,
        random_state=42
    )
    
    optimizer.maximize(init_points=20, n_iter=300)
    
    optimal_weights = optimizer.max['params']
    
    return optimal_weights

# Run Bayesian Optimization using train/validation split
optimal_weights = optimize_signal_weights_bayesian(
    train_features,
    validation_features,
    train_universe,
    validation_universe,
    train_returns,
    validation_returns
)

# Evaluate on test set
portfolio_weights_test = generate_portfolio_vectorized(test_features, test_universe, np.array(list(optimal_weights.values())))
sr_test, _ = backtest_portfolio_new(portfolio_weights_test, test_returns, test_universe,False,False)

print("Optimal Weights:", optimal_weights)
print("Test Set Sharpe Ratio:", sr_test)
# Out:
# Parameter Bounds (pbounds): {'on_balance_volume': (-20, 20), 'trend_1_3': (-20, 20), 'macd': (-20, 20), 'ichimoku': (-20, 20), 'ultimate_oscillator': (-20, 20), 'chaikin_money_flow': (-20, 20), 'volume': (-20, 20), 'know_sure_thing': (-20, 20), 'chande_momentum_oscillator': (-20, 20), 'average_true_range': (-20, 20), 'volatility_20': (-20, 20), 'trend_5_20': (-20, 20)}
# |   iter    |  target   | averag... | chaiki... | chande... | ichimoku  | know_s... |   macd    | on_bal... | trend_1_3 | trend_... | ultima... | volati... |  volume   |
# -------------------------------------------------------------------------------------------------------------------------------------------------------------------------
# Train Sharpe Ratio: -0.327, Validation Sharpe Ratio: -0.569
# Debug: L2 penalty: -2.148656204635009
# Debug: L1 penalty: -0.2181034030488687
# Debug: Objective function value (with penalty): -2.597240392316122
# --------------------------------------------------
# | 1         | -2.597    | -5.018    | 18.03     | 9.28      | 3.946     | -13.76    | -13.76    | -17.68    | 14.65     | 4.045     | 8.323     | -19.18    | 18.8      |
# Train Sharpe Ratio: 0.919, Validation Sharpe Ratio: 0.194
# Debug: L2 penalty: 0.9025668972011898
# Debug: L1 penalty: 0.12671236994919502
# Debug: Objective function value (with penalty): 3.085720732849615
# --------------------------------------------------
# | 2         | 3.086     | 13.3      | -11.51    | -12.73    | -12.66    | -7.83     | 0.9903    | -2.722    | -8.351    | 4.474     | -14.42    | -8.314    | -5.346    |
# Train Sharpe Ratio: 0.66, Validation Sharpe Ratio: -0.446
# Debug: L2 penalty: -0.4424097100297951
# Debug: L1 penalty: -0.045010991411849964
# Debug: Objective function value (with penalty): -0.6545792985583546
# --------------------------------------------------
# | 3         | -0.6546   | -1.757    | 11.41     | -12.01    | 0.5694    | 3.697     | -18.14    | 4.302     | -13.18    | -17.4     | 17.96     | 18.63     | 12.34     |
# Train Sharpe Ratio: 0.307, Validation Sharpe Ratio: 0.524
# Debug: L2 penalty: 1.2999552859111694
# Debug: L1 penalty: 0.14932297436242153
# Debug: Objective function value (with penalty): 3.1397217397264097
# --------------------------------------------------
# | 4         | 3.14      | -7.815    | -16.09    | 7.369     | -2.394    | -15.12    | -0.1929   | -18.62    | 16.37     | -9.649    | 6.501     | -7.532    | 0.8027    |
# Train Sharpe Ratio: -0.854, Validation Sharpe Ratio: -0.746
# Debug: L2 penalty: -3.570450165479328
# Debug: L1 penalty: -0.35547729553111057
# Debug: Objective function value (with penalty): -3.858072538989561
# --------------------------------------------------
# | 5         | -3.858    | 1.868     | -12.61    | 18.78     | 11.01     | 17.58     | 15.79     | 3.916     | 16.87     | -16.46    | -12.16    | -18.19    | -6.987    |
# Train Sharpe Ratio: 0.202, Validation Sharpe Ratio: 0.673
# Debug: L2 penalty: 1.7801971754993808
# Debug: L1 penalty: 0.20550359645551178
# Debug: Objective function value (with penalty): 3.3312992280451077
# --------------------------------------------------
# | 6         | 3.331     | -4.453    | -9.146    | 13.15     | -5.73     | -8.763    | 1.708     | -14.36    | 12.09     | -17.02    | 19.48     | 10.89     | -12.05    |
# Train Sharpe Ratio: -0.16, Validation Sharpe Ratio: -0.213
# Debug: L2 penalty: -0.7745215992226592
# Debug: L1 penalty: -0.0842162550961344
# Debug: Objective function value (with penalty): -1.1122621456812065
# --------------------------------------------------
# | 7         | -1.112    | -19.78    | 12.62     | 8.274     | 9.16      | 10.85     | -17.04    | -5.661    | -15.37    | 14.52     | 4.932     | -6.764    | -17.46    |
# Train Sharpe Ratio: -1.196, Validation Sharpe Ratio: -0.767
# Debug: L2 penalty: -1.7886559988807538
# Debug: L1 penalty: -0.25139219881773817
# Debug: Objective function value (with penalty): -6.916951802301507
# --------------------------------------------------
# | 8         | -6.917    | -7.561    | -6.993    | 9.184     | 5.502     | 15.49     | -1.111    | -15.22    | 8.53      | 10.43     | 2.451     | 10.84     | -0.2482   |
# Train Sharpe Ratio: 0.534, Validation Sharpe Ratio: 0.012
# Debug: L2 penalty: 0.5178038951832528
# Debug: L1 penalty: 0.05593176162427286
# Debug: Objective function value (with penalty): 1.1122643431924744
# --------------------------------------------------
# | 9         | 1.112     | 0.9093    | -2.898    | -18.98    | -15.68    | -18.74    | 5.456     | -7.426    | 0.3428    | 16.3      | -10.03    | -3.585    | 10.22     |
# Train Sharpe Ratio: -0.859, Validation Sharpe Ratio: -0.759
# Debug: L2 penalty: -3.0119225659944635
# Debug: L1 penalty: -0.33468762890299536
# Debug: Objective function value (with penalty): -4.54338980510254
# --------------------------------------------------
# | 10        | -4.543    | -10.85    | -16.92    | -8.41     | -13.55    | 17.19     | 12.32     | 5.336     | 14.86     | 12.15     | -12.54    | 15.7      | 1.574     |
# Train Sharpe Ratio: 1.455, Validation Sharpe Ratio: 0.606
# Debug: L2 penalty: 2.959263467303704
# Debug: L1 penalty: 0.3267342668052437
# Debug: Objective function value (with penalty): 5.321002265891051
# --------------------------------------------------
# | 11        | 5.321     | 12.3      | 15.84     | -7.28     | -15.6     | -10.88    | -2.916    | 12.72     | 14.43     | -19.72    | 0.4299    | -3.304    | -11.12    |
# Train Sharpe Ratio: -1.754, Validation Sharpe Ratio: -0.324
# Debug: L2 penalty: -2.4003686588434765
# Debug: L1 penalty: -0.2624710845107182
# Debug: Objective function value (with penalty): -4.867160256645805
# --------------------------------------------------
# | 12        | -4.867    | -15.21    | -6.495    | 17.72     | -7.072    | 0.7516    | 8.121     | -5.455    | 18.87     | 18.5      | -9.929    | -0.1101   | -7.965    |
# Train Sharpe Ratio: 0.301, Validation Sharpe Ratio: 0.559
# Debug: L2 penalty: 1.827859733558273
# Debug: L1 penalty: 0.1871502750531007
# Debug: Objective function value (with penalty): 2.800989991388627
# --------------------------------------------------
# | 13        | 2.801     | -8.606    | -18.52    | 4.383     | 0.1072    | -17.94    | -8.854    | 16.33     | -10.42    | -14.2     | -0.4219   | 19.43     | -10.32    |
# Train Sharpe Ratio: 0.834, Validation Sharpe Ratio: 0.223
# Debug: L2 penalty: 0.8890091548963202
# Debug: L1 penalty: 0.12656449174984102
# Debug: Objective function value (with penalty): 3.0474263533538384
# --------------------------------------------------
# | 14        | 3.047     | 6.885     | 10.46     | -10.49    | 9.129     | -5.289    | 5.292     | 5.341     | 1.431     | -16.39    | 13.41     | -7.169    | -12.54    |
# Train Sharpe Ratio: 0.279, Validation Sharpe Ratio: 0.531
# Debug: L2 penalty: 1.541567388769406
# Debug: L1 penalty: 0.16781905773531353
# Debug: Objective function value (with penalty): 2.84461355349528
# --------------------------------------------------
# | 15        | 2.845     | -18.37    | 3.636     | 7.103     | -19.34    | 0.4837    | -10.94    | 5.807     | -13.03    | 7.638     | -4.531    | 17.47     | -14.5     |
# Train Sharpe Ratio: -1.3, Validation Sharpe Ratio: -0.6
# Debug: L2 penalty: -2.789359020697668
# Debug: L1 penalty: -0.3123881452492822
# Debug: Objective function value (with penalty): -4.9982528340530505
# --------------------------------------------------
# | 16        | -4.998    | -6.357    | -15.46    | 16.99     | 15.09     | -9.682    | 6.399     | 12.69     | 2.208     | 1.186     | -10.33    | -16.28    | 15.89     |
# Train Sharpe Ratio: -0.5, Validation Sharpe Ratio: -1.163
# Debug: L2 penalty: -3.486406657866343
# Debug: L1 penalty: -0.3968380461785496
# Debug: Objective function value (with penalty): -5.757755295955107
# --------------------------------------------------
# | 17        | -5.758    | 16.02     | 5.324     | -6.439    | -6.032    | 9.038     | 15.88     | 15.48     | 11.2      | 5.681     | -16.63    | -13.53    | 15.94     |
# Train Sharpe Ratio: 0.154, Validation Sharpe Ratio: 0.296
# Debug: L2 penalty: 0.8515570682528224
# Debug: L1 penalty: 0.09537906071654877
# Debug: Objective function value (with penalty): 1.5870638710306286
# --------------------------------------------------
# | 18        | 1.587     | 4.257     | -19.63    | -15.94    | 6.54      | -19.8     | -13.57    | 1.949     | 7.676     | 6.078     | -11.03    | 8.487     | -10.51    |
# Train Sharpe Ratio: -2.007, Validation Sharpe Ratio: -1.135
# Debug: L2 penalty: -3.591097813945965
# Debug: L1 penalty: -0.4617494382237253
# Debug: Objective function value (with penalty): -9.913152747830308
# --------------------------------------------------
# | 19        | -9.913    | -6.984    | 9.86      | 5.985     | 13.97     | 6.305     | 2.732     | -16.25    | -5.291    | -9.392    | -10.24    | 18.92     | -4.276    |
# Train Sharpe Ratio: -1.249, Validation Sharpe Ratio: -0.677
# Debug: L2 penalty: -2.1884544888095743
# Debug: L1 penalty: -0.2643051783725732
# Debug: Objective function value (with penalty): -6.033240332817853
# --------------------------------------------------
# | 20        | -6.033    | 15.68     | 5.246     | 11.79     | 0.1055    | 3.076     | -0.2993   | -12.19    | 8.898     | -8.769    | -19.03    | 5.819     | -12.92    |
# Train Sharpe Ratio: 1.867, Validation Sharpe Ratio: 0.973
# Debug: L2 penalty: 7.5151527043383854
# Debug: L1 penalty: 0.630626057317521
# Debug: Objective function value (with penalty): 4.266221238344093
# --------------------------------------------------
# | 21        | 4.266     | -1.686    | -14.67    | -16.23    | -20.0     | -20.0     | -14.05    | 3.722     | -0.721    | -20.0     | 20.0      | -18.27    | -20.0     |
# Train Sharpe Ratio: 1.251, Validation Sharpe Ratio: 0.76
# Debug: L2 penalty: 4.920533345879993
# Debug: L1 penalty: 0.43756269973200573
# Debug: Objective function value (with penalty): 3.714903954388
# --------------------------------------------------
# | 22        | 3.715     | 18.32     | 6.204     | -9.755    | -20.0     | -20.0     | -5.044    | 20.0      | -13.05    | 1.79      | 20.0      | 6.596     | -20.0     |
# Train Sharpe Ratio: 1.5, Validation Sharpe Ratio: 0.716
# Debug: L2 penalty: 2.6435554322355475
# Debug: L1 penalty: 0.33708428004330493
# Debug: Objective function value (with penalty): 6.531360287721146
# --------------------------------------------------
# | 23        | 6.531     | 10.61     | 9.594     | -12.77    | -16.34    | -8.514    | 0.5116    | 9.912     | 14.61     | -12.94    | -11.53    | -2.962    | -7.836    |
# Train Sharpe Ratio: 0.531, Validation Sharpe Ratio: 0.131
# Debug: L2 penalty: 0.5654248676052237
# Debug: L1 penalty: 0.07870838666846841
# Debug: Objective function value (with penalty): 1.8658667457263076
# --------------------------------------------------
# | 24        | 1.866     | 12.17     | -15.92    | -9.622    | -11.8     | -6.84     | 4.91      | -2.607    | -7.586    | 3.511     | -15.53    | -5.312    | -8.722    |
# Train Sharpe Ratio: 1.323, Validation Sharpe Ratio: 0.832
# Debug: L2 penalty: 5.876934217814938
# Debug: L1 penalty: 0.5126986006118257
# Debug: Objective function value (with penalty): 3.403367181573236
# --------------------------------------------------
# | 25        | 3.403     | -6.52     | 7.998     | -20.0     | -20.0     | -20.0     | -12.23    | 20.0      | -2.308    | -15.49    | -20.0     | -9.974    | -20.0     |
# Train Sharpe Ratio: 1.601, Validation Sharpe Ratio: 0.766
# Debug: L2 penalty: 4.00027572225339
# Debug: L1 penalty: 0.4439304665201463
# Debug: Objective function value (with penalty): 5.720793811226463
# --------------------------------------------------
# | 26        | 5.721     | 15.02     | 5.486     | -13.12    | -13.31    | -6.143    | -8.999    | 15.22     | 18.48     | -10.66    | -17.8     | -8.146    | -13.19    |
# Train Sharpe Ratio: 0.046, Validation Sharpe Ratio: 0.192
# Debug: L2 penalty: 0.3112902750318309
# Debug: L1 penalty: 0.04398267790697424
# Debug: Objective function value (with penalty): 1.1267270470611948
# --------------------------------------------------
# | 27        | 1.127     | -9.083    | -14.74    | 8.447     | 1.097     | -6.245    | -6.475    | -17.03    | 12.82     | -3.145    | 7.225     | -7.021    | 5.604     |
# Train Sharpe Ratio: 1.214, Validation Sharpe Ratio: 1.139
# Debug: L2 penalty: 8.556978691149762
# Debug: L1 penalty: 0.6687071926394864
# Debug: Objective function value (with penalty): 2.3893141162107514
# --------------------------------------------------
# | 28        | 2.389     | -20.0     | -20.0     | -1.908    | -20.0     | -20.0     | -20.0     | -20.0     | -20.0     | 1.132     | 20.0      | 8.87      | -20.0     |
# Train Sharpe Ratio: 1.795, Validation Sharpe Ratio: 0.822
# Debug: L2 penalty: 5.936817562850504
# Debug: L1 penalty: 0.4962183476381984
# Debug: Objective function value (with penalty): 4.705964089511297
# --------------------------------------------------
# | 29        | 4.706     | 20.0      | -12.53    | -20.0     | -20.0     | -20.0     | 1.399     | -0.352    | 20.0      | -20.0     | 0.7518    | -4.022    | -9.44     |
# Train Sharpe Ratio: 1.344, Validation Sharpe Ratio: 0.544
# Debug: L2 penalty: 7.526400000000001
# Debug: L1 penalty: 0.56448
# Debug: Objective function value (with penalty): -0.25088000000000077
# --------------------------------------------------
# | 30        | -0.2509   | 20.0      | -20.0     | -20.0     | 20.0      | -20.0     | -20.0     | 20.0      | 20.0      | -20.0     | 20.0      | -20.0     | -20.0     |
# Train Sharpe Ratio: 1.715, Validation Sharpe Ratio: 0.958
# Debug: L2 penalty: 5.273000049071445
# Debug: L1 penalty: 0.5562384170875794
# Debug: Objective function value (with penalty): 6.021761533840975
# --------------------------------------------------
# | 31        | 6.022     | 13.2      | 6.955     | -12.9     | -11.69    | -16.83    | -17.02    | 18.95     | 16.32     | -12.95    | -9.675    | -5.506    | -14.46    |
# Train Sharpe Ratio: 0.037, Validation Sharpe Ratio: 0.12
# Debug: L2 penalty: 0.91296
# Debug: L1 penalty: 0.06847199999999999
# Debug: Objective function value (with penalty): -0.03043200000000014
# --------------------------------------------------
# | 32        | -0.03043  | -20.0     | 20.0      | 20.0      | -20.0     | -20.0     | -20.0     | 20.0      | -20.0     | 20.0      | 20.0      | 20.0      | -20.0     |
# Train Sharpe Ratio: 1.672, Validation Sharpe Ratio: 0.807
# Debug: L2 penalty: 4.875666243819645
# Debug: L1 penalty: 0.4775875328738598
# Debug: Objective function value (with penalty): 5.3117462233064945
# --------------------------------------------------
# | 33        | 5.312     | 18.47     | 5.804     | -17.38    | -16.42    | -15.46    | -5.679    | 19.64     | 19.09     | -8.194    | -1.617    | -7.872    | -13.64    |
# Train Sharpe Ratio: 0.014, Validation Sharpe Ratio: -0.456
# Debug: L2 penalty: -0.7359177016678697
# Debug: L1 penalty: -0.09118938694161742
# Debug: Objective function value (with penalty): -2.322892911390513
# --------------------------------------------------
# | 34        | -2.323    | 17.92     | -10.48    | -14.45    | -4.079    | -9.853    | 2.392     | -2.132    | -6.415    | -0.9969   | -17.62    | -4.921    | 5.232     |
# Train Sharpe Ratio: 1.249, Validation Sharpe Ratio: 0.628
# Debug: L2 penalty: 1.7983220712196524
# Debug: L1 penalty: 0.2627108747801621
# Debug: Objective function value (with penalty): 6.081967054000186
# --------------------------------------------------
# | 35        | 6.082     | 6.551     | -8.141    | -12.74    | -15.8     | -12.44    | 4.882     | -6.78     | -13.07    | 6.79      | -5.748    | -8.282    | -6.313    |
# Train Sharpe Ratio: 1.807, Validation Sharpe Ratio: 0.935
# Debug: L2 penalty: 5.709355178441666
# Debug: L1 penalty: 0.5070270751291837
# Debug: Objective function value (with penalty): 5.749617746429149
# --------------------------------------------------
# | 36        | 5.75      | 8.834     | 6.997     | -20.0     | -20.0     | -17.65    | -2.209    | -17.91    | -2.33     | 1.705     | 3.6       | -20.0     | -20.0     |
# Train Sharpe Ratio: 2.082, Validation Sharpe Ratio: 1.191
# Debug: L2 penalty: 6.28032428190824
# Debug: L1 penalty: 0.5894140627079315
# Debug: Objective function value (with penalty): 7.713261655383827
# --------------------------------------------------
# | 37        | 7.713     | -9.047    | 0.2851    | -20.0     | -20.0     | -9.943    | -13.34    | 1.225     | 20.0      | -12.1     | 2.393     | 6.389     | -20.0     |
# Train Sharpe Ratio: 0.306, Validation Sharpe Ratio: 0.507
# Debug: L2 penalty: 1.1096693380651692
# Debug: L1 penalty: 0.1406722416154121
# Debug: Objective function value (with penalty): 3.2166584203194186
# --------------------------------------------------
# | 38        | 3.217     | 4.76      | -12.17    | -11.51    | 2.476     | -19.16    | -14.84    | -2.722    | 1.888     | 11.16     | -6.196    | 7.072     | -11.01    |
# Train Sharpe Ratio: 1.85, Validation Sharpe Ratio: 0.786
# Debug: L2 penalty: 7.9056461082379546
# Debug: L1 penalty: 0.6420597289011278
# Debug: Objective function value (with penalty): 2.5042941628609174
# --------------------------------------------------
# | 39        | 2.504     | -0.9523   | -20.0     | -20.0     | -20.0     | -15.97    | -20.0     | -9.867    | 20.0      | 19.8      | 19.24     | -7.822    | -20.0     |
# Train Sharpe Ratio: 1.708, Validation Sharpe Ratio: 0.821
# Debug: L2 penalty: 5.548897940485128
# Debug: L1 penalty: 0.48748399465950437
# Debug: Objective function value (with penalty): 4.834618064855366
# --------------------------------------------------
# | 40        | 4.835     | 0.083     | -8.242    | -20.0     | -20.0     | -8.472    | -13.09    | 3.997     | -20.0     | 20.0      | -0.6      | -14.99    | -20.0     |
# Train Sharpe Ratio: 1.604, Validation Sharpe Ratio: 0.679
# Debug: L2 penalty: 3.31286688502941
# Debug: L1 penalty: 0.3665555952633073
# Debug: Objective function value (with penalty): 5.885577519707283
# --------------------------------------------------
# | 41        | 5.886     | 17.53     | 1.895     | -8.913    | -18.02    | -4.895    | -0.7808   | 14.61     | 10.82     | -13.45    | -9.761    | -16.63    | -10.44    |
# Train Sharpe Ratio: 1.293, Validation Sharpe Ratio: 1.004
# Debug: L2 penalty: 7.196298656283067
# Debug: L1 penalty: 0.5951435600265995
# Debug: Objective function value (with penalty): 3.115557783690334
# --------------------------------------------------
# | 42        | 3.116     | -20.0     | -17.91    | 8.534     | -20.0     | -20.0     | -20.0     | 9.105     | 20.0      | -20.0     | 2.085     | 4.249     | -20.0     |
# Train Sharpe Ratio: 0.862, Validation Sharpe Ratio: 0.453
# Debug: L2 penalty: 1.4383491629304022
# Debug: L1 penalty: 0.1904783930760744
# Debug: Objective function value (with penalty): 4.128172443993523
# --------------------------------------------------
# | 43        | 4.128     | 8.322     | -13.82    | -8.603    | -11.67    | -12.59    | -7.25     | -2.688    | -8.881    | 6.739     | -19.15    | -7.875    | -2.693    |
# Train Sharpe Ratio: 1.584, Validation Sharpe Ratio: 0.623
# Debug: L2 penalty: 3.6619461198692234
# Debug: L1 penalty: 0.3862812802656949
# Debug: Objective function value (with penalty): 5.064772599865082
# --------------------------------------------------
# | 44        | 5.065     | 19.56     | 12.17     | -11.99    | -13.57    | -9.669    | -1.264    | 15.5      | 18.71     | -11.18    | 2.781     | -9.096    | -15.79    |
# Train Sharpe Ratio: 0.442, Validation Sharpe Ratio: 0.09
# Debug: L2 penalty: 0.4876178508166581
# Debug: L1 penalty: 0.0634447197661313
# Debug: Objective function value (with penalty): 1.4049374294172106
# --------------------------------------------------
# | 45        | 1.405     | 9.173     | -10.08    | -12.36    | -11.23    | -8.14     | 15.65     | -1.097    | -7.667    | 0.2545    | -17.03    | -8.532    | -6.9      |
# Train Sharpe Ratio: 0.633, Validation Sharpe Ratio: -0.145
# Debug: L2 penalty: 0.2648789050759764
# Debug: L1 penalty: 0.031179839893427434
# Debug: Objective function value (with penalty): 0.5879412550305961
# --------------------------------------------------
# | 46        | 0.5879    | 14.24     | -13.78    | -12.88    | -19.92    | -3.058    | 4.461     | -9.815    | -14.95    | 7.087     | -10.35    | -5.944    | 1.091     |
# Train Sharpe Ratio: 1.044, Validation Sharpe Ratio: 0.377
# Debug: L2 penalty: 1.631378067858985
# Debug: L1 penalty: 0.18885750569436655
# Debug: Objective function value (with penalty): 3.9507644264466477
# --------------------------------------------------
# | 47        | 3.951     | 15.29     | 1.33      | -4.028    | -6.281    | -1.476    | -4.523    | 14.02     | 17.85     | -10.69    | -18.77    | -9.426    | -5.411    |
# Train Sharpe Ratio: -0.514, Validation Sharpe Ratio: -0.204
# Debug: L2 penalty: -0.6998531296207642
# Debug: L1 penalty: -0.09780599885280707
# Debug: Objective function value (with penalty): -2.1723408715264285
# --------------------------------------------------
# | 48        | -2.172    | 12.46     | -12.3     | -13.22    | 8.752     | -15.9     | -10.57    | -2.935    | 5.67      | 8.818     | -3.896    | 9.31      | -5.933    |
# Train Sharpe Ratio: 0.958, Validation Sharpe Ratio: 0.579
# Debug: L2 penalty: 2.4380853648536127
# Debug: L1 penalty: 0.2701890534412657
# Debug: Objective function value (with penalty): 4.218725581705121
# --------------------------------------------------
# | 49        | 4.219     | 13.72     | -11.11    | -12.04    | -8.381    | -16.6     | -10.08    | -2.252    | -18.06    | 1.588     | -19.59    | -7.802    | -8.79     |
# Train Sharpe Ratio: 1.173, Validation Sharpe Ratio: 0.811
# Debug: L2 penalty: 3.6294036284604076
# Debug: L1 penalty: 0.37007329382292303
# Debug: Objective function value (with penalty): 5.1965230777166695
# --------------------------------------------------
# | 50        | 5.197     | -17.34    | 3.046     | -18.29    | -15.65    | -17.91    | 9.82      | 4.592     | 0.2431    | -18.39    | 13.51     | 5.806     | -9.539    |
# Train Sharpe Ratio: 1.603, Validation Sharpe Ratio: 1.17
# Debug: L2 penalty: 3.5162236373769464
# Debug: L1 penalty: 0.3817106272348139
# Debug: Objective function value (with penalty): 9.101065735388241
# --------------------------------------------------
# | 51        | 9.101     | -3.043    | -5.383    | -8.538    | -20.0     | -20.0     | -9.117    | -2.173    | 0.5682    | -1.294    | -4.989    | -5.589    | -17.19    |
# Train Sharpe Ratio: 0.026, Validation Sharpe Ratio: 0.518
# Debug: L2 penalty: 0.649456966284701
# Debug: L1 penalty: 0.09692780068725315
# Debug: Objective function value (with penalty): 2.9576152330280454
# --------------------------------------------------
# | 52        | 2.958     | -2.092    | -9.878    | -6.094    | 3.486     | -13.11    | -16.24    | -0.5246   | 3.729     | 8.701     | -5.0      | 10.95     | -7.428    |
# Train Sharpe Ratio: 1.353, Validation Sharpe Ratio: 0.947
# Debug: L2 penalty: 9.987779488253858
# Debug: L1 penalty: 0.7583307739513505
# Debug: Objective function value (with penalty): -0.058110262205210095
# --------------------------------------------------
# | 53        | -0.05811  | -20.0     | 16.51     | -20.0     | -20.0     | -20.0     | -20.0     | -20.0     | 20.0      | -20.0     | 20.0      | 20.0      | -20.0     |
# Train Sharpe Ratio: 1.12, Validation Sharpe Ratio: 0.75
# Debug: L2 penalty: 4.782440190582907
# Debug: L1 penalty: 0.4133387061619746
# Debug: Objective function value (with penalty): 3.4142211032551177
# --------------------------------------------------
# | 54        | 3.414     | -4.089    | -8.107    | -2.364    | -20.0     | -20.0     | 20.0      | -4.638    | -20.0     | -5.368    | 15.46     | -20.0     | -20.0     |
# Train Sharpe Ratio: 2.093, Validation Sharpe Ratio: 1.002
# Debug: L2 penalty: 6.036922862096515
# Debug: L1 penalty: 0.589119372585764
# Debug: Objective function value (with penalty): 6.66695776531772
# --------------------------------------------------
# | 55        | 6.667     | -9.938    | -4.554    | -20.0     | -20.0     | -8.798    | -10.93    | -3.68     | 20.0      | -16.66    | -7.178    | -19.07    | -6.908    |
# Train Sharpe Ratio: 1.392, Validation Sharpe Ratio: 0.877
# Debug: L2 penalty: 3.8845257504781374
# Debug: L1 penalty: 0.40626383076039596
# Debug: Objective function value (with penalty): 6.024210418761465
# --------------------------------------------------
# | 56        | 6.024     | -5.735    | 2.148     | -17.15    | -19.91    | -13.06    | -18.08    | 18.43     | 8.466     | 6.563     | -6.241    | 12.44     | -3.063    |
# Train Sharpe Ratio: -0.76, Validation Sharpe Ratio: -1.076
# Debug: L2 penalty: -5.1654232202705535
# Debug: L1 penalty: -0.505038530503871
# Debug: Objective function value (with penalty): -4.141538249225575
# --------------------------------------------------
# | 57        | -4.142    | 14.95     | -17.44    | -11.1     | 8.85      | 7.48      | 18.72     | -11.01    | -12.93    | 19.11     | 19.27     | -15.13    | 15.57     |
# Train Sharpe Ratio: 2.048, Validation Sharpe Ratio: 0.759
# Debug: L2 penalty: 7.601182105889871
# Debug: L1 penalty: 0.6348913536392933
# Debug: Objective function value (with penalty): 3.2209265404708347
# --------------------------------------------------
# | 58        | 3.221     | -9.954    | -3.69     | -20.0     | -20.0     | 20.0      | -10.83    | 20.0      | 20.0      | -20.0     | 16.54     | -3.701    | -20.0     |
# Train Sharpe Ratio: 1.39, Validation Sharpe Ratio: 0.922
# Debug: L2 penalty: 4.482423349061125
# Debug: L1 penalty: 0.4197226092237963
# Debug: Objective function value (with penalty): 5.72185404171508
# --------------------------------------------------
# | 59        | 5.722     | -8.573    | -3.361    | -19.57    | -20.0     | -20.0     | 6.058     | 3.41      | 17.95     | -3.822    | -1.594    | -7.351    | -20.0     |
# Train Sharpe Ratio: 0.954, Validation Sharpe Ratio: -0.158
# Debug: L2 penalty: 0.9437837174698759
# Debug: L1 penalty: 0.09070746918515207
# Debug: Objective function value (with penalty): 0.7215088133449719
# --------------------------------------------------
# | 60        | 0.7215    | -4.975    | -17.75    | -17.49    | -14.92    | 9.588     | -18.56    | 9.261     | -19.93    | 17.09     | -15.01    | -13.11    | 14.5      |
# Train Sharpe Ratio: 0.212, Validation Sharpe Ratio: -0.292
# Debug: L2 penalty: -0.6472055353813556
# Debug: L1 penalty: -0.06519127178283053
# Debug: Objective function value (with penalty): -0.6956031928358137
# --------------------------------------------------
# | 61        | -0.6956   | -7.373    | -5.136    | -10.82    | 18.2      | 18.19     | 3.612     | 13.41     | -16.05    | 16.87     | 12.85     | -11.92    | -19.89    |
# Train Sharpe Ratio: 1.406, Validation Sharpe Ratio: 1.189
# Debug: L2 penalty: 5.855282645240567
# Debug: L1 penalty: 0.5559089617643618
# Debug: Objective function value (with penalty): 6.129808392995072
# --------------------------------------------------
# | 62        | 6.13      | -10.27    | -5.572    | -16.56    | -18.77    | -17.86    | -19.43    | 3.365     | -0.8083   | -7.092    | -10.84    | 17.23     | -19.95    |
# Train Sharpe Ratio: 1.095, Validation Sharpe Ratio: 0.331
# Debug: L2 penalty: 1.1888716953039355
# Debug: L1 penalty: 0.1669422086155354
# Debug: Objective function value (with penalty): 4.246186096080529
# --------------------------------------------------
# | 63        | 4.246     | -1.036    | -7.465    | -15.41    | -12.36    | -3.413    | 5.787     | -12.54    | -13.82    | 4.445     | -8.864    | -10.39    | -3.809    |
# Train Sharpe Ratio: 0.571, Validation Sharpe Ratio: 0.042
# Debug: L2 penalty: 0.5589150671079662
# Debug: L1 penalty: 0.06970058349711672
# Debug: Objective function value (with penalty): 1.3783843493949168
# --------------------------------------------------
# | 64        | 1.378     | 15.61     | -8.318    | -6.509    | 11.88     | -3.073    | 3.287     | 19.79     | -9.473    | -6.114    | 14.38     | -8.781    | -8.544    |
# Train Sharpe Ratio: -2.493, Validation Sharpe Ratio: -1.706
# Debug: L2 penalty: -6.038361409158956
# Debug: L1 penalty: -0.6446968545700485
# Debug: Objective function value (with penalty): -12.737941736270995
# --------------------------------------------------
# | 65        | -12.74    | 5.982     | 17.75     | 12.83     | 17.23     | 0.7258    | -10.46    | 8.721     | 14.67     | -3.14     | -0.6107   | 18.19     | 0.3474    |
# Train Sharpe Ratio: 2.45, Validation Sharpe Ratio: 1.202
# Debug: L2 penalty: 3.6773421518554708
# Debug: L1 penalty: 0.4182286153628715
# Debug: Objective function value (with penalty): 11.668429232781659
# --------------------------------------------------
# | 66        | 11.67     | -2.561    | -3.623    | -12.35    | -20.0     | -9.754    | -20.0     | 0.8538    | -1.202    | -6.389    | 1.273     | -5.205    | -5.222    |
# Train Sharpe Ratio: 1.096, Validation Sharpe Ratio: 0.728
# Debug: L2 penalty: 2.6142947563665366
# Debug: L1 penalty: 0.3076893557945181
# Debug: Objective function value (with penalty): 5.4620158878389455
# --------------------------------------------------
# | 67        | 5.462     | 10.83     | -15.13    | -10.02    | -19.25    | -18.02    | 7.796     | -13.15    | -7.784    | 3.611     | -2.428    | -6.258    | -8.054    |
# Train Sharpe Ratio: -0.748, Validation Sharpe Ratio: -0.375
# Debug: L2 penalty: -1.63048783527938
# Debug: L1 penalty: -0.18139028124975135
# Debug: Objective function value (with penalty): -3.0571218834708684
# --------------------------------------------------
# | 68        | -3.057    | 0.6475    | 2.551     | 16.51     | 7.219     | 9.042     | -10.24    | 19.22     | -18.8     | -10.71    | -5.749    | 13.92     | -9.561    |
# Train Sharpe Ratio: 1.896, Validation Sharpe Ratio: 1.101
# Debug: L2 penalty: 4.626764364110246
# Debug: L1 penalty: 0.48162432606222655
# Debug: Objective function value (with penalty): 8.286611309827528
# --------------------------------------------------
# | 69        | 8.287     | -6.613    | -3.914    | -9.107    | -20.0     | -20.0     | -20.0     | -1.85     | -12.25    | -7.605    | 1.742     | -12.26    | 4.508     |
# Train Sharpe Ratio: 2.645, Validation Sharpe Ratio: 1.196
# Debug: L2 penalty: 4.541643621196218
# Debug: L1 penalty: 0.48116813963701627
# Debug: Objective function value (with penalty): 11.284188239166767
# --------------------------------------------------
# | 70        | 11.28     | 0.1673    | -7.504    | -10.28    | -20.0     | -0.47     | -20.0     | -4.965    | -2.04     | -15.71    | 0.6467    | -5.374    | -11.21    |
# Train Sharpe Ratio: 2.923, Validation Sharpe Ratio: 0.857
# Debug: L2 penalty: 4.480364324632402
# Debug: L1 penalty: 0.510667986976738
# Debug: Objective function value (with penalty): 9.776967688390858
# --------------------------------------------------
# | 71        | 9.777     | -0.6029   | 6.067     | -16.59    | -13.74    | 5.866     | -15.6     | -7.317    | -2.432    | -15.67    | 18.54     | -8.263    | -4.577    |
# Train Sharpe Ratio: 2.591, Validation Sharpe Ratio: 0.671
# Debug: L2 penalty: 9.640496251864018
# Debug: L1 penalty: 0.7838341862711845
# Debug: Objective function value (with penalty): 2.045669561864796
# --------------------------------------------------
# | 72        | 2.046     | 10.75     | 8.234     | -20.0     | -20.0     | 20.0      | -20.0     | -12.46    | -20.0     | -20.0     | 20.0      | -20.0     | -18.08    |
# Train Sharpe Ratio: 0.169, Validation Sharpe Ratio: 0.341
# Debug: L2 penalty: 0.9911756404033281
# Debug: L1 penalty: 0.11352418023316045
# Debug: Objective function value (with penalty): 1.7893001793635117
# --------------------------------------------------
# | 73        | 1.789     | -14.82    | 2.071     | 6.618     | 4.544     | 7.551     | 14.4      | -19.42    | -9.201    | -12.97    | 11.92     | -10.75    | -16.5     |
# Train Sharpe Ratio: 0.084, Validation Sharpe Ratio: -0.488
# Debug: L2 penalty: -1.5865370217822663
# Debug: L1 penalty: -0.15897667877410862
# Debug: Objective function value (with penalty): -1.4184862994436247
# --------------------------------------------------
# | 74        | -1.418    | -10.36    | -16.18    | 15.73     | 12.5      | 9.406     | 5.728     | 12.54     | 15.7      | -18.29    | 15.21     | -18.69    | 17.16     |
# Train Sharpe Ratio: -0.991, Validation Sharpe Ratio: -0.67
# Debug: L2 penalty: -1.208073149073208
# Debug: L1 penalty: -0.16575351860977544
# Debug: Objective function value (with penalty): -6.289173332317017
# --------------------------------------------------
# | 75        | -6.289    | 15.72     | 0.5355    | 17.33     | -3.066    | -2.414    | -2.928    | -1.31     | 7.616     | 3.117     | 9.656     | -1.157    | -7.247    |
# Train Sharpe Ratio: -0.465, Validation Sharpe Ratio: -0.897
# Debug: L2 penalty: -2.946785562986439
# Debug: L1 penalty: -0.31663690144116513
# Debug: Objective function value (with penalty): -4.410577535572397
# --------------------------------------------------
# | 76        | -4.411    | -16.32    | 12.59     | -13.83    | 6.76      | 1.243     | 12.58     | -18.15    | 3.893     | 8.65      | 19.29     | -9.54     | 14.68     |
# Train Sharpe Ratio: 0.834, Validation Sharpe Ratio: -0.26
# Debug: L2 penalty: 0.23821608603478925
# Debug: L1 penalty: 0.02502290029969895
# Debug: Objective function value (with penalty): 0.4187610136655116
# --------------------------------------------------
# | 77        | 0.4188    | 8.082     | -15.94    | -16.14    | -0.4329   | 11.17     | -5.134    | 19.72     | -13.56    | 5.225     | 1.466     | -19.42    | 6.021     |
# Train Sharpe Ratio: -1.968, Validation Sharpe Ratio: -1.414
# Debug: L2 penalty: -8.081676672740427
# Debug: L1 penalty: -0.7744625951923855
# Debug: Objective function value (with penalty): -6.945860732067185
# --------------------------------------------------
# | 78        | -6.946    | -11.81    | -2.983    | 15.22     | 19.22     | 13.83     | 19.58     | 18.89     | 15.48     | 5.755     | -19.53    | -10.85    | 10.23     |
# Train Sharpe Ratio: 1.256, Validation Sharpe Ratio: 0.501
# Debug: L2 penalty: 1.7827794103911978
# Debug: L1 penalty: 0.22822003867016133
# Debug: Objective function value (with penalty): 5.26400055093864
# --------------------------------------------------
# | 79        | 5.264     | 7.897     | -6.297    | -15.55    | -16.95    | -9.914    | 11.45     | -7.906    | -15.24    | 0.07822   | -1.7      | -5.752    | -5.834    |
# Train Sharpe Ratio: 2.312, Validation Sharpe Ratio: 0.874
# Debug: L2 penalty: 5.349446933113893
# Debug: L1 penalty: 0.5543272677121558
# Debug: Objective function value (with penalty): 7.150225799173949
# --------------------------------------------------
# | 80        | 7.15      | -3.872    | -3.492    | -18.82    | -17.15    | -10.91    | -19.05    | 10.56     | 6.018     | -19.69    | 8.327     | -13.67    | 9.98      |
# Train Sharpe Ratio: -0.842, Validation Sharpe Ratio: -0.601
# Debug: L2 penalty: -2.253201756103374
# Debug: L1 penalty: -0.25342866925322777
# Debug: Objective function value (with penalty): -4.226369574643399
# --------------------------------------------------
# | 81        | -4.226    | -17.12    | 2.244     | 12.4      | -9.928    | 13.8      | 15.39     | 6.432     | 8.007     | 2.033     | 19.47     | 13.4      | -5.252    |
# Train Sharpe Ratio: 2.394, Validation Sharpe Ratio: 1.017
# Debug: L2 penalty: 2.9277580069609677
# Debug: L1 penalty: 0.387007997475605
# Debug: Objective function value (with penalty): 10.986233995563426
# --------------------------------------------------
# | 82        | 10.99     | -3.4      | 3.102     | -14.33    | -17.47    | -8.643    | -15.9     | 4.041     | -1.67     | -7.186    | -1.152    | -8.009    | 5.301     |
# Train Sharpe Ratio: 1.482, Validation Sharpe Ratio: 0.543
# Debug: L2 penalty: 2.330021783182797
# Debug: L1 penalty: 0.29277128002122216
# Debug: Objective function value (with penalty): 5.62420693679598
# --------------------------------------------------
# | 83        | 5.624     | 10.61     | 8.466     | -18.7     | -9.872    | -4.229    | -5.948    | 9.791     | 7.319     | -13.04    | -18.1     | -4.439    | -7.815    |
# Train Sharpe Ratio: 2.777, Validation Sharpe Ratio: 1.143
# Debug: L2 penalty: 4.954199531888764
# Debug: L1 penalty: 0.5281353189028707
# Debug: Objective function value (with penalty): 10.849665149208365
# --------------------------------------------------
# | 84        | 10.85     | -13.06    | 4.524     | -16.81    | -20.0     | 3.243     | -20.0     | -4.622    | -1.776    | -11.96    | 0.8283    | -6.91     | -4.052    |
# Train Sharpe Ratio: 1.043, Validation Sharpe Ratio: -0.16
# Debug: L2 penalty: 0.8276118147414572
# Debug: L1 penalty: 0.08778768463612943
# Debug: Objective function value (with penalty): 1.093600500622413
# --------------------------------------------------
# | 85        | 1.094     | -18.09    | 18.99     | -15.29    | -13.71    | -4.099    | -6.506    | 12.68     | 6.79      | 18.05     | 13.14     | -6.157    | 12.16     |
# Train Sharpe Ratio: 2.378, Validation Sharpe Ratio: 1.075
# Debug: L2 penalty: 3.3085505081928304
# Debug: L1 penalty: 0.40447349562082796
# Debug: Objective function value (with penalty): 10.945975996186341
# --------------------------------------------------
# | 86        | 10.95     | -5.053    | -0.7002   | -17.31    | -9.034    | -3.798    | -20.0     | -1.403    | -2.002    | -10.83    | 3.259     | -8.944    | -9.645    |
# Train Sharpe Ratio: -0.787, Validation Sharpe Ratio: -0.892
# Debug: L2 penalty: -3.068258577264318
# Debug: L1 penalty: -0.3323804487105215
# Debug: Objective function value (with penalty): -5.204360974025159
# --------------------------------------------------
# | 87        | -5.204    | 17.27     | 10.36     | 18.96     | -12.7     | -6.076    | -0.6411   | -17.19    | 8.632     | 1.462     | 13.35     | -7.575    | 14.54     |
# Train Sharpe Ratio: -0.325, Validation Sharpe Ratio: -0.637
# Debug: L2 penalty: -2.5126611529634557
# Debug: L1 penalty: -0.24548260062896343
# Debug: Objective function value (with penalty): -2.675856246407581
# --------------------------------------------------
# | 88        | -2.676    | 10.79     | 15.1      | -17.7     | 8.711     | -5.412    | 18.55     | -19.03    | 18.5      | -19.54    | 9.359     | -4.062    | 3.829     |
# Train Sharpe Ratio: 2.817, Validation Sharpe Ratio: 1.062
# Debug: L2 penalty: 4.679449178186379
# Debug: L1 penalty: 0.49335306701602466
# Debug: Objective function value (with penalty): 10.712197754797597
# --------------------------------------------------
# | 89        | 10.71     | 1.932     | 3.945     | -18.31    | -20.0     | -4.59     | -20.0     | -8.926    | 3.491     | -13.06    | 1.845     | -5.145    | -2.289    |
# Train Sharpe Ratio: 1.153, Validation Sharpe Ratio: 0.591
# Debug: L2 penalty: 1.948461551077812
# Debug: L1 penalty: 0.23082203453342165
# Debug: Objective function value (with penalty): 5.416716414388766
# --------------------------------------------------
# | 90        | 5.417     | -3.901    | -4.316    | -2.778    | -16.49    | 0.7407    | -10.75    | 10.09     | -8.223    | -15.65    | -19.75    | -1.883    | 6.727     |
# Train Sharpe Ratio: -1.126, Validation Sharpe Ratio: -0.78
# Debug: L2 penalty: -2.207687100899752
# Debug: L1 penalty: -0.263724768465271
# Debug: Objective function value (with penalty): -6.366588130634976
# --------------------------------------------------
# | 91        | -6.367    | 10.96     | -2.101    | -16.14    | 7.976     | 7.914     | 11.35     | -1.269    | -5.889    | 1.266     | 0.8352    | 16.64     | -17.13    |
# Train Sharpe Ratio: 0.607, Validation Sharpe Ratio: 0.208
# Debug: L2 penalty: 1.5907708317156275
# Debug: L1 penalty: 0.15876217538500478
# Debug: Objective function value (with penalty): 1.5274669928993678
# --------------------------------------------------
# | 92        | 1.527     | -13.34    | -16.56    | -16.75    | -4.224    | 10.62     | 19.45     | -8.755    | -9.969    | -9.615    | -18.2     | -15.06    | -18.94    |
# Train Sharpe Ratio: -0.813, Validation Sharpe Ratio: -1.515
# Debug: L2 penalty: -3.5971893573697105
# Debug: L1 penalty: -0.4442534962463521
# Debug: Objective function value (with penalty): -9.002557146383934
# --------------------------------------------------
# | 93        | -9.003    | 2.276     | 10.7      | 10.13     | 4.242     | 8.22      | 5.378     | 9.582     | -5.479    | -15.18    | 16.15     | -6.541    | 19.66     |
# Train Sharpe Ratio: 2.802, Validation Sharpe Ratio: 1.117
# Debug: L2 penalty: 3.875867348195698
# Debug: L1 penalty: 0.43788083062507227
# Debug: Objective function value (with penalty): 11.911251821179231
# --------------------------------------------------
# | 94        | 11.91     | -2.099    | 5.595     | -8.689    | -20.0     | -0.4421   | -20.0     | 2.152     | 1.14      | -9.702    | 1.947     | -11.71    | -6.485    |
# Train Sharpe Ratio: 0.601, Validation Sharpe Ratio: 0.103
# Debug: L2 penalty: 0.7418781857808332
# Debug: L1 penalty: 0.08736809311738189
# Debug: Objective function value (with penalty): 1.6947537211017845
# --------------------------------------------------
# | 95        | 1.695     | -14.38    | 4.67      | -12.84    | -0.505    | 15.15     | -16.32    | -3.835    | 18.32     | 7.287     | -5.479    | 6.194     | -10.4     |
# Train Sharpe Ratio: 2.494, Validation Sharpe Ratio: 1.132
# Debug: L2 penalty: 2.9431020638218994
# Debug: L1 penalty: 0.3851232488021148
# Debug: Objective function value (with penalty): 12.077774687375983
# --------------------------------------------------
# | 96        | 12.08     | -4.646    | -0.1515   | -11.52    | -20.0     | -2.559    | -9.151    | -1.829    | -0.01292  | -12.79    | 6.153     | -6.782    | -7.734    |
# Train Sharpe Ratio: 3.026, Validation Sharpe Ratio: 1.22
# Debug: L2 penalty: 4.547558196984236
# Debug: L1 penalty: 0.5376200426000388
# Debug: Objective function value (with penalty): 12.532821760415727
# --------------------------------------------------
# | 97        | 12.53     | -7.306    | -2.815    | -6.85     | -20.0     | 1.698     | -20.0     | -4.743    | 6.545     | -14.41    | 7.711     | -5.404    | -4.242    |
# Train Sharpe Ratio: -1.179, Validation Sharpe Ratio: -1.347
# Debug: L2 penalty: -4.801466459403197
# Debug: L1 penalty: -0.494293044713986
# Debug: Objective function value (with penalty): -7.670240495882817
# --------------------------------------------------
# | 98        | -7.67     | 11.09     | 17.54     | 1.463     | -3.259    | 17.65     | 19.53     | -17.6     | -10.61    | -3.089    | -10.12    | -13.34    | -1.789    |
# Train Sharpe Ratio: 3.008, Validation Sharpe Ratio: 1.254
# Debug: L2 penalty: 3.419414542524426
# Debug: L1 penalty: 0.44693676301535384
# Debug: Objective function value (with penalty): 13.935648694460221
# --------------------------------------------------
# | 99        | 13.94     | -9.818    | -1.692    | -4.258    | -12.07    | 7.866     | -19.78    | -1.465    | 5.183     | -13.72    | -1.228    | -1.909    | -4.708    |
# Train Sharpe Ratio: 2.569, Validation Sharpe Ratio: 1.217
# Debug: L2 penalty: 7.239783374296476
# Debug: L1 penalty: 0.6905952155210986
# Debug: Objective function value (with penalty): 8.295621410182425
# --------------------------------------------------
# | 100       | 8.296     | -20.0     | -8.264    | 3.984     | -18.3     | 20.0      | -20.0     | -5.64     | 8.29      | -20.0     | -5.609    | -3.608    | -8.176    |
# Train Sharpe Ratio: 1.679, Validation Sharpe Ratio: 0.926
# Debug: L2 penalty: 2.7767308611604147
# Debug: L1 penalty: 0.3371146548545484
# Debug: Objective function value (with penalty): 8.405154483985035
# --------------------------------------------------
# | 101       | 8.405     | -14.46    | 4.332     | 3.958     | -7.269    | 2.502     | -17.36    | -8.446    | -3.041    | -19.76    | -1.949    | -10.54    | -3.945    |
# Train Sharpe Ratio: 2.246, Validation Sharpe Ratio: 0.537
# Debug: L2 penalty: 3.597684151767778
# Debug: L1 penalty: 0.4117788386319779
# Debug: Objective function value (with penalty): 6.487537009600244
# --------------------------------------------------
# | 102       | 6.488     | -13.96    | -9.771    | -10.42    | -11.22    | 10.37     | -18.26    | -5.0      | 14.04     | -18.06    | 6.584     | -0.5901   | 12.47     |
# Train Sharpe Ratio: 2.179, Validation Sharpe Ratio: 1.019
# Debug: L2 penalty: 4.143090948027685
# Debug: L1 penalty: 0.4981888265323541
# Debug: Objective function value (with penalty): 9.02872022543996
# --------------------------------------------------
# | 103       | 9.029     | -7.423    | -8.429    | -1.343    | -19.7     | 6.401     | -15.46    | 11.83     | 15.98     | -6.289    | -6.995    | -9.903    | -11.73    |
# Train Sharpe Ratio: 2.279, Validation Sharpe Ratio: 0.834
# Debug: L2 penalty: 3.219072098063348
# Debug: L1 penalty: 0.3345914264892155
# Debug: Objective function value (with penalty): 9.121336475447437
# --------------------------------------------------
# | 104       | 9.121     | -0.05901  | -2.18     | -0.6601   | -19.83    | 0.8751    | -12.08    | 13.54     | 12.14     | -3.4      | 1.797     | -19.36    | 2.068     |
# Train Sharpe Ratio: -1.58, Validation Sharpe Ratio: -1.264
# Debug: L2 penalty: -4.713181232557769
# Debug: L1 penalty: -0.5251832871644104
# Debug: Objective function value (with penalty): -8.349635480277822
# --------------------------------------------------
# | 105       | -8.35     | -5.482    | 17.0      | 15.35     | 11.04     | 4.564     | 16.47     | -17.92    | -7.011    | -15.99    | 6.954     | -9.403    | 1.645     |
# Train Sharpe Ratio: 1.889, Validation Sharpe Ratio: 0.929
# Debug: L2 penalty: 3.069050762862924
# Debug: L1 penalty: 0.3663719110433057
# Debug: Objective function value (with penalty): 8.734577326093772
# --------------------------------------------------
# | 106       | 8.735     | -5.314    | 1.105     | -5.297    | -14.9     | 8.452     | -18.06    | 13.24     | -6.455    | -13.42    | -0.3987   | 0.04805   | -13.66    |
# Train Sharpe Ratio: -1.945, Validation Sharpe Ratio: -1.317
# Debug: L2 penalty: -4.52185410353143
# Debug: L1 penalty: -0.5379533656881867
# Debug: Objective function value (with penalty): -9.994192530780381
# --------------------------------------------------
# | 107       | -9.994    | 2.381     | 13.42     | 14.3      | 8.266     | -4.889    | -5.805    | -6.468    | 4.036     | 17.04     | 9.617     | 17.81     | 15.08     |
# Train Sharpe Ratio: -0.574, Validation Sharpe Ratio: -0.502
# Debug: L2 penalty: -1.1830013340247592
# Debug: L1 penalty: -0.1641130819050198
# Debug: Objective function value (with penalty): -3.8888855840702212
# --------------------------------------------------
# | 108       | -3.889    | 3.672     | 6.964     | 8.943     | -2.825    | -6.989    | -10.22    | -11.32    | -9.697    | 9.813     | -17.56    | -13.88    | 2.583     |
# Train Sharpe Ratio: 2.045, Validation Sharpe Ratio: 0.929
# Debug: L2 penalty: 2.2705040083002594
# Debug: L1 penalty: 0.31634866261758576
# Debug: Objective function value (with penalty): 10.051147329082154
# --------------------------------------------------
# | 109       | 10.05     | -7.709    | -10.87    | -10.11    | -11.18    | -3.061    | -12.03    | 3.333     | 3.885     | -17.53    | 0.8808    | -2.136    | -0.7132   |
# Train Sharpe Ratio: 0.577, Validation Sharpe Ratio: -0.016
# Debug: L2 penalty: 0.708024853426497
# Debug: L1 penalty: 0.07348400102009556
# Debug: Objective function value (with penalty): 0.8374911455534072
# --------------------------------------------------
# | 110       | 0.8375    | 15.49     | -9.24     | 8.69      | -14.36    | 14.26     | 14.78     | 17.59     | -18.0     | -7.82     | 16.87     | -13.35    | -0.8555   |
# Train Sharpe Ratio: 0.974, Validation Sharpe Ratio: 0.042
# Debug: L2 penalty: 1.0711510782257672
# Debug: L1 penalty: 0.12353946992399319
# Debug: Objective function value (with penalty): 2.021309451850239
# --------------------------------------------------
# | 111       | 2.021     | 8.485     | -17.02    | -8.094    | 8.205     | 8.142     | -6.199    | -2.882    | 18.73     | -5.632    | 17.28     | -14.68    | -12.71    |
# Train Sharpe Ratio: 2.138, Validation Sharpe Ratio: 0.397
# Debug: L2 penalty: 3.487128213809149
# Debug: L1 penalty: 0.3874341981482337
# Debug: Objective function value (with penalty): 5.318437588042618
# --------------------------------------------------
# | 112       | 5.318     | -2.297    | 17.4      | -10.18    | -17.33    | 15.53     | -14.04    | -8.982    | 12.0      | -16.21    | -5.893    | -12.73    | -7.898    |
# ...
# Train Sharpe Ratio: 2.526, Validation Sharpe Ratio: 1.049
# Debug: L2 penalty: 1.928525922782268
# Debug: L1 penalty: 0.333808462311183
# Debug: Objective function value (with penalty): 12.658665614906546
# --------------------------------------------------
# | 285       | 12.66     | -1.678    | -9.876    | 0.2345    | -10.04    | 2.106     | -13.27    | -3.559    | 8.262     | -3.321    | 7.237     | -5.518    | -9.469    |
# Train Sharpe Ratio: 1.894, Validation Sharpe Ratio: 0.509
# Debug: L2 penalty: 2.42623672779343
# Debug: L1 penalty: 0.31222970515182286
# Debug: Objective function value (with penalty): 6.506533567054746
# --------------------------------------------------
# | 286       | 6.507     | -13.95    | 12.15     | -7.059    | -16.41    | 12.84     | -15.37    | 6.52      | -3.614    | 3.208     | 11.26     | 3.5       | -6.696    |
# Train Sharpe Ratio: 3.034, Validation Sharpe Ratio: 1.083
# Debug: L2 penalty: 3.20338212903175
# Debug: L1 penalty: 0.42992428874222605
# Debug: Objective function value (with penalty): 13.049693582226023
# --------------------------------------------------
# | 287       | 13.05     | 2.541     | -5.048    | -2.655    | -17.5     | 7.101     | -17.25    | 2.449     | 10.01     | -10.49    | -1.018    | 4.148     | -5.69     |
# Train Sharpe Ratio: 3.174, Validation Sharpe Ratio: 1.151
# Debug: L2 penalty: 2.7579041326907543
# Debug: L1 penalty: 0.40855615099205594
# Debug: Objective function value (with penalty): 14.412539716317188
# --------------------------------------------------
# | 288       | 14.41     | 3.534     | -2.175    | -1.521    | -18.1     | 1.441     | -12.35    | -4.649    | 11.44     | -7.522    | 4.077     | -4.937    | -5.73     |
# Train Sharpe Ratio: 1.868, Validation Sharpe Ratio: 1.209
# Debug: L2 penalty: 2.8634217345361694
# Debug: L1 penalty: 0.3705619770518565
# Debug: Objective function value (with penalty): 10.833016288411974
# --------------------------------------------------
# | 289       | 10.83     | -2.204    | -2.096    | -4.738    | -9.822    | -10.66    | -14.58    | -2.925    | 14.12     | 3.318     | 5.337     | -0.2321   | -17.77    |
# Train Sharpe Ratio: 1.967, Validation Sharpe Ratio: 0.993
# Debug: L2 penalty: 2.100078645925975
# Debug: L1 penalty: 0.31050710562447914
# Debug: Objective function value (with penalty): 10.441414248449545
# --------------------------------------------------
# | 290       | 10.44     | 1.271     | 3.08      | -4.214    | -15.7     | 4.764     | -9.566    | -12.64    | 2.358     | -4.082    | -2.513    | -6.161    | -14.19    |
# Train Sharpe Ratio: 2.339, Validation Sharpe Ratio: 1.175
# Debug: L2 penalty: 4.524397910724069
# Debug: L1 penalty: 0.47803941900266134
# Debug: Objective function value (with penalty): 10.239562670273271
# --------------------------------------------------
# | 291       | 10.24     | -0.4487   | -8.286    | -1.804    | -19.84    | -1.603    | -9.998    | -12.11    | -0.08849  | -5.709    | 18.71     | -7.978    | -17.97    |
# Train Sharpe Ratio: 2.471, Validation Sharpe Ratio: 1.102
# Debug: L2 penalty: 2.883228513592245
# Debug: L1 penalty: 0.37440997245996227
# Debug: Objective function value (with penalty): 11.869361513947792
# --------------------------------------------------
# | 292       | 11.87     | -18.25    | -6.416    | -4.459    | -11.11    | 11.86     | -14.93    | 0.9233    | -0.8245   | -2.388    | 3.112     | -0.8669   | -7.367    |
# Train Sharpe Ratio: 1.683, Validation Sharpe Ratio: 0.822
# Debug: L2 penalty: 2.8601126403017263
# Debug: L1 penalty: 0.34712669594805046
# Debug: Objective function value (with penalty): 7.59576066375022
# --------------------------------------------------
# | 293       | 7.596     | -17.78    | -2.606    | 2.379     | 0.5131    | 8.024     | -8.74     | -6.604    | 6.378     | -14.05    | 12.28     | -18.15    | -9.608    |
# Train Sharpe Ratio: 3.153, Validation Sharpe Ratio: 1.037
# Debug: L2 penalty: 4.080349673629628
# Debug: L1 penalty: 0.43983512303152006
# Debug: Objective function value (with penalty): 12.19781520333885
# --------------------------------------------------
# | 294       | 12.2      | -0.5029   | 0.9504    | -13.63    | -15.31    | 0.6777    | -17.2     | 5.108     | 11.81     | -18.17    | 1.23      | -1.986    | 1.112     |
# Train Sharpe Ratio: 1.112, Validation Sharpe Ratio: 0.717
# Debug: L2 penalty: 1.375739315291449
# Debug: L1 penalty: 0.17772415550318385
# Debug: Objective function value (with penalty): 6.801536529205365
# --------------------------------------------------
# | 295       | 6.802     | -2.158    | -3.837    | 12.08     | -14.45    | -0.3269   | -14.3     | -0.4279   | 14.62     | -0.1945   | 0.804     | 3.417     | -4.294    |
# Train Sharpe Ratio: 1.373, Validation Sharpe Ratio: 0.988
# Debug: L2 penalty: 3.256174408549928
# Debug: L1 penalty: 0.3755400448341674
# Debug: Objective function value (with penalty): 7.403285546615905
# --------------------------------------------------
# | 296       | 7.403     | 2.082     | -8.428    | 7.881     | -7.701    | -11.64    | -6.212    | -2.131    | 16.99     | -18.17    | 2.48      | -10.78    | -18.94    |
# Train Sharpe Ratio: 2.767, Validation Sharpe Ratio: 0.68
# Debug: L2 penalty: 1.885510042324059
# Debug: L1 penalty: 0.27587777728206103
# Debug: Objective function value (with penalty): 10.899612180393879
# --------------------------------------------------
# | 297       | 10.9      | 11.44     | -2.497    | -8.66     | -17.99    | -0.56     | -8.732    | -1.439    | 8.524     | -4.608    | -1.613    | -3.036    | -1.308    |
# Train Sharpe Ratio: 2.714, Validation Sharpe Ratio: 0.996
# Debug: L2 penalty: 3.5067692749401225
# Debug: L1 penalty: 0.4409154253486952
# Debug: Objective function value (with penalty): 11.166315299711181
# --------------------------------------------------
# | 298       | 11.17     | 6.75      | -0.2101   | 0.6544    | -17.89    | -8.282    | -13.69    | -7.175    | 6.773     | 4.227     | 13.47     | -15.27    | -2.848    |
# Train Sharpe Ratio: 2.241, Validation Sharpe Ratio: 1.135
# Debug: L2 penalty: 3.809271672348701
# Debug: L1 penalty: 0.4338459587709109
# Debug: Objective function value (with penalty): 10.424882368880388
# --------------------------------------------------
# | 299       | 10.42     | -10.04    | -9.061    | -10.18    | -18.29    | 4.266     | -18.78    | -11.3     | 0.1903    | -3.262    | -0.04221  | -0.2129   | -12.97    |
# Train Sharpe Ratio: 2.136, Validation Sharpe Ratio: 1.181
# Debug: L2 penalty: 1.8586410152489325
# Debug: L1 penalty: 0.29570179359290344
# Debug: Objective function value (with penalty): 12.520657191158165
# --------------------------------------------------
# | 300       | 12.52     | -9.601    | -0.8678   | -10.2     | -16.44    | -3.865    | -3.097    | -9.517    | 1.671     | 3.217     | 2.868     | -0.4131   | -5.404    |
# Train Sharpe Ratio: 1.818, Validation Sharpe Ratio: 1.14
# Debug: L2 penalty: 3.24773271170533
# Debug: L1 penalty: 0.4242888509448739
# Debug: Objective function value (with penalty): 9.761978437349795
# --------------------------------------------------
# | 301       | 9.762     | -6.145    | -7.631    | -8.055    | -11.5     | -11.66    | -16.53    | 3.219     | 13.26     | -14.31    | -0.7011   | 10.59     | -1.674    |
# Train Sharpe Ratio: 2.73, Validation Sharpe Ratio: 1.129
# Debug: L2 penalty: 3.623761086687221
# Debug: L1 penalty: 0.4594661101326268
# Debug: Objective function value (with penalty): 12.009772803180152
# --------------------------------------------------
# | 302       | 12.01     | 4.964     | 6.255     | -1.546    | -17.78    | -0.8524   | -16.11    | -2.809    | 10.55     | -15.28    | -4.307    | -5.949    | -8.773    |
# Train Sharpe Ratio: 3.07, Validation Sharpe Ratio: 0.803
# Debug: L2 penalty: 2.295267596390687
# Debug: L1 penalty: 0.3291980231126174
# Debug: Objective function value (with penalty): 12.206534380496695
# --------------------------------------------------
# | 303       | 12.21     | -0.6993   | 9.489     | -9.966    | -17.65    | 2.291     | -13.59    | 3.514     | 5.198     | -1.656    | 5.512     | -1.93     | -2.491    |
# Train Sharpe Ratio: 2.204, Validation Sharpe Ratio: 1.238
# Debug: L2 penalty: 2.1871711661348683
# Debug: L1 penalty: 0.3566040590196239
# Debug: Objective function value (with penalty): 12.734224774845508
# --------------------------------------------------
# | 304       | 12.73     | -6.7      | 0.8358    | -7.42     | -10.24    | -4.973    | -10.5     | 1.233     | 16.11     | -5.377    | 1.601     | 5.799     | -7.023    |
# Train Sharpe Ratio: 2.535, Validation Sharpe Ratio: 1.131
# Debug: L2 penalty: 1.6858326927334961
# Debug: L1 penalty: 0.235176431410002
# Debug: Objective function value (with penalty): 13.600990875856501
# --------------------------------------------------
# | 305       | 13.6      | -0.798    | -4.347    | 0.97      | -18.13    | -2.638    | -9.338    | -0.34     | -1.605    | -1.772    | 9.664     | -0.5277   | 0.3721    |
# Train Sharpe Ratio: 1.395, Validation Sharpe Ratio: 0.376
# Debug: L2 penalty: 6.54432
# Debug: L1 penalty: 0.49082400000000004
# Debug: Objective function value (with penalty): -0.21814399999999978
# --------------------------------------------------
# | 306       | -0.2181   | -20.0     | 20.0      | -20.0     | 20.0      | 20.0      | -20.0     | 20.0      | -20.0     | -20.0     | 20.0      | -20.0     | -20.0     |
# Train Sharpe Ratio: 2.708, Validation Sharpe Ratio: 1.03
# Debug: L2 penalty: 3.387202376643745
# Debug: L1 penalty: 0.4350844859900692
# Debug: Objective function value (with penalty): 11.511713137366185
# --------------------------------------------------
# | 307       | 11.51     | 6.806     | -10.78    | -4.058    | -13.18    | -4.088    | -17.2     | 1.69      | 17.59     | -3.864    | -0.4473   | -6.676    | -8.203    |
# Train Sharpe Ratio: 1.855, Validation Sharpe Ratio: 0.649
# Debug: L2 penalty: 1.2727245421737738
# Debug: L1 penalty: 0.23778901018301898
# Debug: Objective function value (with penalty): 8.597486447643206
# --------------------------------------------------
# | 308       | 8.597     | -4.682    | -6.816    | -5.473    | -2.854    | 11.09     | -10.89    | 0.5671    | -7.822    | -10.89    | -6.204    | -4.833    | -6.3      |
# Train Sharpe Ratio: 2.561, Validation Sharpe Ratio: 1.082
# Debug: L2 penalty: 3.7022392119817686
# Debug: L1 penalty: 0.47076372857997045
# Debug: Objective function value (with penalty): 11.08399705943826
# --------------------------------------------------
# | 309       | 11.08     | 3.686     | -0.9299   | -4.621    | -16.86    | 1.069     | -10.11    | -8.658    | -12.8     | 6.192     | 15.62     | -7.992    | -14.31    |
# Train Sharpe Ratio: 2.761, Validation Sharpe Ratio: 0.9
# Debug: L2 penalty: 2.4147159340200632
# Debug: L1 penalty: 0.3577736397952958
# Debug: Objective function value (with penalty): 11.81051042618464
# --------------------------------------------------
# | 310       | 11.81     | 5.692     | 8.283     | -4.916    | -13.77    | -2.773    | -18.99    | 3.126     | -2.531    | 2.649     | 5.647     | -6.746    | -6.659    |
# Train Sharpe Ratio: 2.457, Validation Sharpe Ratio: 1.077
# Debug: L2 penalty: 4.946784921602297
# Debug: L1 penalty: 0.5473196951291152
# Debug: Objective function value (with penalty): 9.415895383268587
# --------------------------------------------------
# | 311       | 9.416     | 4.15      | -0.7435   | 6.458     | -17.71    | -9.749    | -17.4     | -3.797    | 10.77     | -11.19    | 15.42     | -18.92    | -6.053    |
# Train Sharpe Ratio: 2.485, Validation Sharpe Ratio: 1.052
# Debug: L2 penalty: 1.8266371189716188
# Debug: L1 penalty: 0.2952173425497761
# Debug: Objective function value (with penalty): 12.697145538478605
# --------------------------------------------------
# | 312       | 12.7      | -10.14    | -5.189    | -1.251    | -4.99     | 5.116     | -17.28    | 7.16      | 6.662     | -6.087    | -0.4914   | -1.466    | -0.5762   |
# Train Sharpe Ratio: 1.642, Validation Sharpe Ratio: 0.874
# Debug: L2 penalty: 1.3406906113844936
# Debug: L1 penalty: 0.2418158812329771
# Debug: Objective function value (with penalty): 9.46149350738253
# --------------------------------------------------
# | 313       | 9.461     | -10.01    | -1.901    | -9.005    | -1.32     | 6.052     | -9.83     | 2.776     | -5.43     | -8.474    | -5.454    | -0.5669   | -12.17    |
# Train Sharpe Ratio: 1.411, Validation Sharpe Ratio: 1.046
# Debug: L2 penalty: 2.9217759690610086
# Debug: L1 penalty: 0.3225628747930263
# Debug: Objective function value (with penalty): 8.310661156145963
# --------------------------------------------------
# | 314       | 8.311     | -17.17    | -11.39    | -0.681    | -18.77    | -2.967    | -4.044    | -1.831    | -2.213    | -2.476    | 6.075     | 6.119     | -19.31    |
# Train Sharpe Ratio: 3.205, Validation Sharpe Ratio: 0.878
# Debug: L2 penalty: 3.332082396997429
# Debug: L1 penalty: 0.40492177514099426
# Debug: Objective function value (with penalty): 12.023995827861576
# --------------------------------------------------
# | 315       | 12.02     | 3.567     | -3.098    | -11.06    | -18.2     | 5.151     | -14.16    | -0.8481   | 0.3714    | -17.16    | 6.357     | -3.894    | 1.767     |
# Train Sharpe Ratio: 2.243, Validation Sharpe Ratio: 0.791
# Debug: L2 penalty: 2.033977199982818
# Debug: L1 penalty: 0.3032354520710978
# Debug: Objective function value (with penalty): 9.928787347946082
# --------------------------------------------------
# | 316       | 9.929     | 2.288     | 2.526     | 8.474     | -18.65    | 0.716     | -11.25    | -5.289    | 10.12     | -6.392    | 7.143     | -5.946    | -3.607    |
# Train Sharpe Ratio: 3.162, Validation Sharpe Ratio: 0.836
# Debug: L2 penalty: 2.9851259759523474
# Debug: L1 penalty: 0.3650752882376933
# Debug: Objective function value (with penalty): 11.987798735809957
# --------------------------------------------------
# | 317       | 11.99     | 0.5141    | -2.044    | -6.648    | -18.52    | 2.603     | -16.95    | 4.463     | 3.84      | -2.152    | 0.4923    | -14.08    | 7.027     |
# Train Sharpe Ratio: 2.577, Validation Sharpe Ratio: 1.149
# Debug: L2 penalty: 3.0894945754364245
# Debug: L1 penalty: 0.4286779325513996
# Debug: Objective function value (with penalty): 12.255827492012175
# --------------------------------------------------
# | 318       | 12.26     | 0.5597    | 4.084     | -7.758    | -16.57    | 1.848     | -7.039    | -6.694    | -8.724    | -5.32     | 13.31     | -3.27     | -15.42    |
# Train Sharpe Ratio: 2.503, Validation Sharpe Ratio: 0.995
# Debug: L2 penalty: 3.2267701613193607
# Debug: L1 penalty: 0.4206705779425409
# Debug: Objective function value (with penalty): 10.826559260738097
# --------------------------------------------------
# | 319       | 10.83     | -10.94    | 4.529     | -11.27    | -18.26    | 11.45     | -11.91    | 3.967     | 1.11      | -13.18    | -5.844    | -0.4143   | -4.002    |
# Train Sharpe Ratio: 0.896, Validation Sharpe Ratio: -0.353
# Debug: L2 penalty: 0.20832000000000025
# Debug: L1 penalty: 0.015624000000000016
# Debug: Objective function value (with penalty): -0.006944000000000023
# --------------------------------------------------
# | 320       | -0.006944 | -20.0     | -20.0     | -20.0     | 20.0      | 20.0      | -20.0     | 20.0      | 20.0      | -20.0     | -20.0     | -20.0     | 20.0      |
# =========================================================================================================================================================================
# Optimal Weights: {'average_true_range': 0.2875316881647642, 'chaikin_money_flow': -1.9752995549505012, 'chande_momentum_oscillator': -1.8640883585701926, 'ichimoku': -19.828101328449076, 'know_sure_thing': -0.5547779974842556, 'macd': -11.271204432742135, 'on_balance_volume': 0.8947678636093155, 'trend_1_3': 7.652860063044346, 'trend_5_20': -5.5668763313155045, 'ultimate_oscillator': 2.639056327719508, 'volatility_20': -1.2722463491667522, 'volume': -7.2769434193930405}
# Test Set Sharpe Ratio: 0.213

# %%
optimal_weights = {
    "average_true_range": 0.2558,
    "chaikin_money_flow": -0.3338,
    "chande_momentum_oscillator": -1.084,
    "ichimoku": -5.0,
    "know_sure_thing": 0.3446,
    "macd": -5.0,
    "on_balance_volume": 1.19,
    "trend_1_3": 3.472,
    "trend_5_20": -4.825,
    "ultimate_oscillator": 1.106,
    "volatility_20": 1.619,
    "volume": -1.455
}

# %%
portfolio_weights_test = generate_portfolio_vectorized(test_features, test_universe, np.array(list(optimal_weights.values())))
sr_test, _ = backtest_portfolio_new(portfolio_weights_test, test_returns, test_universe,False,False)

print("Optimal Weights:", optimal_weights)
print("Test Set Sharpe Ratio:", sr_test)
# Out:
# Optimal Weights: {'average_true_range': 0.2558, 'chaikin_money_flow': -0.3338, 'chande_momentum_oscillator': -1.084, 'ichimoku': -5.0, 'know_sure_thing': 0.3446, 'macd': -5.0, 'on_balance_volume': 1.19, 'trend_1_3': 3.472, 'trend_5_20': -4.825, 'ultimate_oscillator': 1.106, 'volatility_20': 1.619, 'volume': -1.455}
# Test Set Sharpe Ratio: 0.62
