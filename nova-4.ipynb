# %%
import pandas as pd
import numpy as np

import datetime
import os, sys
import importlib

import utils
importlib.reload(utils)

from utils import plot_series, plot_series_with_names, plot_series_bar
from utils import plot_dataframe
from utils import get_universe_adjusted_series, scale_weights_to_one, scale_to_book_long_short
from utils import generate_portfolio, backtest_portfolio
from utils import match_implementations

import plotly.graph_objects as go

# %%
# This directory can be used if you're working on a Kaggle Notebook inside the competition
# Change the directory as per your requirements if you're working somewhere else
data_dir = "/kaggle/input/qrt-quant-quest-iit-bombay-2025/"

features = pd.read_parquet(os.path.join(data_dir, "features.parquet"))

universe = pd.read_parquet(os.path.join(data_dir, "universe.parquet"))
 
returns = pd.read_parquet(os.path.join(data_dir, "returns.parquet"))

# %%
# Original selected features
selected_features = [
    'on_balance_volume', 'trend_1_3', 'macd', 'ichimoku',
    'ultimate_oscillator', 'chaikin_money_flow', 'volume',
    'know_sure_thing', 'chande_momentum_oscillator',
    'average_true_range', 'volatility_20', 'trend_5_20'
]

# %%
train_features = features.loc["2005":"2015"]
validation_features = features.loc["2016":"2018"]
test_features = features.loc["2019"]

train_universe = universe.loc["2005":"2015"]
validation_universe = universe.loc["2016":"2018"]
test_universe = universe.loc["2019"]

train_returns = returns.loc["2005":"2015"]
validation_returns = returns.loc["2016":"2018"]
test_returns = returns.loc["2019"]

# Filter features based on selected features

# Check if columns have a MultiIndex
if isinstance(train_features.columns, pd.MultiIndex):
    # Filter columns based on level 0 of MultiIndex
    train_features = train_features.loc[:, train_features.columns.get_level_values(0).isin(selected_features)]
    validation_features = validation_features.loc[:, validation_features.columns.get_level_values(0).isin(selected_features)]
    test_features = test_features.loc[:, test_features.columns.get_level_values(0).isin(selected_features)]
    
    # Remove unused levels from MultiIndex
    train_features.columns = train_features.columns.remove_unused_levels()
    validation_features.columns = validation_features.columns.remove_unused_levels()
    test_features.columns = test_features.columns.remove_unused_levels()
else:
    # If columns are not MultiIndexed, filter directly
    train_features = train_features[selected_features]
    validation_features = validation_features[selected_features]
    test_features = test_features[selected_features]

# Debugging: Print filtered column levels
if isinstance(train_features.columns, pd.MultiIndex):
    print("Filtered Train Features Columns (Level 0):", train_features.columns.get_level_values(0).unique())
else:
    print("Filtered Train Features Columns:", train_features.columns)
# Out:
# Filtered Train Features Columns (Level 0): Index(['macd', 'trend_1_3', 'trend_5_20', 'ichimoku', 'know_sure_thing',
#        'average_true_range', 'volatility_20', 'on_balance_volume',
#        'chaikin_money_flow', 'volume', 'ultimate_oscillator',
#        'chande_momentum_oscillator'],
#       dtype='object')

# %%
def backtest_portfolio_new(portfolio: pd.DataFrame, returns: pd.DataFrame, universe: pd.DataFrame, plot_: bool, print_: bool):

    """
    Computes performance metrics from a given portfolio DataFrame.

    This function calculates the net Sharpe ratio, along with other portfolio metrics,
    ensuring that certain constraints are met. It performs checks for:
    - Shape alignment of input DataFrames.
    - portfolio weights only in stocks that are part of the universe.
    - Dollar neutrality.
    - Unit capital constraint.
    - Maximum weight constraint.

    Parameters:
    ----------
    portfolio : pd.DataFrame
        DataFrame representing portfolio over time.
    returns : pd.DataFrame
        DataFrame containing stock returns corresponding to the portfolio.
    universe : pd.DataFrame
        Boolean DataFrame indicating whether a stock is part of the investable universe.
    plot_: bool
        Boolean Flag which decides whether to plot the cumulative PnL
    print_: bool
        Boolean Flag which decides whether to print the metrics of backtest

    Raises:
    ------
    ValueError
        If the input DataFrames do not have matching shapes.
        If portfolio contain stocks that are not in the universe.
        If the portfolio violates the dollar neutrality constraint.
        If the unit capital constraint is violated.
        If the maximum weight constraint is exceeded.

    Returns
    -------
    tuple
        - Net Sharpe Ratio (rounded to 3 decimal places).
        - Pandas Series containing gross PnL over time.

    Additional Outputs:
    -------------------
    - Prints the gross and net Sharpe ratios.
    - Prints the turnover percentage.
    - Plots cumulative Gross and Net PnL.

    Notes:
    ------
    - The turnover is calculated as the average traded capital divided by the average book value.
    - The gross and net Sharpe ratios are annualized using a factor of √252.
    - The net PnL accounts for trading costs (assumed to be 0.01% per unit traded).
    """

    universe = universe.astype(bool)
    
    if not (portfolio.shape == returns.shape == universe.shape):
        raise ValueError("Shapes of portfolio, returns and universe are not algined")

    if ((portfolio.replace(0, np.nan))[~universe].notna().sum().sum() != 0):
        raise ValueError("Your portfolio are present for a stock not present in the universe")

    if ((portfolio.sum(1).abs() > 0.01).sum() > 0):
        raise ValueError("Dollar Neutral Constraint is violated")
    
    if (((portfolio.abs().sum(1) - 1) > 0.01).sum() > 0):
        raise ValueError("Unit Capital Constraint is violated")

    if ((portfolio.abs().max(1) > 0.1).sum() > 0):
        raise ValueError("Maximum Weight Constraint is violated")

    portfolio = portfolio.fillna(0)

    rets = returns.fillna(0)

    gross_pnl = (portfolio * rets).sum(axis=1)

    traded = portfolio.diff(1).abs().sum(axis=1).fillna(0)

    net_pnl = gross_pnl - traded * 1e-4

    gross_sharpe_ratio = (gross_pnl.mean() / gross_pnl.std()) * np.sqrt(252)

    net_sharpe_ratio = (net_pnl.mean() / net_pnl.std()) * np.sqrt(252)

    if print_:
        print("Gross Sharpe Ratio: ", round(gross_sharpe_ratio, 3))
        print("Net Sharpe Ratio: ", round(net_sharpe_ratio, 3))

    return round(net_sharpe_ratio, 3), gross_pnl

# %%
def normalize_signal(feature, universe_boolean):
    """
    Normalize a feature signal for a given universe.
    Parameters:
        feature (pd.DataFrame): Feature data for all stocks.
        universe_boolean (pd.DataFrame): Boolean DataFrame indicating tradable stocks.
    Returns:
        pd.DataFrame: Normalized signal.
    """
    signal = feature.shift(1)  # Avoid lookahead bias
    signal = signal.where(universe_boolean, np.nan)
    signal = signal.rank(axis=1, method="min", ascending=True)
    signal = signal.sub(signal.mean(axis=1), axis=0)
    signal = signal.div(signal.abs().sum(axis=1), axis=0)
    return signal
    
def generate_portfolio_vectorized(features, universe, weights):
    """
    Generate portfolio weights using a vectorized approach.
    Parameters:
        features (pd.DataFrame): DataFrame containing all features for stocks.
        universe (pd.DataFrame): Binary DataFrame indicating tradable stocks.
        weights (array-like): Weights for each feature.
    Returns:
        pd.DataFrame: Portfolio weights for each stock on each trading day.
    """
    universe_boolean = universe.astype(bool)
    # features =  features.loc[:'2019']
    # Combine signals into a portfolio
    portfolio_weights = pd.DataFrame(0, index=features.index, columns=features.columns.get_level_values(1).unique())
    
    for i, feature_name in enumerate(features.columns.levels[0]):
        feature_data = features[feature_name]
        normalized_signal = normalize_signal(feature_data, universe_boolean)
        portfolio_weights += normalized_signal * weights[i]
    
    # Enforce dollar neutrality and normalize weights to sum to 1 per day
    portfolio_weights = portfolio_weights.sub(portfolio_weights.mean(axis=1), axis=0)
    portfolio_weights = portfolio_weights.div(portfolio_weights.abs().sum(axis=1), axis=0)
    
    return portfolio_weights.fillna(0)

# %%
from bayes_opt import BayesianOptimization
import numpy as np
import matplotlib.pyplot as plt
from joblib import Parallel, delayed

# %%
def optimize_signal_weights_bayesian(features_train, features_validation, universe_train, universe_validation, returns_train, returns_validation):
    selected_features = [
        'on_balance_volume', 'trend_1_3', 'macd', 'ichimoku',
        'ultimate_oscillator', 'chaikin_money_flow', 'volume',
        'know_sure_thing', 'chande_momentum_oscillator',
        'average_true_range', 'volatility_20', 'trend_5_20'
    ]

    def sharpe_ratio_objective(**weights):
        # Get all feature names from train_features
        all_features = sorted(features_train.columns.levels[0])
        
        # Assign 0 weight to features not in selected_features
        weight_array = np.array([weights.get(feature, 0) if feature in selected_features else 0 for feature in all_features])
        
        # Debug: Print the weight array
        # print(f"Weight Array: {weight_array}")
        
        # Generate portfolio weights for training set
        portfolio_weights_train = generate_portfolio_vectorized(features_train, universe_train, weight_array)
        
        # Backtest on training data
        sr_train, _ = backtest_portfolio_new(portfolio_weights_train, returns_train, universe_train, False, False)
        
        # Validate on validation set
        portfolio_weights_validation = generate_portfolio_vectorized(features_validation, universe_validation, weight_array)
        sr_validation, _ = backtest_portfolio_new(portfolio_weights_validation, validation_returns, validation_universe, False, False)
        
        print(f"Train Sharpe Ratio: {sr_train}, Validation Sharpe Ratio: {sr_validation}")
        
        # Combine training and validation Sharpe ratios
        alpha = 0.55  # Weight for training Sharpe ratio
        combined_sharpe_ratio = alpha * sr_train + (1 - alpha) * sr_validation
        
        # Add penalties to prevent overfitting
        penalty_l2 = np.sum(np.square(weight_array)) * combined_sharpe_ratio * 0.0005
        penalty_l1 = np.sum(np.abs(weight_array)) * combined_sharpe_ratio * 0.001
        
        result = combined_sharpe_ratio * 10 - penalty_l2 - penalty_l1
        print(f"Debug: L2 penalty: {penalty_l2}")
        print(f"Debug: L1 penalty: {penalty_l1}")
        print(f"Debug: Objective function value (with penalty): {result}")
        print("-" * 50)
        return result

    # Create pbounds for selected features only
    pbounds = {feature: (-20, 20) for feature in selected_features}
    print(f"Parameter Bounds (pbounds): {pbounds}")
    
    optimizer = BayesianOptimization(
        f=sharpe_ratio_objective,
        pbounds=pbounds,
        random_state=42
    )
    
    optimizer.maximize(init_points=20, n_iter=250)
    
    optimal_weights = optimizer.max['params']
    
    return optimal_weights

# Run Bayesian Optimization using train/validation split
optimal_weights = optimize_signal_weights_bayesian(
    train_features,
    validation_features,
    train_universe,
    validation_universe,
    train_returns,
    validation_returns
)

# Evaluate on test set
portfolio_weights_test = generate_portfolio_vectorized(test_features, test_universe, np.array(list(optimal_weights.values())))
sr_test, _ = backtest_portfolio_new(portfolio_weights_test, test_returns, test_universe)

print("Optimal Weights:", optimal_weights)
print("Test Set Sharpe Ratio:", sr_test)
# Out:
# Parameter Bounds (pbounds): {'on_balance_volume': (-20, 20), 'trend_1_3': (-20, 20), 'macd': (-20, 20), 'ichimoku': (-20, 20), 'ultimate_oscillator': (-20, 20), 'chaikin_money_flow': (-20, 20), 'volume': (-20, 20), 'know_sure_thing': (-20, 20), 'chande_momentum_oscillator': (-20, 20), 'average_true_range': (-20, 20), 'volatility_20': (-20, 20), 'trend_5_20': (-20, 20)}
# |   iter    |  target   | averag... | chaiki... | chande... | ichimoku  | know_s... |   macd    | on_bal... | trend_1_3 | trend_... | ultima... | volati... |  volume   |
# -------------------------------------------------------------------------------------------------------------------------------------------------------------------------
# Train Sharpe Ratio: -0.327, Validation Sharpe Ratio: -0.569
# Debug: L2 penalty: -0.4716958297745771
# Debug: L1 penalty: -0.06384050052981591
# Debug: Objective function value (with penalty): -3.8234636696956072
# --------------------------------------------------
# | 1         | -3.823    | -5.018    | 18.03     | 9.28      | 3.946     | -13.76    | -13.76    | -17.68    | 14.65     | 4.045     | 8.323     | -19.18    | 18.8      |
# Train Sharpe Ratio: 0.919, Validation Sharpe Ratio: 0.194
# Debug: L2 penalty: 0.3250282675066861
# Debug: L1 penalty: 0.06084143968196465
# Debug: Objective function value (with penalty): 5.541630292811351
# --------------------------------------------------
# | 2         | 5.542     | 13.3      | -11.51    | -12.73    | -12.66    | -7.83     | 0.9903    | -2.722    | -8.351    | 4.474     | -14.42    | -8.314    | -5.346    |
# Train Sharpe Ratio: 0.66, Validation Sharpe Ratio: -0.446
# Debug: L2 penalty: 0.15718716273606784
# Debug: L1 penalty: 0.021323070362356256
# Debug: Objective function value (with penalty): 1.4444897669015764
# --------------------------------------------------
# | 3         | 1.444     | -1.757    | 11.41     | -12.01    | 0.5694    | 3.697     | -18.14    | 4.302     | -13.18    | -17.4     | 17.96     | 18.63     | 12.34     |
# Train Sharpe Ratio: 0.307, Validation Sharpe Ratio: 0.524
# Debug: L2 penalty: 0.28656946308779396
# Debug: L1 penalty: 0.043890129712903216
# Debug: Objective function value (with penalty): 3.7160404071993027
# --------------------------------------------------
# | 4         | 3.716     | -7.815    | -16.09    | 7.369     | -2.394    | -15.12    | -0.1929   | -18.62    | 16.37     | -9.649    | 6.501     | -7.532    | 0.8027    |
# Train Sharpe Ratio: -0.854, Validation Sharpe Ratio: -0.746
# Debug: L2 penalty: -0.9235741788531123
# Debug: L1 penalty: -0.12260252390405808
# Debug: Objective function value (with penalty): -7.007823297242828
# --------------------------------------------------
# | 5         | -7.008    | 1.868     | -12.61    | 18.78     | 11.01     | 17.58     | 15.79     | 3.916     | 16.87     | -16.46    | -12.16    | -18.19    | -6.987    |
# Train Sharpe Ratio: 0.202, Validation Sharpe Ratio: 0.673
# Debug: L2 penalty: 0.34648891329601683
# Debug: L1 penalty: 0.05333095965943144
# Debug: Objective function value (with penalty): 3.7396801270445517
# --------------------------------------------------
# | 6         | 3.74      | -4.453    | -9.146    | 13.15     | -5.73     | -8.763    | 1.708     | -14.36    | 12.09     | -17.02    | 19.48     | 10.89     | -12.05    |
# Train Sharpe Ratio: -0.16, Validation Sharpe Ratio: -0.213
# Debug: L2 penalty: -0.18061364284257472
# Debug: L1 penalty: -0.026184945880981414
# Debug: Objective function value (with penalty): -1.631701411276444
# --------------------------------------------------
# | 7         | -1.632    | -19.78    | 12.62     | 8.274     | 9.16      | 10.85     | -17.04    | -5.661    | -15.37    | 14.52     | 4.932     | -6.764    | -17.46    |
# Train Sharpe Ratio: -1.196, Validation Sharpe Ratio: -0.767
# Debug: L2 penalty: -0.5007068589029396
# Debug: L1 penalty: -0.09383119564000242
# Debug: Objective function value (with penalty): -9.43496194545706
# --------------------------------------------------
# | 8         | -9.435    | -7.561    | -6.993    | 9.184     | 5.502     | 15.49     | -1.111    | -15.22    | 8.53      | 10.43     | 2.451     | 10.84     | -0.2482   |
# Train Sharpe Ratio: 0.534, Validation Sharpe Ratio: 0.012
# Debug: L2 penalty: 0.22964879159150492
# Debug: L1 penalty: 0.033074713131316755
# Debug: Objective function value (with penalty): 2.728276495277179
# --------------------------------------------------
# | 9         | 2.728     | 0.9093    | -2.898    | -18.98    | -15.68    | -18.74    | 5.456     | -7.426    | 0.3428    | 16.3      | -10.03    | -3.585    | 10.22     |
# Train Sharpe Ratio: -0.859, Validation Sharpe Ratio: -0.759
# Debug: L2 penalty: -0.7768393437007268
# Debug: L1 penalty: -0.11509747778920079
# Debug: Objective function value (with penalty): -7.248063178510073
# --------------------------------------------------
# | 10        | -7.248    | -10.85    | -16.92    | -8.41     | -13.55    | 17.19     | 12.32     | 5.336     | 14.86     | 12.15     | -12.54    | 15.7      | 1.574     |
# Train Sharpe Ratio: 1.455, Validation Sharpe Ratio: 0.606
# Debug: L2 penalty: 0.9222556457660943
# Debug: L1 penalty: 0.13576915362251124
# Debug: Objective function value (with penalty): 9.671475200611395
# --------------------------------------------------
# | 11        | 9.671     | 12.3      | 15.84     | -7.28     | -15.6     | -10.88    | -2.916    | 12.72     | 14.43     | -19.72    | 0.4299    | -3.304    | -11.12    |
# Train Sharpe Ratio: -1.754, Validation Sharpe Ratio: -0.324
# Debug: L2 penalty: -0.8849964792980348
# Debug: L1 penalty: -0.129027950132427
# Debug: Objective function value (with penalty): -10.090975570569539
# --------------------------------------------------
# | 12        | -10.09    | -15.21    | -6.495    | 17.72     | -7.072    | 0.7516    | 8.121     | -5.455    | 18.87     | 18.5      | -9.929    | -0.1101   | -7.965    |
# Train Sharpe Ratio: 0.301, Validation Sharpe Ratio: 0.559
# Debug: L2 penalty: 0.39576427266775105
# Debug: L1 penalty: 0.05402850202425823
# Debug: Objective function value (with penalty): 3.7212072253079906
# --------------------------------------------------
# | 13        | 3.721     | -8.606    | -18.52    | 4.383     | 0.1072    | -17.94    | -8.854    | 16.33     | -10.42    | -14.2     | -0.4219   | 19.43     | -10.32    |
# Train Sharpe Ratio: 0.834, Validation Sharpe Ratio: 0.223
# Debug: L2 penalty: 0.3058088653979743
# Debug: L1 penalty: 0.05804896145110233
# Debug: Objective function value (with penalty): 5.226642173150924
# --------------------------------------------------
# | 14        | 5.227     | 6.885     | 10.46     | -10.49    | 9.129     | -5.289    | 5.292     | 5.341     | 1.431     | -16.39    | 13.41     | -7.169    | -12.54    |
# Train Sharpe Ratio: 0.279, Validation Sharpe Ratio: 0.531
# Debug: L2 penalty: 0.3320767695175203
# Debug: L1 penalty: 0.04820099418484632
# Debug: Objective function value (with penalty): 3.5437222362976337
# --------------------------------------------------
# | 15        | 3.544     | -18.37    | 3.636     | 7.103     | -19.34    | 0.4837    | -10.94    | 5.807     | -13.03    | 7.638     | -4.531    | 17.47     | -14.5     |
# Train Sharpe Ratio: -1.3, Validation Sharpe Ratio: -0.6
# Debug: L2 penalty: -0.847999578823211
# Debug: L1 penalty: -0.1266264703994004
# Debug: Objective function value (with penalty): -8.875373950777389
# --------------------------------------------------
# | 16        | -8.875    | -6.357    | -15.46    | 16.99     | 15.09     | -9.682    | 6.399     | 12.69     | 2.208     | 1.186     | -10.33    | -16.28    | 15.89     |
# Train Sharpe Ratio: -0.5, Validation Sharpe Ratio: -1.163
# Debug: L2 penalty: -0.7217541632889728
# Debug: L1 penalty: -0.10953761856192135
# Debug: Objective function value (with penalty): -7.152208218149106
# --------------------------------------------------
# | 17        | -7.152    | 16.02     | 5.324     | -6.439    | -6.032    | 9.038     | 15.88     | 15.48     | 11.2      | 5.681     | -16.63    | -13.53    | 15.94     |
# Train Sharpe Ratio: 0.154, Validation Sharpe Ratio: 0.296
# Debug: L2 penalty: 0.18306460652356946
# Debug: L1 penalty: 0.027338986227487476
# Debug: Objective function value (with penalty): 1.9685964072489428
# --------------------------------------------------
# | 18        | 1.969     | 4.257     | -19.63    | -15.94    | 6.54      | -19.8     | -13.57    | 1.949     | 7.676     | 6.078     | -11.03    | 8.487     | -10.51    |
# Train Sharpe Ratio: -2.007, Validation Sharpe Ratio: -1.135
# Debug: L2 penalty: -1.0379110930826931
# Debug: L1 penalty: -0.17794182131749178
# Debug: Objective function value (with penalty): -14.930147085599817
# --------------------------------------------------
# | 19        | -14.93    | -6.984    | 9.86      | 5.985     | 13.97     | 6.305     | 2.732     | -16.25    | -5.291    | -9.392    | -10.24    | 18.92     | -4.276    |
# Train Sharpe Ratio: -1.249, Validation Sharpe Ratio: -0.677
# Debug: L2 penalty: -0.6393092950458326
# Debug: L1 penalty: -0.10294799861506937
# Debug: Objective function value (with penalty): -9.173742706339098
# --------------------------------------------------
# | 20        | -9.174    | 15.68     | 5.246     | 11.79     | 0.1055    | 3.076     | -0.2993   | -12.19    | 8.898     | -8.769    | -19.03    | 5.819     | -12.92    |
# Train Sharpe Ratio: 1.987, Validation Sharpe Ratio: 0.991
# Debug: L2 penalty: 2.423250127106083
# Debug: L1 penalty: 0.2733059647126711
# Debug: Objective function value (with penalty): 12.691443908181247
# --------------------------------------------------
# | 21        | 12.69     | 4.444     | -9.418    | -20.0     | -20.0     | -20.0     | -17.0     | 6.188     | -3.124    | -20.0     | 20.0      | -17.44    | -20.0     |
# Train Sharpe Ratio: 1.538, Validation Sharpe Ratio: 0.833
# Debug: L2 penalty: 2.4875559882214833
# Debug: L1 penalty: 0.2580654480508472
# Debug: Objective function value (with penalty): 9.46187856372767
# --------------------------------------------------
# | 22        | 9.462     | -20.0     | 20.0      | -20.0     | -20.0     | -20.0     | -20.0     | 20.0      | 7.989     | -20.0     | 20.0      | -3.41     | -20.0     |
# Train Sharpe Ratio: 1.5, Validation Sharpe Ratio: 0.716
# Debug: L2 penalty: 0.7970686479869167
# Debug: L1 penalty: 0.13551411762884757
# Debug: Objective function value (with penalty): 10.539417234384235
# --------------------------------------------------
# | 23        | 10.54     | 10.61     | 9.594     | -12.77    | -16.34    | -8.514    | 0.5116    | 9.912     | 14.61     | -12.94    | -11.53    | -2.962    | -7.836    |
# Train Sharpe Ratio: 0.531, Validation Sharpe Ratio: 0.131
# Debug: L2 penalty: 0.19767343479027244
# Debug: L1 penalty: 0.036688769881317945
# Debug: Objective function value (with penalty): 3.2756377953284095
# --------------------------------------------------
# | 24        | 3.276     | 12.17     | -15.92    | -9.622    | -11.8     | -6.84     | 4.91      | -2.607    | -7.586    | 3.511     | -15.53    | -5.312    | -8.722    |
# Train Sharpe Ratio: 1.492, Validation Sharpe Ratio: 0.818
# Debug: L2 penalty: 2.3216025752823093
# Debug: L1 penalty: 0.24754194989157177
# Debug: Objective function value (with penalty): 9.31785547482612
# --------------------------------------------------
# | 25        | 9.318     | 5.583     | 8.319     | -20.0     | -20.0     | -20.0     | -20.0     | 20.0      | -14.34    | -20.0     | -20.0     | -20.0     | -20.0     |
# Train Sharpe Ratio: 1.601, Validation Sharpe Ratio: 0.766
# Debug: L2 penalty: 1.2054446209274388
# Debug: L1 penalty: 0.1783655694716541
# Debug: Objective function value (with penalty): 10.868689809600907
# --------------------------------------------------
# | 26        | 10.87     | 15.02     | 5.486     | -13.12    | -13.31    | -6.143    | -8.999    | 15.22     | 18.48     | -10.66    | -17.8     | -8.146    | -13.19    |
# Train Sharpe Ratio: 0.046, Validation Sharpe Ratio: 0.192
# Debug: L2 penalty: 0.05865574176966178
# Debug: L1 penalty: 0.011050078997321237
# Debug: Objective function value (with penalty): 1.047294179233017
# --------------------------------------------------
# | 27        | 1.047     | -9.083    | -14.74    | 8.447     | 1.097     | -6.245    | -6.475    | -17.03    | 12.82     | -3.145    | 7.225     | -7.021    | 5.604     |
# Train Sharpe Ratio: 1.715, Validation Sharpe Ratio: 1.032
# Debug: L2 penalty: 3.1003233788009372
# Debug: L1 penalty: 0.31281906590145653
# Debug: Objective function value (with penalty): 10.663357555297608
# --------------------------------------------------
# | 28        | 10.66     | -20.0     | -20.0     | -20.0     | -20.0     | -20.0     | -20.0     | -20.0     | -20.0     | 2.228     | 20.0      | -20.0     | -20.0     |
# Train Sharpe Ratio: 1.624, Validation Sharpe Ratio: 0.78
# Debug: L2 penalty: 2.493178157373319
# Debug: L1 penalty: 0.25371254950045724
# Debug: Objective function value (with penalty): 9.695109293126224
# --------------------------------------------------
# | 29        | 9.695     | 20.0      | 2.037     | -20.0     | -20.0     | -20.0     | -20.0     | 20.0      | -20.0     | 20.0      | 20.0      | -1.88     | -20.0     |
# Train Sharpe Ratio: 1.267, Validation Sharpe Ratio: 0.551
# Debug: L2 penalty: 2.264976517143289
# Debug: L1 penalty: 0.22662439499781376
# Debug: Objective function value (with penalty): 6.956399087858897
# --------------------------------------------------
# | 30        | 6.956     | 20.0      | -20.0     | -20.0     | -20.0     | -20.0     | 19.86     | 20.0      | 20.0      | -20.0     | 20.0      | -20.0     | -20.0     |
# Train Sharpe Ratio: 1.715, Validation Sharpe Ratio: 0.958
# Debug: L2 penalty: 1.5287628928869597
# Debug: L1 penalty: 0.21502159269943885
# Debug: Objective function value (with penalty): 11.999715514413603
# --------------------------------------------------
# | 31        | 12.0      | 13.2      | 6.955     | -12.9     | -11.69    | -16.83    | -17.02    | 18.95     | 16.32     | -12.95    | -9.675    | -5.506    | -14.46    |
# Train Sharpe Ratio: 1.796, Validation Sharpe Ratio: 0.89
# Debug: L2 penalty: 2.814083412590759
# Debug: L1 penalty: 0.2915218406296565
# Debug: Objective function value (with penalty): 10.777394746779585
# --------------------------------------------------
# | 32        | 10.78     | 20.0      | 6.433     | -20.0     | -20.0     | -20.0     | 3.552     | -20.0     | -20.0     | -20.0     | 20.0      | -20.0     | -20.0     |
# Train Sharpe Ratio: 1.672, Validation Sharpe Ratio: 0.807
# Debug: L2 penalty: 1.4660714660711793
# Debug: L1 penalty: 0.1914753579602887
# Debug: Objective function value (with penalty): 11.169953175968532
# --------------------------------------------------
# | 33        | 11.17     | 18.47     | 5.804     | -17.38    | -16.42    | -15.46    | -5.679    | 19.64     | 19.09     | -8.194    | -1.617    | -7.872    | -13.64    |
# Train Sharpe Ratio: 0.014, Validation Sharpe Ratio: -0.456
# Debug: L2 penalty: -0.11535217942809863
# Debug: L1 penalty: -0.019058099387269246
# Debug: Objective function value (with penalty): -1.8405897211846318
# --------------------------------------------------
# | 34        | -1.841    | 17.92     | -10.48    | -14.45    | -4.079    | -9.853    | 2.392     | -2.132    | -6.415    | -0.9969   | -17.62    | -4.921    | 5.232     |
# Train Sharpe Ratio: 2.021, Validation Sharpe Ratio: 0.707
# Debug: L2 penalty: 2.956115939480188
# Debug: L1 penalty: 0.30569182195188077
# Debug: Objective function value (with penalty): 11.035192238567932
# --------------------------------------------------
# | 35        | 11.04     | 2.443     | -20.0     | -20.0     | -20.0     | 11.37     | -20.0     | -20.0     | 20.0      | -20.0     | 20.0      | -20.0     | -20.0     |
# Train Sharpe Ratio: 1.867, Validation Sharpe Ratio: 0.218
# Debug: L2 penalty: 2.302247983543242
# Debug: L1 penalty: 0.2395914623982673
# Debug: Objective function value (with penalty): 8.70766055405849
# --------------------------------------------------
# | 36        | 8.708     | 20.0      | -20.0     | -20.0     | -20.0     | 20.0      | -20.0     | -4.388    | -20.0     | 8.591     | 20.0      | -20.0     | -20.0     |
# Train Sharpe Ratio: 1.248, Validation Sharpe Ratio: 0.789
# Debug: L2 penalty: 2.49948
# Debug: L1 penalty: 0.249948
# Debug: Objective function value (with penalty): 7.665072
# --------------------------------------------------
# | 37        | 7.665     | -20.0     | -20.0     | 20.0      | -20.0     | -20.0     | -20.0     | 20.0      | -20.0     | -20.0     | 20.0      | -20.0     | -20.0     |
# Train Sharpe Ratio: 1.588, Validation Sharpe Ratio: 0.719
# Debug: L2 penalty: 0.5255451329337135
# Debug: L1 penalty: 0.10949430652859259
# Debug: Objective function value (with penalty): 11.334460560537694
# --------------------------------------------------
# | 38        | 11.33     | 10.3      | -11.92    | -11.73    | -9.494    | -13.17    | -10.01    | 0.2675    | -4.365    | 2.893     | -5.867    | -6.48     | -4.993    |
# Train Sharpe Ratio: 1.977, Validation Sharpe Ratio: 1.0
# Debug: L2 penalty: 2.2528024152189556
# Debug: L1 penalty: 0.2556556761851803
# Debug: Objective function value (with penalty): 12.865041908595865
# --------------------------------------------------
# | 39        | 12.87     | 12.35     | -5.677    | -20.0     | -20.0     | -20.0     | -20.0     | -15.22    | 10.5      | 1.959     | -0.5928   | -20.0     | -20.0     |
# Train Sharpe Ratio: 1.667, Validation Sharpe Ratio: 0.698
# Debug: L2 penalty: 1.8843962530987604
# Debug: L1 penalty: 0.2141632147895351
# Debug: Objective function value (with penalty): 10.210940532111705
# --------------------------------------------------
# | 40        | 10.21     | 15.97     | -20.0     | -20.0     | -20.0     | -20.0     | -20.0     | -16.96    | -6.443    | -6.88     | 20.0      | 3.442     | -4.291    |
# Train Sharpe Ratio: 1.027, Validation Sharpe Ratio: 0.702
# Debug: L2 penalty: 0.6873375599424241
# Debug: L1 penalty: 0.09466244317240562
# Debug: Objective function value (with penalty): 8.02549999688517
# --------------------------------------------------
# | 41        | 8.025     | -3.04     | -0.09212  | 19.51     | -0.2576   | -7.018    | -13.31    | -3.384    | 11.04     | -5.057    | 6.113     | -19.99    | -18.67    |
# Train Sharpe Ratio: 2.038, Validation Sharpe Ratio: 1.12
# Debug: L2 penalty: 2.8629167731015563
# Debug: L1 penalty: 0.3127115528188488
# Debug: Objective function value (with penalty): 13.073371674079594
# --------------------------------------------------
# | 42        | 13.07     | 20.0      | -20.0     | 14.78     | -20.0     | -20.0     | -20.0     | -5.189    | -6.755    | 5.724     | 20.0      | -20.0     | -20.0     |
# Train Sharpe Ratio: 1.695, Validation Sharpe Ratio: 0.917
# Debug: L2 penalty: 2.6409164364242335
# Debug: L1 penalty: 0.2865567535126858
# Debug: Objective function value (with penalty): 10.521526810063081
# --------------------------------------------------
# | 43        | 10.52     | -20.0     | -18.69    | -20.0     | -20.0     | -11.99    | -20.0     | 12.16     | 20.0      | -20.0     | -11.28    | -20.0     | -18.95    |
# Train Sharpe Ratio: -0.977, Validation Sharpe Ratio: -0.888
# Debug: L2 penalty: -0.743308762521467
# Debug: L1 penalty: -0.11217756075176406
# Debug: Objective function value (with penalty): -8.514013676726767
# --------------------------------------------------
# | 44        | -8.514    | 6.619     | -12.5     | -16.32    | 17.75     | 9.889     | 19.3      | 6.082     | -3.547    | -13.23    | 0.2213    | 9.2       | -5.073    |
# Train Sharpe Ratio: 2.427, Validation Sharpe Ratio: 1.061
# Debug: L2 penalty: 1.3661194201273532
# Debug: L1 penalty: 0.2070432350313082
# Debug: Objective function value (with penalty): 16.54983734484134
# --------------------------------------------------
# | 45        | 16.55     | 1.065     | -4.854    | -11.62    | -19.81    | -9.648    | -17.42    | 2.375     | -4.501    | 6.604     | 8.751     | -17.8     | -9.794    |
# Train Sharpe Ratio: 2.31, Validation Sharpe Ratio: 0.754
# Debug: L2 penalty: 2.6707109668344424
# Debug: L1 penalty: 0.3034973660933862
# Debug: Objective function value (with penalty): 13.123791667072174
# --------------------------------------------------
# | 46        | 13.12     | -5.946    | 8.632     | -20.0     | -20.0     | 20.0      | -20.0     | 20.0      | 15.21     | -8.608    | 10.13     | -20.0     | -20.0     |
# Train Sharpe Ratio: -1.876, Validation Sharpe Ratio: -1.394
# Debug: L2 penalty: -0.5224093297334813
# Debug: L1 penalty: -0.11970165717968652
# Debug: Objective function value (with penalty): -15.948889013086834
# --------------------------------------------------
# | 47        | -15.95    | 1.465     | 12.71     | 8.414     | 4.437     | -2.919    | -8.749    | 5.952     | -4.749    | -3.174    | 5.016     | 14.04     | 0.5278    |
# Train Sharpe Ratio: -0.167, Validation Sharpe Ratio: -0.036
# Debug: L2 penalty: -0.10717995196900734
# Debug: L1 penalty: -0.015326233888951522
# Debug: Objective function value (with penalty): -0.9579938141420412
# --------------------------------------------------
# | 48        | -0.958    | 11.69     | -19.79    | 4.449     | 13.63     | -12.51    | -0.8817   | -11.16    | 19.05     | 9.231     | 12.95     | -12.49    | -14.01    |
# Train Sharpe Ratio: 1.636, Validation Sharpe Ratio: 0.742
# Debug: L2 penalty: 0.6570525567575664
# Debug: L1 penalty: 0.12064254664147919
# Debug: Objective function value (with penalty): 11.559304896600954
# --------------------------------------------------
# | 49        | 11.56     | -2.507    | -11.83    | -2.557    | -9.135    | -3.836    | -12.75    | -0.5048   | 12.1      | 10.15     | 15.48     | 5.399     | -11.54    |
# Train Sharpe Ratio: 2.344, Validation Sharpe Ratio: 0.793
# Debug: L2 penalty: 3.6270183881856974
# Debug: L1 penalty: 0.3664660414930117
# Debug: Objective function value (with penalty): 12.467015570321294
# --------------------------------------------------
# | 50        | 12.47     | -20.0     | 20.0      | -20.0     | -20.0     | 20.0      | -20.0     | -20.0     | -2.634    | -20.0     | 20.0      | -20.0     | -20.0     |
# Train Sharpe Ratio: 1.703, Validation Sharpe Ratio: 0.844
# Debug: L2 penalty: 2.1949335972033945
# Debug: L1 penalty: 0.2382741428800736
# Debug: Objective function value (with penalty): 10.731292259916533
# --------------------------------------------------
# | 51        | 10.73     | -20.0     | 5.85      | -20.0     | 2.704     | -3.422    | -20.0     | -9.021    | 20.0      | -20.0     | 20.0      | -20.0     | -20.0     |
# Train Sharpe Ratio: -1.271, Validation Sharpe Ratio: -0.54
# Debug: L2 penalty: -0.7063198208782925
# Debug: L1 penalty: -0.10578052688789141
# Debug: Objective function value (with penalty): -8.608399652233818
# --------------------------------------------------
# | 52        | -8.608    | 4.351     | -19.99    | -2.336    | 14.09     | -8.148    | 4.105     | 3.052     | -11.78    | -16.09    | -18.3     | 4.163     | 5.883     |
# Train Sharpe Ratio: 1.326, Validation Sharpe Ratio: 0.65
# Debug: L2 penalty: 2.1008947922153904
# Debug: L1 penalty: 0.22189957572265137
# Debug: Objective function value (with penalty): 7.895205632061958
# --------------------------------------------------
# | 53        | 7.895     | -20.0     | 20.0      | -20.0     | -20.0     | -8.557    | 20.0      | -18.16    | 10.45     | -20.0     | 20.0      | -20.0     | -20.0     |
# Train Sharpe Ratio: 2.147, Validation Sharpe Ratio: 0.746
# Debug: L2 penalty: 2.659882393442968
# Debug: L1 penalty: 0.2885961834846244
# Debug: Objective function value (with penalty): 12.217021423072405
# --------------------------------------------------
# | 54        | 12.22     | 1.242     | 20.0      | -20.0     | -20.0     | 5.635     | -20.0     | -11.35    | 20.0      | -20.0     | -12.07    | -20.0     | -20.0     |
# Train Sharpe Ratio: 1.951, Validation Sharpe Ratio: 0.875
# Debug: L2 penalty: 2.4159831585964495
# Debug: L1 penalty: 0.27071710064220816
# Debug: Objective function value (with penalty): 11.981299740761344
# --------------------------------------------------
# | 55        | 11.98     | -20.0     | -20.0     | -20.0     | -20.0     | 9.592     | -20.0     | 6.547     | -2.894    | -9.224    | 20.0      | 16.31     | -20.0     |
# Train Sharpe Ratio: 1.469, Validation Sharpe Ratio: 1.215
# Debug: L2 penalty: 3.001475510678318
# Debug: L1 penalty: 0.3056013345790862
# Debug: Objective function value (with penalty): 10.239923154742597
# --------------------------------------------------
# | 56        | 10.24     | -20.0     | 5.586     | -20.0     | -20.0     | -20.0     | -20.0     | -20.0     | -20.0     | -20.0     | 20.0      | 20.0      | -20.0     |
# Train Sharpe Ratio: -0.76, Validation Sharpe Ratio: -1.076
# Debug: L2 penalty: -1.1873840270403826
# Debug: L1 penalty: -0.1547920105383179
# Debug: Objective function value (with penalty): -7.6798239624213
# --------------------------------------------------
# | 57        | -7.68     | 14.95     | -17.44    | -11.1     | 8.85      | 7.48      | 18.72     | -11.01    | -12.93    | 19.11     | 19.27     | -15.13    | 15.57     |
# Train Sharpe Ratio: 0.073, Validation Sharpe Ratio: -1.247
# Debug: L2 penalty: -0.5939679683249887
# Debug: L1 penalty: -0.07850302236913818
# Debug: Objective function value (with penalty): -4.5375290093058736
# --------------------------------------------------
# | 58        | -4.538    | 17.93     | 16.72     | -4.503    | 9.378     | 7.243     | -18.59    | 11.76     | -0.9566   | 15.57     | 18.51     | -17.3     | 12.22     |
# Train Sharpe Ratio: 1.47, Validation Sharpe Ratio: 0.789
# Debug: L2 penalty: 1.6316981766911773
# Debug: L1 penalty: 0.2013866178227333
# Debug: Objective function value (with penalty): 9.802415205486088
# --------------------------------------------------
# | 59        | 9.802     | -12.62    | -19.83    | -13.67    | -13.37    | -19.93    | -12.9     | 18.58     | 3.018     | 6.762     | 19.39     | -15.49    | -17.53    |
# Train Sharpe Ratio: 0.954, Validation Sharpe Ratio: -0.158
# Debug: L2 penalty: 0.6094821956781546
# Debug: L1 penalty: 0.0781034700500854
# Debug: Objective function value (with penalty): 3.8484143342717605
# --------------------------------------------------
# | 60        | 3.848     | -4.975    | -17.75    | -17.49    | -14.92    | 9.588     | -18.56    | 9.261     | -19.93    | 17.09     | -15.01    | -13.11    | 14.5      |
# Train Sharpe Ratio: 0.212, Validation Sharpe Ratio: -0.292
# Debug: L2 penalty: -0.017007531824652082
# Debug: L1 penalty: -0.002284163878754476
# Debug: Objective function value (with penalty): -0.12870830429659325
# --------------------------------------------------
# | 61        | -0.1287   | -7.373    | -5.136    | -10.82    | 18.2      | 18.19     | 3.612     | 13.41     | -16.05    | 16.87     | 12.85     | -11.92    | -19.89    |
# Train Sharpe Ratio: 1.566, Validation Sharpe Ratio: 0.73
# Debug: L2 penalty: 2.609565149133406
# Debug: L1 penalty: 0.2702225482019279
# Debug: Objective function value (with penalty): 9.018212302664665
# --------------------------------------------------
# | 62        | 9.018     | -20.0     | -20.0     | -20.0     | -20.0     | -20.0     | -20.0     | 10.48     | 20.0      | -20.0     | 20.0      | 16.63     | 20.0      |
# Train Sharpe Ratio: 0.118, Validation Sharpe Ratio: -0.542
# Debug: L2 penalty: -0.07735777545770095
# Debug: L1 penalty: -0.014651685642326679
# Debug: Objective function value (with penalty): -1.6979905388999725
# --------------------------------------------------
# | 63        | -1.698    | 4.844     | -4.717    | 3.905     | 3.56      | 6.107     | -5.888    | -0.4922   | -19.28    | 13.52     | 2.81      | -11.21    | -5.523    |
# Train Sharpe Ratio: 1.037, Validation Sharpe Ratio: 1.009
# Debug: L2 penalty: 1.7186278795400267
# Debug: L1 penalty: 0.18761487591607282
# Debug: Objective function value (with penalty): 8.337757244543901
# --------------------------------------------------
# | 64        | 8.338     | -13.85    | -20.0     | 0.2113    | -20.0     | -20.0     | -20.0     | -15.26    | -2.723    | 20.0      | 20.0      | 11.1      | -20.0     |
# Train Sharpe Ratio: -2.493, Validation Sharpe Ratio: -1.706
# Debug: L2 penalty: -1.6625237243164144
# Debug: L1 penalty: -0.23666990498208956
# Debug: Objective function value (with penalty): -19.489306370701495
# --------------------------------------------------
# | 65        | -19.49    | 5.982     | 17.75     | 12.83     | 17.23     | 0.7258    | -10.46    | 8.721     | 14.67     | -3.14     | -0.6107   | 18.19     | 0.3474    |
# Train Sharpe Ratio: 2.61, Validation Sharpe Ratio: 0.837
# Debug: L2 penalty: 3.2247831094780617
# Debug: L1 penalty: 0.3497850830860646
# Debug: Objective function value (with penalty): 14.546931807435872
# --------------------------------------------------
# | 66        | 14.55     | -20.0     | -2.795    | -20.0     | -20.0     | 5.822     | -20.0     | -9.076    | -20.0     | -20.0     | 20.0      | -20.0     | 15.33     |
# Train Sharpe Ratio: -0.569, Validation Sharpe Ratio: -0.019
# Debug: L2 penalty: -0.3388546421002163
# Debug: L1 penalty: -0.04768579103996563
# Debug: Objective function value (with penalty): -2.8284595668598183
# --------------------------------------------------
# | 67        | -2.828    | 13.83     | -8.56     | 15.92     | 3.591     | -10.63    | -18.7     | -12.44    | 4.453     | 16.15     | 14.6      | 10.71     | -18.74    |
# Train Sharpe Ratio: -0.748, Validation Sharpe Ratio: -0.375
# Debug: L2 penalty: -0.48568880552337873
# Debug: L1 penalty: -0.07204324752998101
# Debug: Objective function value (with penalty): -5.243767946946641
# --------------------------------------------------
# | 68        | -5.244    | 0.6475    | 2.551     | 16.51     | 7.219     | 9.042     | -10.24    | 19.22     | -18.8     | -10.71    | -5.749    | 13.92     | -9.561    |
# Train Sharpe Ratio: 1.642, Validation Sharpe Ratio: 0.638
# Debug: L2 penalty: 2.4032027158066485
# Debug: L1 penalty: 0.2507206181399851
# Debug: Objective function value (with penalty): 9.248076666053366
# --------------------------------------------------
# | 69        | 9.248     | -20.0     | 10.19     | -20.0     | -20.0     | 20.0      | -2.325    | 18.14     | -20.0     | -20.0     | 20.0      | -20.0     | -20.0     |
# Train Sharpe Ratio: 1.887, Validation Sharpe Ratio: -0.035
# Debug: L2 penalty: 2.157438659246002
# Debug: L1 penalty: 0.22593661922242225
# Debug: Objective function value (with penalty): 7.837624721531577
# --------------------------------------------------
# | 70        | 7.838     | 10.52     | 20.0      | -20.0     | -20.0     | 20.0      | -20.0     | -20.0     | -20.0     | -20.0     | 20.0      | -20.0     | 10.53     |
# Train Sharpe Ratio: 1.11, Validation Sharpe Ratio: 0.131
# Debug: L2 penalty: 1.5629532882727504
# Debug: L1 penalty: 0.15826624836655592
# Debug: Objective function value (with penalty): 4.9732804633606955
# --------------------------------------------------
# | 71        | 4.973     | -20.0     | -20.0     | -20.0     | -20.0     | 20.0      | -20.0     | -20.0     | -20.0     | -20.0     | 20.0      | 16.41     | 20.0      |
# Train Sharpe Ratio: 1.758, Validation Sharpe Ratio: 0.724
# Debug: L2 penalty: 3.10248
# Debug: L1 penalty: 0.310248
# Debug: Objective function value (with penalty): 9.514272
# --------------------------------------------------
# | 72        | 9.514     | -20.0     | 20.0      | -20.0     | -20.0     | -20.0     | -20.0     | -20.0     | -20.0     | -20.0     | 20.0      | -20.0     | 20.0      |
# Train Sharpe Ratio: 0.169, Validation Sharpe Ratio: 0.341
# Debug: L2 penalty: 0.2109758792289047
# Debug: L1 penalty: 0.03221879521936274
# Debug: Objective function value (with penalty): 2.2208053255517326
# --------------------------------------------------
# | 73        | 2.221     | -14.82    | 2.071     | 6.618     | 4.544     | 7.551     | 14.4      | -19.42    | -9.201    | -12.97    | 11.92     | -10.75    | -16.5     |
# Train Sharpe Ratio: 0.084, Validation Sharpe Ratio: -0.488
# Debug: L2 penalty: -0.21737161787061068
# Debug: L1 penalty: -0.02904188379628153
# Debug: Objective function value (with penalty): -1.4875864983331073
# --------------------------------------------------
# | 74        | -1.488    | -10.36    | -16.18    | 15.73     | 12.5      | 9.406     | 5.728     | 12.54     | 15.7      | -18.29    | 15.21     | -18.69    | 17.16     |
# Train Sharpe Ratio: -0.991, Validation Sharpe Ratio: -0.67
# Debug: L2 penalty: -0.3336468499112372
# Debug: L1 penalty: -0.061037296611033715
# Debug: Objective function value (with penalty): -8.07081585347773
# --------------------------------------------------
# | 75        | -8.071    | 15.72     | 0.5355    | 17.33     | -3.066    | -2.414    | -2.928    | -1.31     | 7.616     | 3.117     | 9.656     | -1.157    | -7.247    |
# Train Sharpe Ratio: -0.465, Validation Sharpe Ratio: -0.897
# Debug: L2 penalty: -0.6330174616344988
# Debug: L1 penalty: -0.09069167440287736
# Debug: Objective function value (with penalty): -5.870290863962624
# --------------------------------------------------
# | 76        | -5.87     | -16.32    | 12.59     | -13.83    | 6.76      | 1.243     | 12.58     | -18.15    | 3.893     | 8.65      | 19.29     | -9.54     | 14.68     |
# Train Sharpe Ratio: 0.834, Validation Sharpe Ratio: -0.26
# Debug: L2 penalty: 0.29838136582876656
# Debug: L1 penalty: 0.04179044492867612
# Debug: Objective function value (with penalty): 3.0768281892425575
# --------------------------------------------------
# | 77        | 3.077     | 8.082     | -15.94    | -16.14    | -0.4329   | 11.17     | -5.134    | 19.72     | -13.56    | 5.225     | 1.466     | -19.42    | 6.021     |
# Train Sharpe Ratio: -1.968, Validation Sharpe Ratio: -1.414
# Debug: L2 penalty: -2.197503116288915
# Debug: L1 penalty: -0.2807806738297163
# Debug: Objective function value (with penalty): -14.708716209881366
# --------------------------------------------------
# | 78        | -14.71    | -11.81    | -2.983    | 15.22     | 19.22     | 13.83     | 19.58     | 18.89     | 15.48     | 5.755     | -19.53    | -10.85    | 10.23     |
# Train Sharpe Ratio: 2.052, Validation Sharpe Ratio: 0.41
# Debug: L2 penalty: 0.5828660022993146
# Debug: L1 penalty: 0.12438590678145063
# Debug: Objective function value (with penalty): 12.423748090919235
# --------------------------------------------------
# | 79        | 12.42     | 14.03     | 11.37     | -7.791    | -9.4      | -4.006    | -4.41     | 6.557     | 10.59     | -11.41    | 6.901     | -1.892    | -6.37     |
# Train Sharpe Ratio: 2.788, Validation Sharpe Ratio: 0.698
# Debug: L2 penalty: 2.5506229443691684
# Debug: L1 penalty: 0.30426063078981785
# Debug: Objective function value (with penalty): 15.620116424841015
# --------------------------------------------------
# | 80        | 15.62     | 13.52     | 4.152     | -20.0     | -20.0     | 8.034     | -20.0     | 1.9       | 20.0      | -15.29    | 19.79     | 7.431     | -14.58    |
# Train Sharpe Ratio: -0.842, Validation Sharpe Ratio: -0.601
# Debug: L2 penalty: -0.613707169237201
# Debug: L1 penalty: -0.09203554647789751
# Debug: Objective function value (with penalty): -6.629757284284901
# --------------------------------------------------
# | 81        | -6.63     | -17.12    | 2.244     | 12.4      | -9.928    | 13.8      | 15.39     | 6.432     | 8.007     | 2.033     | 19.47     | 13.4      | -5.252    |
# Train Sharpe Ratio: -1.109, Validation Sharpe Ratio: -0.728
# Debug: L2 penalty: -0.59660636863912
# Debug: L1 penalty: -0.09434187461739836
# Debug: Objective function value (with penalty): -8.68455175674348
# --------------------------------------------------
# | 82        | -8.685    | 3.539     | -5.516    | -3.129    | -6.475    | 1.917     | 14.05     | -19.75    | -3.251    | 17.59     | 11.42     | 11.39     | 2.602     |
# Train Sharpe Ratio: 1.828, Validation Sharpe Ratio: 0.898
# Debug: L2 penalty: 1.0762176567747033
# Debug: L1 penalty: 0.16222063748668725
# Debug: Objective function value (with penalty): 12.856561705738608
# --------------------------------------------------
# | 83        | 12.86     | 0.2883    | -12.07    | -13.6     | -18.43    | -15.25    | -10.48    | 2.398     | -10.71    | 7.012     | 1.413     | -17.55    | -5.891    |
# Train Sharpe Ratio: 0.98, Validation Sharpe Ratio: 0.727
# Debug: L2 penalty: 0.49703170657091544
# Debug: L1 penalty: 0.0833182435151761
# Debug: Objective function value (with penalty): 8.081150049913909
# --------------------------------------------------
# | 84        | 8.081     | -3.661    | -12.41    | -1.874    | -5.434    | -7.368    | -0.933    | 4.031     | 14.47     | 9.479     | 13.66     | 3.425     | -19.45    |
# Train Sharpe Ratio: 1.043, Validation Sharpe Ratio: -0.16
# Debug: L2 penalty: 0.5166394560291837
# Debug: L1 penalty: 0.07306900945364915
# Debug: Objective function value (with penalty): 4.426791534517168
# --------------------------------------------------
# | 85        | 4.427     | -18.09    | 18.99     | -15.29    | -13.71    | -4.099    | -6.506    | 12.68     | 6.79      | 18.05     | 13.14     | -6.157    | 12.16     |
# Train Sharpe Ratio: 2.595, Validation Sharpe Ratio: 1.2
# Debug: L2 penalty: 1.6507202701034593
# Debug: L1 penalty: 0.21080718215375
# Debug: Objective function value (with penalty): 17.81097254774279
# --------------------------------------------------
# | 86        | 17.81     | 0.3529    | -6.425    | -6.939    | -20.0     | 3.774     | -20.0     | -1.619    | -0.556    | -17.76    | 2.794     | -6.934    | -20.0     |
# Train Sharpe Ratio: -0.787, Validation Sharpe Ratio: -0.892
# Debug: L2 penalty: -0.7436649384319459
# Debug: L1 penalty: -0.1074136700897744
# Debug: Objective function value (with penalty): -7.491421391478281
# --------------------------------------------------
# | 87        | -7.491    | 17.27     | 10.36     | 18.96     | -12.7     | -6.076    | -0.6411   | -17.19    | 8.632     | 1.462     | 13.35     | -7.575    | 14.54     |
# Train Sharpe Ratio: -0.325, Validation Sharpe Ratio: -0.637
# Debug: L2 penalty: -0.5379980219861944
# Debug: L1 penalty: -0.07008195456552543
# Debug: Objective function value (with penalty): -4.04592002344828
# --------------------------------------------------
# | 88        | -4.046    | 10.79     | 15.1      | -17.7     | 8.711     | -5.412    | 18.55     | -19.03    | 18.5      | -19.54    | 9.359     | -4.062    | 3.829     |
# Train Sharpe Ratio: 1.953, Validation Sharpe Ratio: 1.048
# Debug: L2 penalty: 3.69529085349524
# Debug: L1 penalty: 0.37024582501490866
# Debug: Objective function value (with penalty): 11.391963321489854
# --------------------------------------------------
# | 89        | 11.39     | -20.0     | -20.0     | 20.0      | -20.0     | 19.53     | -20.0     | -20.0     | -20.0     | -20.0     | 20.0      | -20.0     | -20.0     |
# Train Sharpe Ratio: 1.153, Validation Sharpe Ratio: 0.591
# Debug: L2 penalty: 0.5772150612576156
# Debug: L1 penalty: 0.09117207007351802
# Debug: Objective function value (with penalty): 8.332612868668868
# --------------------------------------------------
# | 90        | 8.333     | -3.901    | -4.316    | -2.778    | -16.49    | 0.7407    | -10.75    | 10.09     | -8.223    | -15.65    | -19.75    | -1.883    | 6.727     |
# Train Sharpe Ratio: -1.126, Validation Sharpe Ratio: -0.78
# Debug: L2 penalty: -0.6059399168372452
# Debug: L1 penalty: -0.09651208525377251
# Debug: Objective function value (with penalty): -9.000547997908981
# --------------------------------------------------
# | 91        | -9.001    | 10.96     | -2.101    | -16.14    | 7.976     | 7.914     | 11.35     | -1.269    | -5.889    | 1.266     | 0.8352    | 16.64     | -17.13    |
# Train Sharpe Ratio: 0.607, Validation Sharpe Ratio: 0.208
# Debug: L2 penalty: 0.5187480866774833
# Debug: L1 penalty: 0.06902949025360625
# Debug: Objective function value (with penalty): 3.68672242306891
# --------------------------------------------------
# | 92        | 3.687     | -13.34    | -16.56    | -16.75    | -4.224    | 10.62     | 19.45     | -8.755    | -9.969    | -9.615    | -18.2     | -15.06    | -18.94    |
# Train Sharpe Ratio: -0.813, Validation Sharpe Ratio: -1.515
# Debug: L2 penalty: -0.7783017221585913
# Debug: L1 penalty: -0.12816052640102904
# Debug: Objective function value (with penalty): -10.382537751440378
# --------------------------------------------------
# | 93        | -10.38    | 2.276     | 10.7      | 10.13     | 4.242     | 8.22      | 5.378     | 9.582     | -5.479    | -15.18    | 16.15     | -6.541    | 19.66     |
# Train Sharpe Ratio: 2.866, Validation Sharpe Ratio: 0.634
# Debug: L2 penalty: 1.725632932816548
# Debug: L1 penalty: 0.23762218318447045
# Debug: Objective function value (with penalty): 16.65274488399898
# --------------------------------------------------
# | 94        | 16.65     | 16.34     | 1.29      | -14.37    | -15.58    | 3.337     | -18.59    | 0.7533    | 19.45     | -11.22    | 7.376     | -13.74    | -5.597    |
# Train Sharpe Ratio: 0.601, Validation Sharpe Ratio: 0.103
# Debug: L2 penalty: 0.27695511907765064
# Debug: L1 penalty: 0.043487895266694714
# Debug: Objective function value (with penalty): 3.448556985655655
# --------------------------------------------------
# | 95        | 3.449     | -14.38    | 4.67      | -12.84    | -0.505    | 15.15     | -16.32    | -3.835    | 18.32     | 7.287     | -5.479    | 6.194     | -10.4     |
# Train Sharpe Ratio: 1.096, Validation Sharpe Ratio: 1.0
# Debug: L2 penalty: 2.411515860959161
# Debug: L1 penalty: 0.24635787923956773
# Debug: Objective function value (with penalty): 7.870126259801269
# --------------------------------------------------
# | 96        | 7.87      | -20.0     | -20.0     | 15.76     | -20.0     | -18.24    | -20.0     | -20.0     | -20.0     | -20.0     | -20.0     | -20.0     | -20.0     |
# Train Sharpe Ratio: 2.234, Validation Sharpe Ratio: 0.913
# Debug: L2 penalty: 1.2097796592338788
# Debug: L1 penalty: 0.19631180649047472
# Debug: Objective function value (with penalty): 14.989408534275649
# --------------------------------------------------
# | 97        | 14.99     | -12.89    | -5.211    | -14.8     | -18.3     | 0.6208    | -10.79    | 6.373     | 7.35      | -11.43    | 12.03     | -14.61    | -5.34     |
# Train Sharpe Ratio: -1.179, Validation Sharpe Ratio: -1.347
# Debug: L2 penalty: -1.1614838462068584
# Debug: L1 penalty: -0.15942723376476087
# Debug: Objective function value (with penalty): -11.22508892002838
# --------------------------------------------------
# | 98        | -11.23    | 11.09     | 17.54     | 1.463     | -3.259    | 17.65     | 19.53     | -17.6     | -10.61    | -3.089    | -10.12    | -13.34    | -1.789    |
# Train Sharpe Ratio: -2.707, Validation Sharpe Ratio: -1.929
# Debug: L2 penalty: -2.1509952979488185
# Debug: L1 penalty: -0.30245798776491956
# Debug: Objective function value (with penalty): -21.11554671428626
# --------------------------------------------------
# | 99        | -21.12    | -13.78    | 15.64     | 18.68     | 13.54     | 16.22     | 12.92     | -1.524    | -0.9077   | 14.6      | 13.37     | -1.599    | -5.544    |
# Train Sharpe Ratio: 2.026, Validation Sharpe Ratio: 0.876
# Debug: L2 penalty: 3.0767962690822794
# Debug: L1 penalty: 0.31921532729034524
# Debug: Objective function value (with penalty): 11.688988403627373
# --------------------------------------------------
# | 100       | 11.69     | -20.0     | 3.369     | -20.0     | -20.0     | 20.0      | -20.0     | -8.242    | -20.0     | -20.0     | -20.0     | -20.0     | -20.0     |
# Train Sharpe Ratio: 1.221, Validation Sharpe Ratio: 0.641
# Debug: L2 penalty: 2.272808765173866
# Debug: L1 penalty: 0.2287713638950943
# Debug: Objective function value (with penalty): 7.098419870931041
# --------------------------------------------------
# | 101       | 7.098     | -20.0     | -20.0     | 18.3      | -20.0     | 20.0      | -20.0     | 20.0      | -20.0     | -20.0     | -20.0     | -20.0     | -20.0     |
# Train Sharpe Ratio: 2.608, Validation Sharpe Ratio: 1.152
# Debug: L2 penalty: 1.4100138503807507
# Debug: L1 penalty: 0.20792925413538732
# Debug: Objective function value (with penalty): 17.910056895483862
# --------------------------------------------------
# | 102       | 17.91     | 8.689     | 2.067     | -14.0     | -19.45    | -19.36    | -11.66    | 0.9861    | 9.511     | -1.452    | 12.84     | -3.312    | -3.153    |
# Train Sharpe Ratio: 1.249, Validation Sharpe Ratio: 0.492
# Debug: L2 penalty: 2.1615487931465385
# Debug: L1 penalty: 0.2170546337953076
# Debug: Objective function value (with penalty): 6.7048965730581545
# --------------------------------------------------
# | 103       | 6.705     | -20.0     | -20.0     | -20.0     | 18.95     | 20.0      | -20.0     | -20.0     | -20.0     | -20.0     | 20.0      | -20.0     | -20.0     |
# Train Sharpe Ratio: 2.279, Validation Sharpe Ratio: 0.834
# Debug: L2 penalty: 1.0341348480711394
# Debug: L1 penalty: 0.14331776091895063
# Debug: Objective function value (with penalty): 15.110047391009907
# --------------------------------------------------
# | 104       | 15.11     | -0.05901  | -2.18     | -0.6601   | -19.83    | 0.8751    | -12.08    | 13.54     | 12.14     | -3.4      | 1.797     | -19.36    | 2.068     |
# Train Sharpe Ratio: -1.58, Validation Sharpe Ratio: -1.264
# Debug: L2 penalty: -1.2468008493103402
# Debug: L1 penalty: -0.18523906640295099
# Debug: Objective function value (with penalty): -12.94596008428671
# --------------------------------------------------
# | 105       | -12.95    | -5.482    | 17.0      | 15.35     | 11.04     | 4.564     | 16.47     | -17.92    | -7.011    | -15.99    | 6.954     | -9.403    | 1.645     |
# Train Sharpe Ratio: 2.201, Validation Sharpe Ratio: 0.947
# Debug: L2 penalty: 2.3405253866975224
# Debug: L1 penalty: 0.2661078699915957
# Debug: Objective function value (with penalty): 13.760366743310888
# --------------------------------------------------
# | 106       | 13.76     | 7.497     | -20.0     | 3.247     | -20.0     | -0.8884   | -20.0     | 16.13     | 20.0      | -10.77    | 20.0      | -4.06     | -20.0     |
# Train Sharpe Ratio: -1.945, Validation Sharpe Ratio: -1.317
# Debug: L2 penalty: -1.2483609442192527
# Debug: L1 penalty: -0.1980190591913648
# Debug: Objective function value (with penalty): -15.177619996589385
# --------------------------------------------------
# | 107       | -15.18    | 2.381     | 13.42     | 14.3      | 8.266     | -4.889    | -5.805    | -6.468    | 4.036     | 17.04     | 9.617     | 17.81     | 15.08     |
# Train Sharpe Ratio: -0.574, Validation Sharpe Ratio: -0.502
# Debug: L2 penalty: -0.3059174572707265
# Debug: L1 penalty: -0.056584953628570626
# Debug: Objective function value (with penalty): -5.053497589100703
# --------------------------------------------------
# | 108       | -5.053    | 3.672     | 6.964     | 8.943     | -2.825    | -6.989    | -10.22    | -11.32    | -9.697    | 9.813     | -17.56    | -13.88    | 2.583     |
# Train Sharpe Ratio: 1.369, Validation Sharpe Ratio: 1.009
# Debug: L2 penalty: 2.8968
# Debug: L1 penalty: 0.28967999999999994
# Debug: Objective function value (with penalty): 8.883519999999997
# --------------------------------------------------
# | 109       | 8.884     | -20.0     | -20.0     | 20.0      | -20.0     | -20.0     | -20.0     | -20.0     | 20.0      | -20.0     | 20.0      | -20.0     | -20.0     |
# Train Sharpe Ratio: 0.577, Validation Sharpe Ratio: -0.016
# Debug: L2 penalty: 0.33908880217762216
# Debug: L1 penalty: 0.04692415671480882
# Debug: Objective function value (with penalty): 2.7154870411075693
# --------------------------------------------------
# | 110       | 2.715     | 15.49     | -9.24     | 8.69      | -14.36    | 14.26     | 14.78     | 17.59     | -18.0     | -7.82     | 16.87     | -13.35    | -0.8555   |
# Train Sharpe Ratio: 0.974, Validation Sharpe Ratio: 0.042
# Debug: L2 penalty: 0.4618006747388143
# Debug: L1 penalty: 0.07101470773201353
# Debug: Objective function value (with penalty): 5.013184617529173
# --------------------------------------------------
# | 111       | 5.013     | 8.485     | -17.02    | -8.094    | 8.205     | 8.142     | -6.199    | -2.882    | 18.73     | -5.632    | 17.28     | -14.68    | -12.71    |
# Train Sharpe Ratio: 2.679, Validation Sharpe Ratio: 0.851
# Debug: L2 penalty: 2.5393616019576504
# Debug: L1 penalty: 0.29594509793129925
# Debug: Objective function value (with penalty): 15.728693300111049
# --------------------------------------------------
# ...
# Debug: L2 penalty: -0.8932007058275685
# Debug: L1 penalty: -0.12234720706433944
# Debug: Objective function value (with penalty): -9.145952087108093
# --------------------------------------------------
# | 189       | -9.146    | 7.629     | 9.58      | -2.419    | -16.07    | -0.02076  | 19.82     | -19.93    | -2.213    | -12.43    | -9.166    | -3.953    | 17.16     |
# Train Sharpe Ratio: 0.822, Validation Sharpe Ratio: 0.718
# Debug: L2 penalty: 0.6892412079521888
# Debug: L1 penalty: 0.09708215155470455
# Debug: Objective function value (with penalty): 6.965676640493106
# --------------------------------------------------
# | 190       | 6.966     | -1.676    | -11.73    | -5.377    | -2.218    | 0.6311    | -15.26    | 16.78     | 15.74     | -11.23    | -9.186    | 19.13     | -16.28    |
# Train Sharpe Ratio: 0.944, Validation Sharpe Ratio: 0.621
# Debug: L2 penalty: 1.91676
# Debug: L1 penalty: 0.19167599999999999
# Debug: Objective function value (with penalty): 5.878063999999999
# --------------------------------------------------
# | 191       | 5.878     | -20.0     | -20.0     | 20.0      | -20.0     | 20.0      | -20.0     | 20.0      | -20.0     | -20.0     | 20.0      | 20.0      | -20.0     |
# Train Sharpe Ratio: 1.039, Validation Sharpe Ratio: 0.456
# Debug: L2 penalty: 0.8246030431636472
# Debug: L1 penalty: 0.12002181574197729
# Debug: Objective function value (with penalty): 6.821875141094376
# --------------------------------------------------
# | 192       | 6.822     | -17.35    | 10.35     | -11.94    | -14.96    | -14.24    | 8.366     | 17.82     | -11.58    | -7.258    | 16.63     | -13.8     | 10.25     |
# Train Sharpe Ratio: 2.301, Validation Sharpe Ratio: 0.756
# Debug: L2 penalty: 1.3462332339519751
# Debug: L1 penalty: 0.2050558915416672
# Debug: Objective function value (with penalty): 14.506210874506358
# --------------------------------------------------
# | 193       | 14.51     | -14.09    | -8.983    | -19.18    | -14.38    | 7.044     | -15.06    | 8.465     | 2.066     | -15.46    | 11.65     | -9.636    | 1.682     |
# Train Sharpe Ratio: -1.211, Validation Sharpe Ratio: -0.329
# Debug: L2 penalty: -0.5453307786790139
# Debug: L1 penalty: -0.08946506522294262
# Debug: Objective function value (with penalty): -7.506204156098046
# --------------------------------------------------
# | 194       | -7.506    | -2.703    | -17.86    | 1.456     | -11.57    | -15.21    | 11.11     | -16.92    | -4.397    | 7.596     | -4.866    | 6.637     | 9.564     |
# Train Sharpe Ratio: 2.174, Validation Sharpe Ratio: 0.917
# Debug: L2 penalty: 2.770649674270042
# Debug: L1 penalty: 0.3054611084783279
# Debug: Objective function value (with penalty): 13.00738921725163
# --------------------------------------------------
# | 195       | 13.01     | -11.18    | -6.002    | -20.0     | -20.0     | -20.0     | -20.0     | -5.114    | 20.0      | -20.0     | -7.624    | -20.0     | 20.0      |
# Train Sharpe Ratio: 2.4, Validation Sharpe Ratio: 1.03
# Debug: L2 penalty: 1.5309657790123978
# Debug: L1 penalty: 0.21932023417512128
# Debug: Objective function value (with penalty): 16.08471398681248
# --------------------------------------------------
# | 196       | 16.08     | 7.17      | 11.64     | -11.59    | -19.17    | -9.328    | -18.99    | -3.111    | -5.53     | 2.814     | 1.033     | -16.18    | -16.4     |
# Train Sharpe Ratio: 0.518, Validation Sharpe Ratio: -0.554
# Debug: L2 penalty: 0.034810174084668084
# Debug: L1 penalty: 0.004609653409852479
# Debug: Objective function value (with penalty): 0.31658017250547993
# --------------------------------------------------
# | 197       | 0.3166    | 19.42     | -18.67    | -7.899    | -6.305    | 5.536     | 0.0672    | 8.062     | 18.88     | 18.0      | 12.59     | -13.88    | -0.1608   |
# Train Sharpe Ratio: -0.045, Validation Sharpe Ratio: 0.099
# Debug: L2 penalty: 0.016844721177531836
# Debug: L1 penalty: 0.0025088522455150144
# Debug: Objective function value (with penalty): 0.17864642657695315
# --------------------------------------------------
# | 198       | 0.1786    | -12.95    | 13.17     | 15.5      | -18.41    | -7.889    | -3.45     | -11.92    | 18.68     | -2.135    | -12.59    | -6.172    | -3.843    |
# Train Sharpe Ratio: 0.318, Validation Sharpe Ratio: 0.039
# Debug: L2 penalty: 0.10292335876075247
# Debug: L1 penalty: 0.018161520265961927
# Debug: Objective function value (with penalty): 1.8034151209732858
# --------------------------------------------------
# | 199       | 1.803     | 9.902     | -10.37    | -17.21    | -1.371    | -4.646    | 8.431     | -17.64    | -2.44     | -4.339    | -2.634    | -5.252    | -10.13    |
# Train Sharpe Ratio: 2.963, Validation Sharpe Ratio: 1.006
# Debug: L2 penalty: 2.7298258434149307
# Debug: L1 penalty: 0.31042681191784266
# Debug: Objective function value (with penalty): 17.78324734466723
# --------------------------------------------------
# | 200       | 17.78     | 2.791     | -7.842    | 0.5331    | -20.0     | 20.0      | -20.0     | -0.4793   | 8.425     | -20.0     | 20.0      | -9.005    | -20.0     |
# Train Sharpe Ratio: 0.531, Validation Sharpe Ratio: 0.502
# Debug: L2 penalty: 0.5073269401712475
# Debug: L1 penalty: 0.06517287859622889
# Debug: Objective function value (with penalty): 4.607000181232523
# --------------------------------------------------
# | 201       | 4.607     | -15.45    | 2.399     | 14.37     | -3.579    | -17.93    | -1.556    | 16.59     | -12.75    | -2.114    | 19.51     | -0.9396   | -18.64    |
# Train Sharpe Ratio: 1.876, Validation Sharpe Ratio: 1.185
# Debug: L2 penalty: 1.1638735914427523
# Debug: L1 penalty: 0.18024258153612246
# Debug: Objective function value (with penalty): 14.306383827021127
# --------------------------------------------------
# | 202       | 14.31     | -1.371    | -6.852    | -7.677    | -19.63    | -16.6     | -9.884    | -5.52     | 14.35     | -9.405    | -0.7905   | -7.738    | -15.34    |
# Train Sharpe Ratio: 1.283, Validation Sharpe Ratio: 0.064
# Debug: L2 penalty: 0.6535350239116914
# Debug: L1 penalty: 0.08559253277256335
# Debug: Objective function value (with penalty): 6.605372443315746
# --------------------------------------------------
# | 203       | 6.605     | 13.89     | -2.581    | -1.108    | -19.85    | -1.614    | -16.88    | -4.262    | -15.28    | -4.578    | 17.21     | 1.203     | 18.09     |
# Train Sharpe Ratio: 3.022, Validation Sharpe Ratio: 1.17
# Debug: L2 penalty: 2.0562748912541355
# Debug: L1 penalty: 0.2709759741289847
# Debug: Objective function value (with penalty): 19.558749134616885
# --------------------------------------------------
# | 204       | 19.56     | -3.545    | -3.108    | -4.353    | -20.0     | 9.131     | -20.0     | 6.148     | 20.0      | -2.755    | 7.27      | -7.502    | -20.0     |
# Train Sharpe Ratio: 1.499, Validation Sharpe Ratio: 0.777
# Debug: L2 penalty: 2.39273567586143
# Debug: L1 penalty: 0.24584667299250365
# Debug: Objective function value (with penalty): 9.10241765114607
# --------------------------------------------------
# | 205       | 9.102     | -20.0     | 8.994     | -20.0     | -20.0     | -20.0     | -20.0     | -0.5307   | -20.0     | -20.0     | -20.0     | -20.0     | 19.87     |
# Train Sharpe Ratio: 2.394, Validation Sharpe Ratio: 0.762
# Debug: L2 penalty: 3.2165057443071636
# Debug: L1 penalty: 0.34435386385672206
# Debug: Objective function value (with penalty): 13.03514039183612
# --------------------------------------------------
# | 206       | 13.04     | -20.0     | 12.94     | -20.0     | -20.0     | -8.482    | -20.0     | 6.07      | 20.0      | -20.0     | 20.0      | -20.0     | 20.0      |
# Train Sharpe Ratio: 2.841, Validation Sharpe Ratio: 0.955
# Debug: L2 penalty: 2.3508204061581486
# Debug: L1 penalty: 0.28854257756372814
# Debug: Objective function value (with penalty): 17.283637016278124
# --------------------------------------------------
# | 207       | 17.28     | 17.98     | 11.05     | -20.0     | -20.0     | -20.0     | -20.0     | -1.801    | 4.162     | -10.63    | 7.737     | -10.99    | 0.4757    |
# Train Sharpe Ratio: 1.892, Validation Sharpe Ratio: 0.324
# Debug: L2 penalty: 2.8449426775948496
# Debug: L1 penalty: 0.2846148244666041
# Debug: Objective function value (with penalty): 8.734442497938545
# --------------------------------------------------
# | 208       | 8.734     | -20.0     | -20.0     | -20.0     | -20.0     | 20.0      | -20.0     | -19.9     | 20.0      | -20.0     | 20.0      | -20.0     | 20.0      |
# Train Sharpe Ratio: 0.727, Validation Sharpe Ratio: 0.421
# Debug: L2 penalty: 0.4489771264084267
# Debug: L1 penalty: 0.06277925906494398
# Debug: Objective function value (with penalty): 5.38124361452663
# --------------------------------------------------
# | 209       | 5.381     | -17.27    | 14.72     | -1.933    | 5.235     | 0.6222    | -0.8476   | -10.05    | 0.3109    | -17.24    | 15.68     | -5.127    | -17.51    |
# Train Sharpe Ratio: -1.206, Validation Sharpe Ratio: -0.96
# Debug: L2 penalty: -1.0141382116803486
# Debug: L1 penalty: -0.13611093611778716
# Debug: Objective function value (with penalty): -9.802750852201864
# --------------------------------------------------
# | 210       | -9.803    | 18.35     | 1.286     | -9.188    | 19.1      | 3.178     | -13.39    | -2.161    | -13.35    | 4.214     | 3.76      | 17.28     | 19.01     |
# Train Sharpe Ratio: 2.395, Validation Sharpe Ratio: 0.606
# Debug: L2 penalty: 1.7263512679135493
# Debug: L1 penalty: 0.2358772950428178
# Debug: Objective function value (with penalty): 13.937271437043632
# --------------------------------------------------
# | 211       | 13.94     | 15.31     | 15.59     | -11.8     | -19.98    | -16.46    | -19.83    | -1.414    | 13.15     | -9.415    | -8.198    | -11.14    | 6.076     |
# Train Sharpe Ratio: 0.741, Validation Sharpe Ratio: 0.158
# Debug: L2 penalty: 0.23154156662045094
# Debug: L1 penalty: 0.04209940663184749
# Debug: Objective function value (with penalty): 4.512859026747702
# --------------------------------------------------
# | 212       | 4.513     | -7.961    | 1.222     | -1.809    | -18.22    | 8.061     | -7.769    | 8.556     | -14.08    | 11.52     | -3.499    | 0.1971    | 5.06      |
# Train Sharpe Ratio: 0.655, Validation Sharpe Ratio: 0.143
# Debug: L2 penalty: 0.414268270168869
# Debug: L1 penalty: 0.06035705194015306
# Debug: Objective function value (with penalty): 3.7713746778909787
# --------------------------------------------------
# | 213       | 3.771     | 4.232     | 10.49     | 17.87     | -11.52    | 11.06     | 3.664     | 10.03     | -15.63    | -17.19    | 10.06     | -11.22    | -19.19    |
# Train Sharpe Ratio: 2.276, Validation Sharpe Ratio: 1.108
# Debug: L2 penalty: 1.266469181321756
# Debug: L1 penalty: 0.18484223444537026
# Debug: Objective function value (with penalty): 16.05268858423287
# --------------------------------------------------
# | 214       | 16.05     | 3.247     | 11.25     | -16.37    | -19.23    | -14.26    | -17.29    | 2.15      | 1.467     | -2.706    | -1.064    | -5.329    | -11.24    |
# Train Sharpe Ratio: -1.322, Validation Sharpe Ratio: -1.038
# Debug: L2 penalty: -0.9022569438707899
# Debug: L1 penalty: -0.142900924680995
# Debug: Objective function value (with penalty): -10.896842131448215
# --------------------------------------------------
# | 215       | -10.9     | 4.979     | 4.038     | 17.52     | 9.405     | 2.144     | -15.25    | -13.9     | -7.402    | 5.513     | -15.68    | -8.097    | 15.74     |
# Train Sharpe Ratio: 1.292, Validation Sharpe Ratio: 0.626
# Debug: L2 penalty: 0.5428641971081919
# Debug: L1 penalty: 0.09382487078799252
# Debug: Objective function value (with penalty): 9.286310932103815
# --------------------------------------------------
# | 216       | 9.286     | -1.562    | -11.28    | -5.106    | -5.152    | -16.83    | -3.46     | 3.859     | 15.53     | 11.9      | 6.51      | -13.29    | -0.07476  |
# Train Sharpe Ratio: 3.246, Validation Sharpe Ratio: 0.819
# Debug: L2 penalty: 2.0107845330155185
# Debug: L1 penalty: 0.2647325323101224
# Debug: Objective function value (with penalty): 19.262982934674362
# --------------------------------------------------
# | 217       | 19.26     | -4.708    | -0.785    | -3.561    | -17.78    | 12.31     | -19.07    | 8.45      | 19.28     | -2.444    | 15.87     | -17.25    | -1.406    |
# Train Sharpe Ratio: 3.172, Validation Sharpe Ratio: 0.962
# Debug: L2 penalty: 2.3164027876956825
# Debug: L1 penalty: 0.2851459619744568
# Debug: Objective function value (with penalty): 19.17345125032986
# --------------------------------------------------
# | 218       | 19.17     | -2.278    | 2.598     | -2.211    | -20.0     | 6.345     | -20.0     | 3.956     | 20.0      | 4.2       | 20.0      | -16.44    | -12.93    |
# Train Sharpe Ratio: -0.513, Validation Sharpe Ratio: -0.403
# Debug: L2 penalty: -0.41205381250105894
# Debug: L1 penalty: -0.059144553509634844
# Debug: Objective function value (with penalty): -4.163801633989307
# --------------------------------------------------
# | 219       | -4.164    | -4.14     | 8.514     | 18.15     | -11.7     | 15.5      | 4.86      | 18.87     | -7.419    | 4.091     | -17.32    | 1.992     | -15.06    |
# Train Sharpe Ratio: 3.175, Validation Sharpe Ratio: 1.037
# Debug: L2 penalty: 2.001977642044192
# Debug: L1 penalty: 0.2565273864620249
# Debug: Objective function value (with penalty): 19.87049497149378
# --------------------------------------------------
# | 220       | 19.87     | -5.801    | 3.87      | -8.91     | -20.0     | 2.732     | -20.0     | 2.925     | 20.0      | -0.3267   | 5.079     | -20.0     | -6.28     |
# Train Sharpe Ratio: 2.612, Validation Sharpe Ratio: 1.118
# Debug: L2 penalty: 1.638148076066086
# Debug: L1 penalty: 0.23404269015425103
# Debug: Objective function value (with penalty): 17.524809233779667
# --------------------------------------------------
# | 221       | 17.52     | -3.949    | -10.26    | 6.911     | -16.96    | 4.182     | -19.84    | 4.776     | 15.56     | -5.9      | -0.261    | -18.02    | -14.03    |
# Train Sharpe Ratio: 2.99, Validation Sharpe Ratio: 0.681
# Debug: L2 penalty: 3.148925639209941
# Debug: L1 penalty: 0.33760237667062687
# Debug: Objective function value (with penalty): 16.022971984119433
# --------------------------------------------------
# | 222       | 16.02     | -20.0     | 1.82      | -17.8     | -20.0     | 20.0      | -20.0     | 9.939     | 20.0      | 0.495     | 20.0      | -20.0     | 2.992     |
# Train Sharpe Ratio: 1.166, Validation Sharpe Ratio: 0.246
# Debug: L2 penalty: 0.7804652739788327
# Debug: L1 penalty: 0.09979594539154543
# Debug: Objective function value (with penalty): 6.639738780629621
# --------------------------------------------------
# | 223       | 6.64      | 15.04     | -17.86    | -11.97    | -19.58    | -8.293    | -16.52    | 0.6659    | 19.07     | 0.333     | 6.332     | 16.02     | -1.019    |
# Train Sharpe Ratio: 3.239, Validation Sharpe Ratio: 0.888
# Debug: L2 penalty: 2.6476080550644667
# Debug: L1 penalty: 0.3163203378465785
# Debug: Objective function value (with penalty): 18.84657160708895
# --------------------------------------------------
# | 224       | 18.85     | -4.59     | 0.891     | -6.504    | -20.0     | 14.36     | -20.0     | 7.652     | 20.0      | -20.0     | 20.0      | -9.883    | -1.155    |
# Train Sharpe Ratio: 2.974, Validation Sharpe Ratio: 0.808
# Debug: L2 penalty: 1.7624853453468279
# Debug: L1 penalty: 0.25713685755013416
# Debug: Objective function value (with penalty): 17.97337779710304
# --------------------------------------------------
# | 225       | 17.97     | 3.309     | 13.52     | -11.8     | -17.04    | 0.7828    | -18.28    | 5.164     | 19.15     | -9.948    | 8.532     | -13.5     | -7.585    |
# Train Sharpe Ratio: 1.27, Validation Sharpe Ratio: 0.87
# Debug: L2 penalty: 2.1180417188217073
# Debug: L1 penalty: 0.22409557290974674
# Debug: Objective function value (with penalty): 8.557862708268546
# --------------------------------------------------
# | 226       | 8.558     | -20.0     | -14.28    | -20.0     | 0.5298    | -20.0     | -20.0     | 13.35     | 20.0      | -20.0     | 20.0      | 17.43     | -20.0     |

# %%
optimal_weights = {
    "average_true_range": -1.91,
    "chaikin_money_flow": 1.654,
    "chande_momentum_oscillator": -11.9,
    "ichimoku": -20.0,
    "know_sure_thing": 3.845,
    "macd": -20.0,
    "on_balance_volume": 1.67,
    "trend_1_3": 7.33,
    "trend_5_20": -20.0,
    "ultimate_oscillator": -0.4255,
    "volatility_20": 5.358,
    "volume": -5.626
}

# %%
portfolio_weights_test = generate_portfolio_vectorized(test_features, test_universe, np.array(list(optimal_weights.values())))
sr_test, _ = backtest_portfolio_new(portfolio_weights_test, test_returns, test_universe,True,True)

print("Optimal Weights:", optimal_weights)
print("Test Set Sharpe Ratio:", sr_test)
# Out:
# Gross Sharpe Ratio:  0.685
# Net Sharpe Ratio:  0.5
# Optimal Weights: {'average_true_range': -1.91, 'chaikin_money_flow': 1.654, 'chande_momentum_oscillator': -11.9, 'ichimoku': -20.0, 'know_sure_thing': 3.845, 'macd': -20.0, 'on_balance_volume': 1.67, 'trend_1_3': 7.33, 'trend_5_20': -20.0, 'ultimate_oscillator': -0.4255, 'volatility_20': 5.358, 'volume': -5.626}
# Test Set Sharpe Ratio: 0.5

# %%
all_features = sorted(train_features.columns.levels[0])
all_features
# Out:
# ['average_true_range',
#  'chaikin_money_flow',
#  'chande_momentum_oscillator',
#  'ichimoku',
#  'know_sure_thing',
#  'macd',
#  'on_balance_volume',
#  'trend_1_3',
#  'trend_5_20',
#  'ultimate_oscillator',
#  'volatility_20',
#  'volume']

# %%
def optimize_signal_weights_bayesian(features_train, features_validation, universe_train, universe_validation, returns_train, returns_validation):
    selected_features = [
        'on_balance_volume', 'trend_1_3', 'macd', 'ichimoku',
        'ultimate_oscillator', 'chaikin_money_flow', 'volume',
        'know_sure_thing', 'chande_momentum_oscillator',
        'average_true_range', 'volatility_20', 'trend_5_20'
    ]

    def sharpe_ratio_objective(**weights):
        # Get all feature names from train_features
        all_features = sorted(features_train.columns.levels[0])
        
        # Assign 0 weight to features not in selected_features
        weight_array = np.array([weights.get(feature, 0) if feature in selected_features else 0 for feature in all_features])
        
        # Debug: Print the weight array
        # print(f"Weight Array: {weight_array}")
        
        # Generate portfolio weights for training set
        portfolio_weights_train = generate_portfolio_vectorized(features_train, universe_train, weight_array)
        
        # Backtest on training data
        sr_train, _ = backtest_portfolio_new(portfolio_weights_train, returns_train, universe_train, False, False)
        
        # Validate on validation set
        portfolio_weights_validation = generate_portfolio_vectorized(features_validation, universe_validation, weight_array)
        sr_validation, _ = backtest_portfolio_new(portfolio_weights_validation, validation_returns, validation_universe, False, False)
        
        print(f"Train Sharpe Ratio: {sr_train}, Validation Sharpe Ratio: {sr_validation}")
        
        # Combine training and validation Sharpe ratios
        alpha = 0.4  # Weight for training Sharpe ratio
        combined_sharpe_ratio = alpha * sr_train + (1 - alpha) * sr_validation
        
        # Add penalties to prevent overfitting
        penalty_l2 = np.sum(np.square(weight_array)) * combined_sharpe_ratio * 0.005
        penalty_l1 = np.sum(np.abs(weight_array)) * combined_sharpe_ratio * 0.008
        
        result = combined_sharpe_ratio * 10 - penalty_l2 - penalty_l1
        print(f"Debug: L2 penalty: {penalty_l2}")
        print(f"Debug: L1 penalty: {penalty_l1}")
        print(f"Debug: Objective function value (with penalty): {result}")
        print("-" * 50)
        return result

    # Create pbounds for selected features only
    pbounds = {feature: (-5, 5) for feature in selected_features}
    print(f"Parameter Bounds (pbounds): {pbounds}")
    
    optimizer = BayesianOptimization(
        f=sharpe_ratio_objective,
        pbounds=pbounds,
        random_state=42
    )
    
    optimizer.maximize(init_points=20, n_iter=300)
    
    optimal_weights = optimizer.max['params']
    
    return optimal_weights

# Run Bayesian Optimization using train/validation split
optimal_weights = optimize_signal_weights_bayesian(
    train_features,
    validation_features,
    train_universe,
    validation_universe,
    train_returns,
    validation_returns
)

# Evaluate on test set
portfolio_weights_test = generate_portfolio_vectorized(test_features, test_universe, np.array(list(optimal_weights.values())))
sr_test, _ = backtest_portfolio_new(portfolio_weights_test, test_returns, test_universe,False,False)

print("Optimal Weights:", optimal_weights)
print("Test Set Sharpe Ratio:", sr_test)
# Out:
# Parameter Bounds (pbounds): {'on_balance_volume': (-5, 5), 'trend_1_3': (-5, 5), 'macd': (-5, 5), 'ichimoku': (-5, 5), 'ultimate_oscillator': (-5, 5), 'chaikin_money_flow': (-5, 5), 'volume': (-5, 5), 'know_sure_thing': (-5, 5), 'chande_momentum_oscillator': (-5, 5), 'average_true_range': (-5, 5), 'volatility_20': (-5, 5), 'trend_5_20': (-5, 5)}
# |   iter    |  target   | averag... | chaiki... | chande... | ichimoku  | know_s... |   macd    | on_bal... | trend_1_3 | trend_... | ultima... | volati... |  volume   |
# -------------------------------------------------------------------------------------------------------------------------------------------------------------------------
# Train Sharpe Ratio: -0.327, Validation Sharpe Ratio: -0.569
# Debug: L2 penalty: -0.31936047662817635
# Debug: L1 penalty: -0.1383137616434002
# Debug: Objective function value (with penalty): -4.264325761728423
# --------------------------------------------------
# | 1         | -4.264    | -1.255    | 4.507     | 2.32      | 0.9866    | -3.44     | -3.44     | -4.419    | 3.662     | 1.011     | 2.081     | -4.794    | 4.699     |
# Train Sharpe Ratio: 0.919, Validation Sharpe Ratio: 0.194
# Debug: L2 penalty: 0.1658727134892831
# Debug: L1 penalty: 0.09935809972524971
# Debug: Objective function value (with penalty): 4.574769186785468
# --------------------------------------------------
# | 2         | 4.575     | 3.324     | -2.877    | -3.182    | -3.166    | -1.958    | 0.2476    | -0.6805   | -2.088    | 1.119     | -3.605    | -2.079    | -1.336    |
# Train Sharpe Ratio: 0.66, Validation Sharpe Ratio: -0.446
# Debug: L2 penalty: -0.0021791196312763513
# Debug: L1 penalty: -0.0009459402748549885
# Debug: Objective function value (with penalty): -0.032874940093868585
# --------------------------------------------------
# | 3         | -0.03287  | -0.4393   | 2.852     | -3.003    | 0.1423    | 0.9241    | -4.535    | 1.075     | -3.295    | -4.349    | 4.489     | 4.656     | 3.084     |
# Train Sharpe Ratio: 0.307, Validation Sharpe Ratio: 0.524
# Debug: L2 penalty: 0.19351317382612063
# Debug: L1 penalty: 0.0948412935152912
# Debug: Objective function value (with penalty): 4.083645532658588
# --------------------------------------------------
# | 4         | 4.084     | -1.954    | -4.023    | 1.842     | -0.5985   | -3.78     | -0.04823  | -4.656    | 4.093     | -2.412    | 1.625     | -1.883    | 0.2007    |
# Train Sharpe Ratio: -0.854, Validation Sharpe Ratio: -0.746
# Debug: L2 penalty: -0.5656232477269652
# Debug: L1 penalty: -0.24027293733569072
# Debug: Objective function value (with penalty): -7.086103814937344
# --------------------------------------------------
# | 5         | -7.086    | 0.4671    | -3.151    | 4.696     | 2.751     | 4.395     | 3.948     | 0.979     | 4.219     | -4.115    | -3.04     | -4.548    | -1.747    |
# Train Sharpe Ratio: 0.202, Validation Sharpe Ratio: 0.673
# Debug: L2 penalty: 0.25351571352707114
# Debug: L1 penalty: 0.12486620630974984
# Debug: Objective function value (with penalty): 4.467618080163179
# --------------------------------------------------
# | 6         | 4.468     | -1.113    | -2.287    | 3.287     | -1.432    | -2.191    | 0.427     | -3.591    | 3.022     | -4.254    | 4.869     | 2.722     | -3.013    |
# Train Sharpe Ratio: -0.16, Validation Sharpe Ratio: -0.213
# Debug: L2 penalty: -0.11776481063776796
# Debug: L1 penalty: -0.05463445874323889
# Debug: Objective function value (with penalty): -1.7456007306189931
# --------------------------------------------------
# | 7         | -1.746    | -4.945    | 3.155     | 2.069     | 2.29      | 2.713     | -4.26     | -1.415    | -3.841    | 3.631     | 1.233     | -1.691    | -4.364    |
# Train Sharpe Ratio: -1.196, Validation Sharpe Ratio: -0.767
# Debug: L2 penalty: -0.2928632146208056
# Debug: L1 penalty: -0.1756218360390972
# Debug: Objective function value (with penalty): -8.917514949340097
# --------------------------------------------------
# | 8         | -8.918    | -1.89     | -1.748    | 2.296     | 1.376     | 3.872     | -0.2779   | -3.804    | 2.132     | 2.608     | 0.6128    | 2.71      | -0.06204  |
# Train Sharpe Ratio: 0.534, Validation Sharpe Ratio: 0.012
# Debug: L2 penalty: 0.10595631307130617
# Debug: L1 penalty: 0.04883247515476255
# Debug: Objective function value (with penalty): 2.0532112117739314
# --------------------------------------------------
# | 9         | 2.053     | 0.2273    | -0.7246   | -4.746    | -3.921    | -4.686    | 1.364     | -1.856    | 0.08571   | 4.076     | -2.507    | -0.8962   | 2.556     |
# Train Sharpe Ratio: -0.859, Validation Sharpe Ratio: -0.759
# Debug: L2 penalty: -0.47657757648716265
# Debug: L1 penalty: -0.2259530337925588
# Debug: Objective function value (with penalty): -7.287469389720278
# --------------------------------------------------
# | 10        | -7.287    | -2.712    | -4.23     | -2.102    | -3.388    | 4.297     | 3.081     | 1.334     | 3.715     | 3.037     | -3.134    | 3.926     | 0.3934    |
# Train Sharpe Ratio: 1.455, Validation Sharpe Ratio: 0.606
# Debug: L2 penalty: 0.5079948615012458
# Debug: L1 penalty: 0.23930902962010647
# Debug: Objective function value (with penalty): 8.708696108878648
# --------------------------------------------------
# | 11        | 8.709     | 3.074     | 3.961     | -1.82     | -3.899    | -2.721    | -0.7289   | 3.18      | 3.607     | -4.93     | 0.1075    | -0.8259   | -2.779    |
# Train Sharpe Ratio: -1.754, Validation Sharpe Ratio: -0.324
# Debug: L2 penalty: -0.4462836815910846
# Debug: L1 penalty: -0.2082107939102289
# Debug: Objective function value (with penalty): -8.305505524498686
# --------------------------------------------------
# | 12        | -8.306    | -3.801    | -1.624    | 4.429     | -1.768    | 0.1879    | 2.03      | -1.364    | 4.718     | 4.624     | -2.482    | -0.02751  | -1.991    |
# Train Sharpe Ratio: 0.301, Validation Sharpe Ratio: 0.559
# Debug: L2 penalty: 0.2703029181880259
# Debug: L1 penalty: 0.11808291164064685
# Debug: Objective function value (with penalty): 4.169614170171328
# --------------------------------------------------
# | 13        | 4.17      | -2.152    | -4.631    | 1.096     | 0.02679   | -4.485    | -2.214    | 4.083     | -2.604    | -3.551    | -0.1055   | 4.857     | -2.579    |
# Train Sharpe Ratio: 0.834, Validation Sharpe Ratio: 0.223
# Debug: L2 penalty: 0.1597968246210236
# Debug: L1 penalty: 0.09706496586081828
# Debug: Objective function value (with penalty): 4.417138209518158
# --------------------------------------------------
# | 14        | 4.417     | 1.721     | 2.616     | -2.624    | 2.282     | -1.322    | 1.323     | 1.335     | 0.3577    | -4.097    | 3.353     | -1.792    | -3.135    |
# Train Sharpe Ratio: 0.279, Validation Sharpe Ratio: 0.531
# Debug: L2 penalty: 0.2275411350765119
# Debug: L1 penalty: 0.10568841844200248
# Debug: Objective function value (with penalty): 3.9687704464814857
# --------------------------------------------------
# | 15        | 3.969     | -4.592    | 0.9089    | 1.776     | -4.834    | 0.1209    | -2.735    | 1.452     | -3.256    | 1.909     | -1.133    | 4.367     | -3.625    |
# Train Sharpe Ratio: -1.3, Validation Sharpe Ratio: -0.6
# Debug: L2 penalty: -0.4735023028962091
# Debug: L1 penalty: -0.22625643441923318
# Debug: Objective function value (with penalty): -8.100241262684559
# --------------------------------------------------
# | 16        | -8.1      | -1.589    | -3.865    | 4.247     | 3.773     | -2.421    | 1.6       | 3.172     | 0.552     | 0.2965    | -2.581    | -4.069    | 3.972     |
# Train Sharpe Ratio: -0.5, Validation Sharpe Ratio: -1.163
# Debug: L2 penalty: -0.5072891649972128
# Debug: L1 penalty: -0.24636531332095693
# Debug: Objective function value (with penalty): -8.22434552168183
# --------------------------------------------------
# | 17        | -8.224    | 4.004     | 1.331     | -1.61     | -1.508    | 2.26      | 3.971     | 3.871     | 2.799     | 1.42      | -4.159    | -3.384    | 3.986     |
# Train Sharpe Ratio: 0.154, Validation Sharpe Ratio: 0.296
# Debug: L2 penalty: 0.12559962677959446
# Debug: L1 penalty: 0.06002281326860948
# Debug: Objective function value (with penalty): 2.2063775599517954
# --------------------------------------------------
# | 18        | 2.206     | 1.064     | -4.908    | -3.985    | 1.635     | -4.949    | -3.392    | 0.4873    | 1.919     | 1.52      | -2.757    | 2.122     | -2.628    |
# Train Sharpe Ratio: -2.007, Validation Sharpe Ratio: -1.135
# Debug: L2 penalty: -0.5961431933281075
# Debug: L1 penalty: -0.3270532323434835
# Debug: Objective function value (with penalty): -13.91480357432841
# --------------------------------------------------
# | 19        | -13.91    | -1.746    | 2.465     | 1.496     | 3.492     | 1.576     | 0.6831    | -4.063    | -1.323    | -2.348    | -2.56     | 4.73      | -1.069    |
# Train Sharpe Ratio: -1.249, Validation Sharpe Ratio: -0.677
# Debug: L2 penalty: -0.36499493208735573
# Debug: L1 penalty: -0.1880804702410848
# Debug: Objective function value (with penalty): -8.50492459767156
# --------------------------------------------------
# | 20        | -8.505    | 3.92      | 1.311     | 2.948     | 0.02637   | 0.769     | -0.07482  | -3.048    | 2.225     | -2.192    | -4.757    | 1.455     | -3.229    |
# Train Sharpe Ratio: 1.95, Validation Sharpe Ratio: 0.989
# Debug: L2 penalty: 1.3352638679993185
# Debug: L1 penalty: 0.47495555386645816
# Debug: Objective function value (with penalty): 11.923780578134224
# --------------------------------------------------
# | 21        | 11.92     | 0.3521    | -3.036    | -4.815    | -5.0      | -5.0      | -4.181    | 1.352     | -0.3061   | -5.0      | 5.0       | -4.185    | -5.0      |
# Train Sharpe Ratio: 1.531, Validation Sharpe Ratio: 0.836
# Debug: L2 penalty: 1.4287450021228214
# Debug: L1 penalty: 0.47043722786017167
# Debug: Objective function value (with penalty): 9.240817770017005
# --------------------------------------------------
# | 22        | 9.241     | -5.0      | 5.0       | -5.0      | -5.0      | -5.0      | -5.0      | 5.0       | 2.539     | -5.0      | 5.0       | -0.2481   | -5.0      |
# Train Sharpe Ratio: 1.5, Validation Sharpe Ratio: 0.716
# Debug: L2 penalty: 0.4471004837688118
# Debug: L1 penalty: 0.24324500612040004
# Debug: Objective function value (with penalty): 9.605654510110789
# --------------------------------------------------
# | 23        | 9.606     | 2.653     | 2.399     | -3.192    | -4.085    | -2.128    | 0.1279    | 2.478     | 3.652     | -3.234    | -2.883    | -0.7404   | -1.959    |
# Train Sharpe Ratio: 1.257, Validation Sharpe Ratio: 0.66
# Debug: L2 penalty: 0.9696281666463372
# Debug: L1 penalty: 0.34891216393446384
# Debug: Objective function value (with penalty): 7.669459669419198
# --------------------------------------------------
# | 24        | 7.669     | 1.632     | -4.415    | -5.0      | -5.0      | -5.0      | 4.807     | 2.155     | 5.0       | -5.0      | 2.191     | -3.325    | -5.0      |
# Train Sharpe Ratio: 1.489, Validation Sharpe Ratio: 1.018
# Debug: L2 penalty: 1.5326622761391955
# Debug: L1 penalty: 0.5093802129483573
# Debug: Objective function value (with penalty): 10.021957510912447
# --------------------------------------------------
# | 25        | 10.02     | -5.0      | -5.0      | -5.0      | -5.0      | -5.0      | -1.727    | -5.0      | -5.0      | -5.0      | 5.0       | -1.052    | -5.0      |
# Train Sharpe Ratio: 1.426, Validation Sharpe Ratio: 0.818
# Debug: L2 penalty: 1.3151432249984223
# Debug: L1 penalty: 0.444418485694059
# Debug: Objective function value (with penalty): 8.852438289307516
# --------------------------------------------------
# | 26        | 8.852     | -1.292    | 1.835     | -5.0      | -5.0      | -5.0      | -5.0      | 5.0       | -4.222    | -5.0      | -5.0      | -5.0      | -5.0      |
# Train Sharpe Ratio: 1.818, Validation Sharpe Ratio: 0.705
# Debug: L2 penalty: 1.7149283743406718
# Debug: L1 penalty: 0.5504054816853688
# Debug: Objective function value (with penalty): 9.236666143973961
# --------------------------------------------------
# | 27        | 9.237     | -5.0      | -5.0      | -5.0      | -5.0      | 4.816     | -5.0      | 5.0       | -5.0      | -5.0      | 5.0       | -5.0      | -5.0      |
# Train Sharpe Ratio: 1.835, Validation Sharpe Ratio: 0.849
# Debug: L2 penalty: 1.6431606969335777
# Debug: L1 penalty: 0.5398385284366239
# Debug: Objective function value (with penalty): 10.251000774629796
# --------------------------------------------------
# | 28        | 10.25     | 5.0       | 3.745     | -5.0      | -5.0      | -5.0      | -0.5254   | -5.0      | -5.0      | -5.0      | 5.0       | -5.0      | -5.0      |
# Train Sharpe Ratio: 1.351, Validation Sharpe Ratio: 0.901
# Debug: L2 penalty: 1.4881585837511813
# Debug: L1 penalty: 0.48060780551635685
# Debug: Objective function value (with penalty): 8.841233610732461
# --------------------------------------------------
# | 29        | 8.841     | -5.0      | -5.0      | 5.0       | -5.0      | -5.0      | -5.0      | 0.5744    | -5.0      | -5.0      | 5.0       | -5.0      | -5.0      |
# Train Sharpe Ratio: 1.843, Validation Sharpe Ratio: 0.876
# Debug: L2 penalty: 1.8941999999999999
# Debug: L1 penalty: 0.606144
# Debug: Objective function value (with penalty): 10.127656
# --------------------------------------------------
# | 30        | 10.13     | 5.0       | -5.0      | -5.0      | -5.0      | -5.0      | -5.0      | 5.0       | 5.0       | -5.0      | 5.0       | 5.0       | -5.0      |
# Train Sharpe Ratio: 1.978, Validation Sharpe Ratio: 0.582
# Debug: L2 penalty: 1.657990700394665
# Debug: L1 penalty: 0.5380096196997344
# Debug: Objective function value (with penalty): 9.207999679905601
# --------------------------------------------------
# | 31        | 9.208     | 5.0       | -5.0      | -5.0      | -5.0      | -5.0      | -5.0      | -5.0      | -5.0      | -5.0      | 5.0       | -5.0      | 3.972     |
# Train Sharpe Ratio: 1.249, Validation Sharpe Ratio: 0.684
# Debug: L2 penalty: 1.3390704723865126
# Debug: L1 penalty: 0.43238332162796883
# Debug: Objective function value (with penalty): 7.32854620598552
# --------------------------------------------------
# | 32        | 7.329     | -5.0      | -5.0      | -5.0      | 4.393     | -5.0      | -5.0      | 5.0       | 5.0       | -5.0      | 5.0       | -5.0      | -5.0      |
# Train Sharpe Ratio: 1.844, Validation Sharpe Ratio: 0.521
# Debug: L2 penalty: 1.472319710193133
# Debug: L1 penalty: 0.48159064954958164
# Debug: Objective function value (with penalty): 8.548089640257286
# --------------------------------------------------
# | 33        | 8.548     | 5.0       | -5.0      | -5.0      | -5.0      | 2.321     | -5.0      | -5.0      | 5.0       | -5.0      | 5.0       | -5.0      | -5.0      |
# Train Sharpe Ratio: 1.828, Validation Sharpe Ratio: 0.897
# Debug: L2 penalty: 1.7579901321870748
# Debug: L1 penalty: 0.5728245369656201
# Debug: Objective function value (with penalty): 10.363185330847307
# --------------------------------------------------
# | 34        | 10.36     | -5.0      | -5.0      | -5.0      | -5.0      | -5.0      | -5.0      | -5.0      | 5.0       | -5.0      | 5.0       | -5.0      | 1.407     |
# Train Sharpe Ratio: 1.556, Validation Sharpe Ratio: 0.672
# Debug: L2 penalty: 1.5384
# Debug: L1 penalty: 0.492288
# Debug: Objective function value (with penalty): 8.225312
# --------------------------------------------------
# | 35        | 8.225     | -5.0      | -5.0      | -5.0      | -5.0      | -5.0      | -5.0      | 5.0       | -5.0      | -5.0      | 5.0       | -5.0      | 5.0       |
# Train Sharpe Ratio: 1.366, Validation Sharpe Ratio: 0.661
# Debug: L2 penalty: 1.4145
# Debug: L1 penalty: 0.45264000000000004
# Debug: Objective function value (with penalty): 7.56286
# --------------------------------------------------
# | 36        | 7.563     | 5.0       | -5.0      | -5.0      | -5.0      | -5.0      | 5.0       | -5.0      | -5.0      | -5.0      | 5.0       | -5.0      | -5.0      |
# Train Sharpe Ratio: 1.056, Validation Sharpe Ratio: 0.571
# Debug: L2 penalty: 1.1475
# Debug: L1 penalty: 0.36719999999999997
# Debug: Objective function value (with penalty): 6.135300000000001
# --------------------------------------------------
# | 37        | 6.135     | -5.0      | 5.0       | -5.0      | -5.0      | -5.0      | 5.0       | 5.0       | -5.0      | -5.0      | 5.0       | -5.0      | -5.0      |
# Train Sharpe Ratio: 1.163, Validation Sharpe Ratio: 0.773
# Debug: L2 penalty: 1.3184677598971957
# Debug: L1 penalty: 0.43086525336858944
# Debug: Objective function value (with penalty): 7.540666986734216
# --------------------------------------------------
# | 38        | 7.541     | -5.0      | -5.0      | -5.0      | -5.0      | -5.0      | -5.0      | 5.0       | -5.0      | 5.0       | 5.0       | 2.974     | -5.0      |
# Train Sharpe Ratio: 2.239, Validation Sharpe Ratio: 0.905
# Debug: L2 penalty: 2.1579
# Debug: L1 penalty: 0.690528
# Debug: Objective function value (with penalty): 11.537572
# --------------------------------------------------
# | 39        | 11.54     | -5.0      | -5.0      | -5.0      | -5.0      | 5.0       | -5.0      | -5.0      | -5.0      | -5.0      | 5.0       | -5.0      | -5.0      |
# Train Sharpe Ratio: 1.005, Validation Sharpe Ratio: 0.532
# Debug: L2 penalty: 1.0817999999999999
# Debug: L1 penalty: 0.346176
# Debug: Objective function value (with penalty): 5.7840240000000005
# --------------------------------------------------
# | 40        | 5.784     | 5.0       | -5.0      | -5.0      | 5.0       | -5.0      | -5.0      | -5.0      | -5.0      | -5.0      | 5.0       | -5.0      | -5.0      |
# Train Sharpe Ratio: 1.465, Validation Sharpe Ratio: 1.029
# Debug: L2 penalty: 1.713242079371949
# Debug: L1 penalty: 0.5595316318136876
# Debug: Objective function value (with penalty): 9.761226288814365
# --------------------------------------------------
# | 41        | 9.761     | -5.0      | -5.0      | 3.12      | -5.0      | -5.0      | -5.0      | -5.0      | 5.0       | -5.0      | 5.0       | -5.0      | -5.0      |
# Train Sharpe Ratio: 2.161, Validation Sharpe Ratio: 0.768
# Debug: L2 penalty: 1.9053549393517597
# Debug: L1 penalty: 0.6208545306398775
# Debug: Objective function value (with penalty): 10.725790530008364
# --------------------------------------------------
# | 42        | 10.73     | -5.0      | 4.952     | -5.0      | -5.0      | 3.61      | -5.0      | -5.0      | 5.0       | -5.0      | 5.0       | -5.0      | -5.0      |
# Train Sharpe Ratio: 1.978, Validation Sharpe Ratio: 0.926
# Debug: L2 penalty: 1.8531010116981268
# Debug: L1 penalty: 0.5972359466733019
# Debug: Objective function value (with penalty): 11.01766304162857
# --------------------------------------------------
# | 43        | 11.02     | -5.0      | 5.0       | -5.0      | -5.0      | -0.431    | -5.0      | -5.0      | -5.0      | -5.0      | 5.0       | -5.0      | -5.0      |
# Train Sharpe Ratio: 1.372, Validation Sharpe Ratio: 1.018
# Debug: L2 penalty: 1.7394000000000003
# Debug: L1 penalty: 0.5566080000000001
# Debug: Objective function value (with penalty): 9.299992000000001
# --------------------------------------------------
# | 44        | 9.3       | -5.0      | -5.0      | -5.0      | -5.0      | -5.0      | -5.0      | -5.0      | 5.0       | -5.0      | 5.0       | 5.0       | -5.0      |
# Train Sharpe Ratio: 1.89, Validation Sharpe Ratio: 0.957
# Debug: L2 penalty: 1.092421707807147
# Debug: L1 penalty: 0.4426709057033983
# Debug: Objective function value (with penalty): 11.766907386489454
# --------------------------------------------------
# | 45        | 11.77     | 4.227     | 2.91      | -4.73     | -4.328    | -4.708    | -4.558    | 2.212     | -4.645    | -2.595    | 1.297     | -1.199    | -4.189    |
# Train Sharpe Ratio: 1.438, Validation Sharpe Ratio: 0.817
# Debug: L2 penalty: 1.4384882076399261
# Debug: L1 penalty: 0.4721130741499896
# Debug: Objective function value (with penalty): 8.743398718210084
# --------------------------------------------------
# | 46        | 8.743     | -5.0      | 4.355     | -5.0      | -5.0      | -5.0      | 1.037     | -5.0      | 5.0       | -5.0      | 5.0       | -5.0      | -5.0      |
# Train Sharpe Ratio: 1.473, Validation Sharpe Ratio: 0.778
# Debug: L2 penalty: 1.584
# Debug: L1 penalty: 0.50688
# Debug: Objective function value (with penalty): 8.46912
# --------------------------------------------------
# | 47        | 8.469     | 5.0       | -5.0      | -5.0      | -5.0      | -5.0      | -5.0      | 5.0       | -5.0      | -5.0      | 5.0       | 5.0       | -5.0      |
# Train Sharpe Ratio: 1.789, Validation Sharpe Ratio: 0.915
# Debug: L2 penalty: 1.8969000000000003
# Debug: L1 penalty: 0.6070080000000001
# Debug: Objective function value (with penalty): 10.142092
# --------------------------------------------------
# | 48        | 10.14     | 5.0       | -5.0      | 5.0       | -5.0      | -5.0      | -5.0      | 5.0       | 5.0       | -5.0      | 5.0       | -5.0      | -5.0      |
# Train Sharpe Ratio: 2.109, Validation Sharpe Ratio: 0.66
# Debug: L2 penalty: 1.8594
# Debug: L1 penalty: 0.5950080000000001
# Debug: Objective function value (with penalty): 9.941592
# --------------------------------------------------
# | 49        | 9.942     | 5.0       | 5.0       | -5.0      | -5.0      | -5.0      | -5.0      | 5.0       | 5.0       | 5.0       | 5.0       | -5.0      | -5.0      |
# Train Sharpe Ratio: 2.36, Validation Sharpe Ratio: 0.902
# Debug: L2 penalty: 1.8963013376539892
# Debug: L1 penalty: 0.6437422049872398
# Debug: Objective function value (with penalty): 12.31195645735877
# --------------------------------------------------
# | 50        | 12.31     | -5.0      | -3.402    | -5.0      | -5.0      | 3.912     | -5.0      | 1.865     | 5.0       | -5.0      | 5.0       | -5.0      | -5.0      |
# Train Sharpe Ratio: 1.466, Validation Sharpe Ratio: 0.899
# Debug: L2 penalty: 1.329792746490665
# Debug: L1 penalty: 0.45281983233800793
# Debug: Objective function value (with penalty): 9.475387421171327
# --------------------------------------------------
# | 51        | 9.475     | -5.0      | -5.0      | 2.715     | -5.0      | -0.7405   | -5.0      | 5.0       | 5.0       | -5.0      | 5.0       | 1.822     | -5.0      |
# Train Sharpe Ratio: 1.741, Validation Sharpe Ratio: 0.246
# Debug: L2 penalty: 1.167392191113516
# Debug: L1 penalty: 0.37998888863281566
# Debug: Objective function value (with penalty): 6.89261892025367
# --------------------------------------------------
# | 52        | 6.893     | 5.0       | 5.0       | -5.0      | -5.0      | 5.0       | -5.0      | 5.0       | -5.0      | 1.278     | 5.0       | -5.0      | -5.0      |
# Train Sharpe Ratio: 0.982, Validation Sharpe Ratio: 0.321
# Debug: L2 penalty: 0.8781
# Debug: L1 penalty: 0.280992
# Debug: Objective function value (with penalty): 4.694908
# --------------------------------------------------
# | 53        | 4.695     | 5.0       | 5.0       | -5.0      | -5.0      | -5.0      | -5.0      | 5.0       | -5.0      | 5.0       | 5.0       | 5.0       | -5.0      |
# Train Sharpe Ratio: 1.918, Validation Sharpe Ratio: 1.039
# Debug: L2 penalty: 1.7236225357569317
# Debug: L1 penalty: 0.5700639577311378
# Debug: Objective function value (with penalty): 11.612313506511931
# --------------------------------------------------
# | 54        | 11.61     | -0.258    | -1.424    | -5.0      | -5.0      | -5.0      | -5.0      | -5.0      | -5.0      | 4.561     | 5.0       | -5.0      | -5.0      |
# Train Sharpe Ratio: 1.763, Validation Sharpe Ratio: 0.901
# Debug: L2 penalty: 1.5316980229793171
# Debug: L1 penalty: 0.521608334751328
# Debug: Objective function value (with penalty): 10.404693642269356
# --------------------------------------------------
# | 55        | 10.4      | 5.0       | -5.0      | 1.143     | -5.0      | -5.0      | -5.0      | 2.644     | -5.0      | 3.55      | 5.0       | -5.0      | -5.0      |
# Train Sharpe Ratio: 2.362, Validation Sharpe Ratio: 1.003
# Debug: L2 penalty: 1.480689383672267
# Debug: L1 penalty: 0.5363126804257888
# Debug: Objective function value (with penalty): 13.448997935901943
# --------------------------------------------------
# | 56        | 13.45     | -5.0      | -2.004    | -5.0      | -5.0      | 0.2631    | -5.0      | -2.211    | 2.04      | 1.828     | 5.0       | -5.0      | -5.0      |
# Train Sharpe Ratio: 2.023, Validation Sharpe Ratio: 0.682
# Debug: L2 penalty: 1.6783729269225882
# Debug: L1 penalty: 0.5503130575946619
# Debug: Objective function value (with penalty): 9.95531401548275
# --------------------------------------------------
# | 57        | 9.955     | 5.0       | -5.0      | -5.0      | -5.0      | -5.0      | -5.0      | -1.705    | 5.0       | 4.754     | 5.0       | -5.0      | -5.0      |
# Train Sharpe Ratio: 2.042, Validation Sharpe Ratio: 0.978
# Debug: L2 penalty: 1.6109931175718404
# Debug: L1 penalty: 0.5365370984601597
# Debug: Objective function value (with penalty): 11.888469783967999
# --------------------------------------------------
# | 58        | 11.89     | -5.0      | -5.0      | -5.0      | -5.0      | -0.04561  | -5.0      | -5.0      | 0.7339    | -2.003    | 5.0       | -5.0      | -5.0      |
# Train Sharpe Ratio: 2.07, Validation Sharpe Ratio: 1.047
# Debug: L2 penalty: 1.3043966942092435
# Debug: L1 penalty: 0.4952434343847849
# Debug: Objective function value (with penalty): 12.762359871405971
# --------------------------------------------------
# | 59        | 12.76     | 3.545     | -1.342    | -4.561    | -4.408    | -4.796    | -4.947    | -0.3797   | 4.499     | -1.325    | -3.52     | -4.997    | -4.192    |
# Train Sharpe Ratio: 2.231, Validation Sharpe Ratio: 0.42
# Debug: L2 penalty: 1.7166000000000003
# Debug: L1 penalty: 0.549312
# Debug: Objective function value (with penalty): 9.178088
# --------------------------------------------------
# | 60        | 9.178     | -5.0      | -5.0      | -5.0      | -5.0      | 5.0       | -5.0      | -5.0      | -5.0      | -5.0      | 5.0       | -5.0      | 5.0       |
# Train Sharpe Ratio: 1.757, Validation Sharpe Ratio: 1.021
# Debug: L2 penalty: 1.644588966807824
# Debug: L1 penalty: 0.5290818181174239
# Debug: Objective function value (with penalty): 10.980329215074752
# --------------------------------------------------
# | 61        | 10.98     | 5.0       | -0.05823  | -5.0      | -5.0      | -5.0      | -5.0      | 5.0       | 5.0       | -5.0      | -5.0      | -0.2194   | -5.0      |
# Train Sharpe Ratio: 2.499, Validation Sharpe Ratio: 0.841
# Debug: L2 penalty: 1.6194926758710326
# Debug: L1 penalty: 0.5555718010910761
# Debug: Objective function value (with penalty): 12.86693552303789
# --------------------------------------------------
# | 62        | 12.87     | 5.0       | -0.9852   | -5.0      | -5.0      | -5.0      | -5.0      | 3.359     | 5.0       | -5.0      | 0.07179   | -5.0      | 1.752     |
# Train Sharpe Ratio: 2.285, Validation Sharpe Ratio: 1.02
# Debug: L2 penalty: 1.2371109747043607
# Debug: L1 penalty: 0.4564479239923692
# Debug: Objective function value (with penalty): 13.56644110130327
# --------------------------------------------------
# | 63        | 13.57     | -1.06     | 1.19      | -5.0      | -5.0      | -1.263    | -5.0      | 2.487     | 5.0       | -1.346    | -0.04187  | -5.0      | -5.0      |
# Train Sharpe Ratio: 1.728, Validation Sharpe Ratio: 0.909
# Debug: L2 penalty: 1.6463345168422314
# Debug: L1 penalty: 0.5477036593122814
# Debug: Objective function value (with penalty): 10.17196182384549
# --------------------------------------------------
# | 64        | 10.17     | -5.0      | -1.712    | -5.0      | -5.0      | -5.0      | -5.0      | 5.0       | 5.0       | 3.652     | 5.0       | -5.0      | -5.0      |
# Train Sharpe Ratio: 2.194, Validation Sharpe Ratio: 1.16
# Debug: L2 penalty: 1.1347749066923838
# Debug: L1 penalty: 0.4500949557937509
# Debug: Objective function value (with penalty): 14.151130137513864
# --------------------------------------------------
# | 65        | 14.15     | 0.8568    | 0.683     | -5.0      | -5.0      | -5.0      | -5.0      | -1.474    | 2.441     | -5.0      | -1.228    | -2.261    | -1.81     |
# Train Sharpe Ratio: 2.163, Validation Sharpe Ratio: 0.666
# Debug: L2 penalty: 1.4244790475205187
# Debug: L1 penalty: 0.4965364912990892
# Debug: Objective function value (with penalty): 10.726984461180392
# --------------------------------------------------
# | 66        | 10.73     | 1.437     | -5.0      | -5.0      | -5.0      | -5.0      | -5.0      | 2.607     | 5.0       | -5.0      | 5.0       | 1.146     | 3.883     |
# Train Sharpe Ratio: 1.79, Validation Sharpe Ratio: 0.961
# Debug: L2 penalty: 1.4112748150115442
# Debug: L1 penalty: 0.48585715227061976
# Debug: Objective function value (with penalty): 11.028868032717837
# --------------------------------------------------
# | 67        | 11.03     | -2.956    | -3.282    | -5.0      | -5.0      | -5.0      | -5.0      | 0.9547    | 5.0       | -5.0      | -4.79     | -5.0      | 0.00205   |
# Train Sharpe Ratio: 1.607, Validation Sharpe Ratio: 1.131
# Debug: L2 penalty: 1.9821000000000002
# Debug: L1 penalty: 0.6342720000000001
# Debug: Objective function value (with penalty): 10.597628000000002
# --------------------------------------------------
# | 68        | 10.6      | 5.0       | -5.0      | 5.0       | -5.0      | -5.0      | -5.0      | -5.0      | -5.0      | -5.0      | 5.0       | -5.0      | -5.0      |
# Train Sharpe Ratio: 0.45, Validation Sharpe Ratio: 0.964
# Debug: L2 penalty: 1.0497929714138605
# Debug: L1 penalty: 0.34571000142308983
# Debug: Objective function value (with penalty): 6.1884970271630495
# --------------------------------------------------
# | 69        | 6.188     | -5.0      | -5.0      | 5.0       | -5.0      | -5.0      | -5.0      | -5.0      | -5.0      | 2.376     | 5.0       | 4.604     | -5.0      |
# Train Sharpe Ratio: 2.261, Validation Sharpe Ratio: 0.71
# Debug: L2 penalty: 1.8313793080046923
# Debug: L1 penalty: 0.5913265281722604
# Debug: Objective function value (with penalty): 10.881294163823048
# --------------------------------------------------
# | 70        | 10.88     | -5.0      | -0.5591   | -5.0      | -5.0      | 5.0       | -5.0      | -5.0      | -5.0      | 5.0       | 5.0       | -5.0      | -5.0      |
# Train Sharpe Ratio: 2.044, Validation Sharpe Ratio: 0.903
# Debug: L2 penalty: 1.2853853609438664
# Debug: L1 penalty: 0.45995006954720313
# Debug: Objective function value (with penalty): 11.84866456950893
# --------------------------------------------------
# | 71        | 11.85     | 3.093     | 4.959     | -5.0      | -5.0      | -5.0      | -5.0      | -1.487    | 0.885     | -0.6081   | -1.262    | -5.0      | -5.0      |
# Train Sharpe Ratio: 2.557, Validation Sharpe Ratio: 1.157
# Debug: L2 penalty: 0.9481124131938482
# Debug: L1 penalty: 0.37725038938462024
# Debug: Objective function value (with penalty): 15.844637197421534
# --------------------------------------------------
# | 72        | 15.84     | 0.0387    | -0.3846   | -5.0      | -5.0      | -1.415    | -5.0      | -0.1522   | 0.7037    | -1.482    | 1.932     | -1.355    | -5.0      |
# Train Sharpe Ratio: 2.608, Validation Sharpe Ratio: 1.05
# Debug: L2 penalty: 0.8887763456531032
# Debug: L1 penalty: 0.41206965940565354
# Debug: Objective function value (with penalty): 15.431153994941242
# --------------------------------------------------
# | 73        | 15.43     | 1.663     | -0.8488   | -5.0      | -5.0      | -3.086    | -5.0      | 1.488     | 1.683     | -1.101    | 1.568     | -2.351    | -1.996    |
# Train Sharpe Ratio: 2.533, Validation Sharpe Ratio: 0.99
# Debug: L2 penalty: 0.9732846137753814
# Debug: L1 penalty: 0.395011633912845
# Debug: Objective function value (with penalty): 14.703703752311776
# --------------------------------------------------
# | 74        | 14.7      | 1.672     | -1.277    | -5.0      | -5.0      | -0.1836   | -5.0      | 0.7725    | 0.6301    | -4.649    | -0.4228   | -2.764    | -3.351    |
# Train Sharpe Ratio: 2.575, Validation Sharpe Ratio: 1.143
# Debug: L2 penalty: 1.2304760565804305
# Debug: L1 penalty: 0.4836464352231063
# Debug: Objective function value (with penalty): 15.443877508196465
# --------------------------------------------------
# | 75        | 15.44     | 4.368     | -0.6122   | -5.0      | -5.0      | -3.745    | -5.0      | -0.3215   | 1.612     | -1.91     | 1.475     | -1.19     | -5.0      |
# Train Sharpe Ratio: 2.805, Validation Sharpe Ratio: 1.065
# Debug: L2 penalty: 1.3452020468016699
# Debug: L1 penalty: 0.4727325168428805
# Debug: Objective function value (with penalty): 15.792065436355449
# --------------------------------------------------
# | 76        | 15.79     | 0.5082    | 0.4816    | -5.0      | -5.0      | -1.008    | -5.0      | 0.01351   | 5.0       | -0.9702   | 5.0       | -0.5747   | -5.0      |
# Train Sharpe Ratio: 2.863, Validation Sharpe Ratio: 1.051
# Debug: L2 penalty: 1.3923643117874216
# Debug: L1 penalty: 0.5261015706948954
# Debug: Objective function value (with penalty): 15.839534117517683
# --------------------------------------------------
# | 77        | 15.84     | -3.401    | 0.3329    | -5.0      | -5.0      | 2.788     | -5.0      | 0.8036    | 3.268     | -0.7537   | 5.0       | 0.6852    | -5.0      |
# Train Sharpe Ratio: 2.515, Validation Sharpe Ratio: 0.692
# Debug: L2 penalty: 1.6421754305070306
# Debug: L1 penalty: 0.5688247810938047
# Debug: Objective function value (with penalty): 12.000999788399165
# --------------------------------------------------
# | 78        | 12.0      | -5.0      | 3.695     | -5.0      | -5.0      | 5.0       | -5.0      | 3.189     | 5.0       | 2.651     | 5.0       | -0.495    | -5.0      |
# Train Sharpe Ratio: 1.854, Validation Sharpe Ratio: 0.97
# Debug: L2 penalty: 1.5762672411311216
# Debug: L1 penalty: 0.5513909194672395
# Debug: Objective function value (with penalty): 11.108341839401637
# --------------------------------------------------
# | 79        | 11.11     | 5.0       | -3.117    | -5.0      | -5.0      | -5.0      | -5.0      | -2.707    | -5.0      | -4.022    | -2.228    | -5.0      | -5.0      |
# Train Sharpe Ratio: 2.757, Validation Sharpe Ratio: 1.142
# Debug: L2 penalty: 1.259181227600343
# Debug: L1 penalty: 0.4851727876104865
# Debug: Objective function value (with penalty): 16.135645984789168
# --------------------------------------------------
# | 80        | 16.14     | -0.6518   | -0.6652   | -5.0      | -5.0      | 0.4543    | -5.0      | 1.148     | 5.0       | -2.935    | 1.804     | 1.261     | -5.0      |
# Train Sharpe Ratio: 2.769, Validation Sharpe Ratio: 1.108
# Debug: L2 penalty: 1.1993202121045219
# Debug: L1 penalty: 0.46183955934263693
# Debug: Objective function value (with penalty): 16.062840228552847
# --------------------------------------------------
# | 81        | 16.06     | -3.215    | -0.3648   | -5.0      | -5.0      | 0.1274    | -5.0      | -0.1576   | 4.94      | -2.678    | 3.357     | -0.09194  | -2.64     |
# Train Sharpe Ratio: 2.981, Validation Sharpe Ratio: 1.058
# Debug: L2 penalty: 1.369213071418331
# Debug: L1 penalty: 0.5149369107943896
# Debug: Objective function value (with penalty): 16.38785001778728
# --------------------------------------------------
# | 82        | 16.39     | -0.6205   | -0.2643   | -5.0      | -5.0      | 1.564     | -5.0      | 0.1763    | 3.233     | -4.495    | 5.0       | 0.9533    | -3.921    |
# Train Sharpe Ratio: 2.811, Validation Sharpe Ratio: 0.822
# Debug: L2 penalty: 1.239090672399207
# Debug: L1 penalty: 0.47359949113592426
# Debug: Objective function value (with penalty): 14.463309836464866
# --------------------------------------------------
# | 83        | 14.46     | 0.09388   | -1.008    | -5.0      | -5.0      | 2.33      | -5.0      | 2.674     | 5.0       | -2.709    | 5.0       | 0.08958   | -2.693    |
# Train Sharpe Ratio: 2.604, Validation Sharpe Ratio: 1.04
# Debug: L2 penalty: 2.077314736182605
# Debug: L1 penalty: 0.6843341257822314
# Debug: Objective function value (with penalty): 13.894351138035164
# --------------------------------------------------
# | 84        | 13.89     | -5.0      | 0.5212    | -5.0      | -5.0      | 5.0       | -5.0      | -1.03     | 5.0       | -5.0      | 5.0       | 4.807     | -5.0      |
# Train Sharpe Ratio: 2.579, Validation Sharpe Ratio: 1.088
# Debug: L2 penalty: 1.2399001042853006
# Debug: L1 penalty: 0.49977511220533827
# Debug: Objective function value (with penalty): 15.104324783509362
# --------------------------------------------------
# | 85        | 15.1      | -1.153    | 1.2       | -5.0      | -5.0      | 0.5899    | -5.0      | -2.571    | 2.365     | -2.639    | 4.58      | 1.991     | -5.0      |
# Train Sharpe Ratio: 2.374, Validation Sharpe Ratio: 1.121
# Debug: L2 penalty: 1.358586179139266
# Debug: L1 penalty: 0.5010228238149539
# Debug: Objective function value (with penalty): 14.362390997045782
# --------------------------------------------------
# | 86        | 14.36     | -5.0      | -0.6836   | -5.0      | -5.0      | 1.799     | -5.0      | 0.5229    | 1.479     | -5.0      | 3.253     | 0.8704    | -5.0      |
# Train Sharpe Ratio: 2.744, Validation Sharpe Ratio: 1.101
# Debug: L2 penalty: 1.2529131000814526
# Debug: L1 penalty: 0.4837580023889336
# Debug: Objective function value (with penalty): 15.845328897529614
# --------------------------------------------------
# | 87        | 15.85     | 1.036     | -0.8841   | -5.0      | -5.0      | -1.55     | -5.0      | -0.4223   | 5.0       | -4.774    | 2.372     | -0.2556   | -3.099    |
# Train Sharpe Ratio: 2.741, Validation Sharpe Ratio: 1.108
# Debug: L2 penalty: 1.537123341725752
# Debug: L1 penalty: 0.551211332660836
# Debug: Objective function value (with penalty): 15.523665325613413
# --------------------------------------------------
# | 88        | 15.52     | -2.323    | 0.8514    | -5.0      | -5.0      | 1.11      | -5.0      | 0.2628    | 5.0       | -4.113    | 5.0       | 0.4618    | -5.0      |
# Train Sharpe Ratio: 2.471, Validation Sharpe Ratio: 0.861
# Debug: L2 penalty: 1.2655987773626163
# Debug: L1 penalty: 0.4958754181070564
# Debug: Objective function value (with penalty): 13.288525804530327
# --------------------------------------------------
# | 89        | 13.29     | -1.163    | -3.666    | -5.0      | -5.0      | 2.565     | -5.0      | -1.032    | 3.138     | -2.644    | 5.0       | 1.978     | -5.0      |
# Train Sharpe Ratio: 2.745, Validation Sharpe Ratio: 0.987
# Debug: L2 penalty: 1.514934707740524
# Debug: L1 penalty: 0.5539632204363141
# Debug: Objective function value (with penalty): 14.833102071823163
# --------------------------------------------------
# | 90        | 14.83     | 5.0       | 1.597     | -5.0      | -5.0      | -5.0      | -5.0      | -0.8255   | 3.698     | -3.092    | 5.0       | -0.08632  | -1.671    |
# Train Sharpe Ratio: 2.426, Validation Sharpe Ratio: 1.166
# Debug: L2 penalty: 1.0749633286788294
# Debug: L1 penalty: 0.42803890974411735
# Debug: Objective function value (with penalty): 15.196997761577052
# --------------------------------------------------
# | 91        | 15.2      | 0.4247    | 0.5802    | -4.79     | -4.776    | -3.777    | -4.926    | 0.5154    | 4.816     | -0.8904   | 0.5836    | -2.09     | -3.869    |
# Train Sharpe Ratio: 3.166, Validation Sharpe Ratio: 0.966
# Debug: L2 penalty: 1.144047940009565
# Debug: L1 penalty: 0.4770044554191455
# Debug: Objective function value (with penalty): 16.838947604571292
# --------------------------------------------------
# | 92        | 16.84     | -0.2973   | 1.388     | -5.0      | -5.0      | 1.312     | -5.0      | -0.6346   | 1.58      | -2.826    | 5.0       | -1.782    | -2.481    |
# Train Sharpe Ratio: 2.868, Validation Sharpe Ratio: 1.025
# Debug: L2 penalty: 0.8717042635160221
# Debug: L1 penalty: 0.38480966102991593
# Debug: Objective function value (with penalty): 16.36548607545406
# --------------------------------------------------
# | 93        | 16.37     | -0.07271  | 1.089     | -5.0      | -5.0      | 0.4147    | -2.871    | 0.2267    | 2.446     | -2.952    | 3.691     | -0.2312   | -3.301    |
# Train Sharpe Ratio: 3.294, Validation Sharpe Ratio: 0.98
# Debug: L2 penalty: 1.0972489224836077
# Debug: L1 penalty: 0.4715717291514871
# Debug: Objective function value (with penalty): 17.487179348364904
# --------------------------------------------------
# | 94        | 17.49     | 0.6452    | 1.967     | -5.0      | -5.0      | 1.42      | -5.0      | 0.1783    | 3.25      | -2.841    | 2.243     | 0.2079    | -3.182    |
# Train Sharpe Ratio: 3.157, Validation Sharpe Ratio: 1.101
# Debug: L2 penalty: 1.0877141694017494
# Debug: L1 penalty: 0.4855571292493404
# Debug: Objective function value (with penalty): 17.660728701348912
# --------------------------------------------------
# | 95        | 17.66     | 0.5673    | 1.854     | -5.0      | -5.0      | -0.4873   | -5.0      | 1.12      | 2.96      | -2.786    | 2.54      | 1.456     | -2.785    |
# Train Sharpe Ratio: 3.302, Validation Sharpe Ratio: 0.949
# Debug: L2 penalty: 1.378126563383125
# Debug: L1 penalty: 0.5413402368082663
# Debug: Objective function value (with penalty): 16.982533199808607
# --------------------------------------------------
# | 96        | 16.98     | 0.6059    | 2.505     | -5.0      | -5.0      | 0.5168    | -5.0      | 0.858     | 5.0       | -4.547    | 1.448     | 3.452     | -1.867    |
# Train Sharpe Ratio: 3.202, Validation Sharpe Ratio: 1.022
# Debug: L2 penalty: 1.145232932503943
# Debug: L1 penalty: 0.4965713483502327
# Debug: Objective function value (with penalty): 17.298195719145824
# --------------------------------------------------
# | 97        | 17.3      | -0.935    | 2.21      | -5.0      | -5.0      | 1.313     | -5.0      | 1.257     | 3.039     | -4.499    | 1.958     | 0.9073    | -1.654    |
# Train Sharpe Ratio: 2.881, Validation Sharpe Ratio: 0.914
# Debug: L2 penalty: 1.317176590642884
# Debug: L1 penalty: 0.5459504545576055
# Debug: Objective function value (with penalty): 15.14487295479951
# --------------------------------------------------
# | 98        | 15.14     | 1.299     | 3.057     | -5.0      | -5.0      | 2.077     | -5.0      | 2.009     | 2.474     | -4.515    | 2.237     | 2.954     | -4.502    |
# Train Sharpe Ratio: 3.212, Validation Sharpe Ratio: 0.771
# Debug: L2 penalty: 1.13110852208527
# Debug: L1 penalty: 0.4450144342082661
# Debug: Objective function value (with penalty): 15.897877043706467
# --------------------------------------------------
# | 99        | 15.9      | 0.4824    | 2.68      | -5.0      | -5.0      | 0.2873    | -5.0      | -0.4872   | 4.381     | -3.756    | 3.526     | 0.9553    | -0.2783   |
# Train Sharpe Ratio: 2.718, Validation Sharpe Ratio: 1.153
# Debug: L2 penalty: 1.1950244170942754
# Debug: L1 penalty: 0.5048336163693982
# Debug: Objective function value (with penalty): 16.090141966536326
# --------------------------------------------------
# | 100       | 16.09     | -1.766    | 2.412     | -5.0      | -5.0      | -0.5964   | -5.0      | 1.826     | 5.0       | -2.879    | -1.14     | 2.851     | -2.001    |
# Train Sharpe Ratio: 2.524, Validation Sharpe Ratio: 1.231
# Debug: L2 penalty: 0.7369261406247287
# Debug: L1 penalty: 0.37879300049677056
# Debug: Objective function value (with penalty): 16.366280858878504
# --------------------------------------------------
# | 101       | 16.37     | 1.265     | -0.3863   | -3.006    | -4.986    | -2.41     | -4.918    | 1.178     | 1.769     | -1.324    | -1.627    | -1.45     | -2.765    |
# Train Sharpe Ratio: 3.075, Validation Sharpe Ratio: 0.916
# Debug: L2 penalty: 1.538579868894316
# Debug: L1 penalty: 0.5709928405938484
# Debug: Objective function value (with penalty): 15.686427290511837
# --------------------------------------------------
# | 102       | 15.69     | -5.0      | 1.38      | -5.0      | -5.0      | 5.0       | -5.0      | -0.1405   | 1.022     | -3.078    | 5.0       | -2.695    | -1.792    |
# Train Sharpe Ratio: 3.267, Validation Sharpe Ratio: 1.261
# Debug: L2 penalty: 0.9108931719171273
# Debug: L1 penalty: 0.42511189860310145
# Debug: Objective function value (with penalty): 19.297994929479767
# --------------------------------------------------
# | 103       | 19.3      | 0.03514   | 0.66      | -2.657    | -5.0      | -0.0881   | -5.0      | 0.6936    | 3.059     | -3.0      | 2.0       | 0.8831    | -2.678    |
# Train Sharpe Ratio: 2.359, Validation Sharpe Ratio: 1.239
# Debug: L2 penalty: 0.7672806584371713
# Debug: L1 penalty: 0.36822498566754874
# Debug: Objective function value (with penalty): 15.73449435589528
# --------------------------------------------------
# | 104       | 15.73     | -1.595    | -0.4452   | -3.803    | -4.3      | -1.847    | -4.626    | 0.1166    | 1.071     | -4.522    | 0.994     | 2.018     | -1.947    |
# Train Sharpe Ratio: 3.0, Validation Sharpe Ratio: 1.121
# Debug: L2 penalty: 0.9873197972372605
# Debug: L1 penalty: 0.42673515638079934
# Debug: Objective function value (with penalty): 17.311945046381943
# --------------------------------------------------
# | 105       | 17.31     | -1.022    | 0.7047    | -0.1547   | -5.0      | 1.724     | -5.0      | 0.1736    | 1.896     | -2.505    | 5.0       | -1.669    | -3.637    |
# Train Sharpe Ratio: 2.889, Validation Sharpe Ratio: 1.33
# Debug: L2 penalty: 0.9577301142741418
# Debug: L1 penalty: 0.4571957118692678
# Debug: Objective function value (with penalty): 18.12107417385659
# --------------------------------------------------
# | 106       | 18.12     | 1.618     | -0.1913   | -0.7338   | -5.0      | -2.403    | -5.0      | 0.6362    | 3.726     | -2.5      | 2.562     | 2.276     | -2.609    |
# Train Sharpe Ratio: 2.891, Validation Sharpe Ratio: 0.922
# Debug: L2 penalty: 0.7774244006655792
# Debug: L1 penalty: 0.3852413131649714
# Debug: Objective function value (with penalty): 15.933334286169448
# --------------------------------------------------
# | 107       | 15.93     | 0.9107    | 1.942     | -2.559    | -4.975    | 0.4485    | -3.517    | -0.9684   | 4.748     | -2.116    | 2.539     | 0.6868    | -2.755    |
# Train Sharpe Ratio: 3.274, Validation Sharpe Ratio: 1.273
# Debug: L2 penalty: 0.976363373168278
# Debug: L1 penalty: 0.42603344608565674
# Debug: Objective function value (with penalty): 19.33160318074606
# --------------------------------------------------
# | 108       | 19.33     | 0.2558    | -0.3338   | -1.084    | -5.0      | 0.3446    | -5.0      | 1.19      | 3.472     | -4.825    | 1.106     | 1.619     | -1.455    |
# Train Sharpe Ratio: 3.22, Validation Sharpe Ratio: 1.244
# Debug: L2 penalty: 0.8671906779973938
# Debug: L1 penalty: 0.40061659166348934
# Debug: Objective function value (with penalty): 19.07619273033912
# --------------------------------------------------
# | 109       | 19.08     | 1.358     | -0.4953   | -0.981    | -5.0      | -0.2481   | -5.0      | 0.7485    | 1.683     | -4.431    | 2.428     | 0.5268    | -1.716    |
# Train Sharpe Ratio: 3.324, Validation Sharpe Ratio: 1.168
# Debug: L2 penalty: 0.905975356180788
# Debug: L1 penalty: 0.4316854591489523
# Debug: Objective function value (with penalty): 18.96633918467026
# --------------------------------------------------
# | 110       | 18.97     | 1.631     | -0.361    | -2.212    | -5.0      | 0.1226    | -5.0      | 1.199     | 2.934     | -3.764    | 0.7831    | 2.199     | -1.37     |
# Train Sharpe Ratio: 3.064, Validation Sharpe Ratio: 1.322
# Debug: L2 penalty: 0.9396900432465851
# Debug: L1 penalty: 0.4232377802101683
# Debug: Objective function value (with penalty): 18.825072176543248
# --------------------------------------------------
# | 111       | 18.83     | 0.5934    | -0.05906  | -1.053    | -5.0      | 0.2365    | -5.0      | 1.13      | 2.601     | -4.324    | 1.423     | 1.568     | -3.217    |
# Train Sharpe Ratio: 2.178, Validation Sharpe Ratio: 1.121
# Debug: L2 penalty: 1.1063359838043947
# Debug: L1 penalty: 0.42857677127585375
# Debug: Objective function value (with penalty): 13.903087244919753
# --------------------------------------------------
# | 112       | 13.9      | 4.019     | -2.85     | 0.1579    | -5.0      | -5.0      | -5.0      | 0.6419    | 3.775     | -5.0      | -0.5511   | 1.798     | 0.9077    |
# Train Sharpe Ratio: 2.891, Validation Sharpe Ratio: 1.206
# Debug: L2 penalty: 0.7435065639207287
# Debug: L1 penalty: 0.35407017499094895
# Debug: Objective function value (with penalty): 17.70242326108832
# --------------------------------------------------
# ...
# | 284       | 15.65     | -0.02853  | 3.328     | -4.444    | -4.931    | -0.5718   | -4.225    | -0.3691   | 1.182     | -2.476    | -0.1057   | -3.337    | -0.9135   |
# Train Sharpe Ratio: 3.011, Validation Sharpe Ratio: 1.25
# Debug: L2 penalty: 0.831519398943919
# Debug: L1 penalty: 0.39797703546776814
# Debug: Objective function value (with penalty): 18.314503565588314
# --------------------------------------------------
# | 285       | 18.31     | -0.3527   | -1.807    | -1.336    | -4.743    | 1.231     | -4.852    | 0.02286   | 2.565     | -4.297    | -0.4939   | 1.758     | -1.995    |
# Train Sharpe Ratio: 2.717, Validation Sharpe Ratio: 1.0
# Debug: L2 penalty: 0.5851587009262125
# Debug: L1 penalty: 0.2921071898587768
# Debug: Objective function value (with penalty): 15.99073410921501
# --------------------------------------------------
# | 286       | 15.99     | 0.06993   | -1.474    | 0.3547    | -4.647    | 2.198     | -3.179    | -0.0706   | -0.8301   | -1.607    | 0.225     | -4.674    | -2.316    |
# Train Sharpe Ratio: 3.034, Validation Sharpe Ratio: 1.083
# Debug: L2 penalty: 0.559062955107535
# Debug: L1 penalty: 0.32013463591371016
# Debug: Objective function value (with penalty): 17.754802408978755
# --------------------------------------------------
# | 287       | 17.75     | 0.6352    | -1.262    | -0.6639   | -4.375    | 1.775     | -4.312    | 0.6123    | 2.502     | -2.622    | -0.2546   | 1.037     | -1.423    |
# Train Sharpe Ratio: 3.174, Validation Sharpe Ratio: 1.151
# Debug: L2 penalty: 0.48051329719590996
# Debug: L1 penalty: 0.3037153297209277
# Debug: Objective function value (with penalty): 18.817771373083165
# --------------------------------------------------
# | 288       | 18.82     | 0.8835    | -0.5437   | -0.3803   | -4.524    | 0.3603    | -3.087    | -1.162    | 2.86      | -1.881    | 1.019     | -1.234    | -1.433    |
# Train Sharpe Ratio: 2.541, Validation Sharpe Ratio: 1.056
# Debug: L2 penalty: 0.708398846048137
# Debug: L1 penalty: 0.36201825947167754
# Debug: Objective function value (with penalty): 15.429582894480186
# --------------------------------------------------
# | 289       | 15.43     | -4.185    | 1.101     | -2.782    | -4.987    | 2.083     | -3.778    | 1.715     | 2.33      | -2.435    | -0.5577   | 1.07      | 0.4021    |
# Train Sharpe Ratio: 2.541, Validation Sharpe Ratio: 1.185
# Debug: L2 penalty: 0.7217973294314503
# Debug: L1 penalty: 0.3095967958456021
# Debug: Objective function value (with penalty): 16.242605874722944
# --------------------------------------------------
# | 290       | 16.24     | -3.148    | 0.8958    | -1.162    | -4.885    | 1.118     | -4.697    | -0.03559  | -0.09675  | -4.814    | 0.587     | -0.07382  | -0.8896   |
# Train Sharpe Ratio: 2.339, Validation Sharpe Ratio: 1.175
# Debug: L2 penalty: 0.7609245026421555
# Debug: L1 penalty: 0.3430308668222745
# Debug: Objective function value (with penalty): 15.302044630535569
# --------------------------------------------------
# | 291       | 15.3      | -0.1122   | -2.072    | -0.451    | -4.961    | -0.4007   | -2.499    | -3.026    | -0.02212  | -1.427    | 4.677     | -1.994    | -4.493    |
# Train Sharpe Ratio: 2.668, Validation Sharpe Ratio: 1.103
# Debug: L2 penalty: 0.8449906139977585
# Debug: L1 penalty: 0.4063958573937314
# Debug: Objective function value (with penalty): 16.038613528608508
# --------------------------------------------------
# | 292       | 16.04     | -2.141    | -2.47     | -0.5009   | -4.462    | 3.198     | -3.135    | 0.2675    | 1.916     | -3.226    | 3.723     | 0.001187  | -4.339    |
# Train Sharpe Ratio: 2.693, Validation Sharpe Ratio: 1.222
# Debug: L2 penalty: 0.49682592648403695
# Debug: L1 penalty: 0.2865429780283862
# Debug: Objective function value (with penalty): 17.320631095487578
# --------------------------------------------------
# | 293       | 17.32     | 0.9411    | -0.8083   | -1.433    | -4.115    | -1.656    | -4.137    | -0.6577   | -0.09891  | -3.165    | -0.3549   | -1.912    | -0.5044   |
# Train Sharpe Ratio: 3.153, Validation Sharpe Ratio: 1.037
# Debug: L2 penalty: 0.7182500313391669
# Debug: L1 penalty: 0.33033675109365757
# Debug: Objective function value (with penalty): 17.785413217567175
# --------------------------------------------------
# | 294       | 17.79     | -0.1257   | 0.2376    | -3.408    | -3.828    | 0.1694    | -4.301    | 1.277     | 2.953     | -4.543    | 0.3076    | -0.4966   | 0.2779    |
# Train Sharpe Ratio: 2.404, Validation Sharpe Ratio: 1.196
# Debug: L2 penalty: 1.3397787776446892
# Debug: L1 penalty: 0.5423831495942881
# Debug: Objective function value (with penalty): 14.909838072761021
# --------------------------------------------------
# | 295       | 14.91     | 2.21      | 2.438     | -4.876    | -4.455    | -4.686    | -4.986    | 1.501     | 4.556     | -3.083    | 0.5538    | 4.136     | -2.895    |
# Train Sharpe Ratio: 2.778, Validation Sharpe Ratio: 1.129
# Debug: L2 penalty: 0.8403823857584313
# Debug: L1 penalty: 0.3994583054687627
# Debug: Objective function value (with penalty): 16.646159308772805
# --------------------------------------------------
# | 296       | 16.65     | 1.35      | 1.731     | -0.8794   | -3.682    | -0.5452   | -4.722    | 0.2752    | 4.013     | -4.062    | 2.247     | 0.6597    | -3.75     |
# Train Sharpe Ratio: 2.48, Validation Sharpe Ratio: 1.243
# Debug: L2 penalty: 1.1026761486590562
# Debug: L1 penalty: 0.47360406262992727
# Debug: Objective function value (with penalty): 15.801719788711015
# --------------------------------------------------
# | 297       | 15.8      | -3.267    | -0.4194   | -0.3393   | -4.678    | 1.828     | -4.134    | 0.4517    | 3.486     | -3.855    | 4.039     | 2.933     | -4.635    |
# Train Sharpe Ratio: 2.659, Validation Sharpe Ratio: 1.052
# Debug: L2 penalty: 0.9907161893557581
# Debug: L1 penalty: 0.4460016227903387
# Debug: Objective function value (with penalty): 15.511282187853903
# --------------------------------------------------
# | 298       | 15.51     | -4.07     | 0.3807    | -1.434    | -3.935    | 1.321     | -4.727    | -1.107    | 4.897     | -1.554    | 3.521     | -3.633    | -2.317    |
# Train Sharpe Ratio: 2.655, Validation Sharpe Ratio: 1.065
# Debug: L2 penalty: 0.6562454978376715
# Debug: L1 penalty: 0.3529403700213179
# Debug: Objective function value (with penalty): 16.000814132141013
# --------------------------------------------------
# | 299       | 16.0      | -2.051    | -0.7784   | -2.362    | -4.631    | -1.69     | -4.548    | 1.362     | 3.028     | -1.198    | -0.001959 | -2.41     | 1.877     |
# Train Sharpe Ratio: 3.102, Validation Sharpe Ratio: 1.139
# Debug: L2 penalty: 0.8434028796690695
# Debug: L1 penalty: 0.39484137652429013
# Debug: Objective function value (with penalty): 18.00375574380664
# --------------------------------------------------
# | 300       | 18.0      | -4.53     | 0.2806    | -0.3913   | -3.712    | 3.885     | -4.829    | -0.5724   | 1.418     | 0.2771    | 2.197     | -1.02     | -2.538    |
# Train Sharpe Ratio: 2.485, Validation Sharpe Ratio: 1.086
# Debug: L2 penalty: 0.7719886466861615
# Debug: L1 penalty: 0.38195958356557413
# Debug: Objective function value (with penalty): 15.302051769748264
# --------------------------------------------------
# | 301       | 15.3      | 1.549     | -0.5433   | -4.267    | -4.66     | -2.632    | -3.361    | -0.0182   | 3.577     | -2.533    | -0.749    | -2.764    | -2.362    |
# Train Sharpe Ratio: 2.575, Validation Sharpe Ratio: 1.361
# Debug: L2 penalty: 0.9327846252599651
# Debug: L1 penalty: 0.42739594699451106
# Debug: Objective function value (with penalty): 17.105819427745523
# --------------------------------------------------
# | 302       | 17.11     | 2.675     | -0.9014   | 0.01003   | -4.603    | -3.674    | -4.288    | 0.9571    | 4.925     | -2.874    | 0.5346    | 1.441     | -2.048    |
# Train Sharpe Ratio: 2.268, Validation Sharpe Ratio: 1.142
# Debug: L2 penalty: 0.6424450719901725
# Debug: L1 penalty: 0.32928237818327105
# Debug: Objective function value (with penalty): 14.952272549826557
# --------------------------------------------------
# | 303       | 14.95     | 0.07513   | 1.775     | -4.622    | -2.825    | -2.591    | -3.67     | -0.1837   | 2.672     | -3.746    | -0.1716   | 1.217     | -2.299    |
# Train Sharpe Ratio: 2.691, Validation Sharpe Ratio: 1.009
# Debug: L2 penalty: 0.55206139788092
# Debug: L1 penalty: 0.3168711927839606
# Debug: Objective function value (with penalty): 15.949067409335118
# --------------------------------------------------
# | 304       | 15.95     | -2.352    | -1.261    | -0.222    | -4.617    | 3.485     | -2.577    | 0.5812    | 0.1104    | -2.404    | 1.471     | -2.445    | -2.025    |
# Train Sharpe Ratio: 2.766, Validation Sharpe Ratio: 0.536
# Debug: L2 penalty: 1.905850015194986
# Debug: L1 penalty: 0.6309622895037018
# Debug: Objective function value (with penalty): 11.743187695301312
# --------------------------------------------------
# | 305       | 11.74     | -5.0      | 1.342     | -5.0      | -5.0      | 5.0       | -5.0      | 3.889     | 5.0       | -5.0      | 5.0       | -5.0      | 5.0       |
# Train Sharpe Ratio: 2.665, Validation Sharpe Ratio: 0.966
# Debug: L2 penalty: 0.7631923431009903
# Debug: L1 penalty: 0.37200554176633116
# Debug: Objective function value (with penalty): 15.320802115132679
# --------------------------------------------------
# | 306       | 15.32     | -2.896    | 0.1816    | -0.4125   | -4.955    | 2.365     | -2.779    | -3.158    | 1.12      | 0.4969    | 3.79      | -4.009    | -2.095    |
# Train Sharpe Ratio: 2.224, Validation Sharpe Ratio: 1.291
# Debug: L2 penalty: 0.4771719564420082
# Debug: L1 penalty: 0.2620534303005444
# Debug: Objective function value (with penalty): 15.902774613257453
# --------------------------------------------------
# | 307       | 15.9      | -2.062    | -0.2997   | -0.08017  | -3.786    | -1.759    | -4.304    | 0.3602    | 3.391     | -1.359    | 0.4228    | -0.01711  | -1.842    |
# Train Sharpe Ratio: 2.624, Validation Sharpe Ratio: 1.279
# Debug: L2 penalty: 0.911738874487142
# Debug: L1 penalty: 0.4494509158227923
# Debug: Objective function value (with penalty): 16.80881020969007
# --------------------------------------------------
# | 308       | 16.81     | 2.943     | -1.887    | -1.427    | -3.612    | -1.386    | -4.602    | 0.7179    | 1.533     | -4.229    | 1.822     | 2.15      | -4.611    |
# Train Sharpe Ratio: 2.906, Validation Sharpe Ratio: 0.947
# Debug: L2 penalty: 0.8068734404571178
# Debug: L1 penalty: 0.35963321608633575
# Debug: Objective function value (with penalty): 16.139493343456543
# --------------------------------------------------
# | 309       | 16.14     | 0.6005    | 0.1554    | -2.785    | -4.257    | -1.315    | -4.404    | -0.7104   | -2.246    | 0.2294    | 4.277     | -4.676    | 0.3207    |
# Train Sharpe Ratio: 2.818, Validation Sharpe Ratio: 0.99
# Debug: L2 penalty: 0.7659333811372111
# Debug: L1 penalty: 0.38578150925884214
# Debug: Objective function value (with penalty): 16.060285109603946
# --------------------------------------------------
# | 310       | 16.06     | 1.274     | -1.823    | -2.385    | -3.991    | -1.607    | -4.674    | -0.7652   | 4.184     | -3.106    | 1.033     | -3.03     | -0.1448   |
# Train Sharpe Ratio: 2.833, Validation Sharpe Ratio: 1.174
# Debug: L2 penalty: 0.7014504671428954
# Debug: L1 penalty: 0.38205870665019287
# Debug: Objective function value (with penalty): 17.292490826206915
# --------------------------------------------------
# | 311       | 17.29     | -1.771    | 1.811     | -2.974    | -4.901    | 1.611     | -2.914    | 0.07988   | 2.934     | -2.607    | -1.37     | -0.06915  | -2.948    |
# Train Sharpe Ratio: 2.859, Validation Sharpe Ratio: 0.802
# Debug: L2 penalty: 0.5755100918489228
# Debug: L1 penalty: 0.32788914471144326
# Debug: Objective function value (with penalty): 15.344600763439635
# --------------------------------------------------
# | 312       | 15.34     | 2.303     | -2.542    | -1.348    | -2.63     | 0.615     | -4.663    | 0.9392    | 0.8182    | -1.007    | 4.029     | -2.311    | -2.019    |
# Train Sharpe Ratio: 2.846, Validation Sharpe Ratio: 1.057
# Debug: L2 penalty: 0.947385075076424
# Debug: L1 penalty: 0.4189305537115317
# Debug: Objective function value (with penalty): 16.359684371212044
# --------------------------------------------------
# | 313       | 16.36     | -1.561    | -0.4554   | -0.3624   | -3.237    | 1.851     | -4.959    | 0.2832    | 4.221     | 1.449     | 4.163     | -2.123    | -4.877    |
# Train Sharpe Ratio: 3.387, Validation Sharpe Ratio: 0.89
# Debug: L2 penalty: 0.9903287993999897
# Debug: L1 penalty: 0.4151650130831519
# Debug: Objective function value (with penalty): 17.48250618751686
# --------------------------------------------------
# | 314       | 17.48     | -0.1073   | 1.18      | -1.774    | -4.435    | -0.03682  | -4.607    | -0.01097  | 4.193     | -4.889    | 0.3214    | -3.347    | 2.574     |
# Train Sharpe Ratio: 3.111, Validation Sharpe Ratio: 0.796
# Debug: L2 penalty: 0.9409529392313101
# Debug: L1 penalty: 0.43227460872697704
# Debug: Objective function value (with penalty): 15.846772452041716
# --------------------------------------------------
# | 315       | 15.85     | -3.846    | -1.027    | -4.135    | -4.828    | 2.324     | -3.153    | 0.007928  | 4.161     | -2.398    | 0.1876    | -3.147    | 2.164     |
# Train Sharpe Ratio: 3.071, Validation Sharpe Ratio: 1.037
# Debug: L2 penalty: 0.8753285499551158
# Debug: L1 penalty: 0.3911125671458421
# Debug: Objective function value (with penalty): 17.239558882899043
# --------------------------------------------------
# | 316       | 17.24     | -4.311    | -1.295    | 1.159     | -4.538    | 4.42      | -4.455    | 0.8138    | 3.036     | -0.03636  | -0.259    | -1.707    | -0.3868   |
# Train Sharpe Ratio: 3.162, Validation Sharpe Ratio: 0.836
# Debug: L2 penalty: 0.5371591924389412
# Debug: L1 penalty: 0.28029251494895535
# Debug: Objective function value (with penalty): 16.846548292612106
# --------------------------------------------------
# | 317       | 16.85     | 0.1285    | -0.5109   | -1.662    | -4.631    | 0.6507    | -4.237    | 1.116     | 0.9599    | -0.5379   | 0.1231    | -3.521    | 1.757     |
# Train Sharpe Ratio: 2.768, Validation Sharpe Ratio: 1.085
# Debug: L2 penalty: 1.04605325695232
# Debug: L1 penalty: 0.46344938627264387
# Debug: Objective function value (with penalty): 16.072497356775038
# --------------------------------------------------
# | 318       | 16.07     | 0.1494    | 0.5657    | -4.09     | -4.663    | 2.819     | -4.582    | 1.411     | 3.094     | -4.136    | -1.471    | 1.846     | -4.123    |
# Train Sharpe Ratio: 2.81, Validation Sharpe Ratio: 0.843
# Debug: L2 penalty: 0.7189222531408526
# Debug: L1 penalty: 0.375369930112975
# Debug: Objective function value (with penalty): 15.20370781674617
# --------------------------------------------------
# | 319       | 15.2      | -2.302    | 1.191     | 1.407     | -4.647    | 3.177     | -3.561    | 0.7659    | 4.21      | 0.9414    | 1.277     | -2.32     | -2.99     |
# Train Sharpe Ratio: 3.235, Validation Sharpe Ratio: 1.213
# Debug: L2 penalty: 1.179102204727724
# Debug: L1 penalty: 0.46441387409336155
# Debug: Objective function value (with penalty): 18.574483921178913
# --------------------------------------------------
# | 320       | 18.57     | -5.0      | -0.3279   | -0.8265   | -5.0      | 4.04      | -5.0      | -0.3579   | 4.248     | -0.5022   | 0.3781    | -0.6916   | -2.34     |
# =========================================================================================================================================================================
# Optimal Weights: {'average_true_range': 0.2557941628640061, 'chaikin_money_flow': -0.333829730192845, 'chande_momentum_oscillator': -1.0837598858574995, 'ichimoku': -5.0, 'know_sure_thing': 0.3445911733719533, 'macd': -5.0, 'on_balance_volume': 1.1896206843819945, 'trend_1_3': 3.471536796384712, 'trend_5_20': -4.825031170216047, 'ultimate_oscillator': 1.1062942450553623, 'volatility_20': 1.6189453910591598, 'volume': -1.4550670802397847}
# Test Set Sharpe Ratio: 0.62
